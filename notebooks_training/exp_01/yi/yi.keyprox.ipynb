# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
# %cd "drive/MyDrive/Tesis/scRNN"
# Out:
# /content/drive/MyDrive/Tesis/scRNN

# %%
import torch

torch.cuda.is_available()
# Out:
# True

# %%
# !pip install sacrebleu
# Out:
# Collecting sacrebleu
#   Downloading sacrebleu-2.0.0-py3-none-any.whl (90 kB)
#      |████████████████████████████████| 90 kB 4.0 MB/s
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from sacrebleu) (1.19.5)
# Collecting colorama
#   Downloading colorama-0.4.4-py2.py3-none-any.whl (16 kB)
# Requirement already satisfied: tabulate>=0.8.9 in /usr/local/lib/python3.7/dist-packages (from sacrebleu) (0.8.9)
# Requirement already satisfied: regex in /usr/local/lib/python3.7/dist-packages (from sacrebleu) (2019.12.20)
# Collecting portalocker
#   Downloading portalocker-2.3.2-py2.py3-none-any.whl (15 kB)
# Installing collected packages: portalocker, colorama, sacrebleu
# Successfully installed colorama-0.4.4 portalocker-2.3.2 sacrebleu-2.0.0

# %%
# !python3 train.py --language yi --task-name keyprox --num-epochs 100 --batch-size 32 --vocab-size 2999 --new-vocab --train --train-sentences-errors-file yi.keyprox.train.sentences.errors.txt --train-sentences-file yi.keyprox.train.sentences.txt --val-sentences-errors-file yi.keyprox.val.sentences.errors.txt --val-sentences-file yi.keyprox.val.sentences.txt --test-sentences-errors-file yi.keyprox.test.sentences.errors.txt --test-sentences-file yi.keyprox.test.sentences.txt --metric chrF --save
# Out:
# Parameters
# {'language': 'yi', 'task_name': 'keyprox', 'vocab_size': 2999, 'num_epochs': 100, 'batch_size': 32, 'model_name': 'shi_random_20531_100_32', 'new_vocab': True, 'need_to_train': True, 'train_sentences_errors_file': 'yi.keyprox.train.sentences.errors.txt', 'train_sentences_file': 'yi.keyprox.train.sentences.txt', 'val_sentences_errors_file': 'yi.keyprox.val.sentences.errors.txt', 'val_sentences_file': 'yi.keyprox.val.sentences.txt', 'test_sentences_errors_file': 'yi.keyprox.test.sentences.errors.txt', 'test_sentences_file': 'yi.keyprox.test.sentences.txt', 'metric': 'chrF', 'save_model': True}
#
#
# Creating new vocabulary
# Len of w2i:  2999
# Len of i2w:  2999
# Len of char vocab:  21
#
#
# Initializing an only ScRNN model
#
#
# Training the model...
#
# Average train loss after 1 iteration = 0.1828
# Total train chrF after 1 iteration = 57.8197
# Average val loss after 1 iteration = 0.2054
# Total val chrF after 1 iteration = 60.6989
# Average test loss after 1 iteration = 0.1958
# Total test chrF after 1 iteration = 59.0088
# Dumping after  1
# Time for the iteration 4.3 seconds
#
#
# Average train loss after 2 iteration = 0.1634
# Total train chrF after 2 iteration = 57.7506
# Average val loss after 2 iteration = 0.1587
# Total val chrF after 2 iteration = 58.9453
# Average test loss after 2 iteration = 0.1524
# Total test chrF after 2 iteration = 57.4663
# Time for the iteration 4.2 seconds
#
#
# Average train loss after 3 iteration = 0.1442
# Total train chrF after 3 iteration = 59.2455
# Average val loss after 3 iteration = 0.1379
# Total val chrF after 3 iteration = 60.3864
# Average test loss after 3 iteration = 0.1323
# Total test chrF after 3 iteration = 59.2564
# Time for the iteration 4.2 seconds
#
#
# Average train loss after 4 iteration = 0.1273
# Total train chrF after 4 iteration = 61.9793
# Average val loss after 4 iteration = 0.1190
# Total val chrF after 4 iteration = 63.4745
# Average test loss after 4 iteration = 0.1140
# Total test chrF after 4 iteration = 62.6338
# Dumping after  4
# Time for the iteration 4.2 seconds
#
#
# Average train loss after 5 iteration = 0.1121
# Total train chrF after 5 iteration = 64.2851
# Average val loss after 5 iteration = 0.1052
# Total val chrF after 5 iteration = 65.1978
# Average test loss after 5 iteration = 0.1006
# Total test chrF after 5 iteration = 64.3509
# Dumping after  5
# Time for the iteration 4.2 seconds
#
#
# Average train loss after 6 iteration = 0.0990
# Total train chrF after 6 iteration = 66.4118
# Average val loss after 6 iteration = 0.0935
# Total val chrF after 6 iteration = 66.6708
# Average test loss after 6 iteration = 0.0895
# Total test chrF after 6 iteration = 66.3893
# Dumping after  6
# Time for the iteration 4.2 seconds
#
#
# Average train loss after 7 iteration = 0.0873
# Total train chrF after 7 iteration = 68.2829
# Average val loss after 7 iteration = 0.0832
# Total val chrF after 7 iteration = 68.0776
# Average test loss after 7 iteration = 0.0800
# Total test chrF after 7 iteration = 68.0808
# Dumping after  7
# Time for the iteration 4.3 seconds
#
#
# Average train loss after 8 iteration = 0.0770
# Total train chrF after 8 iteration = 69.8606
# Average val loss after 8 iteration = 0.0743
# Total val chrF after 8 iteration = 69.0078
# Average test loss after 8 iteration = 0.0718
# Total test chrF after 8 iteration = 68.8501
# Dumping after  8
# Time for the iteration 4.2 seconds
#
#
# Average train loss after 9 iteration = 0.0683
# Total train chrF after 9 iteration = 71.3397
# Average val loss after 9 iteration = 0.0668
# Total val chrF after 9 iteration = 70.2948
# Average test loss after 9 iteration = 0.0649
# Total test chrF after 9 iteration = 69.9933
# Dumping after  9
# Time for the iteration 4.3 seconds
#
#
# Average train loss after 10 iteration = 0.0607
# Total train chrF after 10 iteration = 72.7032
# Average val loss after 10 iteration = 0.0605
# Total val chrF after 10 iteration = 71.1297
# Average test loss after 10 iteration = 0.0589
# Total test chrF after 10 iteration = 70.4966
# Dumping after  10
# Time for the iteration 4.3 seconds
#
#
# Average train loss after 11 iteration = 0.0542
# Total train chrF after 11 iteration = 73.9480
# Average val loss after 11 iteration = 0.0552
# Total val chrF after 11 iteration = 71.8869
# Average test loss after 11 iteration = 0.0539
# Total test chrF after 11 iteration = 71.5821
# Dumping after  11
# Time for the iteration 4.3 seconds
#
#
# Average train loss after 12 iteration = 0.0484
# Total train chrF after 12 iteration = 75.0257
# Average val loss after 12 iteration = 0.0507
# Total val chrF after 12 iteration = 72.4764
# Average test loss after 12 iteration = 0.0496
# Total test chrF after 12 iteration = 72.0762
# Dumping after  12
# Time for the iteration 4.3 seconds
#
#
# Average train loss after 13 iteration = 0.0434
# Total train chrF after 13 iteration = 76.1104
# Average val loss after 13 iteration = 0.0467
# Total val chrF after 13 iteration = 73.1457
# Average test loss after 13 iteration = 0.0459
# Total test chrF after 13 iteration = 72.7030
# Dumping after  13
# Time for the iteration 4.2 seconds
#
#
# Average train loss after 14 iteration = 0.0389
# Total train chrF after 14 iteration = 77.2220
# Average val loss after 14 iteration = 0.0433
# Total val chrF after 14 iteration = 73.9115
# Average test loss after 14 iteration = 0.0426
# Total test chrF after 14 iteration = 73.3176
# Dumping after  14
# Time for the iteration 4.3 seconds
#
#
# Average train loss after 15 iteration = 0.0349
# Total train chrF after 15 iteration = 78.1856
# Average val loss after 15 iteration = 0.0402
# Total val chrF after 15 iteration = 74.3277
# Average test loss after 15 iteration = 0.0397
# Total test chrF after 15 iteration = 73.8129
# Dumping after  15
# Time for the iteration 4.3 seconds
#
#
# Average train loss after 16 iteration = 0.0314
# Total train chrF after 16 iteration = 79.1295
# Average val loss after 16 iteration = 0.0375
# Total val chrF after 16 iteration = 75.0339
# Average test loss after 16 iteration = 0.0372
# Total test chrF after 16 iteration = 74.1986
# Dumping after  16
# Time for the iteration 4.4 seconds
#
#
# Average train loss after 17 iteration = 0.0283
# Total train chrF after 17 iteration = 80.0851
# Average val loss after 17 iteration = 0.0351
# Total val chrF after 17 iteration = 75.3433
# Average test loss after 17 iteration = 0.0349
# Total test chrF after 17 iteration = 74.9377
# Dumping after  17
# Time for the iteration 4.4 seconds
#
#
# Average train loss after 18 iteration = 0.0255
# Total train chrF after 18 iteration = 80.9814
# Average val loss after 18 iteration = 0.0330
# Total val chrF after 18 iteration = 75.7096
# Average test loss after 18 iteration = 0.0329
# Total test chrF after 18 iteration = 75.2736
# Dumping after  18
# Time for the iteration 4.2 seconds
#
#
# Average train loss after 19 iteration = 0.0230
# Total train chrF after 19 iteration = 81.8149
# Average val loss after 19 iteration = 0.0312
# Total val chrF after 19 iteration = 76.0384
# Average test loss after 19 iteration = 0.0311
# Total test chrF after 19 iteration = 75.6735
# Dumping after  19
# Time for the iteration 4.3 seconds
#
#
# Average train loss after 20 iteration = 0.0209
# Total train chrF after 20 iteration = 82.5610
# Average val loss after 20 iteration = 0.0296
# Total val chrF after 20 iteration = 76.2068
# Average test loss after 20 iteration = 0.0296
# Total test chrF after 20 iteration = 76.0869
# Dumping after  20
# Time for the iteration 4.3 seconds
#
#
# Average train loss after 21 iteration = 0.0190
# Total train chrF after 21 iteration = 83.3289
# Average val loss after 21 iteration = 0.0282
# Total val chrF after 21 iteration = 76.6895
# Average test loss after 21 iteration = 0.0283
# Total test chrF after 21 iteration = 76.3580
# Dumping after  21
# Time for the iteration 4.4 seconds
#
#
# Average train loss after 22 iteration = 0.0174
# Total train chrF after 22 iteration = 83.9771
# Average val loss after 22 iteration = 0.0270
# Total val chrF after 22 iteration = 76.9554
# Average test loss after 22 iteration = 0.0272
# Total test chrF after 22 iteration = 76.7374
# Dumping after  22
# Time for the iteration 4.3 seconds
#
#
# Average train loss after 23 iteration = 0.0160
# Total train chrF after 23 iteration = 84.6135
# Average val loss after 23 iteration = 0.0259
# Total val chrF after 23 iteration = 77.1859
# Average test loss after 23 iteration = 0.0261
# Total test chrF after 23 iteration = 77.0537
# Dumping after  23
# Time for the iteration 4.3 seconds
#
#
# Average train loss after 24 iteration = 0.0147
# Total train chrF after 24 iteration = 85.1921
# Average val loss after 24 iteration = 0.0249
# Total val chrF after 24 iteration = 77.3644
# Average test loss after 24 iteration = 0.0252
# Total test chrF after 24 iteration = 77.3881
# Dumping after  24
# Time for the iteration 4.4 seconds
#
#
# Average train loss after 25 iteration = 0.0136
# Total train chrF after 25 iteration = 85.7232
# Average val loss after 25 iteration = 0.0241
# Total val chrF after 25 iteration = 77.6451
# Average test loss after 25 iteration = 0.0244
# Total test chrF after 25 iteration = 77.4871
# Dumping after  25
# Time for the iteration 4.4 seconds
#
#
# Average train loss after 26 iteration = 0.0126
# Total train chrF after 26 iteration = 86.1704
# Average val loss after 26 iteration = 0.0233
# Total val chrF after 26 iteration = 77.8507
# Average test loss after 26 iteration = 0.0237
# Total test chrF after 26 iteration = 77.7720
# Dumping after  26
# Time for the iteration 4.4 seconds
#
#
# Average train loss after 27 iteration = 0.0117
# Total train chrF after 27 iteration = 86.5866
# Average val loss after 27 iteration = 0.0226
# Total val chrF after 27 iteration = 78.0506
# Average test loss after 27 iteration = 0.0231
# Total test chrF after 27 iteration = 78.3028
# Dumping after  27
# Time for the iteration 4.3 seconds
#
#
# Average train loss after 28 iteration = 0.0109
# Total train chrF after 28 iteration = 86.8939
# Average val loss after 28 iteration = 0.0220
# Total val chrF after 28 iteration = 78.1638
# Average test loss after 28 iteration = 0.0225
# Total test chrF after 28 iteration = 78.3936
# Dumping after  28
# Time for the iteration 4.3 seconds
#
#
# Average train loss after 29 iteration = 0.0101
# Total train chrF after 29 iteration = 87.2141
# Average val loss after 29 iteration = 0.0214
# Total val chrF after 29 iteration = 78.3812
# Average test loss after 29 iteration = 0.0220
# Total test chrF after 29 iteration = 78.6111
# Dumping after  29
# Time for the iteration 4.3 seconds
#
#
# Average train loss after 30 iteration = 0.0095
# Total train chrF after 30 iteration = 87.4852
# Average val loss after 30 iteration = 0.0209
# Total val chrF after 30 iteration = 78.5007
# Average test loss after 30 iteration = 0.0215
# Total test chrF after 30 iteration = 78.8573
# Dumping after  30
# Time for the iteration 4.4 seconds
#
#
# Average train loss after 31 iteration = 0.0089
# Total train chrF after 31 iteration = 87.7157
# Average val loss after 31 iteration = 0.0205
# Total val chrF after 31 iteration = 78.5213
# Average test loss after 31 iteration = 0.0211
# Total test chrF after 31 iteration = 79.0002
# Dumping after  31
# Time for the iteration 4.4 seconds
#
#
# Average train loss after 32 iteration = 0.0083
# Total train chrF after 32 iteration = 87.9319
# Average val loss after 32 iteration = 0.0200
# Total val chrF after 32 iteration = 78.8231
# Average test loss after 32 iteration = 0.0207
# Total test chrF after 32 iteration = 79.0870
# Dumping after  32
# Time for the iteration 4.4 seconds
#
#
# Average train loss after 33 iteration = 0.0078
# Total train chrF after 33 iteration = 88.1132
# Average val loss after 33 iteration = 0.0197
# Total val chrF after 33 iteration = 78.8866
# Average test loss after 33 iteration = 0.0204
# Total test chrF after 33 iteration = 79.1743
# Dumping after  33
# Time for the iteration 4.3 seconds
#
#
# Average train loss after 34 iteration = 0.0074
# Total train chrF after 34 iteration = 88.2505
# Average val loss after 34 iteration = 0.0193
# Total val chrF after 34 iteration = 78.9523
# Average test loss after 34 iteration = 0.0200
# Total test chrF after 34 iteration = 79.2512
# Dumping after  34
# Time for the iteration 4.3 seconds
#
#
# Average train loss after 35 iteration = 0.0069
# Total train chrF after 35 iteration = 88.3979
# Average val loss after 35 iteration = 0.0190
# Total val chrF after 35 iteration = 78.9466
# Average test loss after 35 iteration = 0.0198
# Total test chrF after 35 iteration = 79.3160
# Time for the iteration 4.3 seconds
#
#
# Average train loss after 36 iteration = 0.0065
# Total train chrF after 36 iteration = 88.5314
# Average val loss after 36 iteration = 0.0187
# Total val chrF after 36 iteration = 79.1658
# Average test loss after 36 iteration = 0.0195
# Total test chrF after 36 iteration = 79.2963
# Dumping after  36
# Time for the iteration 4.4 seconds
#
#
# Average train loss after 37 iteration = 0.0062
# Total train chrF after 37 iteration = 88.6396
# Average val loss after 37 iteration = 0.0185
# Total val chrF after 37 iteration = 79.1942
# Average test loss after 37 iteration = 0.0192
# Total test chrF after 37 iteration = 79.2762
# Dumping after  37
# Time for the iteration 4.4 seconds
#
#
# Average train loss after 38 iteration = 0.0058
# Total train chrF after 38 iteration = 88.7414
# Average val loss after 38 iteration = 0.0182
# Total val chrF after 38 iteration = 79.3157
# Average test loss after 38 iteration = 0.0190
# Total test chrF after 38 iteration = 79.4021
# Dumping after  38
# Time for the iteration 4.4 seconds
#
#
# Average train loss after 39 iteration = 0.0055
# Total train chrF after 39 iteration = 88.8337
# Average val loss after 39 iteration = 0.0180
# Total val chrF after 39 iteration = 79.5230
# Average test loss after 39 iteration = 0.0188
# Total test chrF after 39 iteration = 79.4276
# Dumping after  39
# Time for the iteration 4.4 seconds
#
#
# Average train loss after 40 iteration = 0.0052
# Total train chrF after 40 iteration = 88.9260
# Average val loss after 40 iteration = 0.0178
# Total val chrF after 40 iteration = 79.5756
# Average test loss after 40 iteration = 0.0186
# Total test chrF after 40 iteration = 79.4817
# Dumping after  40
# Time for the iteration 4.4 seconds
#
#
# Average train loss after 41 iteration = 0.0049
# Total train chrF after 41 iteration = 89.0033
# Average val loss after 41 iteration = 0.0176
# Total val chrF after 41 iteration = 79.6248
# Average test loss after 41 iteration = 0.0185
# Total test chrF after 41 iteration = 79.5186
# Dumping after  41
# Time for the iteration 4.4 seconds
#
#
# Average train loss after 42 iteration = 0.0047
# Total train chrF after 42 iteration = 89.0746
# Average val loss after 42 iteration = 0.0174
# Total val chrF after 42 iteration = 79.6736
# Average test loss after 42 iteration = 0.0183
# Total test chrF after 42 iteration = 79.5081
# Dumping after  42
# Time for the iteration 4.4 seconds
#
#
# Average train loss after 43 iteration = 0.0044
# Total train chrF after 43 iteration = 89.1329
# Average val loss after 43 iteration = 0.0173
# Total val chrF after 43 iteration = 79.7158
# Average test loss after 43 iteration = 0.0182
# Total test chrF after 43 iteration = 79.5886
# Dumping after  43
# Time for the iteration 4.4 seconds
#
#
# Average train loss after 44 iteration = 0.0042
# Total train chrF after 44 iteration = 89.1815
# Average val loss after 44 iteration = 0.0171
# Total val chrF after 44 iteration = 79.7126
# Average test loss after 44 iteration = 0.0180
# Total test chrF after 44 iteration = 79.7558
# Time for the iteration 4.3 seconds
#
#
# Average train loss after 45 iteration = 0.0040
# Total train chrF after 45 iteration = 89.2298
# Average val loss after 45 iteration = 0.0170
# Total val chrF after 45 iteration = 79.8340
# Average test loss after 45 iteration = 0.0179
# Total test chrF after 45 iteration = 79.8698
# Dumping after  45
# Time for the iteration 4.3 seconds
#
#
# Average train loss after 46 iteration = 0.0038
# Total train chrF after 46 iteration = 89.2817
# Average val loss after 46 iteration = 0.0169
# Total val chrF after 46 iteration = 79.8676
# Average test loss after 46 iteration = 0.0178
# Total test chrF after 46 iteration = 79.8707
# Dumping after  46
# Time for the iteration 4.3 seconds
#
#
# Average train loss after 47 iteration = 0.0036
# Total train chrF after 47 iteration = 89.3230
# Average val loss after 47 iteration = 0.0168
# Total val chrF after 47 iteration = 79.8965
# Average test loss after 47 iteration = 0.0177
# Total test chrF after 47 iteration = 79.9595
# Dumping after  47
# Time for the iteration 4.3 seconds
#
#
# Average train loss after 48 iteration = 0.0034
# Total train chrF after 48 iteration = 89.3562
# Average val loss after 48 iteration = 0.0167
# Total val chrF after 48 iteration = 80.0460
# Average test loss after 48 iteration = 0.0176
# Total test chrF after 48 iteration = 79.9868
# Dumping after  48
# Time for the iteration 4.3 seconds
#
#
# Average train loss after 49 iteration = 0.0032
# Total train chrF after 49 iteration = 89.3877
# Average val loss after 49 iteration = 0.0166
# Total val chrF after 49 iteration = 80.1120
# Average test loss after 49 iteration = 0.0176
# Total test chrF after 49 iteration = 79.9736
# Dumping after  49
# Time for the iteration 4.3 seconds
#
#
# Average train loss after 50 iteration = 0.0030
# Total train chrF after 50 iteration = 89.4243
# Average val loss after 50 iteration = 0.0166
# Total val chrF after 50 iteration = 80.0971
# Average test loss after 50 iteration = 0.0175
# Total test chrF after 50 iteration = 79.9953
# Time for the iteration 4.4 seconds
#
#
# Average train loss after 51 iteration = 0.0029
# Total train chrF after 51 iteration = 89.4461
# Average val loss after 51 iteration = 0.0165
# Total val chrF after 51 iteration = 80.0575
# Average test loss after 51 iteration = 0.0174
# Total test chrF after 51 iteration = 80.1246
# Time for the iteration 4.3 seconds
#
#
# Average train loss after 52 iteration = 0.0027
# Total train chrF after 52 iteration = 89.4775
# Average val loss after 52 iteration = 0.0164
# Total val chrF after 52 iteration = 80.0384
# Average test loss after 52 iteration = 0.0174
# Total test chrF after 52 iteration = 80.1296
# Time for the iteration 4.3 seconds
#
#
# Average train loss after 53 iteration = 0.0026
# Total train chrF after 53 iteration = 89.4961
# Average val loss after 53 iteration = 0.0164
# Total val chrF after 53 iteration = 80.1277
# Average test loss after 53 iteration = 0.0174
# Total test chrF after 53 iteration = 79.9562
# Dumping after  53
# Time for the iteration 4.4 seconds
#
#
# Average train loss after 54 iteration = 0.0025
# Total train chrF after 54 iteration = 89.5166
# Average val loss after 54 iteration = 0.0164
# Total val chrF after 54 iteration = 80.1368
# Average test loss after 54 iteration = 0.0173
# Total test chrF after 54 iteration = 80.0717
# Dumping after  54
# Time for the iteration 4.3 seconds
#
#
# Average train loss after 55 iteration = 0.0023
# Total train chrF after 55 iteration = 89.5335
# Average val loss after 55 iteration = 0.0163
# Total val chrF after 55 iteration = 80.0865
# Average test loss after 55 iteration = 0.0173
# Total test chrF after 55 iteration = 80.0955
# Time for the iteration 4.5 seconds
#
#
# Average train loss after 56 iteration = 0.0022
# Total train chrF after 56 iteration = 89.5503
# Average val loss after 56 iteration = 0.0163
# Total val chrF after 56 iteration = 80.0453
# Average test loss after 56 iteration = 0.0173
# Total test chrF after 56 iteration = 80.0731
# Time for the iteration 4.4 seconds
#
#
# Average train loss after 57 iteration = 0.0021
# Total train chrF after 57 iteration = 89.5716
# Average val loss after 57 iteration = 0.0163
# Total val chrF after 57 iteration = 80.0449
# Average test loss after 57 iteration = 0.0173
# Total test chrF after 57 iteration = 80.0838
# Time for the iteration 4.3 seconds
#
#
# Average train loss after 58 iteration = 0.0020
# Total train chrF after 58 iteration = 89.5865
# Average val loss after 58 iteration = 0.0163
# Total val chrF after 58 iteration = 80.0792
# Average test loss after 58 iteration = 0.0173
# Total test chrF after 58 iteration = 80.1247
# Time for the iteration 4.4 seconds
#
#
# Average train loss after 59 iteration = 0.0019
# Total train chrF after 59 iteration = 89.5980
# Average val loss after 59 iteration = 0.0163
# Total val chrF after 59 iteration = 80.1252
# Average test loss after 59 iteration = 0.0173
# Total test chrF after 59 iteration = 80.0522
# Time for the iteration 4.3 seconds
#
#
# Average train loss after 60 iteration = 0.0018
# Total train chrF after 60 iteration = 89.6127
# Average val loss after 60 iteration = 0.0163
# Total val chrF after 60 iteration = 80.1994
# Average test loss after 60 iteration = 0.0173
# Total test chrF after 60 iteration = 80.0825
# Dumping after  60
# Time for the iteration 4.3 seconds
#
#
# Average train loss after 61 iteration = 0.0017
# Total train chrF after 61 iteration = 89.6236
# Average val loss after 61 iteration = 0.0163
# Total val chrF after 61 iteration = 80.2624
# Average test loss after 61 iteration = 0.0173
# Total test chrF after 61 iteration = 80.1108
# Dumping after  61
# Time for the iteration 4.3 seconds
#
#
# Average train loss after 62 iteration = 0.0016
# Total train chrF after 62 iteration = 89.6337
# Average val loss after 62 iteration = 0.0163
# Total val chrF after 62 iteration = 80.3334
# Average test loss after 62 iteration = 0.0173
# Total test chrF after 62 iteration = 80.1100
# Dumping after  62
# Time for the iteration 4.4 seconds
#
#
# Average train loss after 63 iteration = 0.0016
# Total train chrF after 63 iteration = 89.6440
# Average val loss after 63 iteration = 0.0163
# Total val chrF after 63 iteration = 80.3066
# Average test loss after 63 iteration = 0.0173
# Total test chrF after 63 iteration = 80.2805
# Time for the iteration 4.3 seconds
#
#
# Average train loss after 64 iteration = 0.0015
# Total train chrF after 64 iteration = 89.6533
# Average val loss after 64 iteration = 0.0163
# Total val chrF after 64 iteration = 80.2938
# Average test loss after 64 iteration = 0.0174
# Total test chrF after 64 iteration = 80.3631
# Time for the iteration 4.2 seconds
#
#
# Average train loss after 65 iteration = 0.0014
# Total train chrF after 65 iteration = 89.6630
# Average val loss after 65 iteration = 0.0163
# Total val chrF after 65 iteration = 80.3757
# Average test loss after 65 iteration = 0.0174
# Total test chrF after 65 iteration = 80.3839
# Dumping after  65
# Time for the iteration 4.3 seconds
#
#
# Average train loss after 66 iteration = 0.0013
# Total train chrF after 66 iteration = 89.6725
# Average val loss after 66 iteration = 0.0164
# Total val chrF after 66 iteration = 80.4573
# Average test loss after 66 iteration = 0.0174
# Total test chrF after 66 iteration = 80.3614
# Dumping after  66
# Time for the iteration 4.3 seconds
#
#
# Average train loss after 67 iteration = 0.0013
# Total train chrF after 67 iteration = 89.6783
# Average val loss after 67 iteration = 0.0164
# Total val chrF after 67 iteration = 80.4238
# Average test loss after 67 iteration = 0.0175
# Total test chrF after 67 iteration = 80.2510
# Time for the iteration 4.4 seconds
#
#
# Average train loss after 68 iteration = 0.0012
# Total train chrF after 68 iteration = 89.6833
# Average val loss after 68 iteration = 0.0164
# Total val chrF after 68 iteration = 80.4276
# Average test loss after 68 iteration = 0.0175
# Total test chrF after 68 iteration = 80.3316
# Time for the iteration 4.3 seconds
#
#
# Average train loss after 69 iteration = 0.0011
# Total train chrF after 69 iteration = 89.6872
# Average val loss after 69 iteration = 0.0165
# Total val chrF after 69 iteration = 80.4670
# Average test loss after 69 iteration = 0.0176
# Total test chrF after 69 iteration = 80.3494
# Dumping after  69
# Time for the iteration 4.4 seconds
#
#
# Average train loss after 70 iteration = 0.0011
# Total train chrF after 70 iteration = 89.6926
# Average val loss after 70 iteration = 0.0165
# Total val chrF after 70 iteration = 80.5103
# Average test loss after 70 iteration = 0.0176
# Total test chrF after 70 iteration = 80.3765
# Dumping after  70
# Time for the iteration 4.3 seconds
#
#
# Average train loss after 71 iteration = 0.0010
# Total train chrF after 71 iteration = 89.6966
# Average val loss after 71 iteration = 0.0166
# Total val chrF after 71 iteration = 80.5243
# Average test loss after 71 iteration = 0.0177
# Total test chrF after 71 iteration = 80.4402
# Dumping after  71
# Time for the iteration 4.3 seconds
#
#
# Average train loss after 72 iteration = 0.0010
# Total train chrF after 72 iteration = 89.6997
# Average val loss after 72 iteration = 0.0166
# Total val chrF after 72 iteration = 80.6807
# Average test loss after 72 iteration = 0.0177
# Total test chrF after 72 iteration = 80.4394
# Dumping after  72
# Time for the iteration 4.4 seconds
#
#
# Average train loss after 73 iteration = 0.0009
# Total train chrF after 73 iteration = 89.7031
# Average val loss after 73 iteration = 0.0167
# Total val chrF after 73 iteration = 80.7454
# Average test loss after 73 iteration = 0.0178
# Total test chrF after 73 iteration = 80.4711
# Dumping after  73
# Time for the iteration 4.3 seconds
#
#
# Average train loss after 74 iteration = 0.0009
# Total train chrF after 74 iteration = 89.7063
# Average val loss after 74 iteration = 0.0167
# Total val chrF after 74 iteration = 80.7950
# Average test loss after 74 iteration = 0.0178
# Total test chrF after 74 iteration = 80.4173
# Dumping after  74
# Time for the iteration 4.3 seconds
#
#
# Average train loss after 75 iteration = 0.0008
# Total train chrF after 75 iteration = 89.7096
# Average val loss after 75 iteration = 0.0168
# Total val chrF after 75 iteration = 80.7666
# Average test loss after 75 iteration = 0.0179
# Total test chrF after 75 iteration = 80.4531
# Time for the iteration 4.3 seconds
#
#
# Average train loss after 76 iteration = 0.0008
# Total train chrF after 76 iteration = 89.7130
# Average val loss after 76 iteration = 0.0169
# Total val chrF after 76 iteration = 80.8023
# Average test loss after 76 iteration = 0.0180
# Total test chrF after 76 iteration = 80.5393
# Dumping after  76
# Time for the iteration 4.4 seconds
#
#
# Average train loss after 77 iteration = 0.0007
# Total train chrF after 77 iteration = 89.7153
# Average val loss after 77 iteration = 0.0169
# Total val chrF after 77 iteration = 80.8227
# Average test loss after 77 iteration = 0.0180
# Total test chrF after 77 iteration = 80.5123
# Dumping after  77
# Time for the iteration 4.3 seconds
#
#
# Average train loss after 78 iteration = 0.0007
# Total train chrF after 78 iteration = 89.7167
# Average val loss after 78 iteration = 0.0170
# Total val chrF after 78 iteration = 80.8279
# Average test loss after 78 iteration = 0.0181
# Total test chrF after 78 iteration = 80.4827
# Dumping after  78
# Time for the iteration 4.3 seconds
#
#
# Average train loss after 79 iteration = 0.0007
# Total train chrF after 79 iteration = 89.7187
# Average val loss after 79 iteration = 0.0171
# Total val chrF after 79 iteration = 80.8635
# Average test loss after 79 iteration = 0.0182
# Total test chrF after 79 iteration = 80.4481
# Dumping after  79
# Time for the iteration 4.3 seconds
#
#
# Average train loss after 80 iteration = 0.0006
# Total train chrF after 80 iteration = 89.7201
# Average val loss after 80 iteration = 0.0172
# Total val chrF after 80 iteration = 80.9045
# Average test loss after 80 iteration = 0.0182
# Total test chrF after 80 iteration = 80.4699
# Dumping after  80
# Time for the iteration 4.4 seconds
#
#
# Average train loss after 81 iteration = 0.0006
# Total train chrF after 81 iteration = 89.7230
# Average val loss after 81 iteration = 0.0172
# Total val chrF after 81 iteration = 80.8501
# Average test loss after 81 iteration = 0.0183
# Total test chrF after 81 iteration = 80.4256
# Time for the iteration 4.3 seconds
#
#
# Average train loss after 82 iteration = 0.0006
# Total train chrF after 82 iteration = 89.7252
# Average val loss after 82 iteration = 0.0173
# Total val chrF after 82 iteration = 80.8662
# Average test loss after 82 iteration = 0.0184
# Total test chrF after 82 iteration = 80.4290
# Time for the iteration 4.3 seconds
#
#
# Average train loss after 83 iteration = 0.0005
# Total train chrF after 83 iteration = 89.7260
# Average val loss after 83 iteration = 0.0174
# Total val chrF after 83 iteration = 80.8557
# Average test loss after 83 iteration = 0.0185
# Total test chrF after 83 iteration = 80.4376
# Time for the iteration 4.3 seconds
#
#
# Average train loss after 84 iteration = 0.0005
# Total train chrF after 84 iteration = 89.7279
# Average val loss after 84 iteration = 0.0175
# Total val chrF after 84 iteration = 80.8111
# Average test loss after 84 iteration = 0.0185
# Total test chrF after 84 iteration = 80.3935
# Time for the iteration 4.3 seconds
#
#
# Average train loss after 85 iteration = 0.0005
# Total train chrF after 85 iteration = 89.7296
# Average val loss after 85 iteration = 0.0176
# Total val chrF after 85 iteration = 80.8126
# Average test loss after 85 iteration = 0.0186
# Total test chrF after 85 iteration = 80.4206
# Time for the iteration 4.3 seconds
#
#
# Average train loss after 86 iteration = 0.0005
# Total train chrF after 86 iteration = 89.7310
# Average val loss after 86 iteration = 0.0176
# Total val chrF after 86 iteration = 80.8126
# Average test loss after 86 iteration = 0.0187
# Total test chrF after 86 iteration = 80.3783
# Time for the iteration 4.3 seconds
#
#
# Average train loss after 87 iteration = 0.0004
# Total train chrF after 87 iteration = 89.7316
# Average val loss after 87 iteration = 0.0177
# Total val chrF after 87 iteration = 80.8248
# Average test loss after 87 iteration = 0.0188
# Total test chrF after 87 iteration = 80.3833
# Time for the iteration 4.4 seconds
#
#
# Average train loss after 88 iteration = 0.0004
# Total train chrF after 88 iteration = 89.7329
# Average val loss after 88 iteration = 0.0178
# Total val chrF after 88 iteration = 80.8320
# Average test loss after 88 iteration = 0.0189
# Total test chrF after 88 iteration = 80.3619
# Time for the iteration 4.3 seconds
#
#
# Average train loss after 89 iteration = 0.0004
# Total train chrF after 89 iteration = 89.7337
# Average val loss after 89 iteration = 0.0179
# Total val chrF after 89 iteration = 80.7657
# Average test loss after 89 iteration = 0.0190
# Total test chrF after 89 iteration = 80.3600
# Time for the iteration 4.3 seconds
#
#
# Average train loss after 90 iteration = 0.0004
# Total train chrF after 90 iteration = 89.7347
# Average val loss after 90 iteration = 0.0180
# Total val chrF after 90 iteration = 80.8711
# Average test loss after 90 iteration = 0.0191
# Total test chrF after 90 iteration = 80.3633
# Time for the iteration 4.3 seconds
#
#
# Average train loss after 91 iteration = 0.0004
# Total train chrF after 91 iteration = 89.7352
# Average val loss after 91 iteration = 0.0181
# Total val chrF after 91 iteration = 80.8706
# Average test loss after 91 iteration = 0.0192
# Total test chrF after 91 iteration = 80.3592
# Time for the iteration 4.3 seconds
#
#
# Average train loss after 92 iteration = 0.0003
# Total train chrF after 92 iteration = 89.7356
# Average val loss after 92 iteration = 0.0181
# Total val chrF after 92 iteration = 80.8400
# Average test loss after 92 iteration = 0.0192
# Total test chrF after 92 iteration = 80.3607
# Time for the iteration 4.3 seconds
#
#
# Average train loss after 93 iteration = 0.0003
# Total train chrF after 93 iteration = 89.7360
# Average val loss after 93 iteration = 0.0182
# Total val chrF after 93 iteration = 80.8017
# Average test loss after 93 iteration = 0.0194
# Total test chrF after 93 iteration = 80.4215
# Time for the iteration 4.4 seconds
#
#
# Average train loss after 94 iteration = 0.0003
# Total train chrF after 94 iteration = 89.7370
# Average val loss after 94 iteration = 0.0183
# Total val chrF after 94 iteration = 80.8216
# Average test loss after 94 iteration = 0.0195
# Total test chrF after 94 iteration = 80.3328
# Time for the iteration 4.4 seconds
#
#
# Average train loss after 95 iteration = 0.0003
# Total train chrF after 95 iteration = 89.7371
# Average val loss after 95 iteration = 0.0184
# Total val chrF after 95 iteration = 80.6907
# Average test loss after 95 iteration = 0.0196
# Total test chrF after 95 iteration = 80.3508
# Time for the iteration 4.4 seconds
#
#
# Average train loss after 96 iteration = 0.0003
# Total train chrF after 96 iteration = 89.7372
# Average val loss after 96 iteration = 0.0185
# Total val chrF after 96 iteration = 80.7946
# Average test loss after 96 iteration = 0.0197
# Total test chrF after 96 iteration = 80.3744
# Time for the iteration 4.4 seconds
#
#
# Average train loss after 97 iteration = 0.0003
# Total train chrF after 97 iteration = 89.7379
# Average val loss after 97 iteration = 0.0186
# Total val chrF after 97 iteration = 80.7685
# Average test loss after 97 iteration = 0.0198
# Total test chrF after 97 iteration = 80.3158
# Time for the iteration 4.4 seconds
#
#
# Average train loss after 98 iteration = 0.0002
# Total train chrF after 98 iteration = 89.7383
# Average val loss after 98 iteration = 0.0187
# Total val chrF after 98 iteration = 80.9746
# Average test loss after 98 iteration = 0.0199
# Total test chrF after 98 iteration = 80.3183
# Dumping after  98
# Time for the iteration 4.4 seconds
#
#
# Average train loss after 99 iteration = 0.0002
# Total train chrF after 99 iteration = 89.7383
# Average val loss after 99 iteration = 0.0188
# Total val chrF after 99 iteration = 80.9871
# Average test loss after 99 iteration = 0.0200
# Total test chrF after 99 iteration = 80.3446
# Dumping after  99
# Time for the iteration 4.4 seconds
#
#
# Average train loss after 100 iteration = 0.0002
# Total train chrF after 100 iteration = 89.7385
# Average val loss after 100 iteration = 0.0189
# Total val chrF after 100 iteration = 80.9806
# Average test loss after 100 iteration = 0.0201
# Total test chrF after 100 iteration = 80.4265
# Time for the iteration 4.3 seconds
#
#
# <Figure size 640x480 with 1 Axes>
# <Figure size 640x480 with 1 Axes>

# %%
language = "yi"
task_name = "keyprox"
vocab_size = 2999
num_epochs = 100
batch_size = 32
model = "50_1"
optimizer = "Adam"
metric = "chrF"

# %%
from IPython.display import Image

Image("curves/{}_{}_{}_{}_{}_loss.png".format(language, task_name, vocab_size, num_epochs, batch_size))

# %%
Image("curves/{}_{}_{}_{}_{}_{}.png".format(language, task_name, vocab_size, num_epochs, batch_size, metric))

# %%
print("{}.{}.{}.{}.{}.{}.{}".format(language, task_name, vocab_size, num_epochs, batch_size, model, optimizer))
# Out:
# yi.keyprox.2999.100.32.50_1.Adam
