# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
# %cd "drive/MyDrive/Tesis/scRNN"
# Out:
# /content/drive/MyDrive/Tesis/scRNN

# %%
import torch

torch.cuda.is_available()
# Out:
# True

# %%
# !pip install sacrebleu
# Out:
# ...
#      |████████████████████████████████| 90 kB 4.4 MB/s
# ...

# %%
# !python3 train.py --language yi --task-name all --num-epochs 100 --batch-size 32 --vocab-size 2999 --new-vocab --train --train-sentences-errors-file yi.all.train.sentences.errors.txt --train-sentences-file yi.all.train.sentences.txt --val-sentences-errors-file yi.all.val.sentences.errors.txt --val-sentences-file yi.all.val.sentences.txt --test-sentences-errors-file yi.all.test.sentences.errors.txt --test-sentences-file yi.all.test.sentences.txt --metric chrF --save
# Out:
# Parameters
# {'language': 'yi', 'task_name': 'all', 'vocab_size': 2999, 'num_epochs': 100, 'batch_size': 32, 'model_name': 'shi_random_20531_100_32', 'new_vocab': True, 'need_to_train': True, 'train_sentences_errors_file': 'yi.all.train.sentences.errors.txt', 'train_sentences_file': 'yi.all.train.sentences.txt', 'val_sentences_errors_file': 'yi.all.val.sentences.errors.txt', 'val_sentences_file': 'yi.all.val.sentences.txt', 'test_sentences_errors_file': 'yi.all.test.sentences.errors.txt', 'test_sentences_file': 'yi.all.test.sentences.txt', 'metric': 'chrF', 'save_model': True}
#
#
# Creating new vocabulary
# Len of w2i:  2999
# Len of i2w:  2999
# Len of char vocab:  21
#
#
# Initializing an only ScRNN model
#
#
# Training the model...
#
# Average train loss after 1 iteration = 0.1426
# Total train chrF after 1 iteration = 64.9729
# Average val loss after 1 iteration = 0.1529
# Total val chrF after 1 iteration = 66.3848
# Average test loss after 1 iteration = 0.1439
# ...

# %%
language = "yi"
task_name = "all"
vocab_size = 2999
num_epochs = 100
batch_size = 32
model = "50_1"
optimizer = "Adam"
metric = "chrF"

# %%
from IPython.display import Image

Image("curves/{}_{}_{}_{}_{}_loss.png".format(language, task_name, vocab_size, num_epochs, batch_size))

# %%
Image("curves/{}_{}_{}_{}_{}_{}.png".format(language, task_name, vocab_size, num_epochs, batch_size, metric))

# %%
print("{}.{}.{}.{}.{}.{}.{}".format(language, task_name, vocab_size, num_epochs, batch_size, model, optimizer))
# Out:
# yi.all.2999.100.32.50_1.Adam
