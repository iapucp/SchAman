# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
# %cd "drive/MyDrive/Tesis/scRNN"
# Out:
# /content/drive/MyDrive/Tesis/scRNN

# %%
import torch

torch.cuda.is_available()
# Out:
# True

# %%
# !pip install sacrebleu
# Out:
# ...
#      |████████████████████████████████| 90 kB 4.3 MB/s
# ...

# %%
# !python3 train.py --language ya --task-name sylsim --num-epochs 100 --batch-size 32 --vocab-size 4999 --new-vocab --train --train-sentences-errors-file ya.sylsim.train.sentences.errors.txt --train-sentences-file ya.sylsim.train.sentences.txt --val-sentences-errors-file ya.sylsim.val.sentences.errors.txt --val-sentences-file ya.sylsim.val.sentences.txt --test-sentences-errors-file ya.sylsim.test.sentences.errors.txt --test-sentences-file ya.sylsim.test.sentences.txt --metric chrF --save
# Out:
# Parameters
# {'language': 'ya', 'task_name': 'sylsim', 'vocab_size': 4999, 'num_epochs': 100, 'batch_size': 32, 'model_name': 'shi_random_20531_100_32', 'new_vocab': True, 'need_to_train': True, 'train_sentences_errors_file': 'ya.sylsim.train.sentences.errors.txt', 'train_sentences_file': 'ya.sylsim.train.sentences.txt', 'val_sentences_errors_file': 'ya.sylsim.val.sentences.errors.txt', 'val_sentences_file': 'ya.sylsim.val.sentences.txt', 'test_sentences_errors_file': 'ya.sylsim.test.sentences.errors.txt', 'test_sentences_file': 'ya.sylsim.test.sentences.txt', 'metric': 'chrF', 'save_model': True}
#
#
# Creating new vocabulary
# Len of w2i:  4999
# Len of i2w:  4999
# Len of char vocab:  29
#
#
# Initializing an only ScRNN model
#
#
# Training the model...
#
# Average train loss after 1 iteration = 0.1828
# Total train chrF after 1 iteration = 68.0892
# Average val loss after 1 iteration = 0.2555
# Total val chrF after 1 iteration = 69.5796
# ...

# %%
language = "ya"
task_name = "sylsim"
vocab_size = 4999
num_epochs = 100
batch_size = 32
model = "50_1"
optimizer = "Adam"
metric = "chrF"

# %%
from IPython.display import Image

Image("curves/{}_{}_{}_{}_{}_loss.png".format(language, task_name, vocab_size, num_epochs, batch_size))

# %%
Image("curves/{}_{}_{}_{}_{}_{}.png".format(language, task_name, vocab_size, num_epochs, batch_size, metric))

# %%
print("{}.{}.{}.{}.{}.{}.{}".format(language, task_name, vocab_size, num_epochs, batch_size, model, optimizer))
# Out:
# ya.sylsim.4999.100.32.50_1.Adam
