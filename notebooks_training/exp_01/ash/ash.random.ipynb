# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
# %cd "drive/MyDrive/Tesis/scRNN"
# Out:
# /content/drive/MyDrive/Tesis/scRNN

# %%
import torch

torch.cuda.is_available()
# Out:
# True

# %%
# !pip install sacrebleu
# Out:
# ...
#      |████████████████████████████████| 90 kB 7.2 MB/s
# ...

# %%
# !python3 train.py --language ash --task-name random --num-epochs 100 --vocab-size 4999 --batch-size 32 --new-vocab --train --train-sentences-errors-file ash.random.train.sentences.errors.txt --train-sentences-file ash.random.train.sentences.txt --val-sentences-errors-file ash.random.val.sentences.errors.txt --val-sentences-file ash.random.val.sentences.txt --test-sentences-errors-file ash.random.test.sentences.errors.txt --test-sentences-file ash.random.test.sentences.txt --metric chrF --save
# Out:
# Parameters
# {'language': 'ash', 'task_name': 'random', 'vocab_size': 4999, 'num_epochs': 100, 'batch_size': 32, 'model_name': 'shi_random_20531_100_32', 'new_vocab': True, 'need_to_train': True, 'train_sentences_errors_file': 'ash.random.train.sentences.errors.txt', 'train_sentences_file': 'ash.random.train.sentences.txt', 'val_sentences_errors_file': 'ash.random.val.sentences.errors.txt', 'val_sentences_file': 'ash.random.val.sentences.txt', 'test_sentences_errors_file': 'ash.random.test.sentences.errors.txt', 'test_sentences_file': 'ash.random.test.sentences.txt', 'metric': 'chrF', 'save_model': True}
#
#
# Creating new vocabulary
# Len of w2i:  4999
# Len of i2w:  4999
# Len of char vocab:  20
#
#
# Initializing an only ScRNN model
#
#
# Training the model...
#
# Average train loss after 1 iteration = 0.1920
# Total train chrF after 1 iteration = 65.8818
# Average val loss after 1 iteration = 0.2170
# Total val chrF after 1 iteration = 64.0282
# ...

# %%
language = "ash"
task_name = "random"
vocab_size = 4999
num_epochs = 100
batch_size = 32
model = "50_1"
optimizer = "Adam"
metric = "chrF"

# %%
from IPython.display import Image

Image("curves/{}_{}_{}_{}_{}_loss.png".format(language, task_name, vocab_size, num_epochs, batch_size))

# %%
Image("curves/{}_{}_{}_{}_{}_{}.png".format(language, task_name, vocab_size, num_epochs, batch_size, metric))

# %%
print("{}.{}.{}.{}.{}.{}.{}".format(language, task_name, vocab_size, num_epochs, batch_size, model, optimizer))
# Out:
# ash.random.4999.100.32.50_1.Adam
