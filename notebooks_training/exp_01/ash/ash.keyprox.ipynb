# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
# %cd "drive/MyDrive/Tesis/scRNN"
# Out:
# /content/drive/MyDrive/Tesis/scRNN

# %%
import torch

torch.cuda.is_available()
# Out:
# True

# %%
# !pip install sacrebleu
# Out:
# Collecting sacrebleu
#   Downloading sacrebleu-2.0.0-py3-none-any.whl (90 kB)
#      |████████████████████████████████| 90 kB 4.9 MB/s
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from sacrebleu) (1.19.5)
# Requirement already satisfied: regex in /usr/local/lib/python3.7/dist-packages (from sacrebleu) (2019.12.20)
# Collecting colorama
#   Downloading colorama-0.4.4-py2.py3-none-any.whl (16 kB)
# Requirement already satisfied: tabulate>=0.8.9 in /usr/local/lib/python3.7/dist-packages (from sacrebleu) (0.8.9)
# Collecting portalocker
#   Downloading portalocker-2.3.2-py2.py3-none-any.whl (15 kB)
# Installing collected packages: portalocker, colorama, sacrebleu
# Successfully installed colorama-0.4.4 portalocker-2.3.2 sacrebleu-2.0.0

# %%
# !python3 train.py --language ash --task-name keyprox --num-epochs 100 --batch-size 32 --vocab-size 4999 --new-vocab --train --train-sentences-errors-file ash.keyprox.train.sentences.errors.txt --train-sentences-file ash.keyprox.train.sentences.txt --val-sentences-errors-file ash.keyprox.val.sentences.errors.txt --val-sentences-file ash.keyprox.val.sentences.txt --test-sentences-errors-file ash.keyprox.test.sentences.errors.txt --test-sentences-file ash.keyprox.test.sentences.txt --metric chrF --save
# Out:
# Parameters
# {'language': 'ash', 'task_name': 'keyprox', 'vocab_size': 4999, 'num_epochs': 100, 'batch_size': 32, 'model_name': 'shi_random_20531_100_32', 'new_vocab': True, 'need_to_train': True, 'train_sentences_errors_file': 'ash.keyprox.train.sentences.errors.txt', 'train_sentences_file': 'ash.keyprox.train.sentences.txt', 'val_sentences_errors_file': 'ash.keyprox.val.sentences.errors.txt', 'val_sentences_file': 'ash.keyprox.val.sentences.txt', 'test_sentences_errors_file': 'ash.keyprox.test.sentences.errors.txt', 'test_sentences_file': 'ash.keyprox.test.sentences.txt', 'metric': 'chrF', 'save_model': True}
#
#
# Creating new vocabulary
# Len of w2i:  4999
# Len of i2w:  4999
# Len of char vocab:  20
#
#
# Initializing an only ScRNN model
#
#
# Training the model...
#
# Average train loss after 1 iteration = 0.1924
# Total train chrF after 1 iteration = 63.5822
# Average val loss after 1 iteration = 0.2305
# Total val chrF after 1 iteration = 63.3700
# Average test loss after 1 iteration = 0.2160
# Total test chrF after 1 iteration = 63.6410
# Dumping after  1
# Time for the iteration 10.4 seconds
#
#
# Average train loss after 2 iteration = 0.1646
# Total train chrF after 2 iteration = 64.8393
# Average val loss after 2 iteration = 0.1685
# Total val chrF after 2 iteration = 66.2874
# Average test loss after 2 iteration = 0.1558
# Total test chrF after 2 iteration = 66.5271
# Dumping after  2
# Time for the iteration 10.1 seconds
#
#
# Average train loss after 3 iteration = 0.1365
# Total train chrF after 3 iteration = 67.3577
# Average val loss after 3 iteration = 0.1380
# Total val chrF after 3 iteration = 68.3091
# Average test loss after 3 iteration = 0.1265
# Total test chrF after 3 iteration = 68.6945
# Dumping after  3
# Time for the iteration 10.3 seconds
#
#
# Average train loss after 4 iteration = 0.1128
# Total train chrF after 4 iteration = 69.6739
# Average val loss after 4 iteration = 0.1157
# Total val chrF after 4 iteration = 69.8391
# Average test loss after 4 iteration = 0.1053
# Total test chrF after 4 iteration = 70.4127
# Dumping after  4
# Time for the iteration 10.3 seconds
#
#
# Average train loss after 5 iteration = 0.0946
# Total train chrF after 5 iteration = 71.9882
# Average val loss after 5 iteration = 0.1000
# Total val chrF after 5 iteration = 71.2125
# Average test loss after 5 iteration = 0.0907
# Total test chrF after 5 iteration = 71.4844
# Dumping after  5
# Time for the iteration 10.2 seconds
#
#
# Average train loss after 6 iteration = 0.0803
# Total train chrF after 6 iteration = 73.8988
# Average val loss after 6 iteration = 0.0875
# Total val chrF after 6 iteration = 72.3007
# Average test loss after 6 iteration = 0.0792
# Total test chrF after 6 iteration = 72.6171
# Dumping after  6
# Time for the iteration 10.3 seconds
#
#
# Average train loss after 7 iteration = 0.0688
# Total train chrF after 7 iteration = 75.4522
# Average val loss after 7 iteration = 0.0775
# Total val chrF after 7 iteration = 73.2156
# Average test loss after 7 iteration = 0.0700
# Total test chrF after 7 iteration = 73.5824
# Dumping after  7
# Time for the iteration 10.3 seconds
#
#
# Average train loss after 8 iteration = 0.0593
# Total train chrF after 8 iteration = 76.9362
# Average val loss after 8 iteration = 0.0694
# Total val chrF after 8 iteration = 73.9849
# Average test loss after 8 iteration = 0.0627
# Total test chrF after 8 iteration = 74.2814
# Dumping after  8
# Time for the iteration 10.2 seconds
#
#
# Average train loss after 9 iteration = 0.0516
# Total train chrF after 9 iteration = 78.1558
# Average val loss after 9 iteration = 0.0627
# Total val chrF after 9 iteration = 74.9511
# Average test loss after 9 iteration = 0.0566
# Total test chrF after 9 iteration = 75.0743
# Dumping after  9
# Time for the iteration 10.3 seconds
#
#
# Average train loss after 10 iteration = 0.0451
# Total train chrF after 10 iteration = 79.2699
# Average val loss after 10 iteration = 0.0570
# Total val chrF after 10 iteration = 75.5913
# Average test loss after 10 iteration = 0.0516
# Total test chrF after 10 iteration = 75.6264
# Dumping after  10
# Time for the iteration 10.3 seconds
#
#
# Average train loss after 11 iteration = 0.0397
# Total train chrF after 11 iteration = 80.2979
# Average val loss after 11 iteration = 0.0523
# Total val chrF after 11 iteration = 76.1299
# Average test loss after 11 iteration = 0.0473
# Total test chrF after 11 iteration = 76.1282
# Dumping after  11
# Time for the iteration 10.2 seconds
#
#
# Average train loss after 12 iteration = 0.0351
# Total train chrF after 12 iteration = 81.2719
# Average val loss after 12 iteration = 0.0483
# Total val chrF after 12 iteration = 76.5719
# Average test loss after 12 iteration = 0.0436
# Total test chrF after 12 iteration = 76.5434
# Dumping after  12
# Time for the iteration 10.3 seconds
#
#
# Average train loss after 13 iteration = 0.0313
# Total train chrF after 13 iteration = 82.2372
# Average val loss after 13 iteration = 0.0449
# Total val chrF after 13 iteration = 77.3120
# Average test loss after 13 iteration = 0.0405
# Total test chrF after 13 iteration = 77.0942
# Dumping after  13
# Time for the iteration 10.4 seconds
#
#
# Average train loss after 14 iteration = 0.0280
# Total train chrF after 14 iteration = 83.1439
# Average val loss after 14 iteration = 0.0420
# Total val chrF after 14 iteration = 77.8198
# Average test loss after 14 iteration = 0.0379
# Total test chrF after 14 iteration = 77.7094
# Dumping after  14
# Time for the iteration 10.3 seconds
#
#
# Average train loss after 15 iteration = 0.0252
# Total train chrF after 15 iteration = 84.0021
# Average val loss after 15 iteration = 0.0395
# Total val chrF after 15 iteration = 78.2357
# Average test loss after 15 iteration = 0.0357
# Total test chrF after 15 iteration = 78.0627
# Dumping after  15
# Time for the iteration 10.4 seconds
#
#
# Average train loss after 16 iteration = 0.0228
# Total train chrF after 16 iteration = 84.7759
# Average val loss after 16 iteration = 0.0374
# Total val chrF after 16 iteration = 78.5787
# Average test loss after 16 iteration = 0.0338
# Total test chrF after 16 iteration = 78.4700
# Dumping after  16
# Time for the iteration 10.4 seconds
#
#
# Average train loss after 17 iteration = 0.0208
# Total train chrF after 17 iteration = 85.4981
# Average val loss after 17 iteration = 0.0356
# Total val chrF after 17 iteration = 78.9145
# Average test loss after 17 iteration = 0.0321
# Total test chrF after 17 iteration = 78.8409
# Dumping after  17
# Time for the iteration 10.3 seconds
#
#
# Average train loss after 18 iteration = 0.0191
# Total train chrF after 18 iteration = 86.1286
# Average val loss after 18 iteration = 0.0341
# Total val chrF after 18 iteration = 79.2518
# Average test loss after 18 iteration = 0.0307
# Total test chrF after 18 iteration = 79.1486
# Dumping after  18
# Time for the iteration 10.4 seconds
#
#
# Average train loss after 19 iteration = 0.0175
# Total train chrF after 19 iteration = 86.6809
# Average val loss after 19 iteration = 0.0327
# Total val chrF after 19 iteration = 79.6024
# Average test loss after 19 iteration = 0.0295
# Total test chrF after 19 iteration = 79.4785
# Dumping after  19
# Time for the iteration 10.4 seconds
#
#
# Average train loss after 20 iteration = 0.0162
# Total train chrF after 20 iteration = 87.1980
# Average val loss after 20 iteration = 0.0316
# Total val chrF after 20 iteration = 79.7517
# Average test loss after 20 iteration = 0.0285
# Total test chrF after 20 iteration = 79.7044
# Dumping after  20
# Time for the iteration 10.3 seconds
#
#
# Average train loss after 21 iteration = 0.0151
# Total train chrF after 21 iteration = 87.6448
# Average val loss after 21 iteration = 0.0306
# Total val chrF after 21 iteration = 80.0677
# Average test loss after 21 iteration = 0.0276
# Total test chrF after 21 iteration = 80.0444
# Dumping after  21
# Time for the iteration 10.3 seconds
#
#
# Average train loss after 22 iteration = 0.0140
# Total train chrF after 22 iteration = 88.0333
# Average val loss after 22 iteration = 0.0297
# Total val chrF after 22 iteration = 80.2631
# Average test loss after 22 iteration = 0.0268
# Total test chrF after 22 iteration = 80.2224
# Dumping after  22
# Time for the iteration 10.5 seconds
#
#
# Average train loss after 23 iteration = 0.0131
# Total train chrF after 23 iteration = 88.3614
# Average val loss after 23 iteration = 0.0290
# Total val chrF after 23 iteration = 80.4517
# Average test loss after 23 iteration = 0.0261
# Total test chrF after 23 iteration = 80.3293
# Dumping after  23
# Time for the iteration 10.4 seconds
#
#
# Average train loss after 24 iteration = 0.0123
# Total train chrF after 24 iteration = 88.6575
# Average val loss after 24 iteration = 0.0283
# Total val chrF after 24 iteration = 80.6822
# Average test loss after 24 iteration = 0.0254
# Total test chrF after 24 iteration = 80.4663
# Dumping after  24
# Time for the iteration 10.5 seconds
#
#
# Average train loss after 25 iteration = 0.0115
# Total train chrF after 25 iteration = 88.9374
# Average val loss after 25 iteration = 0.0277
# Total val chrF after 25 iteration = 80.8392
# Average test loss after 25 iteration = 0.0249
# Total test chrF after 25 iteration = 80.6460
# Dumping after  25
# Time for the iteration 10.4 seconds
#
#
# Average train loss after 26 iteration = 0.0109
# Total train chrF after 26 iteration = 89.1599
# Average val loss after 26 iteration = 0.0272
# Total val chrF after 26 iteration = 80.9849
# Average test loss after 26 iteration = 0.0244
# Total test chrF after 26 iteration = 80.8143
# Dumping after  26
# Time for the iteration 10.4 seconds
#
#
# Average train loss after 27 iteration = 0.0102
# Total train chrF after 27 iteration = 89.3794
# Average val loss after 27 iteration = 0.0268
# Total val chrF after 27 iteration = 81.0665
# Average test loss after 27 iteration = 0.0240
# Total test chrF after 27 iteration = 80.9606
# Dumping after  27
# Time for the iteration 10.4 seconds
#
#
# Average train loss after 28 iteration = 0.0097
# Total train chrF after 28 iteration = 89.5701
# Average val loss after 28 iteration = 0.0264
# Total val chrF after 28 iteration = 81.1744
# Average test loss after 28 iteration = 0.0236
# Total test chrF after 28 iteration = 81.1560
# Dumping after  28
# Time for the iteration 10.4 seconds
#
#
# Average train loss after 29 iteration = 0.0091
# Total train chrF after 29 iteration = 89.7339
# Average val loss after 29 iteration = 0.0261
# Total val chrF after 29 iteration = 81.3225
# Average test loss after 29 iteration = 0.0232
# Total test chrF after 29 iteration = 81.2612
# Dumping after  29
# Time for the iteration 10.4 seconds
#
#
# Average train loss after 30 iteration = 0.0086
# Total train chrF after 30 iteration = 89.8796
# Average val loss after 30 iteration = 0.0258
# Total val chrF after 30 iteration = 81.3731
# Average test loss after 30 iteration = 0.0229
# Total test chrF after 30 iteration = 81.3705
# Dumping after  30
# Time for the iteration 10.5 seconds
#
#
# Average train loss after 31 iteration = 0.0082
# Total train chrF after 31 iteration = 90.0198
# Average val loss after 31 iteration = 0.0255
# Total val chrF after 31 iteration = 81.4762
# Average test loss after 31 iteration = 0.0226
# Total test chrF after 31 iteration = 81.5633
# Dumping after  31
# Time for the iteration 10.4 seconds
#
#
# Average train loss after 32 iteration = 0.0078
# Total train chrF after 32 iteration = 90.1452
# Average val loss after 32 iteration = 0.0252
# Total val chrF after 32 iteration = 81.6590
# Average test loss after 32 iteration = 0.0224
# Total test chrF after 32 iteration = 81.5615
# Dumping after  32
# Time for the iteration 10.4 seconds
#
#
# Average train loss after 33 iteration = 0.0074
# Total train chrF after 33 iteration = 90.2583
# Average val loss after 33 iteration = 0.0250
# Total val chrF after 33 iteration = 81.7443
# Average test loss after 33 iteration = 0.0222
# Total test chrF after 33 iteration = 81.6976
# Dumping after  33
# Time for the iteration 10.3 seconds
#
#
# Average train loss after 34 iteration = 0.0070
# Total train chrF after 34 iteration = 90.3586
# Average val loss after 34 iteration = 0.0248
# Total val chrF after 34 iteration = 81.7875
# Average test loss after 34 iteration = 0.0220
# Total test chrF after 34 iteration = 81.8666
# Dumping after  34
# Time for the iteration 10.3 seconds
#
#
# Average train loss after 35 iteration = 0.0067
# Total train chrF after 35 iteration = 90.4540
# Average val loss after 35 iteration = 0.0247
# Total val chrF after 35 iteration = 81.7448
# Average test loss after 35 iteration = 0.0218
# Total test chrF after 35 iteration = 81.8811
# Time for the iteration 10.3 seconds
#
#
# Average train loss after 36 iteration = 0.0063
# Total train chrF after 36 iteration = 90.5344
# Average val loss after 36 iteration = 0.0245
# Total val chrF after 36 iteration = 81.6977
# Average test loss after 36 iteration = 0.0217
# Total test chrF after 36 iteration = 81.9165
# Time for the iteration 10.3 seconds
#
#
# Average train loss after 37 iteration = 0.0060
# Total train chrF after 37 iteration = 90.6198
# Average val loss after 37 iteration = 0.0244
# Total val chrF after 37 iteration = 81.7484
# Average test loss after 37 iteration = 0.0215
# Total test chrF after 37 iteration = 81.9657
# Time for the iteration 10.2 seconds
#
#
# Average train loss after 38 iteration = 0.0058
# Total train chrF after 38 iteration = 90.6981
# Average val loss after 38 iteration = 0.0243
# Total val chrF after 38 iteration = 81.8108
# Average test loss after 38 iteration = 0.0214
# Total test chrF after 38 iteration = 82.0069
# Dumping after  38
# Time for the iteration 10.3 seconds
#
#
# Average train loss after 39 iteration = 0.0055
# Total train chrF after 39 iteration = 90.7562
# Average val loss after 39 iteration = 0.0242
# Total val chrF after 39 iteration = 81.9022
# Average test loss after 39 iteration = 0.0213
# Total test chrF after 39 iteration = 82.0644
# Dumping after  39
# Time for the iteration 10.5 seconds
#
#
# Average train loss after 40 iteration = 0.0052
# Total train chrF after 40 iteration = 90.8250
# Average val loss after 40 iteration = 0.0241
# Total val chrF after 40 iteration = 81.9745
# Average test loss after 40 iteration = 0.0212
# Total test chrF after 40 iteration = 82.0973
# Dumping after  40
# Time for the iteration 10.4 seconds
#
#
# Average train loss after 41 iteration = 0.0050
# Total train chrF after 41 iteration = 90.8962
# Average val loss after 41 iteration = 0.0240
# Total val chrF after 41 iteration = 81.9843
# Average test loss after 41 iteration = 0.0211
# Total test chrF after 41 iteration = 82.1817
# Dumping after  41
# Time for the iteration 10.4 seconds
#
#
# Average train loss after 42 iteration = 0.0048
# Total train chrF after 42 iteration = 90.9506
# Average val loss after 42 iteration = 0.0239
# Total val chrF after 42 iteration = 82.0108
# Average test loss after 42 iteration = 0.0210
# Total test chrF after 42 iteration = 82.2219
# Dumping after  42
# Time for the iteration 10.5 seconds
#
#
# Average train loss after 43 iteration = 0.0045
# Total train chrF after 43 iteration = 90.9985
# Average val loss after 43 iteration = 0.0239
# Total val chrF after 43 iteration = 82.0787
# Average test loss after 43 iteration = 0.0210
# Total test chrF after 43 iteration = 82.2554
# Dumping after  43
# Time for the iteration 10.2 seconds
#
#
# Average train loss after 44 iteration = 0.0043
# Total train chrF after 44 iteration = 91.0410
# Average val loss after 44 iteration = 0.0238
# Total val chrF after 44 iteration = 82.0928
# Average test loss after 44 iteration = 0.0209
# Total test chrF after 44 iteration = 82.3683
# Dumping after  44
# Time for the iteration 10.3 seconds
#
#
# Average train loss after 45 iteration = 0.0041
# Total train chrF after 45 iteration = 91.0898
# Average val loss after 45 iteration = 0.0238
# Total val chrF after 45 iteration = 82.1689
# Average test loss after 45 iteration = 0.0209
# Total test chrF after 45 iteration = 82.4213
# Dumping after  45
# Time for the iteration 10.4 seconds
#
#
# Average train loss after 46 iteration = 0.0040
# Total train chrF after 46 iteration = 91.1291
# Average val loss after 46 iteration = 0.0238
# Total val chrF after 46 iteration = 82.1926
# Average test loss after 46 iteration = 0.0209
# Total test chrF after 46 iteration = 82.4871
# Dumping after  46
# Time for the iteration 10.4 seconds
#
#
# Average train loss after 47 iteration = 0.0038
# Total train chrF after 47 iteration = 91.1643
# Average val loss after 47 iteration = 0.0237
# Total val chrF after 47 iteration = 82.2597
# Average test loss after 47 iteration = 0.0208
# Total test chrF after 47 iteration = 82.5080
# Dumping after  47
# Time for the iteration 10.4 seconds
#
#
# Average train loss after 48 iteration = 0.0036
# Total train chrF after 48 iteration = 91.1980
# Average val loss after 48 iteration = 0.0237
# Total val chrF after 48 iteration = 82.3190
# Average test loss after 48 iteration = 0.0208
# Total test chrF after 48 iteration = 82.5105
# Dumping after  48
# Time for the iteration 10.5 seconds
#
#
# Average train loss after 49 iteration = 0.0035
# Total train chrF after 49 iteration = 91.2355
# Average val loss after 49 iteration = 0.0237
# Total val chrF after 49 iteration = 82.3089
# Average test loss after 49 iteration = 0.0208
# Total test chrF after 49 iteration = 82.5242
# Time for the iteration 10.4 seconds
#
#
# Average train loss after 50 iteration = 0.0033
# Total train chrF after 50 iteration = 91.2728
# Average val loss after 50 iteration = 0.0237
# Total val chrF after 50 iteration = 82.2349
# Average test loss after 50 iteration = 0.0208
# Total test chrF after 50 iteration = 82.6367
# Time for the iteration 10.3 seconds
#
#
# Average train loss after 51 iteration = 0.0032
# Total train chrF after 51 iteration = 91.3033
# Average val loss after 51 iteration = 0.0238
# Total val chrF after 51 iteration = 82.2550
# Average test loss after 51 iteration = 0.0208
# Total test chrF after 51 iteration = 82.6683
# Time for the iteration 10.5 seconds
#
#
# Average train loss after 52 iteration = 0.0030
# Total train chrF after 52 iteration = 91.3221
# Average val loss after 52 iteration = 0.0238
# Total val chrF after 52 iteration = 82.3120
# Average test loss after 52 iteration = 0.0208
# Total test chrF after 52 iteration = 82.6791
# Time for the iteration 10.4 seconds
#
#
# Average train loss after 53 iteration = 0.0029
# Total train chrF after 53 iteration = 91.3500
# Average val loss after 53 iteration = 0.0238
# Total val chrF after 53 iteration = 82.3877
# Average test loss after 53 iteration = 0.0208
# Total test chrF after 53 iteration = 82.7044
# Dumping after  53
# Time for the iteration 10.4 seconds
#
#
# Average train loss after 54 iteration = 0.0028
# Total train chrF after 54 iteration = 91.3776
# Average val loss after 54 iteration = 0.0238
# Total val chrF after 54 iteration = 82.3875
# Average test loss after 54 iteration = 0.0208
# Total test chrF after 54 iteration = 82.7134
# Time for the iteration 10.5 seconds
#
#
# Average train loss after 55 iteration = 0.0027
# Total train chrF after 55 iteration = 91.3995
# Average val loss after 55 iteration = 0.0239
# Total val chrF after 55 iteration = 82.3730
# Average test loss after 55 iteration = 0.0208
# Total test chrF after 55 iteration = 82.7338
# Time for the iteration 10.4 seconds
#
#
# Average train loss after 56 iteration = 0.0025
# Total train chrF after 56 iteration = 91.4197
# Average val loss after 56 iteration = 0.0239
# Total val chrF after 56 iteration = 82.3479
# Average test loss after 56 iteration = 0.0209
# Total test chrF after 56 iteration = 82.7328
# Time for the iteration 10.4 seconds
#
#
# Average train loss after 57 iteration = 0.0024
# Total train chrF after 57 iteration = 91.4374
# Average val loss after 57 iteration = 0.0239
# Total val chrF after 57 iteration = 82.4012
# Average test loss after 57 iteration = 0.0209
# Total test chrF after 57 iteration = 82.8120
# Dumping after  57
# Time for the iteration 10.4 seconds
#
#
# Average train loss after 58 iteration = 0.0023
# Total train chrF after 58 iteration = 91.4576
# Average val loss after 58 iteration = 0.0240
# Total val chrF after 58 iteration = 82.3797
# Average test loss after 58 iteration = 0.0209
# Total test chrF after 58 iteration = 82.8187
# Time for the iteration 10.4 seconds
#
#
# Average train loss after 59 iteration = 0.0022
# Total train chrF after 59 iteration = 91.4758
# Average val loss after 59 iteration = 0.0240
# Total val chrF after 59 iteration = 82.3529
# Average test loss after 59 iteration = 0.0210
# Total test chrF after 59 iteration = 82.8157
# Time for the iteration 10.3 seconds
#
#
# Average train loss after 60 iteration = 0.0021
# Total train chrF after 60 iteration = 91.4911
# Average val loss after 60 iteration = 0.0241
# Total val chrF after 60 iteration = 82.2782
# Average test loss after 60 iteration = 0.0210
# Total test chrF after 60 iteration = 82.8253
# Time for the iteration 10.3 seconds
#
#
# Average train loss after 61 iteration = 0.0020
# Total train chrF after 61 iteration = 91.5060
# Average val loss after 61 iteration = 0.0242
# Total val chrF after 61 iteration = 82.3272
# Average test loss after 61 iteration = 0.0210
# Total test chrF after 61 iteration = 82.7857
# Time for the iteration 10.4 seconds
#
#
# Average train loss after 62 iteration = 0.0020
# Total train chrF after 62 iteration = 91.5196
# Average val loss after 62 iteration = 0.0242
# Total val chrF after 62 iteration = 82.3568
# Average test loss after 62 iteration = 0.0211
# Total test chrF after 62 iteration = 82.8081
# Time for the iteration 10.3 seconds
#
#
# Average train loss after 63 iteration = 0.0019
# Total train chrF after 63 iteration = 91.5319
# Average val loss after 63 iteration = 0.0243
# Total val chrF after 63 iteration = 82.4199
# Average test loss after 63 iteration = 0.0211
# Total test chrF after 63 iteration = 82.7778
# Dumping after  63
# Time for the iteration 10.3 seconds
#
#
# Average train loss after 64 iteration = 0.0018
# Total train chrF after 64 iteration = 91.5448
# Average val loss after 64 iteration = 0.0244
# Total val chrF after 64 iteration = 82.4805
# Average test loss after 64 iteration = 0.0212
# Total test chrF after 64 iteration = 82.7720
# Dumping after  64
# Time for the iteration 10.4 seconds
#
#
# Average train loss after 65 iteration = 0.0017
# Total train chrF after 65 iteration = 91.5556
# Average val loss after 65 iteration = 0.0245
# Total val chrF after 65 iteration = 82.5053
# Average test loss after 65 iteration = 0.0213
# Total test chrF after 65 iteration = 82.8338
# Dumping after  65
# Time for the iteration 10.5 seconds
#
#
# Average train loss after 66 iteration = 0.0016
# Total train chrF after 66 iteration = 91.5653
# Average val loss after 66 iteration = 0.0245
# Total val chrF after 66 iteration = 82.4438
# Average test loss after 66 iteration = 0.0213
# Total test chrF after 66 iteration = 82.8350
# Time for the iteration 10.5 seconds
#
#
# Average train loss after 67 iteration = 0.0016
# Total train chrF after 67 iteration = 91.5741
# Average val loss after 67 iteration = 0.0246
# Total val chrF after 67 iteration = 82.5051
# Average test loss after 67 iteration = 0.0214
# Total test chrF after 67 iteration = 82.9328
# Time for the iteration 10.5 seconds
#
#
# Average train loss after 68 iteration = 0.0015
# Total train chrF after 68 iteration = 91.5795
# Average val loss after 68 iteration = 0.0247
# Total val chrF after 68 iteration = 82.4513
# Average test loss after 68 iteration = 0.0214
# Total test chrF after 68 iteration = 82.9517
# Time for the iteration 10.4 seconds
#
#
# Average train loss after 69 iteration = 0.0014
# Total train chrF after 69 iteration = 91.5868
# Average val loss after 69 iteration = 0.0248
# Total val chrF after 69 iteration = 82.4199
# Average test loss after 69 iteration = 0.0215
# Total test chrF after 69 iteration = 82.9365
# Time for the iteration 10.5 seconds
#
#
# Average train loss after 70 iteration = 0.0014
# Total train chrF after 70 iteration = 91.5929
# Average val loss after 70 iteration = 0.0249
# Total val chrF after 70 iteration = 82.4547
# Average test loss after 70 iteration = 0.0216
# Total test chrF after 70 iteration = 82.9260
# Time for the iteration 10.4 seconds
#
#
# Average train loss after 71 iteration = 0.0013
# Total train chrF after 71 iteration = 91.6024
# Average val loss after 71 iteration = 0.0250
# Total val chrF after 71 iteration = 82.4538
# Average test loss after 71 iteration = 0.0216
# Total test chrF after 71 iteration = 82.9597
# Time for the iteration 10.5 seconds
#
#
# Average train loss after 72 iteration = 0.0013
# Total train chrF after 72 iteration = 91.6094
# Average val loss after 72 iteration = 0.0251
# Total val chrF after 72 iteration = 82.4402
# Average test loss after 72 iteration = 0.0217
# Total test chrF after 72 iteration = 82.9072
# Time for the iteration 10.5 seconds
#
#
# Average train loss after 73 iteration = 0.0012
# Total train chrF after 73 iteration = 91.6165
# Average val loss after 73 iteration = 0.0252
# Total val chrF after 73 iteration = 82.4430
# Average test loss after 73 iteration = 0.0218
# Total test chrF after 73 iteration = 82.9475
# Time for the iteration 10.4 seconds
#
#
# Average train loss after 74 iteration = 0.0012
# Total train chrF after 74 iteration = 91.6200
# Average val loss after 74 iteration = 0.0253
# Total val chrF after 74 iteration = 82.4497
# Average test loss after 74 iteration = 0.0219
# Total test chrF after 74 iteration = 82.8814
# Time for the iteration 10.4 seconds
#
#
# Average train loss after 75 iteration = 0.0011
# Total train chrF after 75 iteration = 91.6248
# Average val loss after 75 iteration = 0.0254
# Total val chrF after 75 iteration = 82.4702
# Average test loss after 75 iteration = 0.0219
# Total test chrF after 75 iteration = 82.8681
# Time for the iteration 10.5 seconds
#
#
# Average train loss after 76 iteration = 0.0011
# Total train chrF after 76 iteration = 91.6304
# Average val loss after 76 iteration = 0.0255
# Total val chrF after 76 iteration = 82.4429
# Average test loss after 76 iteration = 0.0220
# Total test chrF after 76 iteration = 82.9588
# Time for the iteration 10.4 seconds
#
#
# Average train loss after 77 iteration = 0.0010
# Total train chrF after 77 iteration = 91.6343
# Average val loss after 77 iteration = 0.0256
# Total val chrF after 77 iteration = 82.4690
# Average test loss after 77 iteration = 0.0221
# Total test chrF after 77 iteration = 82.9546
# Time for the iteration 10.4 seconds
#
#
# Average train loss after 78 iteration = 0.0010
# Total train chrF after 78 iteration = 91.6371
# Average val loss after 78 iteration = 0.0257
# Total val chrF after 78 iteration = 82.4471
# Average test loss after 78 iteration = 0.0222
# Total test chrF after 78 iteration = 82.9460
# Time for the iteration 10.3 seconds
#
#
# Average train loss after 79 iteration = 0.0009
# Total train chrF after 79 iteration = 91.6407
# Average val loss after 79 iteration = 0.0259
# Total val chrF after 79 iteration = 82.4455
# Average test loss after 79 iteration = 0.0223
# Total test chrF after 79 iteration = 82.9695
# Time for the iteration 10.2 seconds
#
#
# Average train loss after 80 iteration = 0.0009
# Total train chrF after 80 iteration = 91.6439
# Average val loss after 80 iteration = 0.0260
# Total val chrF after 80 iteration = 82.4734
# Average test loss after 80 iteration = 0.0224
# Total test chrF after 80 iteration = 83.0369
# Time for the iteration 10.3 seconds
#
#
# Average train loss after 81 iteration = 0.0008
# Total train chrF after 81 iteration = 91.6454
# Average val loss after 81 iteration = 0.0261
# Total val chrF after 81 iteration = 82.4308
# Average test loss after 81 iteration = 0.0225
# Total test chrF after 81 iteration = 83.0365
# Time for the iteration 10.4 seconds
#
#
# Average train loss after 82 iteration = 0.0008
# Total train chrF after 82 iteration = 91.6475
# Average val loss after 82 iteration = 0.0262
# Total val chrF after 82 iteration = 82.3841
# Average test loss after 82 iteration = 0.0225
# Total test chrF after 82 iteration = 83.0258
# Time for the iteration 10.3 seconds
#
#
# Average train loss after 83 iteration = 0.0008
# Total train chrF after 83 iteration = 91.6503
# Average val loss after 83 iteration = 0.0263
# Total val chrF after 83 iteration = 82.3788
# Average test loss after 83 iteration = 0.0226
# Total test chrF after 83 iteration = 82.9873
# Time for the iteration 10.3 seconds
#
#
# Average train loss after 84 iteration = 0.0007
# Total train chrF after 84 iteration = 91.6528
# Average val loss after 84 iteration = 0.0264
# Total val chrF after 84 iteration = 82.2559
# Average test loss after 84 iteration = 0.0227
# Total test chrF after 84 iteration = 83.0164
# Time for the iteration 10.4 seconds
#
#
# Average train loss after 85 iteration = 0.0007
# Total train chrF after 85 iteration = 91.6555
# Average val loss after 85 iteration = 0.0266
# Total val chrF after 85 iteration = 82.3086
# Average test loss after 85 iteration = 0.0228
# Total test chrF after 85 iteration = 83.0291
# Time for the iteration 10.3 seconds
#
#
# Average train loss after 86 iteration = 0.0007
# Total train chrF after 86 iteration = 91.6574
# Average val loss after 86 iteration = 0.0267
# Total val chrF after 86 iteration = 82.3479
# Average test loss after 86 iteration = 0.0230
# Total test chrF after 86 iteration = 83.0264
# Time for the iteration 10.3 seconds
#
#
# Average train loss after 87 iteration = 0.0006
# Total train chrF after 87 iteration = 91.6596
# Average val loss after 87 iteration = 0.0268
# Total val chrF after 87 iteration = 82.3305
# Average test loss after 87 iteration = 0.0231
# Total test chrF after 87 iteration = 83.0257
# Time for the iteration 10.4 seconds
#
#
# Average train loss after 88 iteration = 0.0006
# Total train chrF after 88 iteration = 91.6615
# Average val loss after 88 iteration = 0.0269
# Total val chrF after 88 iteration = 82.3620
# Average test loss after 88 iteration = 0.0232
# Total test chrF after 88 iteration = 83.0165
# Time for the iteration 10.4 seconds
#
#
# Average train loss after 89 iteration = 0.0006
# Total train chrF after 89 iteration = 91.6629
# Average val loss after 89 iteration = 0.0271
# Total val chrF after 89 iteration = 82.3383
# Average test loss after 89 iteration = 0.0233
# Total test chrF after 89 iteration = 83.0050
# Time for the iteration 10.3 seconds
#
#
# Average train loss after 90 iteration = 0.0006
# Total train chrF after 90 iteration = 91.6642
# Average val loss after 90 iteration = 0.0272
# Total val chrF after 90 iteration = 82.2602
# Average test loss after 90 iteration = 0.0234
# Total test chrF after 90 iteration = 83.0285
# Time for the iteration 10.4 seconds
#
#
# Average train loss after 91 iteration = 0.0005
# Total train chrF after 91 iteration = 91.6653
# Average val loss after 91 iteration = 0.0273
# Total val chrF after 91 iteration = 82.2753
# Average test loss after 91 iteration = 0.0235
# Total test chrF after 91 iteration = 83.0232
# Time for the iteration 10.3 seconds
#
#
# Average train loss after 92 iteration = 0.0005
# Total train chrF after 92 iteration = 91.6662
# Average val loss after 92 iteration = 0.0274
# Total val chrF after 92 iteration = 82.2037
# Average test loss after 92 iteration = 0.0236
# Total test chrF after 92 iteration = 83.0145
# Time for the iteration 10.3 seconds
#
#
#
#
# Aborting since there hasn't been much progress
# <Figure size 640x480 with 1 Axes>
# <Figure size 640x480 with 1 Axes>

# %%
language = "ash"
task_name = "keyprox"
vocab_size = 4999
num_epochs = 100
batch_size = 32
model = "50_1"
optimizer = "Adam"
metric = "chrF"

# %%
from IPython.display import Image

Image("curves/{}_{}_{}_{}_{}_loss.png".format(language, task_name, vocab_size, num_epochs, batch_size))

# %%
Image("curves/{}_{}_{}_{}_{}_{}.png".format(language, task_name, vocab_size, num_epochs, batch_size, metric))

# %%
print("{}.{}.{}.{}.{}.{}.{}".format(language, task_name, vocab_size, num_epochs, batch_size, model, optimizer))
# Out:
# ash.keyprox.4999.100.32.50_1.Adam
