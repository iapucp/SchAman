# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
# %cd "drive/MyDrive/Tesis/scRNN"
# Out:
# /content/drive/MyDrive/Tesis/scRNN

# %%
import torch

torch.cuda.is_available()
# Out:
# True

# %%
# !pip install sacrebleu
# Out:
# Collecting sacrebleu
#   Downloading sacrebleu-2.0.0-py3-none-any.whl (90 kB)
#      |████████████████████████████████| 90 kB 6.9 MB/s
# Requirement already satisfied: tabulate>=0.8.9 in /usr/local/lib/python3.7/dist-packages (from sacrebleu) (0.8.9)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from sacrebleu) (1.19.5)
# Requirement already satisfied: regex in /usr/local/lib/python3.7/dist-packages (from sacrebleu) (2019.12.20)
# Collecting portalocker
#   Downloading portalocker-2.3.2-py2.py3-none-any.whl (15 kB)
# Collecting colorama
#   Downloading colorama-0.4.4-py2.py3-none-any.whl (16 kB)
# Installing collected packages: portalocker, colorama, sacrebleu
# Successfully installed colorama-0.4.4 portalocker-2.3.2 sacrebleu-2.0.0

# %%
# !python3 train.py --language ya --task-name sylsim_teacher_general --num-epochs 100 --batch-size 32 --vocab-size 4999 --new-vocab --train --train-sentences-errors-file ya.sylsim_teacher_general.train.sentences.errors.txt --train-sentences-file ya.sylsim_teacher_general.train.sentences.txt --val-sentences-errors-file ya.teacher_general.val.sentences.errors.txt --val-sentences-file ya.teacher_general.val.sentences.txt --test-sentences-errors-file ya.teacher_general.test.sentences.errors.txt --test-sentences-file ya.teacher_general.test.sentences.txt --metric chrF --save
# Out:
# Parameters
# {'language': 'ya', 'task_name': 'sylsim_teacher_general', 'vocab_size': 4999, 'num_epochs': 100, 'batch_size': 32, 'model_name': 'shi_random_20531_100_32', 'new_vocab': True, 'need_to_train': True, 'train_sentences_errors_file': 'ya.sylsim_teacher_general.train.sentences.errors.txt', 'train_sentences_file': 'ya.sylsim_teacher_general.train.sentences.txt', 'val_sentences_errors_file': 'ya.teacher_general.val.sentences.errors.txt', 'val_sentences_file': 'ya.teacher_general.val.sentences.txt', 'test_sentences_errors_file': 'ya.teacher_general.test.sentences.errors.txt', 'test_sentences_file': 'ya.teacher_general.test.sentences.txt', 'metric': 'chrF', 'save_model': True}
#
#
# Creating new vocabulary
# Len of w2i:  4999
# Len of i2w:  4999
# Len of char vocab:  32
#
#
# Initializing an only ScRNN model
#
#
# Training the model...
#
# Average train loss after 1 iteration = 0.1744
# Total train chrF after 1 iteration = 68.3859
# Average val loss after 1 iteration = 0.2283
# Total val chrF after 1 iteration = 70.6021
# Average test loss after 1 iteration = 0.2278
# Total test chrF after 1 iteration = 71.1796
# Dumping after  1
# Time for the iteration 10.7 seconds
#
#
# Average train loss after 2 iteration = 0.1407
# Total train chrF after 2 iteration = 66.3043
# Average val loss after 2 iteration = 0.1337
# Total val chrF after 2 iteration = 70.6070
# Average test loss after 2 iteration = 0.1323
# Total test chrF after 2 iteration = 71.1942
# Dumping after  2
# Time for the iteration 10.3 seconds
#
#
# Average train loss after 3 iteration = 0.1109
# Total train chrF after 3 iteration = 69.1657
# Average val loss after 3 iteration = 0.1048
# Total val chrF after 3 iteration = 70.8813
# Average test loss after 3 iteration = 0.1038
# Total test chrF after 3 iteration = 71.7157
# Dumping after  3
# Time for the iteration 10.4 seconds
#
#
# Average train loss after 4 iteration = 0.0891
# Total train chrF after 4 iteration = 71.5424
# Average val loss after 4 iteration = 0.0878
# Total val chrF after 4 iteration = 71.1505
# Average test loss after 4 iteration = 0.0871
# Total test chrF after 4 iteration = 71.7813
# Dumping after  4
# Time for the iteration 10.5 seconds
#
#
# Average train loss after 5 iteration = 0.0727
# Total train chrF after 5 iteration = 73.3180
# Average val loss after 5 iteration = 0.0749
# Total val chrF after 5 iteration = 71.3371
# Average test loss after 5 iteration = 0.0744
# Total test chrF after 5 iteration = 71.8946
# Dumping after  5
# Time for the iteration 10.4 seconds
#
#
# Average train loss after 6 iteration = 0.0601
# Total train chrF after 6 iteration = 74.9259
# Average val loss after 6 iteration = 0.0648
# Total val chrF after 6 iteration = 71.6581
# Average test loss after 6 iteration = 0.0643
# Total test chrF after 6 iteration = 72.0874
# Dumping after  6
# Time for the iteration 10.5 seconds
#
#
# Average train loss after 7 iteration = 0.0505
# Total train chrF after 7 iteration = 76.2424
# Average val loss after 7 iteration = 0.0572
# Total val chrF after 7 iteration = 71.8989
# Average test loss after 7 iteration = 0.0568
# Total test chrF after 7 iteration = 72.5092
# Dumping after  7
# Time for the iteration 10.6 seconds
#
#
# Average train loss after 8 iteration = 0.0429
# Total train chrF after 8 iteration = 77.3865
# Average val loss after 8 iteration = 0.0512
# Total val chrF after 8 iteration = 72.0154
# Average test loss after 8 iteration = 0.0509
# Total test chrF after 8 iteration = 72.7682
# Dumping after  8
# Time for the iteration 10.4 seconds
#
#
# Average train loss after 9 iteration = 0.0369
# Total train chrF after 9 iteration = 78.4671
# Average val loss after 9 iteration = 0.0463
# Total val chrF after 9 iteration = 72.1236
# Average test loss after 9 iteration = 0.0462
# Total test chrF after 9 iteration = 72.9651
# Dumping after  9
# Time for the iteration 10.4 seconds
#
#
# Average train loss after 10 iteration = 0.0320
# Total train chrF after 10 iteration = 79.4345
# Average val loss after 10 iteration = 0.0425
# Total val chrF after 10 iteration = 72.3661
# Average test loss after 10 iteration = 0.0425
# Total test chrF after 10 iteration = 73.1514
# Dumping after  10
# Time for the iteration 10.6 seconds
#
#
# Average train loss after 11 iteration = 0.0281
# Total train chrF after 11 iteration = 80.3385
# Average val loss after 11 iteration = 0.0394
# Total val chrF after 11 iteration = 72.4796
# Average test loss after 11 iteration = 0.0395
# Total test chrF after 11 iteration = 73.4135
# Dumping after  11
# Time for the iteration 10.4 seconds
#
#
# Average train loss after 12 iteration = 0.0248
# Total train chrF after 12 iteration = 81.1866
# Average val loss after 12 iteration = 0.0369
# Total val chrF after 12 iteration = 72.7532
# Average test loss after 12 iteration = 0.0370
# Total test chrF after 12 iteration = 73.4549
# Dumping after  12
# Time for the iteration 10.5 seconds
#
#
# Average train loss after 13 iteration = 0.0222
# Total train chrF after 13 iteration = 81.9874
# Average val loss after 13 iteration = 0.0348
# Total val chrF after 13 iteration = 73.0089
# Average test loss after 13 iteration = 0.0350
# Total test chrF after 13 iteration = 73.6245
# Dumping after  13
# Time for the iteration 10.5 seconds
#
#
# Average train loss after 14 iteration = 0.0200
# Total train chrF after 14 iteration = 82.7641
# Average val loss after 14 iteration = 0.0332
# Total val chrF after 14 iteration = 73.1824
# Average test loss after 14 iteration = 0.0335
# Total test chrF after 14 iteration = 73.6379
# Dumping after  14
# Time for the iteration 10.5 seconds
#
#
# Average train loss after 15 iteration = 0.0181
# Total train chrF after 15 iteration = 83.4714
# Average val loss after 15 iteration = 0.0319
# Total val chrF after 15 iteration = 73.3275
# Average test loss after 15 iteration = 0.0323
# Total test chrF after 15 iteration = 73.7218
# Dumping after  15
# Time for the iteration 10.6 seconds
#
#
# Average train loss after 16 iteration = 0.0166
# Total train chrF after 16 iteration = 84.0850
# Average val loss after 16 iteration = 0.0309
# Total val chrF after 16 iteration = 73.4094
# Average test loss after 16 iteration = 0.0313
# Total test chrF after 16 iteration = 73.8638
# Dumping after  16
# Time for the iteration 10.5 seconds
#
#
# Average train loss after 17 iteration = 0.0153
# Total train chrF after 17 iteration = 84.6391
# Average val loss after 17 iteration = 0.0301
# Total val chrF after 17 iteration = 73.4796
# Average test loss after 17 iteration = 0.0305
# Total test chrF after 17 iteration = 73.9937
# Dumping after  17
# Time for the iteration 10.6 seconds
#
#
# Average train loss after 18 iteration = 0.0141
# Total train chrF after 18 iteration = 85.1607
# Average val loss after 18 iteration = 0.0294
# Total val chrF after 18 iteration = 73.5375
# Average test loss after 18 iteration = 0.0298
# Total test chrF after 18 iteration = 74.0473
# Dumping after  18
# Time for the iteration 10.5 seconds
#
#
# Average train loss after 19 iteration = 0.0131
# Total train chrF after 19 iteration = 85.5896
# Average val loss after 19 iteration = 0.0288
# Total val chrF after 19 iteration = 73.7457
# Average test loss after 19 iteration = 0.0293
# Total test chrF after 19 iteration = 74.2615
# Dumping after  19
# Time for the iteration 10.5 seconds
#
#
# Average train loss after 20 iteration = 0.0123
# Total train chrF after 20 iteration = 85.9509
# Average val loss after 20 iteration = 0.0283
# Total val chrF after 20 iteration = 73.7730
# Average test loss after 20 iteration = 0.0288
# Total test chrF after 20 iteration = 74.3572
# Dumping after  20
# Time for the iteration 10.5 seconds
#
#
# Average train loss after 21 iteration = 0.0115
# Total train chrF after 21 iteration = 86.2708
# Average val loss after 21 iteration = 0.0279
# Total val chrF after 21 iteration = 73.9143
# Average test loss after 21 iteration = 0.0285
# Total test chrF after 21 iteration = 74.4680
# Dumping after  21
# Time for the iteration 10.5 seconds
#
#
# Average train loss after 22 iteration = 0.0108
# Total train chrF after 22 iteration = 86.5768
# Average val loss after 22 iteration = 0.0276
# Total val chrF after 22 iteration = 73.9308
# Average test loss after 22 iteration = 0.0282
# Total test chrF after 22 iteration = 74.6235
# Dumping after  22
# Time for the iteration 10.6 seconds
#
#
# Average train loss after 23 iteration = 0.0101
# Total train chrF after 23 iteration = 86.8256
# Average val loss after 23 iteration = 0.0273
# Total val chrF after 23 iteration = 73.9679
# Average test loss after 23 iteration = 0.0279
# Total test chrF after 23 iteration = 74.7069
# Dumping after  23
# Time for the iteration 10.5 seconds
#
#
# Average train loss after 24 iteration = 0.0095
# Total train chrF after 24 iteration = 87.0649
# Average val loss after 24 iteration = 0.0271
# Total val chrF after 24 iteration = 74.0004
# Average test loss after 24 iteration = 0.0277
# Total test chrF after 24 iteration = 74.7617
# Dumping after  24
# Time for the iteration 10.5 seconds
#
#
# Average train loss after 25 iteration = 0.0090
# Total train chrF after 25 iteration = 87.2797
# Average val loss after 25 iteration = 0.0268
# Total val chrF after 25 iteration = 73.9792
# Average test loss after 25 iteration = 0.0275
# Total test chrF after 25 iteration = 74.7656
# Time for the iteration 10.5 seconds
#
#
# Average train loss after 26 iteration = 0.0085
# Total train chrF after 26 iteration = 87.5001
# Average val loss after 26 iteration = 0.0266
# Total val chrF after 26 iteration = 74.0478
# Average test loss after 26 iteration = 0.0273
# Total test chrF after 26 iteration = 74.8445
# Dumping after  26
# Time for the iteration 10.5 seconds
#
#
# Average train loss after 27 iteration = 0.0080
# Total train chrF after 27 iteration = 87.6704
# Average val loss after 27 iteration = 0.0265
# Total val chrF after 27 iteration = 74.1135
# Average test loss after 27 iteration = 0.0271
# Total test chrF after 27 iteration = 74.8597
# Dumping after  27
# Time for the iteration 10.6 seconds
#
#
# Average train loss after 28 iteration = 0.0076
# Total train chrF after 28 iteration = 87.8293
# Average val loss after 28 iteration = 0.0263
# Total val chrF after 28 iteration = 74.1726
# Average test loss after 28 iteration = 0.0270
# Total test chrF after 28 iteration = 74.8758
# Dumping after  28
# Time for the iteration 10.6 seconds
#
#
# Average train loss after 29 iteration = 0.0072
# Total train chrF after 29 iteration = 87.9738
# Average val loss after 29 iteration = 0.0262
# Total val chrF after 29 iteration = 74.1745
# Average test loss after 29 iteration = 0.0269
# Total test chrF after 29 iteration = 74.9131
# Dumping after  29
# Time for the iteration 10.6 seconds
#
#
# Average train loss after 30 iteration = 0.0068
# Total train chrF after 30 iteration = 88.1018
# Average val loss after 30 iteration = 0.0261
# Total val chrF after 30 iteration = 74.2322
# Average test loss after 30 iteration = 0.0269
# Total test chrF after 30 iteration = 74.9853
# Dumping after  30
# Time for the iteration 10.6 seconds
#
#
# Average train loss after 31 iteration = 0.0065
# Total train chrF after 31 iteration = 88.2193
# Average val loss after 31 iteration = 0.0260
# Total val chrF after 31 iteration = 74.2653
# Average test loss after 31 iteration = 0.0268
# Total test chrF after 31 iteration = 75.0324
# Dumping after  31
# Time for the iteration 10.6 seconds
#
#
# Average train loss after 32 iteration = 0.0062
# Total train chrF after 32 iteration = 88.3305
# Average val loss after 32 iteration = 0.0259
# Total val chrF after 32 iteration = 74.3129
# Average test loss after 32 iteration = 0.0268
# Total test chrF after 32 iteration = 75.0336
# Dumping after  32
# Time for the iteration 10.6 seconds
#
#
# Average train loss after 33 iteration = 0.0058
# Total train chrF after 33 iteration = 88.4324
# Average val loss after 33 iteration = 0.0258
# Total val chrF after 33 iteration = 74.2500
# Average test loss after 33 iteration = 0.0267
# Total test chrF after 33 iteration = 75.0642
# Time for the iteration 10.5 seconds
#
#
# Average train loss after 34 iteration = 0.0056
# Total train chrF after 34 iteration = 88.5298
# Average val loss after 34 iteration = 0.0258
# Total val chrF after 34 iteration = 74.3391
# Average test loss after 34 iteration = 0.0267
# Total test chrF after 34 iteration = 75.0605
# Dumping after  34
# Time for the iteration 10.5 seconds
#
#
# Average train loss after 35 iteration = 0.0053
# Total train chrF after 35 iteration = 88.6272
# Average val loss after 35 iteration = 0.0258
# Total val chrF after 35 iteration = 74.3771
# Average test loss after 35 iteration = 0.0267
# Total test chrF after 35 iteration = 75.1474
# Dumping after  35
# Time for the iteration 10.6 seconds
#
#
# Average train loss after 36 iteration = 0.0050
# Total train chrF after 36 iteration = 88.6985
# Average val loss after 36 iteration = 0.0258
# Total val chrF after 36 iteration = 74.4155
# Average test loss after 36 iteration = 0.0268
# Total test chrF after 36 iteration = 75.1425
# Dumping after  36
# Time for the iteration 10.5 seconds
#
#
# Average train loss after 37 iteration = 0.0048
# Total train chrF after 37 iteration = 88.7729
# Average val loss after 37 iteration = 0.0257
# Total val chrF after 37 iteration = 74.5199
# Average test loss after 37 iteration = 0.0268
# Total test chrF after 37 iteration = 75.1522
# Dumping after  37
# Time for the iteration 10.6 seconds
#
#
# Average train loss after 38 iteration = 0.0046
# Total train chrF after 38 iteration = 88.8393
# Average val loss after 38 iteration = 0.0258
# Total val chrF after 38 iteration = 74.5532
# Average test loss after 38 iteration = 0.0268
# Total test chrF after 38 iteration = 75.1637
# Dumping after  38
# Time for the iteration 10.6 seconds
#
#
# Average train loss after 39 iteration = 0.0043
# Total train chrF after 39 iteration = 88.8975
# Average val loss after 39 iteration = 0.0258
# Total val chrF after 39 iteration = 74.5299
# Average test loss after 39 iteration = 0.0269
# Total test chrF after 39 iteration = 75.2213
# Time for the iteration 10.5 seconds
#
#
# Average train loss after 40 iteration = 0.0041
# Total train chrF after 40 iteration = 88.9672
# Average val loss after 40 iteration = 0.0258
# Total val chrF after 40 iteration = 74.5808
# Average test loss after 40 iteration = 0.0270
# Total test chrF after 40 iteration = 75.2394
# Dumping after  40
# Time for the iteration 10.6 seconds
#
#
# Average train loss after 41 iteration = 0.0039
# Total train chrF after 41 iteration = 89.0337
# Average val loss after 41 iteration = 0.0258
# Total val chrF after 41 iteration = 74.6506
# Average test loss after 41 iteration = 0.0270
# Total test chrF after 41 iteration = 75.2926
# Dumping after  41
# Time for the iteration 10.5 seconds
#
#
# Average train loss after 42 iteration = 0.0038
# Total train chrF after 42 iteration = 89.0809
# Average val loss after 42 iteration = 0.0259
# Total val chrF after 42 iteration = 74.6245
# Average test loss after 42 iteration = 0.0271
# Total test chrF after 42 iteration = 75.3095
# Time for the iteration 10.5 seconds
#
#
# Average train loss after 43 iteration = 0.0036
# Total train chrF after 43 iteration = 89.1376
# Average val loss after 43 iteration = 0.0260
# Total val chrF after 43 iteration = 74.6768
# Average test loss after 43 iteration = 0.0272
# Total test chrF after 43 iteration = 75.2628
# Dumping after  43
# Time for the iteration 10.6 seconds
#
#
# Average train loss after 44 iteration = 0.0034
# Total train chrF after 44 iteration = 89.1857
# Average val loss after 44 iteration = 0.0260
# Total val chrF after 44 iteration = 74.6940
# Average test loss after 44 iteration = 0.0273
# Total test chrF after 44 iteration = 75.2862
# Dumping after  44
# Time for the iteration 10.6 seconds
#
#
# Average train loss after 45 iteration = 0.0033
# Total train chrF after 45 iteration = 89.2321
# Average val loss after 45 iteration = 0.0261
# Total val chrF after 45 iteration = 74.7228
# Average test loss after 45 iteration = 0.0274
# Total test chrF after 45 iteration = 75.2908
# Dumping after  45
# Time for the iteration 10.6 seconds
#
#
# Average train loss after 46 iteration = 0.0031
# Total train chrF after 46 iteration = 89.2748
# Average val loss after 46 iteration = 0.0262
# Total val chrF after 46 iteration = 74.7861
# Average test loss after 46 iteration = 0.0275
# Total test chrF after 46 iteration = 75.2670
# Dumping after  46
# Time for the iteration 10.6 seconds
#
#
# Average train loss after 47 iteration = 0.0030
# Total train chrF after 47 iteration = 89.3072
# Average val loss after 47 iteration = 0.0263
# Total val chrF after 47 iteration = 74.8499
# Average test loss after 47 iteration = 0.0277
# Total test chrF after 47 iteration = 75.3087
# Dumping after  47
# Time for the iteration 10.5 seconds
#
#
# Average train loss after 48 iteration = 0.0028
# Total train chrF after 48 iteration = 89.3462
# Average val loss after 48 iteration = 0.0264
# Total val chrF after 48 iteration = 74.8982
# Average test loss after 48 iteration = 0.0278
# Total test chrF after 48 iteration = 75.2991
# Dumping after  48
# Time for the iteration 10.5 seconds
#
#
# Average train loss after 49 iteration = 0.0027
# Total train chrF after 49 iteration = 89.3867
# Average val loss after 49 iteration = 0.0265
# Total val chrF after 49 iteration = 74.9938
# Average test loss after 49 iteration = 0.0279
# Total test chrF after 49 iteration = 75.3171
# Dumping after  49
# Time for the iteration 10.6 seconds
#
#
# Average train loss after 50 iteration = 0.0026
# Total train chrF after 50 iteration = 89.4162
# Average val loss after 50 iteration = 0.0266
# Total val chrF after 50 iteration = 75.0015
# Average test loss after 50 iteration = 0.0281
# Total test chrF after 50 iteration = 75.2747
# Dumping after  50
# Time for the iteration 10.5 seconds
#
#
# Average train loss after 51 iteration = 0.0025
# Total train chrF after 51 iteration = 89.4481
# Average val loss after 51 iteration = 0.0268
# Total val chrF after 51 iteration = 75.0080
# Average test loss after 51 iteration = 0.0282
# Total test chrF after 51 iteration = 75.2440
# Dumping after  51
# Time for the iteration 10.5 seconds
#
#
# Average train loss after 52 iteration = 0.0023
# Total train chrF after 52 iteration = 89.4724
# Average val loss after 52 iteration = 0.0269
# Total val chrF after 52 iteration = 74.9954
# Average test loss after 52 iteration = 0.0284
# Total test chrF after 52 iteration = 75.2427
# Time for the iteration 10.6 seconds
#
#
# Average train loss after 53 iteration = 0.0022
# Total train chrF after 53 iteration = 89.5030
# Average val loss after 53 iteration = 0.0270
# Total val chrF after 53 iteration = 75.0696
# Average test loss after 53 iteration = 0.0285
# Total test chrF after 53 iteration = 75.1551
# Dumping after  53
# Time for the iteration 10.6 seconds
#
#
# Average train loss after 54 iteration = 0.0021
# Total train chrF after 54 iteration = 89.5269
# Average val loss after 54 iteration = 0.0272
# Total val chrF after 54 iteration = 75.1018
# Average test loss after 54 iteration = 0.0287
# Total test chrF after 54 iteration = 75.1962
# Dumping after  54
# Time for the iteration 10.6 seconds
#
#
# Average train loss after 55 iteration = 0.0020
# Total train chrF after 55 iteration = 89.5513
# Average val loss after 55 iteration = 0.0273
# Total val chrF after 55 iteration = 75.0565
# Average test loss after 55 iteration = 0.0289
# Total test chrF after 55 iteration = 75.1686
# Time for the iteration 10.7 seconds
#
#
# Average train loss after 56 iteration = 0.0019
# Total train chrF after 56 iteration = 89.5713
# Average val loss after 56 iteration = 0.0275
# Total val chrF after 56 iteration = 75.0665
# Average test loss after 56 iteration = 0.0290
# Total test chrF after 56 iteration = 75.1781
# Time for the iteration 10.5 seconds
#
#
# Average train loss after 57 iteration = 0.0018
# Total train chrF after 57 iteration = 89.5879
# Average val loss after 57 iteration = 0.0276
# Total val chrF after 57 iteration = 75.0889
# Average test loss after 57 iteration = 0.0292
# Total test chrF after 57 iteration = 75.2043
# Time for the iteration 10.6 seconds
#
#
# Average train loss after 58 iteration = 0.0018
# Total train chrF after 58 iteration = 89.6063
# Average val loss after 58 iteration = 0.0278
# Total val chrF after 58 iteration = 75.0106
# Average test loss after 58 iteration = 0.0294
# Total test chrF after 58 iteration = 75.2820
# Time for the iteration 10.6 seconds
#
#
# Average train loss after 59 iteration = 0.0017
# Total train chrF after 59 iteration = 89.6227
# Average val loss after 59 iteration = 0.0280
# Total val chrF after 59 iteration = 74.9785
# Average test loss after 59 iteration = 0.0296
# Total test chrF after 59 iteration = 75.2784
# Time for the iteration 10.5 seconds
#
#
# Average train loss after 60 iteration = 0.0016
# Total train chrF after 60 iteration = 89.6401
# Average val loss after 60 iteration = 0.0282
# Total val chrF after 60 iteration = 74.9748
# Average test loss after 60 iteration = 0.0298
# Total test chrF after 60 iteration = 75.1850
# Time for the iteration 10.5 seconds
#
#
# Average train loss after 61 iteration = 0.0015
# Total train chrF after 61 iteration = 89.6540
# Average val loss after 61 iteration = 0.0283
# Total val chrF after 61 iteration = 74.9971
# Average test loss after 61 iteration = 0.0300
# Total test chrF after 61 iteration = 75.1780
# Time for the iteration 10.6 seconds
#
#
# Average train loss after 62 iteration = 0.0015
# Total train chrF after 62 iteration = 89.6718
# Average val loss after 62 iteration = 0.0285
# Total val chrF after 62 iteration = 74.9817
# Average test loss after 62 iteration = 0.0302
# Total test chrF after 62 iteration = 75.1082
# Time for the iteration 10.5 seconds
#
#
# Average train loss after 63 iteration = 0.0014
# Total train chrF after 63 iteration = 89.6848
# Average val loss after 63 iteration = 0.0287
# Total val chrF after 63 iteration = 74.9945
# Average test loss after 63 iteration = 0.0304
# Total test chrF after 63 iteration = 75.0564
# Time for the iteration 10.5 seconds
#
#
# Average train loss after 64 iteration = 0.0013
# Total train chrF after 64 iteration = 89.6938
# Average val loss after 64 iteration = 0.0289
# Total val chrF after 64 iteration = 74.9981
# Average test loss after 64 iteration = 0.0306
# Total test chrF after 64 iteration = 75.1524
# Time for the iteration 10.6 seconds
#
#
# Average train loss after 65 iteration = 0.0013
# Total train chrF after 65 iteration = 89.7028
# Average val loss after 65 iteration = 0.0291
# Total val chrF after 65 iteration = 75.0309
# Average test loss after 65 iteration = 0.0308
# Total test chrF after 65 iteration = 75.1643
# Time for the iteration 10.5 seconds
#
#
# Average train loss after 66 iteration = 0.0012
# Total train chrF after 66 iteration = 89.7145
# Average val loss after 66 iteration = 0.0293
# Total val chrF after 66 iteration = 74.9546
# Average test loss after 66 iteration = 0.0310
# Total test chrF after 66 iteration = 75.1781
# Time for the iteration 10.5 seconds
#
#
# Average train loss after 67 iteration = 0.0011
# Total train chrF after 67 iteration = 89.7230
# Average val loss after 67 iteration = 0.0295
# Total val chrF after 67 iteration = 74.9392
# Average test loss after 67 iteration = 0.0313
# Total test chrF after 67 iteration = 75.1017
# Time for the iteration 10.6 seconds
#
#
# Average train loss after 68 iteration = 0.0011
# Total train chrF after 68 iteration = 89.7317
# Average val loss after 68 iteration = 0.0297
# Total val chrF after 68 iteration = 74.9378
# Average test loss after 68 iteration = 0.0315
# Total test chrF after 68 iteration = 75.0672
# Time for the iteration 10.5 seconds
#
#
# Average train loss after 69 iteration = 0.0010
# Total train chrF after 69 iteration = 89.7421
# Average val loss after 69 iteration = 0.0299
# Total val chrF after 69 iteration = 74.9293
# Average test loss after 69 iteration = 0.0317
# Total test chrF after 69 iteration = 75.0744
# Time for the iteration 10.5 seconds
#
#
# Average train loss after 70 iteration = 0.0010
# Total train chrF after 70 iteration = 89.7510
# Average val loss after 70 iteration = 0.0301
# Total val chrF after 70 iteration = 74.9848
# Average test loss after 70 iteration = 0.0319
# Total test chrF after 70 iteration = 75.1131
# Time for the iteration 10.6 seconds
#
#
# Average train loss after 71 iteration = 0.0009
# Total train chrF after 71 iteration = 89.7574
# Average val loss after 71 iteration = 0.0304
# Total val chrF after 71 iteration = 75.0051
# Average test loss after 71 iteration = 0.0322
# Total test chrF after 71 iteration = 74.9558
# Time for the iteration 10.5 seconds
#
#
# Average train loss after 72 iteration = 0.0009
# Total train chrF after 72 iteration = 89.7639
# Average val loss after 72 iteration = 0.0306
# Total val chrF after 72 iteration = 75.0072
# Average test loss after 72 iteration = 0.0324
# Total test chrF after 72 iteration = 74.9905
# Time for the iteration 10.5 seconds
#
#
# Average train loss after 73 iteration = 0.0008
# Total train chrF after 73 iteration = 89.7707
# Average val loss after 73 iteration = 0.0308
# Total val chrF after 73 iteration = 74.9567
# Average test loss after 73 iteration = 0.0326
# Total test chrF after 73 iteration = 74.9787
# Time for the iteration 10.7 seconds
#
#
# Average train loss after 74 iteration = 0.0008
# Total train chrF after 74 iteration = 89.7758
# Average val loss after 74 iteration = 0.0310
# Total val chrF after 74 iteration = 74.9337
# Average test loss after 74 iteration = 0.0329
# Total test chrF after 74 iteration = 74.9752
# Time for the iteration 10.6 seconds
#
#
# Average train loss after 75 iteration = 0.0008
# Total train chrF after 75 iteration = 89.7811
# Average val loss after 75 iteration = 0.0312
# Total val chrF after 75 iteration = 74.9722
# Average test loss after 75 iteration = 0.0331
# Total test chrF after 75 iteration = 75.0171
# Time for the iteration 10.6 seconds
#
#
# Average train loss after 76 iteration = 0.0007
# Total train chrF after 76 iteration = 89.7877
# Average val loss after 76 iteration = 0.0314
# Total val chrF after 76 iteration = 74.9670
# Average test loss after 76 iteration = 0.0334
# Total test chrF after 76 iteration = 75.0792
# Time for the iteration 10.6 seconds
#
#
# Average train loss after 77 iteration = 0.0007
# Total train chrF after 77 iteration = 89.7909
# Average val loss after 77 iteration = 0.0316
# Total val chrF after 77 iteration = 74.8799
# Average test loss after 77 iteration = 0.0336
# Total test chrF after 77 iteration = 75.0476
# Time for the iteration 10.5 seconds
#
#
# Average train loss after 78 iteration = 0.0007
# Total train chrF after 78 iteration = 89.7951
# Average val loss after 78 iteration = 0.0319
# Total val chrF after 78 iteration = 74.8305
# Average test loss after 78 iteration = 0.0338
# Total test chrF after 78 iteration = 75.0540
# Time for the iteration 10.5 seconds
#
#
# Average train loss after 79 iteration = 0.0006
# Total train chrF after 79 iteration = 89.7980
# Average val loss after 79 iteration = 0.0321
# Total val chrF after 79 iteration = 74.7819
# Average test loss after 79 iteration = 0.0341
# Total test chrF after 79 iteration = 75.0518
# Time for the iteration 10.7 seconds
#
#
# Average train loss after 80 iteration = 0.0006
# Total train chrF after 80 iteration = 89.8026
# Average val loss after 80 iteration = 0.0323
# Total val chrF after 80 iteration = 74.6871
# Average test loss after 80 iteration = 0.0343
# Total test chrF after 80 iteration = 75.0841
# Time for the iteration 10.6 seconds
#
#
# Average train loss after 81 iteration = 0.0006
# Total train chrF after 81 iteration = 89.8052
# Average val loss after 81 iteration = 0.0326
# Total val chrF after 81 iteration = 74.7077
# Average test loss after 81 iteration = 0.0346
# Total test chrF after 81 iteration = 75.0266
# Time for the iteration 10.5 seconds
#
#
#
#
# Aborting since there hasn't been much progress
# <Figure size 640x480 with 1 Axes>
# <Figure size 640x480 with 1 Axes>

# %%
language = "ya"
task_name = "sylsim_teacher_general"
vocab_size = 4999
num_epochs = 100
batch_size = 32
model = "50_1"
optimizer = "Adam"
metric = "chrF"

# %%
from IPython.display import Image

Image("curves/{}_{}_{}_{}_{}_loss.png".format(language, task_name, vocab_size, num_epochs, batch_size))

# %%
Image("curves/{}_{}_{}_{}_{}_{}.png".format(language, task_name, vocab_size, num_epochs, batch_size, metric))

# %%
print("{}.{}.{}.{}.{}.{}.{}".format(language, task_name, vocab_size, num_epochs, batch_size, model, optimizer))
# Out:
# ya.sylsim_teacher_general.4999.100.32.50_1.Adam
