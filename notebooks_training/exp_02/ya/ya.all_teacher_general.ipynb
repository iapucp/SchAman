# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
# %cd "drive/MyDrive/Tesis/scRNN"
# Out:
# /content/drive/MyDrive/Tesis/scRNN

# %%
import torch

torch.cuda.is_available()
# Out:
# True

# %%
# !pip install sacrebleu
# Out:
# Collecting sacrebleu
#   Downloading sacrebleu-2.0.0-py3-none-any.whl (90 kB)
#      |████████████████████████████████| 90 kB 6.4 MB/s
# Collecting portalocker
#   Downloading portalocker-2.3.2-py2.py3-none-any.whl (15 kB)
# Collecting colorama
#   Downloading colorama-0.4.4-py2.py3-none-any.whl (16 kB)
# Requirement already satisfied: regex in /usr/local/lib/python3.7/dist-packages (from sacrebleu) (2019.12.20)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from sacrebleu) (1.19.5)
# Requirement already satisfied: tabulate>=0.8.9 in /usr/local/lib/python3.7/dist-packages (from sacrebleu) (0.8.9)
# Installing collected packages: portalocker, colorama, sacrebleu
# Successfully installed colorama-0.4.4 portalocker-2.3.2 sacrebleu-2.0.0

# %%
# !python3 train.py --language ya --task-name all_teacher_general --num-epochs 100 --batch-size 32 --vocab-size 4999 --new-vocab --train --train-sentences-errors-file ya.all_teacher_general.train.sentences.errors.txt --train-sentences-file ya.all_teacher_general.train.sentences.txt --val-sentences-errors-file ya.teacher_general.val.sentences.errors.txt --val-sentences-file ya.teacher_general.val.sentences.txt --test-sentences-errors-file ya.teacher_general.test.sentences.errors.txt --test-sentences-file ya.teacher_general.test.sentences.txt --metric chrF --save
# Out:
# Parameters
# {'language': 'ya', 'task_name': 'all_teacher_general', 'vocab_size': 4999, 'num_epochs': 100, 'batch_size': 32, 'model_name': 'shi_random_20531_100_32', 'new_vocab': True, 'need_to_train': True, 'train_sentences_errors_file': 'ya.all_teacher_general.train.sentences.errors.txt', 'train_sentences_file': 'ya.all_teacher_general.train.sentences.txt', 'val_sentences_errors_file': 'ya.teacher_general.val.sentences.errors.txt', 'val_sentences_file': 'ya.teacher_general.val.sentences.txt', 'test_sentences_errors_file': 'ya.teacher_general.test.sentences.errors.txt', 'test_sentences_file': 'ya.teacher_general.test.sentences.txt', 'metric': 'chrF', 'save_model': True}
#
#
# Creating new vocabulary
# Len of w2i:  4999
# Len of i2w:  4999
# Len of char vocab:  32
#
#
# Initializing an only ScRNN model
#
#
# Training the model...
#
# Average train loss after 1 iteration = 0.1161
# Total train chrF after 1 iteration = 69.9550
# Average val loss after 1 iteration = 0.1087
# Total val chrF after 1 iteration = 70.8234
# Average test loss after 1 iteration = 0.1058
# Total test chrF after 1 iteration = 71.3713
# Dumping after  1
# Time for the iteration 54.2 seconds
#
#
# Average train loss after 2 iteration = 0.0473
# Total train chrF after 2 iteration = 78.4528
# Average val loss after 2 iteration = 0.0716
# Total val chrF after 2 iteration = 71.1899
# Average test loss after 2 iteration = 0.0690
# Total test chrF after 2 iteration = 71.6504
# Dumping after  2
# Time for the iteration 54.2 seconds
#
#
# Average train loss after 3 iteration = 0.0259
# Total train chrF after 3 iteration = 82.3676
# Average val loss after 3 iteration = 0.0577
# Total val chrF after 3 iteration = 71.3823
# Average test loss after 3 iteration = 0.0553
# Total test chrF after 3 iteration = 72.0121
# Dumping after  3
# Time for the iteration 54.5 seconds
#
#
# Average train loss after 4 iteration = 0.0180
# Total train chrF after 4 iteration = 84.4616
# Average val loss after 4 iteration = 0.0491
# Total val chrF after 4 iteration = 71.6728
# Average test loss after 4 iteration = 0.0469
# Total test chrF after 4 iteration = 72.3849
# Dumping after  4
# Time for the iteration 54.6 seconds
#
#
# Average train loss after 5 iteration = 0.0142
# Total train chrF after 5 iteration = 85.6607
# Average val loss after 5 iteration = 0.0439
# Total val chrF after 5 iteration = 72.0263
# Average test loss after 5 iteration = 0.0417
# Total test chrF after 5 iteration = 72.7938
# Dumping after  5
# Time for the iteration 54.5 seconds
#
#
# Average train loss after 6 iteration = 0.0119
# Total train chrF after 6 iteration = 86.4261
# Average val loss after 6 iteration = 0.0405
# Total val chrF after 6 iteration = 72.1838
# Average test loss after 6 iteration = 0.0385
# Total test chrF after 6 iteration = 73.0231
# Dumping after  6
# Time for the iteration 54.5 seconds
#
#
# Average train loss after 7 iteration = 0.0104
# Total train chrF after 7 iteration = 86.9770
# Average val loss after 7 iteration = 0.0382
# Total val chrF after 7 iteration = 72.3688
# Average test loss after 7 iteration = 0.0363
# Total test chrF after 7 iteration = 73.1331
# Dumping after  7
# Time for the iteration 54.5 seconds
#
#
# Average train loss after 8 iteration = 0.0093
# Total train chrF after 8 iteration = 87.4081
# Average val loss after 8 iteration = 0.0365
# Total val chrF after 8 iteration = 72.6499
# Average test loss after 8 iteration = 0.0346
# Total test chrF after 8 iteration = 73.3882
# Dumping after  8
# Time for the iteration 54.5 seconds
#
#
# Average train loss after 9 iteration = 0.0084
# Total train chrF after 9 iteration = 87.7426
# Average val loss after 9 iteration = 0.0353
# Total val chrF after 9 iteration = 72.7409
# Average test loss after 9 iteration = 0.0334
# Total test chrF after 9 iteration = 73.5616
# Dumping after  9
# Time for the iteration 54.7 seconds
#
#
# Average train loss after 10 iteration = 0.0077
# Total train chrF after 10 iteration = 88.0282
# Average val loss after 10 iteration = 0.0343
# Total val chrF after 10 iteration = 72.9076
# Average test loss after 10 iteration = 0.0325
# Total test chrF after 10 iteration = 73.5466
# Dumping after  10
# Time for the iteration 54.5 seconds
#
#
# Average train loss after 11 iteration = 0.0071
# Total train chrF after 11 iteration = 88.2674
# Average val loss after 11 iteration = 0.0336
# Total val chrF after 11 iteration = 73.0029
# Average test loss after 11 iteration = 0.0318
# Total test chrF after 11 iteration = 73.7198
# Dumping after  11
# Time for the iteration 54.5 seconds
#
#
# Average train loss after 12 iteration = 0.0065
# Total train chrF after 12 iteration = 88.4786
# Average val loss after 12 iteration = 0.0331
# Total val chrF after 12 iteration = 73.0689
# Average test loss after 12 iteration = 0.0313
# Total test chrF after 12 iteration = 73.7969
# Dumping after  12
# Time for the iteration 54.9 seconds
#
#
# Average train loss after 13 iteration = 0.0061
# Total train chrF after 13 iteration = 88.6535
# Average val loss after 13 iteration = 0.0327
# Total val chrF after 13 iteration = 73.0048
# Average test loss after 13 iteration = 0.0309
# Total test chrF after 13 iteration = 73.7920
# Time for the iteration 55.1 seconds
#
#
# Average train loss after 14 iteration = 0.0057
# Total train chrF after 14 iteration = 88.8015
# Average val loss after 14 iteration = 0.0323
# Total val chrF after 14 iteration = 73.0161
# Average test loss after 14 iteration = 0.0305
# Total test chrF after 14 iteration = 73.8852
# Time for the iteration 54.7 seconds
#
#
# Average train loss after 15 iteration = 0.0053
# Total train chrF after 15 iteration = 88.9506
# Average val loss after 15 iteration = 0.0321
# Total val chrF after 15 iteration = 73.0917
# Average test loss after 15 iteration = 0.0303
# Total test chrF after 15 iteration = 73.9085
# Dumping after  15
# Time for the iteration 54.9 seconds
#
#
# Average train loss after 16 iteration = 0.0050
# Total train chrF after 16 iteration = 89.0784
# Average val loss after 16 iteration = 0.0319
# Total val chrF after 16 iteration = 73.1561
# Average test loss after 16 iteration = 0.0301
# Total test chrF after 16 iteration = 73.9294
# Dumping after  16
# Time for the iteration 55.3 seconds
#
#
# Average train loss after 17 iteration = 0.0047
# Total train chrF after 17 iteration = 89.1856
# Average val loss after 17 iteration = 0.0317
# Total val chrF after 17 iteration = 73.1793
# Average test loss after 17 iteration = 0.0300
# Total test chrF after 17 iteration = 74.0501
# Dumping after  17
# Time for the iteration 55.2 seconds
#
#
# Average train loss after 18 iteration = 0.0045
# Total train chrF after 18 iteration = 89.2807
# Average val loss after 18 iteration = 0.0316
# Total val chrF after 18 iteration = 73.3035
# Average test loss after 18 iteration = 0.0299
# Total test chrF after 18 iteration = 74.1173
# Dumping after  18
# Time for the iteration 55.5 seconds
#
#
# Average train loss after 19 iteration = 0.0043
# Total train chrF after 19 iteration = 89.3688
# Average val loss after 19 iteration = 0.0315
# Total val chrF after 19 iteration = 73.3544
# Average test loss after 19 iteration = 0.0298
# Total test chrF after 19 iteration = 74.1551
# Dumping after  19
# Time for the iteration 55.4 seconds
#
#
# Average train loss after 20 iteration = 0.0040
# Total train chrF after 20 iteration = 89.4501
# Average val loss after 20 iteration = 0.0315
# Total val chrF after 20 iteration = 73.4477
# Average test loss after 20 iteration = 0.0298
# Total test chrF after 20 iteration = 74.1351
# Dumping after  20
# Time for the iteration 55.3 seconds
#
#
# Average train loss after 21 iteration = 0.0038
# Total train chrF after 21 iteration = 89.5292
# Average val loss after 21 iteration = 0.0315
# Total val chrF after 21 iteration = 73.4754
# Average test loss after 21 iteration = 0.0298
# Total test chrF after 21 iteration = 74.2732
# Dumping after  21
# Time for the iteration 55.6 seconds
#
#
# Average train loss after 22 iteration = 0.0037
# Total train chrF after 22 iteration = 89.6027
# Average val loss after 22 iteration = 0.0314
# Total val chrF after 22 iteration = 73.5450
# Average test loss after 22 iteration = 0.0298
# Total test chrF after 22 iteration = 74.3209
# Dumping after  22
# Time for the iteration 55.1 seconds
#
#
# Average train loss after 23 iteration = 0.0035
# Total train chrF after 23 iteration = 89.6665
# Average val loss after 23 iteration = 0.0314
# Total val chrF after 23 iteration = 73.5584
# Average test loss after 23 iteration = 0.0298
# Total test chrF after 23 iteration = 74.4155
# Dumping after  23
# Time for the iteration 55.3 seconds
#
#
# Average train loss after 24 iteration = 0.0033
# Total train chrF after 24 iteration = 89.7272
# Average val loss after 24 iteration = 0.0315
# Total val chrF after 24 iteration = 73.5798
# Average test loss after 24 iteration = 0.0298
# Total test chrF after 24 iteration = 74.4231
# Dumping after  24
# Time for the iteration 55.4 seconds
#
#
# Average train loss after 25 iteration = 0.0032
# Total train chrF after 25 iteration = 89.7785
# Average val loss after 25 iteration = 0.0315
# Total val chrF after 25 iteration = 73.6155
# Average test loss after 25 iteration = 0.0298
# Total test chrF after 25 iteration = 74.4789
# Dumping after  25
# Time for the iteration 55.5 seconds
#
#
# Average train loss after 26 iteration = 0.0030
# Total train chrF after 26 iteration = 89.8296
# Average val loss after 26 iteration = 0.0315
# Total val chrF after 26 iteration = 73.7079
# Average test loss after 26 iteration = 0.0299
# Total test chrF after 26 iteration = 74.5493
# Dumping after  26
# Time for the iteration 55.1 seconds
#
#
# Average train loss after 27 iteration = 0.0029
# Total train chrF after 27 iteration = 89.8754
# Average val loss after 27 iteration = 0.0316
# Total val chrF after 27 iteration = 73.7739
# Average test loss after 27 iteration = 0.0299
# Total test chrF after 27 iteration = 74.5820
# Dumping after  27
# Time for the iteration 55.1 seconds
#
#
# Average train loss after 28 iteration = 0.0028
# Total train chrF after 28 iteration = 89.9154
# Average val loss after 28 iteration = 0.0317
# Total val chrF after 28 iteration = 73.8476
# Average test loss after 28 iteration = 0.0300
# Total test chrF after 28 iteration = 74.5737
# Dumping after  28
# Time for the iteration 55.3 seconds
#
#
# Average train loss after 29 iteration = 0.0027
# Total train chrF after 29 iteration = 89.9475
# Average val loss after 29 iteration = 0.0318
# Total val chrF after 29 iteration = 73.9334
# Average test loss after 29 iteration = 0.0300
# Total test chrF after 29 iteration = 74.6773
# Dumping after  29
# Time for the iteration 55.1 seconds
#
#
# Average train loss after 30 iteration = 0.0026
# Total train chrF after 30 iteration = 89.9870
# Average val loss after 30 iteration = 0.0319
# Total val chrF after 30 iteration = 73.8843
# Average test loss after 30 iteration = 0.0301
# Total test chrF after 30 iteration = 74.7587
# Time for the iteration 55.4 seconds
#
#
# Average train loss after 31 iteration = 0.0025
# Total train chrF after 31 iteration = 90.0223
# Average val loss after 31 iteration = 0.0320
# Total val chrF after 31 iteration = 73.9632
# Average test loss after 31 iteration = 0.0302
# Total test chrF after 31 iteration = 74.6931
# Dumping after  31
# Time for the iteration 55.1 seconds
#
#
# Average train loss after 32 iteration = 0.0024
# Total train chrF after 32 iteration = 90.0573
# Average val loss after 32 iteration = 0.0322
# Total val chrF after 32 iteration = 74.0041
# Average test loss after 32 iteration = 0.0303
# Total test chrF after 32 iteration = 74.7162
# Dumping after  32
# Time for the iteration 55.3 seconds
#
#
# Average train loss after 33 iteration = 0.0023
# Total train chrF after 33 iteration = 90.0905
# Average val loss after 33 iteration = 0.0323
# Total val chrF after 33 iteration = 74.0019
# Average test loss after 33 iteration = 0.0305
# Total test chrF after 33 iteration = 74.7624
# Time for the iteration 54.9 seconds
#
#
# Average train loss after 34 iteration = 0.0022
# Total train chrF after 34 iteration = 90.1182
# Average val loss after 34 iteration = 0.0325
# Total val chrF after 34 iteration = 73.9551
# Average test loss after 34 iteration = 0.0306
# Total test chrF after 34 iteration = 74.7485
# Time for the iteration 55.2 seconds
#
#
# Average train loss after 35 iteration = 0.0021
# Total train chrF after 35 iteration = 90.1444
# Average val loss after 35 iteration = 0.0327
# Total val chrF after 35 iteration = 73.8916
# Average test loss after 35 iteration = 0.0308
# Total test chrF after 35 iteration = 74.7430
# Time for the iteration 55.4 seconds
#
#
# Average train loss after 36 iteration = 0.0020
# Total train chrF after 36 iteration = 90.1696
# Average val loss after 36 iteration = 0.0329
# Total val chrF after 36 iteration = 73.8274
# Average test loss after 36 iteration = 0.0309
# Total test chrF after 36 iteration = 74.7345
# Time for the iteration 55.3 seconds
#
#
# Average train loss after 37 iteration = 0.0019
# Total train chrF after 37 iteration = 90.1933
# Average val loss after 37 iteration = 0.0331
# Total val chrF after 37 iteration = 73.8395
# Average test loss after 37 iteration = 0.0311
# Total test chrF after 37 iteration = 74.7155
# Time for the iteration 55.3 seconds
#
#
# Average train loss after 38 iteration = 0.0019
# Total train chrF after 38 iteration = 90.2097
# Average val loss after 38 iteration = 0.0332
# Total val chrF after 38 iteration = 73.8977
# Average test loss after 38 iteration = 0.0312
# Total test chrF after 38 iteration = 74.7683
# Time for the iteration 55.5 seconds
#
#
# Average train loss after 39 iteration = 0.0018
# Total train chrF after 39 iteration = 90.2372
# Average val loss after 39 iteration = 0.0335
# Total val chrF after 39 iteration = 73.8754
# Average test loss after 39 iteration = 0.0314
# Total test chrF after 39 iteration = 74.7897
# Time for the iteration 55.5 seconds
#
#
# Average train loss after 40 iteration = 0.0017
# Total train chrF after 40 iteration = 90.2591
# Average val loss after 40 iteration = 0.0337
# Total val chrF after 40 iteration = 73.8351
# Average test loss after 40 iteration = 0.0316
# Total test chrF after 40 iteration = 74.7715
# Time for the iteration 55.3 seconds
#
#
# Average train loss after 41 iteration = 0.0017
# Total train chrF after 41 iteration = 90.2783
# Average val loss after 41 iteration = 0.0340
# Total val chrF after 41 iteration = 73.8953
# Average test loss after 41 iteration = 0.0318
# Total test chrF after 41 iteration = 74.8243
# Time for the iteration 55.5 seconds
#
#
# Average train loss after 42 iteration = 0.0016
# Total train chrF after 42 iteration = 90.2987
# Average val loss after 42 iteration = 0.0342
# Total val chrF after 42 iteration = 73.9211
# Average test loss after 42 iteration = 0.0320
# Total test chrF after 42 iteration = 74.8139
# Time for the iteration 55.5 seconds
#
#
# Average train loss after 43 iteration = 0.0016
# Total train chrF after 43 iteration = 90.3147
# Average val loss after 43 iteration = 0.0345
# Total val chrF after 43 iteration = 73.9067
# Average test loss after 43 iteration = 0.0322
# Total test chrF after 43 iteration = 74.7698
# Time for the iteration 55.2 seconds
#
#
# Average train loss after 44 iteration = 0.0015
# Total train chrF after 44 iteration = 90.3330
# Average val loss after 44 iteration = 0.0347
# Total val chrF after 44 iteration = 73.9273
# Average test loss after 44 iteration = 0.0324
# Total test chrF after 44 iteration = 74.7858
# Time for the iteration 55.2 seconds
#
#
# Average train loss after 45 iteration = 0.0015
# Total train chrF after 45 iteration = 90.3446
# Average val loss after 45 iteration = 0.0350
# Total val chrF after 45 iteration = 73.9047
# Average test loss after 45 iteration = 0.0326
# Total test chrF after 45 iteration = 74.7501
# Time for the iteration 55.1 seconds
#
#
# Average train loss after 46 iteration = 0.0014
# Total train chrF after 46 iteration = 90.3589
# Average val loss after 46 iteration = 0.0352
# Total val chrF after 46 iteration = 73.9466
# Average test loss after 46 iteration = 0.0328
# Total test chrF after 46 iteration = 74.7831
# Time for the iteration 55.1 seconds
#
#
# Average train loss after 47 iteration = 0.0014
# Total train chrF after 47 iteration = 90.3731
# Average val loss after 47 iteration = 0.0355
# Total val chrF after 47 iteration = 73.9036
# Average test loss after 47 iteration = 0.0330
# Total test chrF after 47 iteration = 74.7923
# Time for the iteration 54.9 seconds
#
#
# Average train loss after 48 iteration = 0.0013
# Total train chrF after 48 iteration = 90.3863
# Average val loss after 48 iteration = 0.0358
# Total val chrF after 48 iteration = 73.9163
# Average test loss after 48 iteration = 0.0332
# Total test chrF after 48 iteration = 74.7258
# Time for the iteration 54.9 seconds
#
#
# Average train loss after 49 iteration = 0.0013
# Total train chrF after 49 iteration = 90.3975
# Average val loss after 49 iteration = 0.0360
# Total val chrF after 49 iteration = 73.9089
# Average test loss after 49 iteration = 0.0334
# Total test chrF after 49 iteration = 74.6708
# Time for the iteration 55.4 seconds
#
#
# Average train loss after 50 iteration = 0.0012
# Total train chrF after 50 iteration = 90.4116
# Average val loss after 50 iteration = 0.0363
# Total val chrF after 50 iteration = 73.9139
# Average test loss after 50 iteration = 0.0336
# Total test chrF after 50 iteration = 74.7049
# Time for the iteration 55.2 seconds
#
#
# Average train loss after 51 iteration = 0.0012
# Total train chrF after 51 iteration = 90.4234
# Average val loss after 51 iteration = 0.0366
# Total val chrF after 51 iteration = 73.9235
# Average test loss after 51 iteration = 0.0338
# Total test chrF after 51 iteration = 74.6950
# Time for the iteration 55.3 seconds
#
#
# Average train loss after 52 iteration = 0.0012
# Total train chrF after 52 iteration = 90.4335
# Average val loss after 52 iteration = 0.0368
# Total val chrF after 52 iteration = 73.8202
# Average test loss after 52 iteration = 0.0340
# Total test chrF after 52 iteration = 74.6750
# Time for the iteration 55.2 seconds
#
#
# Average train loss after 53 iteration = 0.0011
# Total train chrF after 53 iteration = 90.4477
# Average val loss after 53 iteration = 0.0372
# Total val chrF after 53 iteration = 73.8453
# Average test loss after 53 iteration = 0.0343
# Total test chrF after 53 iteration = 74.6992
# Time for the iteration 55.3 seconds
#
#
# Average train loss after 54 iteration = 0.0011
# Total train chrF after 54 iteration = 90.4570
# Average val loss after 54 iteration = 0.0374
# Total val chrF after 54 iteration = 73.8037
# Average test loss after 54 iteration = 0.0345
# Total test chrF after 54 iteration = 74.6948
# Time for the iteration 55.4 seconds
#
#
# Average train loss after 55 iteration = 0.0010
# Total train chrF after 55 iteration = 90.4664
# Average val loss after 55 iteration = 0.0377
# Total val chrF after 55 iteration = 73.8001
# Average test loss after 55 iteration = 0.0347
# Total test chrF after 55 iteration = 74.6501
# Time for the iteration 55.3 seconds
#
#
# Average train loss after 56 iteration = 0.0010
# Total train chrF after 56 iteration = 90.4763
# Average val loss after 56 iteration = 0.0380
# Total val chrF after 56 iteration = 73.8394
# Average test loss after 56 iteration = 0.0349
# Total test chrF after 56 iteration = 74.6163
# Time for the iteration 55.3 seconds
#
#
# Average train loss after 57 iteration = 0.0010
# Total train chrF after 57 iteration = 90.4845
# Average val loss after 57 iteration = 0.0383
# Total val chrF after 57 iteration = 73.8764
# Average test loss after 57 iteration = 0.0351
# Total test chrF after 57 iteration = 74.5910
# Time for the iteration 55.1 seconds
#
#
# Average train loss after 58 iteration = 0.0009
# Total train chrF after 58 iteration = 90.4957
# Average val loss after 58 iteration = 0.0386
# Total val chrF after 58 iteration = 73.9089
# Average test loss after 58 iteration = 0.0353
# Total test chrF after 58 iteration = 74.5549
# Time for the iteration 55.0 seconds
#
#
# Average train loss after 59 iteration = 0.0009
# Total train chrF after 59 iteration = 90.5027
# Average val loss after 59 iteration = 0.0389
# Total val chrF after 59 iteration = 73.8576
# Average test loss after 59 iteration = 0.0356
# Total test chrF after 59 iteration = 74.6171
# Time for the iteration 54.8 seconds
#
#
#
#
# Aborting since there hasn't been much progress
# <Figure size 640x480 with 1 Axes>
# <Figure size 640x480 with 1 Axes>

# %%
language = "ya"
task_name = "all_teacher_general"
vocab_size = 4999
num_epochs = 100
batch_size = 32
model = "50_1"
optimizer = "Adam"
metric = "chrF"

# %%
from IPython.display import Image

Image("curves/{}_{}_{}_{}_{}_loss.png".format(language, task_name, vocab_size, num_epochs, batch_size))

# %%
Image("curves/{}_{}_{}_{}_{}_{}.png".format(language, task_name, vocab_size, num_epochs, batch_size, metric))

# %%
print("{}.{}.{}.{}.{}.{}.{}".format(language, task_name, vocab_size, num_epochs, batch_size, model, optimizer))
# Out:
# ya.all_teacher_general.4999.100.32.50_1.Adam
