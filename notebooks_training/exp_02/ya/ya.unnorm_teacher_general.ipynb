# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
# %cd "drive/MyDrive/Tesis/scRNN"
# Out:
# /content/drive/MyDrive/Tesis/scRNN

# %%
import torch

torch.cuda.is_available()
# Out:
# True

# %%
# !pip install sacrebleu
# Out:
# Collecting sacrebleu
#   Downloading sacrebleu-2.0.0-py3-none-any.whl (90 kB)
#      |████████████████████████████████| 90 kB 5.7 MB/s
# Requirement already satisfied: regex in /usr/local/lib/python3.7/dist-packages (from sacrebleu) (2019.12.20)
# Requirement already satisfied: tabulate>=0.8.9 in /usr/local/lib/python3.7/dist-packages (from sacrebleu) (0.8.9)
# Collecting portalocker
#   Downloading portalocker-2.3.2-py2.py3-none-any.whl (15 kB)
# Collecting colorama
#   Downloading colorama-0.4.4-py2.py3-none-any.whl (16 kB)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from sacrebleu) (1.19.5)
# Installing collected packages: portalocker, colorama, sacrebleu
# Successfully installed colorama-0.4.4 portalocker-2.3.2 sacrebleu-2.0.0

# %%
# !python3 train.py --language ya --task-name unnorm_teacher_general --num-epochs 100 --batch-size 32 --vocab-size 4999 --new-vocab --train --train-sentences-errors-file ya.unnorm_teacher_general.train.sentences.errors.txt --train-sentences-file ya.unnorm_teacher_general.train.sentences.txt --val-sentences-errors-file ya.teacher_general.val.sentences.errors.txt --val-sentences-file ya.teacher_general.val.sentences.txt --test-sentences-errors-file ya.teacher_general.test.sentences.errors.txt --test-sentences-file ya.teacher_general.test.sentences.txt --metric chrF --save
# Out:
# Parameters
# {'language': 'ya', 'task_name': 'unnorm_teacher_general', 'vocab_size': 4999, 'num_epochs': 100, 'batch_size': 32, 'model_name': 'shi_random_20531_100_32', 'new_vocab': True, 'need_to_train': True, 'train_sentences_errors_file': 'ya.unnorm_teacher_general.train.sentences.errors.txt', 'train_sentences_file': 'ya.unnorm_teacher_general.train.sentences.txt', 'val_sentences_errors_file': 'ya.teacher_general.val.sentences.errors.txt', 'val_sentences_file': 'ya.teacher_general.val.sentences.txt', 'test_sentences_errors_file': 'ya.teacher_general.test.sentences.errors.txt', 'test_sentences_file': 'ya.teacher_general.test.sentences.txt', 'metric': 'chrF', 'save_model': True}
#
#
# Creating new vocabulary
# Len of w2i:  4999
# Len of i2w:  4999
# Len of char vocab:  32
#
#
# Initializing an only ScRNN model
#
#
# Training the model...
#
# Average train loss after 1 iteration = 0.1781
# Total train chrF after 1 iteration = 74.4426
# Average val loss after 1 iteration = 0.2055
# Total val chrF after 1 iteration = 70.6142
# Average test loss after 1 iteration = 0.2024
# Total test chrF after 1 iteration = 71.1887
# Dumping after  1
# Time for the iteration 10.5 seconds
#
#
# Average train loss after 2 iteration = 0.1385
# Total train chrF after 2 iteration = 74.6269
# Average val loss after 2 iteration = 0.1244
# Total val chrF after 2 iteration = 70.6627
# Average test loss after 2 iteration = 0.1206
# Total test chrF after 2 iteration = 71.6406
# Dumping after  2
# Time for the iteration 10.3 seconds
#
#
# Average train loss after 3 iteration = 0.1031
# Total train chrF after 3 iteration = 78.1283
# Average val loss after 3 iteration = 0.0982
# Total val chrF after 3 iteration = 70.6560
# Average test loss after 3 iteration = 0.0947
# Total test chrF after 3 iteration = 71.6488
# Time for the iteration 10.3 seconds
#
#
# Average train loss after 4 iteration = 0.0785
# Total train chrF after 4 iteration = 80.7214
# Average val loss after 4 iteration = 0.0814
# Total val chrF after 4 iteration = 70.9538
# Average test loss after 4 iteration = 0.0782
# Total test chrF after 4 iteration = 72.0471
# Dumping after  4
# Time for the iteration 10.3 seconds
#
#
# Average train loss after 5 iteration = 0.0603
# Total train chrF after 5 iteration = 82.6677
# Average val loss after 5 iteration = 0.0690
# Total val chrF after 5 iteration = 71.1789
# Average test loss after 5 iteration = 0.0661
# Total test chrF after 5 iteration = 72.3053
# Dumping after  5
# Time for the iteration 10.5 seconds
#
#
# Average train loss after 6 iteration = 0.0471
# Total train chrF after 6 iteration = 84.1379
# Average val loss after 6 iteration = 0.0599
# Total val chrF after 6 iteration = 71.6758
# Average test loss after 6 iteration = 0.0572
# Total test chrF after 6 iteration = 72.6625
# Dumping after  6
# Time for the iteration 10.4 seconds
#
#
# Average train loss after 7 iteration = 0.0372
# Total train chrF after 7 iteration = 85.3500
# Average val loss after 7 iteration = 0.0529
# Total val chrF after 7 iteration = 72.0686
# Average test loss after 7 iteration = 0.0504
# Total test chrF after 7 iteration = 73.1554
# Dumping after  7
# Time for the iteration 10.5 seconds
#
#
# Average train loss after 8 iteration = 0.0298
# Total train chrF after 8 iteration = 86.3994
# Average val loss after 8 iteration = 0.0474
# Total val chrF after 8 iteration = 72.2997
# Average test loss after 8 iteration = 0.0451
# Total test chrF after 8 iteration = 73.3856
# Dumping after  8
# Time for the iteration 10.3 seconds
#
#
# Average train loss after 9 iteration = 0.0241
# Total train chrF after 9 iteration = 87.3004
# Average val loss after 9 iteration = 0.0431
# Total val chrF after 9 iteration = 72.5768
# Average test loss after 9 iteration = 0.0409
# Total test chrF after 9 iteration = 73.4780
# Dumping after  9
# Time for the iteration 10.3 seconds
#
#
# Average train loss after 10 iteration = 0.0197
# Total train chrF after 10 iteration = 88.0668
# Average val loss after 10 iteration = 0.0397
# Total val chrF after 10 iteration = 72.5886
# Average test loss after 10 iteration = 0.0376
# Total test chrF after 10 iteration = 73.7220
# Dumping after  10
# Time for the iteration 10.4 seconds
#
#
# Average train loss after 11 iteration = 0.0164
# Total train chrF after 11 iteration = 88.7518
# Average val loss after 11 iteration = 0.0370
# Total val chrF after 11 iteration = 72.8178
# Average test loss after 11 iteration = 0.0350
# Total test chrF after 11 iteration = 73.9127
# Dumping after  11
# Time for the iteration 10.3 seconds
#
#
# Average train loss after 12 iteration = 0.0138
# Total train chrF after 12 iteration = 89.3488
# Average val loss after 12 iteration = 0.0347
# Total val chrF after 12 iteration = 73.0409
# Average test loss after 12 iteration = 0.0329
# Total test chrF after 12 iteration = 74.1715
# Dumping after  12
# Time for the iteration 10.3 seconds
#
#
# Average train loss after 13 iteration = 0.0118
# Total train chrF after 13 iteration = 89.8654
# Average val loss after 13 iteration = 0.0329
# Total val chrF after 13 iteration = 73.1800
# Average test loss after 13 iteration = 0.0312
# Total test chrF after 13 iteration = 74.3916
# Dumping after  13
# Time for the iteration 10.4 seconds
#
#
# Average train loss after 14 iteration = 0.0103
# Total train chrF after 14 iteration = 90.3123
# Average val loss after 14 iteration = 0.0315
# Total val chrF after 14 iteration = 73.3134
# Average test loss after 14 iteration = 0.0299
# Total test chrF after 14 iteration = 74.5394
# Dumping after  14
# Time for the iteration 10.3 seconds
#
#
# Average train loss after 15 iteration = 0.0090
# Total train chrF after 15 iteration = 90.6353
# Average val loss after 15 iteration = 0.0303
# Total val chrF after 15 iteration = 73.5496
# Average test loss after 15 iteration = 0.0288
# Total test chrF after 15 iteration = 74.6971
# Dumping after  15
# Time for the iteration 10.2 seconds
#
#
# Average train loss after 16 iteration = 0.0080
# Total train chrF after 16 iteration = 90.9250
# Average val loss after 16 iteration = 0.0294
# Total val chrF after 16 iteration = 73.7266
# Average test loss after 16 iteration = 0.0280
# Total test chrF after 16 iteration = 74.9048
# Dumping after  16
# Time for the iteration 10.3 seconds
#
#
# Average train loss after 17 iteration = 0.0071
# Total train chrF after 17 iteration = 91.1581
# Average val loss after 17 iteration = 0.0286
# Total val chrF after 17 iteration = 73.8248
# Average test loss after 17 iteration = 0.0273
# Total test chrF after 17 iteration = 75.0164
# Dumping after  17
# Time for the iteration 10.3 seconds
#
#
# Average train loss after 18 iteration = 0.0064
# Total train chrF after 18 iteration = 91.3646
# Average val loss after 18 iteration = 0.0279
# Total val chrF after 18 iteration = 73.9944
# Average test loss after 18 iteration = 0.0267
# Total test chrF after 18 iteration = 75.2266
# Dumping after  18
# Time for the iteration 10.3 seconds
#
#
# Average train loss after 19 iteration = 0.0058
# Total train chrF after 19 iteration = 91.5522
# Average val loss after 19 iteration = 0.0274
# Total val chrF after 19 iteration = 74.1164
# Average test loss after 19 iteration = 0.0263
# Total test chrF after 19 iteration = 75.4149
# Dumping after  19
# Time for the iteration 10.5 seconds
#
#
# Average train loss after 20 iteration = 0.0052
# Total train chrF after 20 iteration = 91.7155
# Average val loss after 20 iteration = 0.0269
# Total val chrF after 20 iteration = 74.1564
# Average test loss after 20 iteration = 0.0259
# Total test chrF after 20 iteration = 75.4530
# Dumping after  20
# Time for the iteration 10.3 seconds
#
#
# Average train loss after 21 iteration = 0.0048
# Total train chrF after 21 iteration = 91.8313
# Average val loss after 21 iteration = 0.0265
# Total val chrF after 21 iteration = 74.2838
# Average test loss after 21 iteration = 0.0256
# Total test chrF after 21 iteration = 75.5653
# Dumping after  21
# Time for the iteration 10.3 seconds
#
#
# Average train loss after 22 iteration = 0.0044
# Total train chrF after 22 iteration = 91.9440
# Average val loss after 22 iteration = 0.0262
# Total val chrF after 22 iteration = 74.4021
# Average test loss after 22 iteration = 0.0254
# Total test chrF after 22 iteration = 75.7130
# Dumping after  22
# Time for the iteration 10.4 seconds
#
#
# Average train loss after 23 iteration = 0.0040
# Total train chrF after 23 iteration = 92.0409
# Average val loss after 23 iteration = 0.0259
# Total val chrF after 23 iteration = 74.4504
# Average test loss after 23 iteration = 0.0252
# Total test chrF after 23 iteration = 75.7596
# Dumping after  23
# Time for the iteration 10.3 seconds
#
#
# Average train loss after 24 iteration = 0.0037
# Total train chrF after 24 iteration = 92.1436
# Average val loss after 24 iteration = 0.0257
# Total val chrF after 24 iteration = 74.4487
# Average test loss after 24 iteration = 0.0250
# Total test chrF after 24 iteration = 75.8638
# Time for the iteration 10.3 seconds
#
#
# Average train loss after 25 iteration = 0.0034
# Total train chrF after 25 iteration = 92.2255
# Average val loss after 25 iteration = 0.0255
# Total val chrF after 25 iteration = 74.4646
# Average test loss after 25 iteration = 0.0249
# Total test chrF after 25 iteration = 75.9336
# Dumping after  25
# Time for the iteration 10.3 seconds
#
#
# Average train loss after 26 iteration = 0.0031
# Total train chrF after 26 iteration = 92.2981
# Average val loss after 26 iteration = 0.0254
# Total val chrF after 26 iteration = 74.5406
# Average test loss after 26 iteration = 0.0248
# Total test chrF after 26 iteration = 76.0587
# Dumping after  26
# Time for the iteration 10.3 seconds
#
#
# Average train loss after 27 iteration = 0.0029
# Total train chrF after 27 iteration = 92.3618
# Average val loss after 27 iteration = 0.0252
# Total val chrF after 27 iteration = 74.6141
# Average test loss after 27 iteration = 0.0248
# Total test chrF after 27 iteration = 76.0443
# Dumping after  27
# Time for the iteration 10.4 seconds
#
#
# Average train loss after 28 iteration = 0.0026
# Total train chrF after 28 iteration = 92.4154
# Average val loss after 28 iteration = 0.0252
# Total val chrF after 28 iteration = 74.5474
# Average test loss after 28 iteration = 0.0248
# Total test chrF after 28 iteration = 76.0919
# Time for the iteration 10.3 seconds
#
#
# Average train loss after 29 iteration = 0.0024
# Total train chrF after 29 iteration = 92.4602
# Average val loss after 29 iteration = 0.0251
# Total val chrF after 29 iteration = 74.6429
# Average test loss after 29 iteration = 0.0248
# Total test chrF after 29 iteration = 76.1398
# Dumping after  29
# Time for the iteration 10.4 seconds
#
#
# Average train loss after 30 iteration = 0.0022
# Total train chrF after 30 iteration = 92.5069
# Average val loss after 30 iteration = 0.0251
# Total val chrF after 30 iteration = 74.6775
# Average test loss after 30 iteration = 0.0249
# Total test chrF after 30 iteration = 76.1161
# Dumping after  30
# Time for the iteration 10.4 seconds
#
#
# Average train loss after 31 iteration = 0.0021
# Total train chrF after 31 iteration = 92.5507
# Average val loss after 31 iteration = 0.0251
# Total val chrF after 31 iteration = 74.7231
# Average test loss after 31 iteration = 0.0249
# Total test chrF after 31 iteration = 76.1446
# Dumping after  31
# Time for the iteration 10.5 seconds
#
#
# Average train loss after 32 iteration = 0.0019
# Total train chrF after 32 iteration = 92.5808
# Average val loss after 32 iteration = 0.0251
# Total val chrF after 32 iteration = 74.7867
# Average test loss after 32 iteration = 0.0250
# Total test chrF after 32 iteration = 76.2299
# Dumping after  32
# Time for the iteration 10.4 seconds
#
#
# Average train loss after 33 iteration = 0.0018
# Total train chrF after 33 iteration = 92.6180
# Average val loss after 33 iteration = 0.0252
# Total val chrF after 33 iteration = 74.8457
# Average test loss after 33 iteration = 0.0251
# Total test chrF after 33 iteration = 76.2337
# Dumping after  33
# Time for the iteration 10.4 seconds
#
#
# Average train loss after 34 iteration = 0.0017
# Total train chrF after 34 iteration = 92.6465
# Average val loss after 34 iteration = 0.0252
# Total val chrF after 34 iteration = 74.9152
# Average test loss after 34 iteration = 0.0252
# Total test chrF after 34 iteration = 76.3001
# Dumping after  34
# Time for the iteration 10.4 seconds
#
#
# Average train loss after 35 iteration = 0.0015
# Total train chrF after 35 iteration = 92.6715
# Average val loss after 35 iteration = 0.0253
# Total val chrF after 35 iteration = 74.9387
# Average test loss after 35 iteration = 0.0253
# Total test chrF after 35 iteration = 76.3275
# Dumping after  35
# Time for the iteration 10.4 seconds
#
#
# Average train loss after 36 iteration = 0.0014
# Total train chrF after 36 iteration = 92.6903
# Average val loss after 36 iteration = 0.0254
# Total val chrF after 36 iteration = 75.0752
# Average test loss after 36 iteration = 0.0254
# Total test chrF after 36 iteration = 76.3710
# Dumping after  36
# Time for the iteration 10.3 seconds
#
#
# Average train loss after 37 iteration = 0.0013
# Total train chrF after 37 iteration = 92.7097
# Average val loss after 37 iteration = 0.0255
# Total val chrF after 37 iteration = 75.1006
# Average test loss after 37 iteration = 0.0256
# Total test chrF after 37 iteration = 76.4161
# Dumping after  37
# Time for the iteration 10.3 seconds
#
#
# Average train loss after 38 iteration = 0.0012
# Total train chrF after 38 iteration = 92.7276
# Average val loss after 38 iteration = 0.0256
# Total val chrF after 38 iteration = 75.1556
# Average test loss after 38 iteration = 0.0257
# Total test chrF after 38 iteration = 76.4233
# Dumping after  38
# Time for the iteration 10.4 seconds
#
#
# Average train loss after 39 iteration = 0.0011
# Total train chrF after 39 iteration = 92.7496
# Average val loss after 39 iteration = 0.0257
# Total val chrF after 39 iteration = 75.1759
# Average test loss after 39 iteration = 0.0259
# Total test chrF after 39 iteration = 76.4514
# Dumping after  39
# Time for the iteration 10.3 seconds
#
#
# Average train loss after 40 iteration = 0.0011
# Total train chrF after 40 iteration = 92.7614
# Average val loss after 40 iteration = 0.0259
# Total val chrF after 40 iteration = 75.1615
# Average test loss after 40 iteration = 0.0260
# Total test chrF after 40 iteration = 76.4413
# Time for the iteration 10.4 seconds
#
#
# Average train loss after 41 iteration = 0.0010
# Total train chrF after 41 iteration = 92.7677
# Average val loss after 41 iteration = 0.0260
# Total val chrF after 41 iteration = 75.2008
# Average test loss after 41 iteration = 0.0262
# Total test chrF after 41 iteration = 76.5278
# Dumping after  41
# Time for the iteration 10.3 seconds
#
#
# Average train loss after 42 iteration = 0.0009
# Total train chrF after 42 iteration = 92.7813
# Average val loss after 42 iteration = 0.0262
# Total val chrF after 42 iteration = 75.2021
# Average test loss after 42 iteration = 0.0264
# Total test chrF after 42 iteration = 76.5455
# Dumping after  42
# Time for the iteration 10.4 seconds
#
#
# Average train loss after 43 iteration = 0.0009
# Total train chrF after 43 iteration = 92.7946
# Average val loss after 43 iteration = 0.0263
# Total val chrF after 43 iteration = 75.2875
# Average test loss after 43 iteration = 0.0265
# Total test chrF after 43 iteration = 76.6374
# Dumping after  43
# Time for the iteration 10.4 seconds
#
#
# Average train loss after 44 iteration = 0.0008
# Total train chrF after 44 iteration = 92.8037
# Average val loss after 44 iteration = 0.0265
# Total val chrF after 44 iteration = 75.2983
# Average test loss after 44 iteration = 0.0267
# Total test chrF after 44 iteration = 76.6315
# Dumping after  44
# Time for the iteration 10.3 seconds
#
#
# Average train loss after 45 iteration = 0.0007
# Total train chrF after 45 iteration = 92.8163
# Average val loss after 45 iteration = 0.0267
# Total val chrF after 45 iteration = 75.3490
# Average test loss after 45 iteration = 0.0269
# Total test chrF after 45 iteration = 76.6021
# Dumping after  45
# Time for the iteration 10.3 seconds
#
#
# Average train loss after 46 iteration = 0.0007
# Total train chrF after 46 iteration = 92.8249
# Average val loss after 46 iteration = 0.0268
# Total val chrF after 46 iteration = 75.3629
# Average test loss after 46 iteration = 0.0271
# Total test chrF after 46 iteration = 76.6833
# Dumping after  46
# Time for the iteration 10.4 seconds
#
#
# Average train loss after 47 iteration = 0.0006
# Total train chrF after 47 iteration = 92.8311
# Average val loss after 47 iteration = 0.0270
# Total val chrF after 47 iteration = 75.3950
# Average test loss after 47 iteration = 0.0273
# Total test chrF after 47 iteration = 76.6536
# Dumping after  47
# Time for the iteration 10.3 seconds
#
#
# Average train loss after 48 iteration = 0.0006
# Total train chrF after 48 iteration = 92.8352
# Average val loss after 48 iteration = 0.0272
# Total val chrF after 48 iteration = 75.4530
# Average test loss after 48 iteration = 0.0275
# Total test chrF after 48 iteration = 76.7021
# Dumping after  48
# Time for the iteration 10.3 seconds
#
#
# Average train loss after 49 iteration = 0.0006
# Total train chrF after 49 iteration = 92.8420
# Average val loss after 49 iteration = 0.0274
# Total val chrF after 49 iteration = 75.4778
# Average test loss after 49 iteration = 0.0277
# Total test chrF after 49 iteration = 76.7148
# Dumping after  49
# Time for the iteration 10.3 seconds
#
#
# Average train loss after 50 iteration = 0.0005
# Total train chrF after 50 iteration = 92.8511
# Average val loss after 50 iteration = 0.0276
# Total val chrF after 50 iteration = 75.5188
# Average test loss after 50 iteration = 0.0279
# Total test chrF after 50 iteration = 76.7283
# Dumping after  50
# Time for the iteration 10.4 seconds
#
#
# Average train loss after 51 iteration = 0.0005
# Total train chrF after 51 iteration = 92.8554
# Average val loss after 51 iteration = 0.0278
# Total val chrF after 51 iteration = 75.5055
# Average test loss after 51 iteration = 0.0281
# Total test chrF after 51 iteration = 76.7139
# Time for the iteration 10.4 seconds
#
#
# Average train loss after 52 iteration = 0.0004
# Total train chrF after 52 iteration = 92.8603
# Average val loss after 52 iteration = 0.0280
# Total val chrF after 52 iteration = 75.5315
# Average test loss after 52 iteration = 0.0283
# Total test chrF after 52 iteration = 76.7379
# Dumping after  52
# Time for the iteration 10.4 seconds
#
#
# Average train loss after 53 iteration = 0.0004
# Total train chrF after 53 iteration = 92.8640
# Average val loss after 53 iteration = 0.0282
# Total val chrF after 53 iteration = 75.5825
# Average test loss after 53 iteration = 0.0285
# Total test chrF after 53 iteration = 76.7377
# Dumping after  53
# Time for the iteration 10.3 seconds
#
#
# Average train loss after 54 iteration = 0.0004
# Total train chrF after 54 iteration = 92.8679
# Average val loss after 54 iteration = 0.0284
# Total val chrF after 54 iteration = 75.5639
# Average test loss after 54 iteration = 0.0288
# Total test chrF after 54 iteration = 76.7984
# Time for the iteration 10.3 seconds
#
#
# Average train loss after 55 iteration = 0.0004
# Total train chrF after 55 iteration = 92.8718
# Average val loss after 55 iteration = 0.0286
# Total val chrF after 55 iteration = 75.6119
# Average test loss after 55 iteration = 0.0290
# Total test chrF after 55 iteration = 76.8041
# Dumping after  55
# Time for the iteration 10.4 seconds
#
#
# Average train loss after 56 iteration = 0.0003
# Total train chrF after 56 iteration = 92.8740
# Average val loss after 56 iteration = 0.0288
# Total val chrF after 56 iteration = 75.6198
# Average test loss after 56 iteration = 0.0292
# Total test chrF after 56 iteration = 76.8057
# Dumping after  56
# Time for the iteration 10.3 seconds
#
#
# Average train loss after 57 iteration = 0.0003
# Total train chrF after 57 iteration = 92.8752
# Average val loss after 57 iteration = 0.0290
# Total val chrF after 57 iteration = 75.6412
# Average test loss after 57 iteration = 0.0295
# Total test chrF after 57 iteration = 76.8230
# Dumping after  57
# Time for the iteration 10.4 seconds
#
#
# Average train loss after 58 iteration = 0.0003
# Total train chrF after 58 iteration = 92.8787
# Average val loss after 58 iteration = 0.0292
# Total val chrF after 58 iteration = 75.6438
# Average test loss after 58 iteration = 0.0297
# Total test chrF after 58 iteration = 76.7977
# Dumping after  58
# Time for the iteration 10.5 seconds
#
#
# Average train loss after 59 iteration = 0.0003
# Total train chrF after 59 iteration = 92.8844
# Average val loss after 59 iteration = 0.0295
# Total val chrF after 59 iteration = 75.6208
# Average test loss after 59 iteration = 0.0300
# Total test chrF after 59 iteration = 76.7940
# Time for the iteration 10.4 seconds
#
#
# Average train loss after 60 iteration = 0.0002
# Total train chrF after 60 iteration = 92.8929
# Average val loss after 60 iteration = 0.0297
# Total val chrF after 60 iteration = 75.6496
# Average test loss after 60 iteration = 0.0302
# Total test chrF after 60 iteration = 76.7599
# Dumping after  60
# Time for the iteration 10.3 seconds
#
#
# Average train loss after 61 iteration = 0.0002
# Total train chrF after 61 iteration = 92.8916
# Average val loss after 61 iteration = 0.0299
# Total val chrF after 61 iteration = 75.6255
# Average test loss after 61 iteration = 0.0305
# Total test chrF after 61 iteration = 76.8008
# Time for the iteration 10.3 seconds
#
#
# Average train loss after 62 iteration = 0.0002
# Total train chrF after 62 iteration = 92.8932
# Average val loss after 62 iteration = 0.0302
# Total val chrF after 62 iteration = 75.6669
# Average test loss after 62 iteration = 0.0307
# Total test chrF after 62 iteration = 76.8031
# Dumping after  62
# Time for the iteration 10.3 seconds
#
#
# Average train loss after 63 iteration = 0.0002
# Total train chrF after 63 iteration = 92.8954
# Average val loss after 63 iteration = 0.0304
# Total val chrF after 63 iteration = 75.6577
# Average test loss after 63 iteration = 0.0309
# Total test chrF after 63 iteration = 76.8005
# Time for the iteration 10.3 seconds
#
#
# Average train loss after 64 iteration = 0.0002
# Total train chrF after 64 iteration = 92.8974
# Average val loss after 64 iteration = 0.0306
# Total val chrF after 64 iteration = 75.6868
# Average test loss after 64 iteration = 0.0312
# Total test chrF after 64 iteration = 76.8563
# Dumping after  64
# Time for the iteration 10.4 seconds
#
#
# Average train loss after 65 iteration = 0.0002
# Total train chrF after 65 iteration = 92.8989
# Average val loss after 65 iteration = 0.0308
# Total val chrF after 65 iteration = 75.7126
# Average test loss after 65 iteration = 0.0314
# Total test chrF after 65 iteration = 76.8645
# Dumping after  65
# Time for the iteration 10.3 seconds
#
#
# Average train loss after 66 iteration = 0.0002
# Total train chrF after 66 iteration = 92.8999
# Average val loss after 66 iteration = 0.0310
# Total val chrF after 66 iteration = 75.7511
# Average test loss after 66 iteration = 0.0317
# Total test chrF after 66 iteration = 76.8850
# Dumping after  66
# Time for the iteration 10.4 seconds
#
#
# Average train loss after 67 iteration = 0.0001
# Total train chrF after 67 iteration = 92.9006
# Average val loss after 67 iteration = 0.0313
# Total val chrF after 67 iteration = 75.7408
# Average test loss after 67 iteration = 0.0320
# Total test chrF after 67 iteration = 76.9312
# Time for the iteration 10.5 seconds
#
#
# Average train loss after 68 iteration = 0.0001
# Total train chrF after 68 iteration = 92.9013
# Average val loss after 68 iteration = 0.0314
# Total val chrF after 68 iteration = 75.7835
# Average test loss after 68 iteration = 0.0321
# Total test chrF after 68 iteration = 76.8920
# Dumping after  68
# Time for the iteration 10.3 seconds
#
#
# Average train loss after 69 iteration = 0.0001
# Total train chrF after 69 iteration = 92.9021
# Average val loss after 69 iteration = 0.0318
# Total val chrF after 69 iteration = 75.8048
# Average test loss after 69 iteration = 0.0325
# Total test chrF after 69 iteration = 76.8963
# Dumping after  69
# Time for the iteration 10.4 seconds
#
#
# Average train loss after 70 iteration = 0.0001
# Total train chrF after 70 iteration = 92.9028
# Average val loss after 70 iteration = 0.0320
# Total val chrF after 70 iteration = 75.8127
# Average test loss after 70 iteration = 0.0326
# Total test chrF after 70 iteration = 76.9165
# Dumping after  70
# Time for the iteration 10.4 seconds
#
#
# Average train loss after 71 iteration = 0.0001
# Total train chrF after 71 iteration = 92.9029
# Average val loss after 71 iteration = 0.0322
# Total val chrF after 71 iteration = 75.8373
# Average test loss after 71 iteration = 0.0329
# Total test chrF after 71 iteration = 76.9205
# Dumping after  71
# Time for the iteration 10.3 seconds
#
#
# Average train loss after 72 iteration = 0.0001
# Total train chrF after 72 iteration = 92.9013
# Average val loss after 72 iteration = 0.0326
# Total val chrF after 72 iteration = 75.8645
# Average test loss after 72 iteration = 0.0331
# Total test chrF after 72 iteration = 76.8843
# Dumping after  72
# Time for the iteration 10.6 seconds
#
#
# Average train loss after 73 iteration = 0.0001
# Total train chrF after 73 iteration = 92.9007
# Average val loss after 73 iteration = 0.0327
# Total val chrF after 73 iteration = 75.7929
# Average test loss after 73 iteration = 0.0334
# Total test chrF after 73 iteration = 76.7737
# Time for the iteration 10.4 seconds
#
#
# Average train loss after 74 iteration = 0.0001
# Total train chrF after 74 iteration = 92.9022
# Average val loss after 74 iteration = 0.0328
# Total val chrF after 74 iteration = 75.8533
# Average test loss after 74 iteration = 0.0335
# Total test chrF after 74 iteration = 76.9093
# Time for the iteration 10.4 seconds
#
#
# Average train loss after 75 iteration = 0.0001
# Total train chrF after 75 iteration = 92.9025
# Average val loss after 75 iteration = 0.0329
# Total val chrF after 75 iteration = 75.8180
# Average test loss after 75 iteration = 0.0337
# Total test chrF after 75 iteration = 76.9152
# Time for the iteration 10.3 seconds
#
#
# Average train loss after 76 iteration = 0.0001
# Total train chrF after 76 iteration = 92.9022
# Average val loss after 76 iteration = 0.0333
# Total val chrF after 76 iteration = 75.7351
# Average test loss after 76 iteration = 0.0340
# Total test chrF after 76 iteration = 76.9061
# Time for the iteration 10.4 seconds
#
#
# Average train loss after 77 iteration = 0.0001
# Total train chrF after 77 iteration = 92.9040
# Average val loss after 77 iteration = 0.0335
# Total val chrF after 77 iteration = 75.7398
# Average test loss after 77 iteration = 0.0342
# Total test chrF after 77 iteration = 76.9876
# Time for the iteration 10.3 seconds
#
#
# Average train loss after 78 iteration = 0.0001
# Total train chrF after 78 iteration = 92.9043
# Average val loss after 78 iteration = 0.0337
# Total val chrF after 78 iteration = 75.7479
# Average test loss after 78 iteration = 0.0345
# Total test chrF after 78 iteration = 76.9596
# Time for the iteration 10.3 seconds
#
#
# Average train loss after 79 iteration = 0.0001
# Total train chrF after 79 iteration = 92.9046
# Average val loss after 79 iteration = 0.0340
# Total val chrF after 79 iteration = 75.7408
# Average test loss after 79 iteration = 0.0347
# Total test chrF after 79 iteration = 76.9606
# Time for the iteration 10.4 seconds
#
#
# Average train loss after 80 iteration = 0.0001
# Total train chrF after 80 iteration = 92.9048
# Average val loss after 80 iteration = 0.0342
# Total val chrF after 80 iteration = 75.7598
# Average test loss after 80 iteration = 0.0349
# Total test chrF after 80 iteration = 76.9197
# Time for the iteration 10.4 seconds
#
#
# Average train loss after 81 iteration = 0.0001
# Total train chrF after 81 iteration = 92.9048
# Average val loss after 81 iteration = 0.0345
# Total val chrF after 81 iteration = 75.7764
# Average test loss after 81 iteration = 0.0352
# Total test chrF after 81 iteration = 76.9413
# Time for the iteration 10.3 seconds
#
#
# Average train loss after 82 iteration = 0.0000
# Total train chrF after 82 iteration = 92.9048
# Average val loss after 82 iteration = 0.0346
# Total val chrF after 82 iteration = 75.7642
# Average test loss after 82 iteration = 0.0353
# Total test chrF after 82 iteration = 76.8963
# Time for the iteration 10.4 seconds
#
#
# Average train loss after 83 iteration = 0.0000
# Total train chrF after 83 iteration = 92.9050
# Average val loss after 83 iteration = 0.0350
# Total val chrF after 83 iteration = 75.8030
# Average test loss after 83 iteration = 0.0356
# Total test chrF after 83 iteration = 76.9139
# Time for the iteration 10.3 seconds
#
#
# Average train loss after 84 iteration = 0.0000
# Total train chrF after 84 iteration = 92.9050
# Average val loss after 84 iteration = 0.0352
# Total val chrF after 84 iteration = 75.7939
# Average test loss after 84 iteration = 0.0359
# Total test chrF after 84 iteration = 76.9125
# Time for the iteration 10.3 seconds
#
#
# Average train loss after 85 iteration = 0.0000
# Total train chrF after 85 iteration = 92.9041
# Average val loss after 85 iteration = 0.0353
# Total val chrF after 85 iteration = 75.8105
# Average test loss after 85 iteration = 0.0360
# Total test chrF after 85 iteration = 76.9746
# Time for the iteration 10.4 seconds
#
#
# Average train loss after 86 iteration = 0.0000
# Total train chrF after 86 iteration = 92.9050
# Average val loss after 86 iteration = 0.0355
# Total val chrF after 86 iteration = 75.8641
# Average test loss after 86 iteration = 0.0362
# Total test chrF after 86 iteration = 76.8653
# Time for the iteration 10.4 seconds
#
#
# Average train loss after 87 iteration = 0.0000
# Total train chrF after 87 iteration = 92.9050
# Average val loss after 87 iteration = 0.0358
# Total val chrF after 87 iteration = 75.8888
# Average test loss after 87 iteration = 0.0365
# Total test chrF after 87 iteration = 76.8636
# Dumping after  87
# Time for the iteration 10.3 seconds
#
#
# Average train loss after 88 iteration = 0.0000
# Total train chrF after 88 iteration = 92.9050
# Average val loss after 88 iteration = 0.0360
# Total val chrF after 88 iteration = 75.8453
# Average test loss after 88 iteration = 0.0367
# Total test chrF after 88 iteration = 76.8419
# Time for the iteration 10.4 seconds
#
#
# Average train loss after 89 iteration = 0.0000
# Total train chrF after 89 iteration = 92.9050
# Average val loss after 89 iteration = 0.0362
# Total val chrF after 89 iteration = 75.8259
# Average test loss after 89 iteration = 0.0369
# Total test chrF after 89 iteration = 76.7831
# Time for the iteration 10.5 seconds
#
#
# Average train loss after 90 iteration = 0.0000
# Total train chrF after 90 iteration = 92.9050
# Average val loss after 90 iteration = 0.0365
# Total val chrF after 90 iteration = 75.8556
# Average test loss after 90 iteration = 0.0372
# Total test chrF after 90 iteration = 76.7947
# Time for the iteration 10.4 seconds
#
#
# Average train loss after 91 iteration = 0.0000
# Total train chrF after 91 iteration = 92.9050
# Average val loss after 91 iteration = 0.0367
# Total val chrF after 91 iteration = 75.8286
# Average test loss after 91 iteration = 0.0374
# Total test chrF after 91 iteration = 76.8019
# Time for the iteration 10.4 seconds
#
#
# Average train loss after 92 iteration = 0.0000
# Total train chrF after 92 iteration = 92.9050
# Average val loss after 92 iteration = 0.0370
# Total val chrF after 92 iteration = 75.8416
# Average test loss after 92 iteration = 0.0377
# Total test chrF after 92 iteration = 76.8136
# Time for the iteration 10.4 seconds
#
#
# Average train loss after 93 iteration = 0.0000
# Total train chrF after 93 iteration = 92.9050
# Average val loss after 93 iteration = 0.0371
# Total val chrF after 93 iteration = 75.8363
# Average test loss after 93 iteration = 0.0379
# Total test chrF after 93 iteration = 76.8421
# Time for the iteration 10.3 seconds
#
#
# Average train loss after 94 iteration = 0.0000
# Total train chrF after 94 iteration = 92.9024
# Average val loss after 94 iteration = 0.0376
# Total val chrF after 94 iteration = 75.6901
# Average test loss after 94 iteration = 0.0379
# Total test chrF after 94 iteration = 76.8425
# Time for the iteration 10.3 seconds
#
#
# Average train loss after 95 iteration = 0.0000
# Total train chrF after 95 iteration = 92.9042
# Average val loss after 95 iteration = 0.0376
# Total val chrF after 95 iteration = 75.7509
# Average test loss after 95 iteration = 0.0384
# Total test chrF after 95 iteration = 76.7248
# Time for the iteration 10.3 seconds
#
#
# Average train loss after 96 iteration = 0.0000
# Total train chrF after 96 iteration = 92.9050
# Average val loss after 96 iteration = 0.0377
# Total val chrF after 96 iteration = 75.7099
# Average test loss after 96 iteration = 0.0387
# Total test chrF after 96 iteration = 76.8510
# Time for the iteration 10.3 seconds
#
#
# Average train loss after 97 iteration = 0.0000
# Total train chrF after 97 iteration = 92.9050
# Average val loss after 97 iteration = 0.0379
# Total val chrF after 97 iteration = 75.7468
# Average test loss after 97 iteration = 0.0389
# Total test chrF after 97 iteration = 76.8801
# Time for the iteration 10.4 seconds
#
#
# Average train loss after 98 iteration = 0.0000
# Total train chrF after 98 iteration = 92.9050
# Average val loss after 98 iteration = 0.0381
# Total val chrF after 98 iteration = 75.7869
# Average test loss after 98 iteration = 0.0391
# Total test chrF after 98 iteration = 76.8868
# Time for the iteration 10.4 seconds
#
#
# Average train loss after 99 iteration = 0.0000
# Total train chrF after 99 iteration = 92.9050
# Average val loss after 99 iteration = 0.0383
# Total val chrF after 99 iteration = 75.7528
# Average test loss after 99 iteration = 0.0393
# Total test chrF after 99 iteration = 76.9135
# Time for the iteration 10.4 seconds
#
#
# Average train loss after 100 iteration = 0.0000
# Total train chrF after 100 iteration = 92.9050
# Average val loss after 100 iteration = 0.0385
# Total val chrF after 100 iteration = 75.7253
# Average test loss after 100 iteration = 0.0395
# Total test chrF after 100 iteration = 76.8969
# Time for the iteration 10.4 seconds
#
#
# <Figure size 640x480 with 1 Axes>
# <Figure size 640x480 with 1 Axes>

# %%
language = "ya"
task_name = "unnorm_teacher_general"
vocab_size = 4999
num_epochs = 100
batch_size = 32
model = "50_1"
optimizer = "Adam"
metric = "chrF"

# %%
from IPython.display import Image

Image("curves/{}_{}_{}_{}_{}_loss.png".format(language, task_name, vocab_size, num_epochs, batch_size))

# %%
Image("curves/{}_{}_{}_{}_{}_{}.png".format(language, task_name, vocab_size, num_epochs, batch_size, metric))

# %%
print("{}.{}.{}.{}.{}.{}.{}".format(language, task_name, vocab_size, num_epochs, batch_size, model, optimizer))
# Out:
# ya.unnorm_teacher_general.4999.100.32.50_1.Adam
