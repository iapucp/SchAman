# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
# %cd "drive/MyDrive/Tesis/scRNN"
# Out:
# /content/drive/MyDrive/Tesis/scRNN

# %%
import torch

torch.cuda.is_available()
# Out:
# True

# %%
# !pip install sacrebleu
# Out:
# Collecting sacrebleu
#   Downloading sacrebleu-2.0.0-py3-none-any.whl (90 kB)
#      |████████████████████████████████| 90 kB 5.2 MB/s
# Collecting colorama
#   Downloading colorama-0.4.4-py2.py3-none-any.whl (16 kB)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from sacrebleu) (1.19.5)
# Requirement already satisfied: tabulate>=0.8.9 in /usr/local/lib/python3.7/dist-packages (from sacrebleu) (0.8.9)
# Requirement already satisfied: regex in /usr/local/lib/python3.7/dist-packages (from sacrebleu) (2019.12.20)
# Collecting portalocker
#   Downloading portalocker-2.3.2-py2.py3-none-any.whl (15 kB)
# Installing collected packages: portalocker, colorama, sacrebleu
# Successfully installed colorama-0.4.4 portalocker-2.3.2 sacrebleu-2.0.0

# %%
# !python3 train.py --language ya --task-name random_teacher_general --num-epochs 100 --batch-size 32 --vocab-size 4999 --new-vocab --train --train-sentences-errors-file ya.random_teacher_general.train.sentences.errors.txt --train-sentences-file ya.random_teacher_general.train.sentences.txt --val-sentences-errors-file ya.teacher_general.val.sentences.errors.txt --val-sentences-file ya.teacher_general.val.sentences.txt --test-sentences-errors-file ya.teacher_general.test.sentences.errors.txt --test-sentences-file ya.teacher_general.test.sentences.txt --metric chrF --save
# Out:
# Parameters
# {'language': 'ya', 'task_name': 'random_teacher_general', 'vocab_size': 4999, 'num_epochs': 100, 'batch_size': 32, 'model_name': 'shi_random_20531_100_32', 'new_vocab': True, 'need_to_train': True, 'train_sentences_errors_file': 'ya.random_teacher_general.train.sentences.errors.txt', 'train_sentences_file': 'ya.random_teacher_general.train.sentences.txt', 'val_sentences_errors_file': 'ya.teacher_general.val.sentences.errors.txt', 'val_sentences_file': 'ya.teacher_general.val.sentences.txt', 'test_sentences_errors_file': 'ya.teacher_general.test.sentences.errors.txt', 'test_sentences_file': 'ya.teacher_general.test.sentences.txt', 'metric': 'chrF', 'save_model': True}
#
#
# Creating new vocabulary
# Len of w2i:  4999
# Len of i2w:  4999
# Len of char vocab:  32
#
#
# Initializing an only ScRNN model
#
#
# Training the model...
#
# Average train loss after 1 iteration = 0.1741
# Total train chrF after 1 iteration = 62.7584
# Average val loss after 1 iteration = 0.2376
# Total val chrF after 1 iteration = 70.6021
# Average test loss after 1 iteration = 0.2360
# Total test chrF after 1 iteration = 71.1796
# Dumping after  1
# Time for the iteration 10.6 seconds
#
#
# Average train loss after 2 iteration = 0.1389
# Total train chrF after 2 iteration = 63.7708
# Average val loss after 2 iteration = 0.1403
# Total val chrF after 2 iteration = 70.7698
# Average test loss after 2 iteration = 0.1374
# Total test chrF after 2 iteration = 71.2713
# Dumping after  2
# Time for the iteration 10.3 seconds
#
#
# Average train loss after 3 iteration = 0.1088
# Total train chrF after 3 iteration = 67.1810
# Average val loss after 3 iteration = 0.1103
# Total val chrF after 3 iteration = 70.8397
# Average test loss after 3 iteration = 0.1073
# Total test chrF after 3 iteration = 71.3991
# Dumping after  3
# Time for the iteration 10.3 seconds
#
#
# Average train loss after 4 iteration = 0.0880
# Total train chrF after 4 iteration = 69.7678
# Average val loss after 4 iteration = 0.0933
# Total val chrF after 4 iteration = 70.8695
# Average test loss after 4 iteration = 0.0906
# Total test chrF after 4 iteration = 71.5681
# Dumping after  4
# Time for the iteration 10.4 seconds
#
#
# Average train loss after 5 iteration = 0.0720
# Total train chrF after 5 iteration = 71.9282
# Average val loss after 5 iteration = 0.0805
# Total val chrF after 5 iteration = 70.9968
# Average test loss after 5 iteration = 0.0783
# Total test chrF after 5 iteration = 71.6578
# Dumping after  5
# Time for the iteration 10.4 seconds
#
#
# Average train loss after 6 iteration = 0.0591
# Total train chrF after 6 iteration = 73.7656
# Average val loss after 6 iteration = 0.0696
# Total val chrF after 6 iteration = 71.2880
# Average test loss after 6 iteration = 0.0679
# Total test chrF after 6 iteration = 71.8382
# Dumping after  6
# Time for the iteration 10.4 seconds
#
#
# Average train loss after 7 iteration = 0.0490
# Total train chrF after 7 iteration = 75.3149
# Average val loss after 7 iteration = 0.0612
# Total val chrF after 7 iteration = 71.5711
# Average test loss after 7 iteration = 0.0598
# Total test chrF after 7 iteration = 71.9733
# Dumping after  7
# Time for the iteration 10.6 seconds
#
#
# Average train loss after 8 iteration = 0.0412
# Total train chrF after 8 iteration = 76.6792
# Average val loss after 8 iteration = 0.0542
# Total val chrF after 8 iteration = 71.7883
# Average test loss after 8 iteration = 0.0532
# Total test chrF after 8 iteration = 72.1249
# Dumping after  8
# Time for the iteration 10.6 seconds
#
#
# Average train loss after 9 iteration = 0.0350
# Total train chrF after 9 iteration = 77.8908
# Average val loss after 9 iteration = 0.0485
# Total val chrF after 9 iteration = 72.0289
# Average test loss after 9 iteration = 0.0476
# Total test chrF after 9 iteration = 72.3706
# Dumping after  9
# Time for the iteration 10.5 seconds
#
#
# Average train loss after 10 iteration = 0.0300
# Total train chrF after 10 iteration = 79.0220
# Average val loss after 10 iteration = 0.0440
# Total val chrF after 10 iteration = 72.2031
# Average test loss after 10 iteration = 0.0432
# Total test chrF after 10 iteration = 72.6625
# Dumping after  10
# Time for the iteration 10.5 seconds
#
#
# Average train loss after 11 iteration = 0.0261
# Total train chrF after 11 iteration = 80.0164
# Average val loss after 11 iteration = 0.0404
# Total val chrF after 11 iteration = 72.4504
# Average test loss after 11 iteration = 0.0398
# Total test chrF after 11 iteration = 73.0046
# Dumping after  11
# Time for the iteration 10.4 seconds
#
#
# Average train loss after 12 iteration = 0.0230
# Total train chrF after 12 iteration = 80.9360
# Average val loss after 12 iteration = 0.0376
# Total val chrF after 12 iteration = 72.6578
# Average test loss after 12 iteration = 0.0372
# Total test chrF after 12 iteration = 73.2921
# Dumping after  12
# Time for the iteration 10.5 seconds
#
#
# Average train loss after 13 iteration = 0.0204
# Total train chrF after 13 iteration = 81.8558
# Average val loss after 13 iteration = 0.0355
# Total val chrF after 13 iteration = 72.7693
# Average test loss after 13 iteration = 0.0351
# Total test chrF after 13 iteration = 73.4486
# Dumping after  13
# Time for the iteration 10.5 seconds
#
#
# Average train loss after 14 iteration = 0.0183
# Total train chrF after 14 iteration = 82.6160
# Average val loss after 14 iteration = 0.0338
# Total val chrF after 14 iteration = 72.8664
# Average test loss after 14 iteration = 0.0335
# Total test chrF after 14 iteration = 73.6793
# Dumping after  14
# Time for the iteration 10.6 seconds
#
#
# Average train loss after 15 iteration = 0.0166
# Total train chrF after 15 iteration = 83.3115
# Average val loss after 15 iteration = 0.0325
# Total val chrF after 15 iteration = 73.0266
# Average test loss after 15 iteration = 0.0323
# Total test chrF after 15 iteration = 73.8050
# Dumping after  15
# Time for the iteration 10.6 seconds
#
#
# Average train loss after 16 iteration = 0.0152
# Total train chrF after 16 iteration = 83.9205
# Average val loss after 16 iteration = 0.0314
# Total val chrF after 16 iteration = 73.1329
# Average test loss after 16 iteration = 0.0313
# Total test chrF after 16 iteration = 73.9284
# Dumping after  16
# Time for the iteration 10.5 seconds
#
#
# Average train loss after 17 iteration = 0.0139
# Total train chrF after 17 iteration = 84.4625
# Average val loss after 17 iteration = 0.0306
# Total val chrF after 17 iteration = 73.3323
# Average test loss after 17 iteration = 0.0305
# Total test chrF after 17 iteration = 74.0462
# Dumping after  17
# Time for the iteration 10.5 seconds
#
#
# Average train loss after 18 iteration = 0.0129
# Total train chrF after 18 iteration = 84.9145
# Average val loss after 18 iteration = 0.0299
# Total val chrF after 18 iteration = 73.3513
# Average test loss after 18 iteration = 0.0298
# Total test chrF after 18 iteration = 74.1360
# Dumping after  18
# Time for the iteration 10.5 seconds
#
#
# Average train loss after 19 iteration = 0.0119
# Total train chrF after 19 iteration = 85.2883
# Average val loss after 19 iteration = 0.0293
# Total val chrF after 19 iteration = 73.5268
# Average test loss after 19 iteration = 0.0293
# Total test chrF after 19 iteration = 74.1993
# Dumping after  19
# Time for the iteration 10.6 seconds
#
#
# Average train loss after 20 iteration = 0.0111
# Total train chrF after 20 iteration = 85.5917
# Average val loss after 20 iteration = 0.0288
# Total val chrF after 20 iteration = 73.5584
# Average test loss after 20 iteration = 0.0288
# Total test chrF after 20 iteration = 74.3401
# Dumping after  20
# Time for the iteration 10.6 seconds
#
#
# Average train loss after 21 iteration = 0.0104
# Total train chrF after 21 iteration = 85.8967
# Average val loss after 21 iteration = 0.0284
# Total val chrF after 21 iteration = 73.6467
# Average test loss after 21 iteration = 0.0285
# Total test chrF after 21 iteration = 74.2783
# Dumping after  21
# Time for the iteration 10.5 seconds
#
#
# Average train loss after 22 iteration = 0.0097
# Total train chrF after 22 iteration = 86.1275
# Average val loss after 22 iteration = 0.0281
# Total val chrF after 22 iteration = 73.6997
# Average test loss after 22 iteration = 0.0281
# Total test chrF after 22 iteration = 74.4358
# Dumping after  22
# Time for the iteration 10.6 seconds
#
#
# Average train loss after 23 iteration = 0.0091
# Total train chrF after 23 iteration = 86.3528
# Average val loss after 23 iteration = 0.0278
# Total val chrF after 23 iteration = 73.7245
# Average test loss after 23 iteration = 0.0279
# Total test chrF after 23 iteration = 74.5652
# Dumping after  23
# Time for the iteration 10.6 seconds
#
#
# Average train loss after 24 iteration = 0.0086
# Total train chrF after 24 iteration = 86.5588
# Average val loss after 24 iteration = 0.0275
# Total val chrF after 24 iteration = 73.9023
# Average test loss after 24 iteration = 0.0277
# Total test chrF after 24 iteration = 74.5586
# Dumping after  24
# Time for the iteration 10.6 seconds
#
#
# Average train loss after 25 iteration = 0.0081
# Total train chrF after 25 iteration = 86.7611
# Average val loss after 25 iteration = 0.0273
# Total val chrF after 25 iteration = 73.9372
# Average test loss after 25 iteration = 0.0275
# Total test chrF after 25 iteration = 74.6572
# Dumping after  25
# Time for the iteration 10.6 seconds
#
#
# Average train loss after 26 iteration = 0.0076
# Total train chrF after 26 iteration = 86.9200
# Average val loss after 26 iteration = 0.0272
# Total val chrF after 26 iteration = 73.9743
# Average test loss after 26 iteration = 0.0273
# Total test chrF after 26 iteration = 74.7932
# Dumping after  26
# Time for the iteration 10.5 seconds
#
#
# Average train loss after 27 iteration = 0.0072
# Total train chrF after 27 iteration = 87.0750
# Average val loss after 27 iteration = 0.0270
# Total val chrF after 27 iteration = 74.0789
# Average test loss after 27 iteration = 0.0272
# Total test chrF after 27 iteration = 74.8825
# Dumping after  27
# Time for the iteration 10.6 seconds
#
#
# Average train loss after 28 iteration = 0.0068
# Total train chrF after 28 iteration = 87.2306
# Average val loss after 28 iteration = 0.0269
# Total val chrF after 28 iteration = 74.2094
# Average test loss after 28 iteration = 0.0271
# Total test chrF after 28 iteration = 74.8906
# Dumping after  28
# Time for the iteration 10.5 seconds
#
#
# Average train loss after 29 iteration = 0.0065
# Total train chrF after 29 iteration = 87.3545
# Average val loss after 29 iteration = 0.0269
# Total val chrF after 29 iteration = 74.1864
# Average test loss after 29 iteration = 0.0270
# Total test chrF after 29 iteration = 74.8407
# Time for the iteration 10.7 seconds
#
#
# Average train loss after 30 iteration = 0.0061
# Total train chrF after 30 iteration = 87.4711
# Average val loss after 30 iteration = 0.0268
# Total val chrF after 30 iteration = 74.2908
# Average test loss after 30 iteration = 0.0269
# Total test chrF after 30 iteration = 74.8765
# Dumping after  30
# Time for the iteration 10.6 seconds
#
#
# Average train loss after 31 iteration = 0.0058
# Total train chrF after 31 iteration = 87.5644
# Average val loss after 31 iteration = 0.0268
# Total val chrF after 31 iteration = 74.3167
# Average test loss after 31 iteration = 0.0269
# Total test chrF after 31 iteration = 74.9670
# Dumping after  31
# Time for the iteration 10.6 seconds
#
#
# Average train loss after 32 iteration = 0.0055
# Total train chrF after 32 iteration = 87.6572
# Average val loss after 32 iteration = 0.0267
# Total val chrF after 32 iteration = 74.3025
# Average test loss after 32 iteration = 0.0269
# Total test chrF after 32 iteration = 75.0952
# Time for the iteration 10.6 seconds
#
#
# Average train loss after 33 iteration = 0.0052
# Total train chrF after 33 iteration = 87.7542
# Average val loss after 33 iteration = 0.0267
# Total val chrF after 33 iteration = 74.2422
# Average test loss after 33 iteration = 0.0269
# Total test chrF after 33 iteration = 75.0771
# Time for the iteration 10.5 seconds
#
#
# Average train loss after 34 iteration = 0.0049
# Total train chrF after 34 iteration = 87.8400
# Average val loss after 34 iteration = 0.0267
# Total val chrF after 34 iteration = 74.2368
# Average test loss after 34 iteration = 0.0269
# Total test chrF after 34 iteration = 75.1287
# Time for the iteration 10.5 seconds
#
#
# Average train loss after 35 iteration = 0.0047
# Total train chrF after 35 iteration = 87.9153
# Average val loss after 35 iteration = 0.0268
# Total val chrF after 35 iteration = 74.2200
# Average test loss after 35 iteration = 0.0269
# Total test chrF after 35 iteration = 75.1923
# Time for the iteration 10.6 seconds
#
#
# Average train loss after 36 iteration = 0.0045
# Total train chrF after 36 iteration = 87.9923
# Average val loss after 36 iteration = 0.0268
# Total val chrF after 36 iteration = 74.2551
# Average test loss after 36 iteration = 0.0270
# Total test chrF after 36 iteration = 75.2438
# Time for the iteration 10.6 seconds
#
#
# Average train loss after 37 iteration = 0.0042
# Total train chrF after 37 iteration = 88.0482
# Average val loss after 37 iteration = 0.0268
# Total val chrF after 37 iteration = 74.2495
# Average test loss after 37 iteration = 0.0270
# Total test chrF after 37 iteration = 75.2589
# Time for the iteration 10.6 seconds
#
#
# Average train loss after 38 iteration = 0.0040
# Total train chrF after 38 iteration = 88.1040
# Average val loss after 38 iteration = 0.0269
# Total val chrF after 38 iteration = 74.2248
# Average test loss after 38 iteration = 0.0271
# Total test chrF after 38 iteration = 75.1802
# Time for the iteration 10.6 seconds
#
#
# Average train loss after 39 iteration = 0.0038
# Total train chrF after 39 iteration = 88.1704
# Average val loss after 39 iteration = 0.0270
# Total val chrF after 39 iteration = 74.2323
# Average test loss after 39 iteration = 0.0271
# Total test chrF after 39 iteration = 75.1872
# Time for the iteration 10.6 seconds
#
#
# Average train loss after 40 iteration = 0.0036
# Total train chrF after 40 iteration = 88.2326
# Average val loss after 40 iteration = 0.0270
# Total val chrF after 40 iteration = 74.2495
# Average test loss after 40 iteration = 0.0272
# Total test chrF after 40 iteration = 75.1912
# Time for the iteration 10.5 seconds
#
#
# Average train loss after 41 iteration = 0.0035
# Total train chrF after 41 iteration = 88.2837
# Average val loss after 41 iteration = 0.0271
# Total val chrF after 41 iteration = 74.1519
# Average test loss after 41 iteration = 0.0273
# Total test chrF after 41 iteration = 75.1903
# Time for the iteration 10.5 seconds
#
#
# Average train loss after 42 iteration = 0.0033
# Total train chrF after 42 iteration = 88.3265
# Average val loss after 42 iteration = 0.0272
# Total val chrF after 42 iteration = 74.1917
# Average test loss after 42 iteration = 0.0274
# Total test chrF after 42 iteration = 75.1849
# Time for the iteration 10.6 seconds
#
#
# Average train loss after 43 iteration = 0.0031
# Total train chrF after 43 iteration = 88.3702
# Average val loss after 43 iteration = 0.0273
# Total val chrF after 43 iteration = 74.2580
# Average test loss after 43 iteration = 0.0275
# Total test chrF after 43 iteration = 75.1638
# Time for the iteration 10.5 seconds
#
#
# Average train loss after 44 iteration = 0.0030
# Total train chrF after 44 iteration = 88.4025
# Average val loss after 44 iteration = 0.0274
# Total val chrF after 44 iteration = 74.2667
# Average test loss after 44 iteration = 0.0276
# Total test chrF after 44 iteration = 75.1915
# Time for the iteration 10.5 seconds
#
#
# Average train loss after 45 iteration = 0.0028
# Total train chrF after 45 iteration = 88.4384
# Average val loss after 45 iteration = 0.0276
# Total val chrF after 45 iteration = 74.3012
# Average test loss after 45 iteration = 0.0277
# Total test chrF after 45 iteration = 75.1896
# Time for the iteration 10.6 seconds
#
#
# Average train loss after 46 iteration = 0.0027
# Total train chrF after 46 iteration = 88.4743
# Average val loss after 46 iteration = 0.0277
# Total val chrF after 46 iteration = 74.3081
# Average test loss after 46 iteration = 0.0278
# Total test chrF after 46 iteration = 75.2199
# Time for the iteration 10.5 seconds
#
#
# Average train loss after 47 iteration = 0.0026
# Total train chrF after 47 iteration = 88.5108
# Average val loss after 47 iteration = 0.0278
# Total val chrF after 47 iteration = 74.2404
# Average test loss after 47 iteration = 0.0280
# Total test chrF after 47 iteration = 75.2071
# Time for the iteration 10.6 seconds
#
#
# Average train loss after 48 iteration = 0.0025
# Total train chrF after 48 iteration = 88.5416
# Average val loss after 48 iteration = 0.0280
# Total val chrF after 48 iteration = 74.3022
# Average test loss after 48 iteration = 0.0281
# Total test chrF after 48 iteration = 75.1836
# Time for the iteration 10.5 seconds
#
#
# Average train loss after 49 iteration = 0.0023
# Total train chrF after 49 iteration = 88.5695
# Average val loss after 49 iteration = 0.0281
# Total val chrF after 49 iteration = 74.2925
# Average test loss after 49 iteration = 0.0282
# Total test chrF after 49 iteration = 75.1130
# Time for the iteration 10.5 seconds
#
#
# Average train loss after 50 iteration = 0.0022
# Total train chrF after 50 iteration = 88.5984
# Average val loss after 50 iteration = 0.0283
# Total val chrF after 50 iteration = 74.3057
# Average test loss after 50 iteration = 0.0284
# Total test chrF after 50 iteration = 75.1068
# Time for the iteration 10.6 seconds
#
#
# Average train loss after 51 iteration = 0.0021
# Total train chrF after 51 iteration = 88.6248
# Average val loss after 51 iteration = 0.0285
# Total val chrF after 51 iteration = 74.3245
# Average test loss after 51 iteration = 0.0285
# Total test chrF after 51 iteration = 75.1292
# Dumping after  51
# Time for the iteration 10.6 seconds
#
#
# Average train loss after 52 iteration = 0.0020
# Total train chrF after 52 iteration = 88.6491
# Average val loss after 52 iteration = 0.0286
# Total val chrF after 52 iteration = 74.3256
# Average test loss after 52 iteration = 0.0287
# Total test chrF after 52 iteration = 75.1653
# Dumping after  52
# Time for the iteration 10.6 seconds
#
#
# Average train loss after 53 iteration = 0.0019
# Total train chrF after 53 iteration = 88.6694
# Average val loss after 53 iteration = 0.0288
# Total val chrF after 53 iteration = 74.3251
# Average test loss after 53 iteration = 0.0288
# Total test chrF after 53 iteration = 75.1923
# Time for the iteration 10.6 seconds
#
#
# Average train loss after 54 iteration = 0.0018
# Total train chrF after 54 iteration = 88.6894
# Average val loss after 54 iteration = 0.0289
# Total val chrF after 54 iteration = 74.3126
# Average test loss after 54 iteration = 0.0290
# Total test chrF after 54 iteration = 75.1871
# Time for the iteration 10.6 seconds
#
#
# Average train loss after 55 iteration = 0.0017
# Total train chrF after 55 iteration = 88.7077
# Average val loss after 55 iteration = 0.0291
# Total val chrF after 55 iteration = 74.3269
# Average test loss after 55 iteration = 0.0292
# Total test chrF after 55 iteration = 75.2061
# Dumping after  55
# Time for the iteration 10.6 seconds
#
#
# Average train loss after 56 iteration = 0.0017
# Total train chrF after 56 iteration = 88.7260
# Average val loss after 56 iteration = 0.0293
# Total val chrF after 56 iteration = 74.3601
# Average test loss after 56 iteration = 0.0294
# Total test chrF after 56 iteration = 75.1845
# Dumping after  56
# Time for the iteration 10.5 seconds
#
#
# Average train loss after 57 iteration = 0.0016
# Total train chrF after 57 iteration = 88.7444
# Average val loss after 57 iteration = 0.0295
# Total val chrF after 57 iteration = 74.3298
# Average test loss after 57 iteration = 0.0295
# Total test chrF after 57 iteration = 75.1341
# Time for the iteration 10.6 seconds
#
#
# Average train loss after 58 iteration = 0.0015
# Total train chrF after 58 iteration = 88.7637
# Average val loss after 58 iteration = 0.0297
# Total val chrF after 58 iteration = 74.2958
# Average test loss after 58 iteration = 0.0297
# Total test chrF after 58 iteration = 75.0679
# Time for the iteration 10.5 seconds
#
#
# Average train loss after 59 iteration = 0.0014
# Total train chrF after 59 iteration = 88.7774
# Average val loss after 59 iteration = 0.0299
# Total val chrF after 59 iteration = 74.2875
# Average test loss after 59 iteration = 0.0299
# Total test chrF after 59 iteration = 75.0490
# Time for the iteration 10.5 seconds
#
#
# Average train loss after 60 iteration = 0.0014
# Total train chrF after 60 iteration = 88.7978
# Average val loss after 60 iteration = 0.0301
# Total val chrF after 60 iteration = 74.2782
# Average test loss after 60 iteration = 0.0301
# Total test chrF after 60 iteration = 75.0436
# Time for the iteration 10.7 seconds
#
#
# Average train loss after 61 iteration = 0.0013
# Total train chrF after 61 iteration = 88.8134
# Average val loss after 61 iteration = 0.0303
# Total val chrF after 61 iteration = 74.3222
# Average test loss after 61 iteration = 0.0303
# Total test chrF after 61 iteration = 75.0125
# Time for the iteration 10.6 seconds
#
#
# Average train loss after 62 iteration = 0.0012
# Total train chrF after 62 iteration = 88.8229
# Average val loss after 62 iteration = 0.0305
# Total val chrF after 62 iteration = 74.3359
# Average test loss after 62 iteration = 0.0305
# Total test chrF after 62 iteration = 74.9833
# Time for the iteration 10.5 seconds
#
#
# Average train loss after 63 iteration = 0.0012
# Total train chrF after 63 iteration = 88.8336
# Average val loss after 63 iteration = 0.0307
# Total val chrF after 63 iteration = 74.3548
# Average test loss after 63 iteration = 0.0307
# Total test chrF after 63 iteration = 75.0032
# Time for the iteration 10.6 seconds
#
#
# Average train loss after 64 iteration = 0.0011
# Total train chrF after 64 iteration = 88.8458
# Average val loss after 64 iteration = 0.0309
# Total val chrF after 64 iteration = 74.3392
# Average test loss after 64 iteration = 0.0310
# Total test chrF after 64 iteration = 74.9768
# Time for the iteration 10.6 seconds
#
#
# Average train loss after 65 iteration = 0.0010
# Total train chrF after 65 iteration = 88.8537
# Average val loss after 65 iteration = 0.0311
# Total val chrF after 65 iteration = 74.3400
# Average test loss after 65 iteration = 0.0312
# Total test chrF after 65 iteration = 74.9692
# Time for the iteration 10.5 seconds
#
#
# Average train loss after 66 iteration = 0.0010
# Total train chrF after 66 iteration = 88.8599
# Average val loss after 66 iteration = 0.0313
# Total val chrF after 66 iteration = 74.2951
# Average test loss after 66 iteration = 0.0314
# Total test chrF after 66 iteration = 74.9460
# Time for the iteration 10.7 seconds
#
#
# Average train loss after 67 iteration = 0.0009
# Total train chrF after 67 iteration = 88.8663
# Average val loss after 67 iteration = 0.0315
# Total val chrF after 67 iteration = 74.2330
# Average test loss after 67 iteration = 0.0316
# Total test chrF after 67 iteration = 74.8896
# Time for the iteration 10.6 seconds
#
#
# Average train loss after 68 iteration = 0.0009
# Total train chrF after 68 iteration = 88.8725
# Average val loss after 68 iteration = 0.0317
# Total val chrF after 68 iteration = 74.2884
# Average test loss after 68 iteration = 0.0319
# Total test chrF after 68 iteration = 74.8916
# Time for the iteration 10.7 seconds
#
#
# Average train loss after 69 iteration = 0.0009
# Total train chrF after 69 iteration = 88.8789
# Average val loss after 69 iteration = 0.0319
# Total val chrF after 69 iteration = 74.3129
# Average test loss after 69 iteration = 0.0321
# Total test chrF after 69 iteration = 74.9067
# Time for the iteration 10.6 seconds
#
#
# Average train loss after 70 iteration = 0.0008
# Total train chrF after 70 iteration = 88.8841
# Average val loss after 70 iteration = 0.0322
# Total val chrF after 70 iteration = 74.3147
# Average test loss after 70 iteration = 0.0323
# Total test chrF after 70 iteration = 74.9753
# Time for the iteration 10.5 seconds
#
#
# Average train loss after 71 iteration = 0.0008
# Total train chrF after 71 iteration = 88.8898
# Average val loss after 71 iteration = 0.0324
# Total val chrF after 71 iteration = 74.2619
# Average test loss after 71 iteration = 0.0325
# Total test chrF after 71 iteration = 74.9530
# Time for the iteration 10.5 seconds
#
#
# Average train loss after 72 iteration = 0.0007
# Total train chrF after 72 iteration = 88.8947
# Average val loss after 72 iteration = 0.0326
# Total val chrF after 72 iteration = 74.2305
# Average test loss after 72 iteration = 0.0328
# Total test chrF after 72 iteration = 74.9390
# Time for the iteration 10.7 seconds
#
#
# Average train loss after 73 iteration = 0.0007
# Total train chrF after 73 iteration = 88.8987
# Average val loss after 73 iteration = 0.0328
# Total val chrF after 73 iteration = 74.2656
# Average test loss after 73 iteration = 0.0330
# Total test chrF after 73 iteration = 74.8654
# Time for the iteration 10.5 seconds
#
#
# Average train loss after 74 iteration = 0.0007
# Total train chrF after 74 iteration = 88.9027
# Average val loss after 74 iteration = 0.0330
# Total val chrF after 74 iteration = 74.2362
# Average test loss after 74 iteration = 0.0332
# Total test chrF after 74 iteration = 74.8443
# Time for the iteration 10.5 seconds
#
#
# Average train loss after 75 iteration = 0.0006
# Total train chrF after 75 iteration = 88.9061
# Average val loss after 75 iteration = 0.0333
# Total val chrF after 75 iteration = 74.1911
# Average test loss after 75 iteration = 0.0335
# Total test chrF after 75 iteration = 74.8150
# Time for the iteration 10.6 seconds
#
#
# Average train loss after 76 iteration = 0.0006
# Total train chrF after 76 iteration = 88.9091
# Average val loss after 76 iteration = 0.0335
# Total val chrF after 76 iteration = 74.1880
# Average test loss after 76 iteration = 0.0337
# Total test chrF after 76 iteration = 74.8425
# Time for the iteration 10.7 seconds
#
#
# Average train loss after 77 iteration = 0.0006
# Total train chrF after 77 iteration = 88.9115
# Average val loss after 77 iteration = 0.0337
# Total val chrF after 77 iteration = 74.1644
# Average test loss after 77 iteration = 0.0340
# Total test chrF after 77 iteration = 74.9311
# Time for the iteration 10.5 seconds
#
#
# Average train loss after 78 iteration = 0.0005
# Total train chrF after 78 iteration = 88.9157
# Average val loss after 78 iteration = 0.0340
# Total val chrF after 78 iteration = 74.1559
# Average test loss after 78 iteration = 0.0342
# Total test chrF after 78 iteration = 74.9013
# Time for the iteration 10.6 seconds
#
#
# Average train loss after 79 iteration = 0.0005
# Total train chrF after 79 iteration = 88.9168
# Average val loss after 79 iteration = 0.0342
# Total val chrF after 79 iteration = 74.2181
# Average test loss after 79 iteration = 0.0345
# Total test chrF after 79 iteration = 74.9181
# Time for the iteration 10.5 seconds
#
#
# Average train loss after 80 iteration = 0.0005
# Total train chrF after 80 iteration = 88.9180
# Average val loss after 80 iteration = 0.0344
# Total val chrF after 80 iteration = 74.3207
# Average test loss after 80 iteration = 0.0347
# Total test chrF after 80 iteration = 74.9279
# Time for the iteration 10.5 seconds
#
#
# Average train loss after 81 iteration = 0.0004
# Total train chrF after 81 iteration = 88.9206
# Average val loss after 81 iteration = 0.0347
# Total val chrF after 81 iteration = 74.3257
# Average test loss after 81 iteration = 0.0349
# Total test chrF after 81 iteration = 75.0178
# Time for the iteration 10.5 seconds
#
#
# Average train loss after 82 iteration = 0.0004
# Total train chrF after 82 iteration = 88.9222
# Average val loss after 82 iteration = 0.0349
# Total val chrF after 82 iteration = 74.2304
# Average test loss after 82 iteration = 0.0352
# Total test chrF after 82 iteration = 74.9944
# Time for the iteration 10.6 seconds
#
#
# Average train loss after 83 iteration = 0.0004
# Total train chrF after 83 iteration = 88.9236
# Average val loss after 83 iteration = 0.0351
# Total val chrF after 83 iteration = 74.2012
# Average test loss after 83 iteration = 0.0354
# Total test chrF after 83 iteration = 74.9791
# Time for the iteration 10.6 seconds
#
#
#
#
# Aborting since there hasn't been much progress
# <Figure size 640x480 with 1 Axes>
# <Figure size 640x480 with 1 Axes>

# %%
language = "ya"
task_name = "random_teacher_general"
vocab_size = 4999
num_epochs = 100
batch_size = 32
model = "50_1"
optimizer = "Adam"
metric = "chrF"

# %%
from IPython.display import Image

Image("curves/{}_{}_{}_{}_{}_loss.png".format(language, task_name, vocab_size, num_epochs, batch_size))

# %%
Image("curves/{}_{}_{}_{}_{}_{}.png".format(language, task_name, vocab_size, num_epochs, batch_size, metric))

# %%
print("{}.{}.{}.{}.{}.{}.{}".format(language, task_name, vocab_size, num_epochs, batch_size, model, optimizer))
# Out:
# ya.random_teacher_general.4999.100.32.50_1.Adam
