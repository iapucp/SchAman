# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
# %cd "drive/MyDrive/Tesis/scRNN"
# Out:
# /content/drive/MyDrive/Tesis/scRNN

# %%
import torch

torch.cuda.is_available()
# Out:
# True

# %%
# !pip install sacrebleu
# Out:
# Collecting sacrebleu
#   Downloading sacrebleu-2.0.0-py3-none-any.whl (90 kB)
#      |████████████████████████████████| 90 kB 4.1 MB/s
# Requirement already satisfied: tabulate>=0.8.9 in /usr/local/lib/python3.7/dist-packages (from sacrebleu) (0.8.9)
# Collecting colorama
#   Downloading colorama-0.4.4-py2.py3-none-any.whl (16 kB)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from sacrebleu) (1.21.6)
# Requirement already satisfied: regex in /usr/local/lib/python3.7/dist-packages (from sacrebleu) (2019.12.20)
# Collecting portalocker
#   Downloading portalocker-2.4.0-py2.py3-none-any.whl (16 kB)
# Installing collected packages: portalocker, colorama, sacrebleu
# Successfully installed colorama-0.4.4 portalocker-2.4.0 sacrebleu-2.0.0

# %%
# !python3 train.py --language ya --task-name phongrafamb_unnorm_teacher_general --num-epochs 100 --batch-size 32 --vocab-size 4999 --new-vocab --train --train-sentences-errors-file ya.phongrafamb_unnorm_teacher_general.train.sentences.errors.txt --train-sentences-file ya.phongrafamb_unnorm_teacher_general.train.sentences.txt --val-sentences-errors-file ya.teacher_general.val.sentences.errors.txt --val-sentences-file ya.teacher_general.val.sentences.txt --test-sentences-errors-file ya.teacher_general.test.sentences.errors.txt --test-sentences-file ya.teacher_general.test.sentences.txt --metric chrF --save
# Out:
# Parameters
# {'language': 'ya', 'task_name': 'phongrafamb_unnorm_teacher_general', 'vocab_size': 4999, 'num_epochs': 100, 'batch_size': 32, 'model_name': 'shi_random_20531_100_32', 'new_vocab': True, 'need_to_train': True, 'train_sentences_errors_file': 'ya.phongrafamb_unnorm_teacher_general.train.sentences.errors.txt', 'train_sentences_file': 'ya.phongrafamb_unnorm_teacher_general.train.sentences.txt', 'val_sentences_errors_file': 'ya.teacher_general.val.sentences.errors.txt', 'val_sentences_file': 'ya.teacher_general.val.sentences.txt', 'test_sentences_errors_file': 'ya.teacher_general.test.sentences.errors.txt', 'test_sentences_file': 'ya.teacher_general.test.sentences.txt', 'metric': 'chrF', 'save_model': True}
#
#
# Creating new vocabulary
# Len of w2i:  4999
# Len of i2w:  4999
# Len of char vocab:  32
#
#
# Initializing an only ScRNN model
#
#
# Training the model...
#
# Average train loss after 1 iteration = 0.1542
# Total train chrF after 1 iteration = 70.2413
# Average val loss after 1 iteration = 0.1657
# Total val chrF after 1 iteration = 70.6792
# Average test loss after 1 iteration = 0.1606
# Total test chrF after 1 iteration = 71.3009
# Dumping after  1
# Time for the iteration 25.9 seconds
#
#
# Average train loss after 2 iteration = 0.0904
# Total train chrF after 2 iteration = 75.6775
# Average val loss after 2 iteration = 0.1061
# Total val chrF after 2 iteration = 70.9773
# Average test loss after 2 iteration = 0.1025
# Total test chrF after 2 iteration = 71.5605
# Dumping after  2
# Time for the iteration 25.5 seconds
#
#
# Average train loss after 3 iteration = 0.0549
# Total train chrF after 3 iteration = 80.4821
# Average val loss after 3 iteration = 0.0836
# Total val chrF after 3 iteration = 71.2108
# Average test loss after 3 iteration = 0.0805
# Total test chrF after 3 iteration = 71.8640
# Dumping after  3
# Time for the iteration 25.8 seconds
#
#
# Average train loss after 4 iteration = 0.0354
# Total train chrF after 4 iteration = 83.3037
# Average val loss after 4 iteration = 0.0694
# Total val chrF after 4 iteration = 71.5151
# Average test loss after 4 iteration = 0.0667
# Total test chrF after 4 iteration = 72.2894
# Dumping after  4
# Time for the iteration 26.2 seconds
#
#
# Average train loss after 5 iteration = 0.0239
# Total train chrF after 5 iteration = 85.4256
# Average val loss after 5 iteration = 0.0584
# Total val chrF after 5 iteration = 71.6919
# Average test loss after 5 iteration = 0.0560
# Total test chrF after 5 iteration = 72.5916
# Dumping after  5
# Time for the iteration 25.8 seconds
#
#
# Average train loss after 6 iteration = 0.0171
# Total train chrF after 6 iteration = 86.9624
# Average val loss after 6 iteration = 0.0500
# Total val chrF after 6 iteration = 72.0213
# Average test loss after 6 iteration = 0.0479
# Total test chrF after 6 iteration = 73.2515
# Dumping after  6
# Time for the iteration 26.1 seconds
#
#
# Average train loss after 7 iteration = 0.0129
# Total train chrF after 7 iteration = 88.1259
# Average val loss after 7 iteration = 0.0440
# Total val chrF after 7 iteration = 72.4359
# Average test loss after 7 iteration = 0.0422
# Total test chrF after 7 iteration = 73.5276
# Dumping after  7
# Time for the iteration 26.0 seconds
#
#
# Average train loss after 8 iteration = 0.0102
# Total train chrF after 8 iteration = 88.9293
# Average val loss after 8 iteration = 0.0397
# Total val chrF after 8 iteration = 72.7119
# Average test loss after 8 iteration = 0.0382
# Total test chrF after 8 iteration = 73.7876
# Dumping after  8
# Time for the iteration 25.9 seconds
#
#
# Average train loss after 9 iteration = 0.0083
# Total train chrF after 9 iteration = 89.5005
# Average val loss after 9 iteration = 0.0367
# Total val chrF after 9 iteration = 72.8912
# Average test loss after 9 iteration = 0.0354
# Total test chrF after 9 iteration = 74.0795
# Dumping after  9
# Time for the iteration 26.1 seconds
#
#
# Average train loss after 10 iteration = 0.0070
# Total train chrF after 10 iteration = 89.8862
# Average val loss after 10 iteration = 0.0346
# Total val chrF after 10 iteration = 73.0359
# Average test loss after 10 iteration = 0.0334
# Total test chrF after 10 iteration = 74.2529
# Dumping after  10
# Time for the iteration 25.9 seconds
#
#
# Average train loss after 11 iteration = 0.0060
# Total train chrF after 11 iteration = 90.1750
# Average val loss after 11 iteration = 0.0330
# Total val chrF after 11 iteration = 73.2799
# Average test loss after 11 iteration = 0.0319
# Total test chrF after 11 iteration = 74.4115
# Dumping after  11
# Time for the iteration 25.9 seconds
#
#
# Average train loss after 12 iteration = 0.0052
# Total train chrF after 12 iteration = 90.3805
# Average val loss after 12 iteration = 0.0319
# Total val chrF after 12 iteration = 73.3529
# Average test loss after 12 iteration = 0.0309
# Total test chrF after 12 iteration = 74.5440
# Dumping after  12
# Time for the iteration 25.9 seconds
#
#
# Average train loss after 13 iteration = 0.0045
# Total train chrF after 13 iteration = 90.5531
# Average val loss after 13 iteration = 0.0311
# Total val chrF after 13 iteration = 73.3326
# Average test loss after 13 iteration = 0.0301
# Total test chrF after 13 iteration = 74.6436
# Time for the iteration 25.9 seconds
#
#
# Average train loss after 14 iteration = 0.0040
# Total train chrF after 14 iteration = 90.6901
# Average val loss after 14 iteration = 0.0306
# Total val chrF after 14 iteration = 73.5326
# Average test loss after 14 iteration = 0.0296
# Total test chrF after 14 iteration = 74.8759
# Dumping after  14
# Time for the iteration 25.9 seconds
#
#
# Average train loss after 15 iteration = 0.0036
# Total train chrF after 15 iteration = 90.8123
# Average val loss after 15 iteration = 0.0302
# Total val chrF after 15 iteration = 73.7273
# Average test loss after 15 iteration = 0.0292
# Total test chrF after 15 iteration = 75.0828
# Dumping after  15
# Time for the iteration 26.0 seconds
#
#
# Average train loss after 16 iteration = 0.0032
# Total train chrF after 16 iteration = 90.9057
# Average val loss after 16 iteration = 0.0299
# Total val chrF after 16 iteration = 73.7966
# Average test loss after 16 iteration = 0.0289
# Total test chrF after 16 iteration = 75.1941
# Dumping after  16
# Time for the iteration 26.0 seconds
#
#
# Average train loss after 17 iteration = 0.0028
# Total train chrF after 17 iteration = 90.9988
# Average val loss after 17 iteration = 0.0296
# Total val chrF after 17 iteration = 73.9160
# Average test loss after 17 iteration = 0.0287
# Total test chrF after 17 iteration = 75.1563
# Dumping after  17
# Time for the iteration 26.0 seconds
#
#
# Average train loss after 18 iteration = 0.0026
# Total train chrF after 18 iteration = 91.0820
# Average val loss after 18 iteration = 0.0295
# Total val chrF after 18 iteration = 73.9806
# Average test loss after 18 iteration = 0.0285
# Total test chrF after 18 iteration = 75.2384
# Dumping after  18
# Time for the iteration 26.2 seconds
#
#
# Average train loss after 19 iteration = 0.0023
# Total train chrF after 19 iteration = 91.1509
# Average val loss after 19 iteration = 0.0294
# Total val chrF after 19 iteration = 74.0610
# Average test loss after 19 iteration = 0.0284
# Total test chrF after 19 iteration = 75.3383
# Dumping after  19
# Time for the iteration 26.1 seconds
#
#
# Average train loss after 20 iteration = 0.0021
# Total train chrF after 20 iteration = 91.2123
# Average val loss after 20 iteration = 0.0293
# Total val chrF after 20 iteration = 74.0463
# Average test loss after 20 iteration = 0.0283
# Total test chrF after 20 iteration = 75.3336
# Time for the iteration 26.1 seconds
#
#
# Average train loss after 21 iteration = 0.0019
# Total train chrF after 21 iteration = 91.2594
# Average val loss after 21 iteration = 0.0292
# Total val chrF after 21 iteration = 74.0403
# Average test loss after 21 iteration = 0.0283
# Total test chrF after 21 iteration = 75.3686
# Time for the iteration 26.1 seconds
#
#
# Average train loss after 22 iteration = 0.0017
# Total train chrF after 22 iteration = 91.3028
# Average val loss after 22 iteration = 0.0292
# Total val chrF after 22 iteration = 74.0779
# Average test loss after 22 iteration = 0.0283
# Total test chrF after 22 iteration = 75.3837
# Dumping after  22
# Time for the iteration 26.1 seconds
#
#
# Average train loss after 23 iteration = 0.0015
# Total train chrF after 23 iteration = 91.3424
# Average val loss after 23 iteration = 0.0293
# Total val chrF after 23 iteration = 74.1018
# Average test loss after 23 iteration = 0.0283
# Total test chrF after 23 iteration = 75.5439
# Dumping after  23
# Time for the iteration 26.1 seconds
#
#
# Average train loss after 24 iteration = 0.0014
# Total train chrF after 24 iteration = 91.3871
# Average val loss after 24 iteration = 0.0294
# Total val chrF after 24 iteration = 74.1895
# Average test loss after 24 iteration = 0.0284
# Total test chrF after 24 iteration = 75.5667
# Dumping after  24
# Time for the iteration 26.0 seconds
#
#
# Average train loss after 25 iteration = 0.0013
# Total train chrF after 25 iteration = 91.4190
# Average val loss after 25 iteration = 0.0294
# Total val chrF after 25 iteration = 74.2728
# Average test loss after 25 iteration = 0.0284
# Total test chrF after 25 iteration = 75.6276
# Dumping after  25
# Time for the iteration 26.1 seconds
#
#
# Average train loss after 26 iteration = 0.0012
# Total train chrF after 26 iteration = 91.4447
# Average val loss after 26 iteration = 0.0295
# Total val chrF after 26 iteration = 74.3510
# Average test loss after 26 iteration = 0.0285
# Total test chrF after 26 iteration = 75.6661
# Dumping after  26
# Time for the iteration 26.0 seconds
#
#
# Average train loss after 27 iteration = 0.0011
# Total train chrF after 27 iteration = 91.4668
# Average val loss after 27 iteration = 0.0296
# Total val chrF after 27 iteration = 74.3974
# Average test loss after 27 iteration = 0.0286
# Total test chrF after 27 iteration = 75.6771
# Dumping after  27
# Time for the iteration 26.2 seconds
#
#
# Average train loss after 28 iteration = 0.0010
# Total train chrF after 28 iteration = 91.4890
# Average val loss after 28 iteration = 0.0297
# Total val chrF after 28 iteration = 74.4848
# Average test loss after 28 iteration = 0.0287
# Total test chrF after 28 iteration = 75.7254
# Dumping after  28
# Time for the iteration 26.3 seconds
#
#
# Average train loss after 29 iteration = 0.0009
# Total train chrF after 29 iteration = 91.5070
# Average val loss after 29 iteration = 0.0299
# Total val chrF after 29 iteration = 74.5373
# Average test loss after 29 iteration = 0.0288
# Total test chrF after 29 iteration = 75.7159
# Dumping after  29
# Time for the iteration 26.3 seconds
#
#
# Average train loss after 30 iteration = 0.0008
# Total train chrF after 30 iteration = 91.5250
# Average val loss after 30 iteration = 0.0300
# Total val chrF after 30 iteration = 74.5727
# Average test loss after 30 iteration = 0.0289
# Total test chrF after 30 iteration = 75.7098
# Dumping after  30
# Time for the iteration 26.2 seconds
#
#
# Average train loss after 31 iteration = 0.0007
# Total train chrF after 31 iteration = 91.5400
# Average val loss after 31 iteration = 0.0302
# Total val chrF after 31 iteration = 74.6635
# Average test loss after 31 iteration = 0.0291
# Total test chrF after 31 iteration = 75.6626
# Dumping after  31
# Time for the iteration 26.0 seconds
#
#
# Average train loss after 32 iteration = 0.0007
# Total train chrF after 32 iteration = 91.5550
# Average val loss after 32 iteration = 0.0303
# Total val chrF after 32 iteration = 74.7106
# Average test loss after 32 iteration = 0.0292
# Total test chrF after 32 iteration = 75.7774
# Dumping after  32
# Time for the iteration 26.2 seconds
#
#
# Average train loss after 33 iteration = 0.0006
# Total train chrF after 33 iteration = 91.5653
# Average val loss after 33 iteration = 0.0304
# Total val chrF after 33 iteration = 74.7609
# Average test loss after 33 iteration = 0.0293
# Total test chrF after 33 iteration = 75.8514
# Dumping after  33
# Time for the iteration 26.2 seconds
#
#
# Average train loss after 34 iteration = 0.0005
# Total train chrF after 34 iteration = 91.5732
# Average val loss after 34 iteration = 0.0306
# Total val chrF after 34 iteration = 74.8100
# Average test loss after 34 iteration = 0.0295
# Total test chrF after 34 iteration = 75.8940
# Dumping after  34
# Time for the iteration 26.2 seconds
#
#
# Average train loss after 35 iteration = 0.0005
# Total train chrF after 35 iteration = 91.5823
# Average val loss after 35 iteration = 0.0308
# Total val chrF after 35 iteration = 74.8257
# Average test loss after 35 iteration = 0.0297
# Total test chrF after 35 iteration = 76.0305
# Dumping after  35
# Time for the iteration 26.1 seconds
#
#
# Average train loss after 36 iteration = 0.0005
# Total train chrF after 36 iteration = 91.5889
# Average val loss after 36 iteration = 0.0310
# Total val chrF after 36 iteration = 74.8636
# Average test loss after 36 iteration = 0.0299
# Total test chrF after 36 iteration = 76.1172
# Dumping after  36
# Time for the iteration 26.1 seconds
#
#
# Average train loss after 37 iteration = 0.0004
# Total train chrF after 37 iteration = 91.5997
# Average val loss after 37 iteration = 0.0312
# Total val chrF after 37 iteration = 74.8495
# Average test loss after 37 iteration = 0.0302
# Total test chrF after 37 iteration = 76.2178
# Time for the iteration 26.1 seconds
#
#
# Average train loss after 38 iteration = 0.0004
# Total train chrF after 38 iteration = 91.6040
# Average val loss after 38 iteration = 0.0314
# Total val chrF after 38 iteration = 74.8781
# Average test loss after 38 iteration = 0.0304
# Total test chrF after 38 iteration = 76.1886
# Dumping after  38
# Time for the iteration 25.9 seconds
#
#
# Average train loss after 39 iteration = 0.0003
# Total train chrF after 39 iteration = 91.6084
# Average val loss after 39 iteration = 0.0316
# Total val chrF after 39 iteration = 74.8969
# Average test loss after 39 iteration = 0.0306
# Total test chrF after 39 iteration = 76.2071
# Dumping after  39
# Time for the iteration 26.1 seconds
#
#
# Average train loss after 40 iteration = 0.0003
# Total train chrF after 40 iteration = 91.6115
# Average val loss after 40 iteration = 0.0317
# Total val chrF after 40 iteration = 74.9642
# Average test loss after 40 iteration = 0.0307
# Total test chrF after 40 iteration = 76.2828
# Dumping after  40
# Time for the iteration 26.0 seconds
#
#
# Average train loss after 41 iteration = 0.0003
# Total train chrF after 41 iteration = 91.6174
# Average val loss after 41 iteration = 0.0320
# Total val chrF after 41 iteration = 74.9988
# Average test loss after 41 iteration = 0.0309
# Total test chrF after 41 iteration = 76.3492
# Dumping after  41
# Time for the iteration 26.1 seconds
#
#
# Average train loss after 42 iteration = 0.0003
# Total train chrF after 42 iteration = 91.6194
# Average val loss after 42 iteration = 0.0322
# Total val chrF after 42 iteration = 75.0861
# Average test loss after 42 iteration = 0.0312
# Total test chrF after 42 iteration = 76.3612
# Dumping after  42
# Time for the iteration 26.0 seconds
#
#
# Average train loss after 43 iteration = 0.0002
# Total train chrF after 43 iteration = 91.6227
# Average val loss after 43 iteration = 0.0325
# Total val chrF after 43 iteration = 75.1701
# Average test loss after 43 iteration = 0.0314
# Total test chrF after 43 iteration = 76.3615
# Dumping after  43
# Time for the iteration 26.1 seconds
#
#
# Average train loss after 44 iteration = 0.0002
# Total train chrF after 44 iteration = 91.6252
# Average val loss after 44 iteration = 0.0327
# Total val chrF after 44 iteration = 75.2370
# Average test loss after 44 iteration = 0.0316
# Total test chrF after 44 iteration = 76.3269
# Dumping after  44
# Time for the iteration 25.9 seconds
#
#
# Average train loss after 45 iteration = 0.0002
# Total train chrF after 45 iteration = 91.6293
# Average val loss after 45 iteration = 0.0330
# Total val chrF after 45 iteration = 75.2115
# Average test loss after 45 iteration = 0.0318
# Total test chrF after 45 iteration = 76.2849
# Time for the iteration 26.0 seconds
#
#
# Average train loss after 46 iteration = 0.0002
# Total train chrF after 46 iteration = 91.6311
# Average val loss after 46 iteration = 0.0333
# Total val chrF after 46 iteration = 75.2665
# Average test loss after 46 iteration = 0.0320
# Total test chrF after 46 iteration = 76.3669
# Dumping after  46
# Time for the iteration 26.0 seconds
#
#
# Average train loss after 47 iteration = 0.0002
# Total train chrF after 47 iteration = 91.6323
# Average val loss after 47 iteration = 0.0336
# Total val chrF after 47 iteration = 75.3009
# Average test loss after 47 iteration = 0.0323
# Total test chrF after 47 iteration = 76.4470
# Dumping after  47
# Time for the iteration 26.0 seconds
#
#
# Average train loss after 48 iteration = 0.0001
# Total train chrF after 48 iteration = 91.6330
# Average val loss after 48 iteration = 0.0338
# Total val chrF after 48 iteration = 75.3139
# Average test loss after 48 iteration = 0.0326
# Total test chrF after 48 iteration = 76.4990
# Dumping after  48
# Time for the iteration 26.0 seconds
#
#
# Average train loss after 49 iteration = 0.0001
# Total train chrF after 49 iteration = 91.6346
# Average val loss after 49 iteration = 0.0340
# Total val chrF after 49 iteration = 75.3127
# Average test loss after 49 iteration = 0.0328
# Total test chrF after 49 iteration = 76.5675
# Time for the iteration 26.0 seconds
#
#
# Average train loss after 50 iteration = 0.0001
# Total train chrF after 50 iteration = 91.6358
# Average val loss after 50 iteration = 0.0343
# Total val chrF after 50 iteration = 75.3594
# Average test loss after 50 iteration = 0.0330
# Total test chrF after 50 iteration = 76.6212
# Dumping after  50
# Time for the iteration 25.9 seconds
#
#
# Average train loss after 51 iteration = 0.0001
# Total train chrF after 51 iteration = 91.6376
# Average val loss after 51 iteration = 0.0346
# Total val chrF after 51 iteration = 75.3414
# Average test loss after 51 iteration = 0.0333
# Total test chrF after 51 iteration = 76.5920
# Time for the iteration 26.0 seconds
#
#
# Average train loss after 52 iteration = 0.0001
# Total train chrF after 52 iteration = 91.6385
# Average val loss after 52 iteration = 0.0348
# Total val chrF after 52 iteration = 75.3756
# Average test loss after 52 iteration = 0.0336
# Total test chrF after 52 iteration = 76.5989
# Dumping after  52
# Time for the iteration 26.1 seconds
#
#
# Average train loss after 53 iteration = 0.0001
# Total train chrF after 53 iteration = 91.6386
# Average val loss after 53 iteration = 0.0350
# Total val chrF after 53 iteration = 75.3449
# Average test loss after 53 iteration = 0.0338
# Total test chrF after 53 iteration = 76.6055
# Time for the iteration 26.1 seconds
#
#
# Average train loss after 54 iteration = 0.0001
# Total train chrF after 54 iteration = 91.6388
# Average val loss after 54 iteration = 0.0353
# Total val chrF after 54 iteration = 75.3791
# Average test loss after 54 iteration = 0.0340
# Total test chrF after 54 iteration = 76.5953
# Dumping after  54
# Time for the iteration 26.0 seconds
#
#
# Average train loss after 55 iteration = 0.0001
# Total train chrF after 55 iteration = 91.6390
# Average val loss after 55 iteration = 0.0356
# Total val chrF after 55 iteration = 75.3899
# Average test loss after 55 iteration = 0.0343
# Total test chrF after 55 iteration = 76.6359
# Dumping after  55
# Time for the iteration 26.1 seconds
#
#
# Average train loss after 56 iteration = 0.0001
# Total train chrF after 56 iteration = 91.6388
# Average val loss after 56 iteration = 0.0360
# Total val chrF after 56 iteration = 75.3429
# Average test loss after 56 iteration = 0.0346
# Total test chrF after 56 iteration = 76.6010
# Time for the iteration 26.0 seconds
#
#
# Average train loss after 57 iteration = 0.0001
# Total train chrF after 57 iteration = 91.6394
# Average val loss after 57 iteration = 0.0363
# Total val chrF after 57 iteration = 75.3442
# Average test loss after 57 iteration = 0.0349
# Total test chrF after 57 iteration = 76.6056
# Time for the iteration 26.0 seconds
#
#
# Average train loss after 58 iteration = 0.0001
# Total train chrF after 58 iteration = 91.6395
# Average val loss after 58 iteration = 0.0366
# Total val chrF after 58 iteration = 75.3856
# Average test loss after 58 iteration = 0.0352
# Total test chrF after 58 iteration = 76.6927
# Time for the iteration 25.9 seconds
#
#
# Average train loss after 59 iteration = 0.0001
# Total train chrF after 59 iteration = 91.6390
# Average val loss after 59 iteration = 0.0367
# Total val chrF after 59 iteration = 75.3722
# Average test loss after 59 iteration = 0.0354
# Total test chrF after 59 iteration = 76.7916
# Time for the iteration 25.9 seconds
#
#
# Average train loss after 60 iteration = 0.0001
# Total train chrF after 60 iteration = 91.6394
# Average val loss after 60 iteration = 0.0369
# Total val chrF after 60 iteration = 75.3684
# Average test loss after 60 iteration = 0.0356
# Total test chrF after 60 iteration = 76.7634
# Time for the iteration 26.2 seconds
#
#
# Average train loss after 61 iteration = 0.0000
# Total train chrF after 61 iteration = 91.6391
# Average val loss after 61 iteration = 0.0372
# Total val chrF after 61 iteration = 75.3794
# Average test loss after 61 iteration = 0.0359
# Total test chrF after 61 iteration = 76.7243
# Time for the iteration 25.9 seconds
#
#
# Average train loss after 62 iteration = 0.0000
# Total train chrF after 62 iteration = 91.6397
# Average val loss after 62 iteration = 0.0375
# Total val chrF after 62 iteration = 75.3514
# Average test loss after 62 iteration = 0.0362
# Total test chrF after 62 iteration = 76.6490
# Time for the iteration 26.0 seconds
#
#
# Average train loss after 63 iteration = 0.0000
# Total train chrF after 63 iteration = 91.6388
# Average val loss after 63 iteration = 0.0378
# Total val chrF after 63 iteration = 75.3357
# Average test loss after 63 iteration = 0.0365
# Total test chrF after 63 iteration = 76.6399
# Time for the iteration 26.0 seconds
#
#
# Average train loss after 64 iteration = 0.0000
# Total train chrF after 64 iteration = 91.6397
# Average val loss after 64 iteration = 0.0380
# Total val chrF after 64 iteration = 75.3628
# Average test loss after 64 iteration = 0.0366
# Total test chrF after 64 iteration = 76.6981
# Time for the iteration 25.9 seconds
#
#
# Average train loss after 65 iteration = 0.0000
# Total train chrF after 65 iteration = 91.6396
# Average val loss after 65 iteration = 0.0382
# Total val chrF after 65 iteration = 75.4472
# Average test loss after 65 iteration = 0.0369
# Total test chrF after 65 iteration = 76.6852
# Dumping after  65
# Time for the iteration 25.8 seconds
#
#
# Average train loss after 66 iteration = 0.0000
# Total train chrF after 66 iteration = 91.6382
# Average val loss after 66 iteration = 0.0383
# Total val chrF after 66 iteration = 75.4199
# Average test loss after 66 iteration = 0.0371
# Total test chrF after 66 iteration = 76.7028
# Time for the iteration 25.8 seconds
#
#
# Average train loss after 67 iteration = 0.0000
# Total train chrF after 67 iteration = 91.6382
# Average val loss after 67 iteration = 0.0386
# Total val chrF after 67 iteration = 75.4869
# Average test loss after 67 iteration = 0.0374
# Total test chrF after 67 iteration = 76.6558
# Dumping after  67
# Time for the iteration 25.4 seconds
#
#
# Average train loss after 68 iteration = 0.0000
# Total train chrF after 68 iteration = 91.6385
# Average val loss after 68 iteration = 0.0390
# Total val chrF after 68 iteration = 75.4865
# Average test loss after 68 iteration = 0.0377
# Total test chrF after 68 iteration = 76.6922
# Time for the iteration 25.5 seconds
#
#
# Average train loss after 69 iteration = 0.0000
# Total train chrF after 69 iteration = 91.6390
# Average val loss after 69 iteration = 0.0393
# Total val chrF after 69 iteration = 75.5434
# Average test loss after 69 iteration = 0.0380
# Total test chrF after 69 iteration = 76.6847
# Dumping after  69
# Time for the iteration 26.4 seconds
#
#
# Average train loss after 70 iteration = 0.0000
# Total train chrF after 70 iteration = 91.6390
# Average val loss after 70 iteration = 0.0396
# Total val chrF after 70 iteration = 75.5103
# Average test loss after 70 iteration = 0.0382
# Total test chrF after 70 iteration = 76.6881
# Time for the iteration 26.1 seconds
#
#
# Average train loss after 71 iteration = 0.0000
# Total train chrF after 71 iteration = 91.6390
# Average val loss after 71 iteration = 0.0399
# Total val chrF after 71 iteration = 75.5242
# Average test loss after 71 iteration = 0.0385
# Total test chrF after 71 iteration = 76.6608
# Time for the iteration 25.6 seconds
#
#
# Average train loss after 72 iteration = 0.0000
# Total train chrF after 72 iteration = 91.6390
# Average val loss after 72 iteration = 0.0402
# Total val chrF after 72 iteration = 75.5228
# Average test loss after 72 iteration = 0.0387
# Total test chrF after 72 iteration = 76.7355
# Time for the iteration 25.5 seconds
#
#
# Average train loss after 73 iteration = 0.0000
# Total train chrF after 73 iteration = 91.6390
# Average val loss after 73 iteration = 0.0402
# Total val chrF after 73 iteration = 75.5464
# Average test loss after 73 iteration = 0.0389
# Total test chrF after 73 iteration = 76.7153
# Dumping after  73
# Time for the iteration 25.7 seconds
#
#
# Average train loss after 74 iteration = 0.0000
# Total train chrF after 74 iteration = 91.6372
# Average val loss after 74 iteration = 0.0398
# Total val chrF after 74 iteration = 75.4923
# Average test loss after 74 iteration = 0.0384
# Total test chrF after 74 iteration = 76.8302
# Time for the iteration 25.6 seconds
#
#
# Average train loss after 75 iteration = 0.0000
# Total train chrF after 75 iteration = 91.6382
# Average val loss after 75 iteration = 0.0391
# Total val chrF after 75 iteration = 75.4788
# Average test loss after 75 iteration = 0.0382
# Total test chrF after 75 iteration = 76.7894
# Time for the iteration 25.6 seconds
#
#
# Average train loss after 76 iteration = 0.0000
# Total train chrF after 76 iteration = 91.6376
# Average val loss after 76 iteration = 0.0398
# Total val chrF after 76 iteration = 75.6402
# Average test loss after 76 iteration = 0.0388
# Total test chrF after 76 iteration = 76.8547
# Dumping after  76
# Time for the iteration 25.7 seconds
#
#
# Average train loss after 77 iteration = 0.0000
# Total train chrF after 77 iteration = 91.6387
# Average val loss after 77 iteration = 0.0398
# Total val chrF after 77 iteration = 75.7077
# Average test loss after 77 iteration = 0.0392
# Total test chrF after 77 iteration = 76.9232
# Dumping after  77
# Time for the iteration 25.7 seconds
#
#
# Average train loss after 78 iteration = 0.0000
# Total train chrF after 78 iteration = 91.6383
# Average val loss after 78 iteration = 0.0403
# Total val chrF after 78 iteration = 75.6594
# Average test loss after 78 iteration = 0.0397
# Total test chrF after 78 iteration = 76.8390
# Time for the iteration 25.7 seconds
#
#
# Average train loss after 79 iteration = 0.0000
# Total train chrF after 79 iteration = 91.6390
# Average val loss after 79 iteration = 0.0405
# Total val chrF after 79 iteration = 75.7598
# Average test loss after 79 iteration = 0.0397
# Total test chrF after 79 iteration = 76.7643
# Dumping after  79
# Time for the iteration 25.6 seconds
#
#
# Average train loss after 80 iteration = 0.0000
# Total train chrF after 80 iteration = 91.6390
# Average val loss after 80 iteration = 0.0409
# Total val chrF after 80 iteration = 75.7620
# Average test loss after 80 iteration = 0.0400
# Total test chrF after 80 iteration = 76.8098
# Dumping after  80
# Time for the iteration 25.7 seconds
#
#
# Average train loss after 81 iteration = 0.0000
# Total train chrF after 81 iteration = 91.6390
# Average val loss after 81 iteration = 0.0413
# Total val chrF after 81 iteration = 75.7204
# Average test loss after 81 iteration = 0.0403
# Total test chrF after 81 iteration = 76.8165
# Time for the iteration 25.9 seconds
#
#
# Average train loss after 82 iteration = 0.0000
# Total train chrF after 82 iteration = 91.6390
# Average val loss after 82 iteration = 0.0416
# Total val chrF after 82 iteration = 75.6863
# Average test loss after 82 iteration = 0.0406
# Total test chrF after 82 iteration = 76.7729
# Time for the iteration 26.2 seconds
#
#
# Average train loss after 83 iteration = 0.0000
# Total train chrF after 83 iteration = 91.6390
# Average val loss after 83 iteration = 0.0419
# Total val chrF after 83 iteration = 75.6336
# Average test loss after 83 iteration = 0.0409
# Total test chrF after 83 iteration = 76.7465
# Time for the iteration 25.9 seconds
#
#
# Average train loss after 84 iteration = 0.0000
# Total train chrF after 84 iteration = 91.6390
# Average val loss after 84 iteration = 0.0424
# Total val chrF after 84 iteration = 75.7054
# Average test loss after 84 iteration = 0.0411
# Total test chrF after 84 iteration = 76.7624
# Time for the iteration 25.2 seconds
#
#
# Average train loss after 85 iteration = 0.0000
# Total train chrF after 85 iteration = 91.6390
# Average val loss after 85 iteration = 0.0424
# Total val chrF after 85 iteration = 75.6287
# Average test loss after 85 iteration = 0.0414
# Total test chrF after 85 iteration = 76.7827
# Time for the iteration 25.2 seconds
#
#
# Average train loss after 86 iteration = 0.0000
# Total train chrF after 86 iteration = 91.6390
# Average val loss after 86 iteration = 0.0430
# Total val chrF after 86 iteration = 75.5844
# Average test loss after 86 iteration = 0.0417
# Total test chrF after 86 iteration = 76.7211
# Time for the iteration 25.1 seconds
#
#
# Average train loss after 87 iteration = 0.0000
# Total train chrF after 87 iteration = 91.6390
# Average val loss after 87 iteration = 0.0429
# Total val chrF after 87 iteration = 75.5734
# Average test loss after 87 iteration = 0.0420
# Total test chrF after 87 iteration = 76.8260
# Time for the iteration 25.3 seconds
#
#
# Average train loss after 88 iteration = 0.0000
# Total train chrF after 88 iteration = 91.6390
# Average val loss after 88 iteration = 0.0435
# Total val chrF after 88 iteration = 75.6516
# Average test loss after 88 iteration = 0.0422
# Total test chrF after 88 iteration = 76.7351
# Time for the iteration 25.4 seconds
#
#
# Average train loss after 89 iteration = 0.0000
# Total train chrF after 89 iteration = 91.6390
# Average val loss after 89 iteration = 0.0435
# Total val chrF after 89 iteration = 75.5045
# Average test loss after 89 iteration = 0.0424
# Total test chrF after 89 iteration = 76.7991
# Time for the iteration 25.3 seconds
#
#
# Average train loss after 90 iteration = 0.0000
# Total train chrF after 90 iteration = 91.6390
# Average val loss after 90 iteration = 0.0439
# Total val chrF after 90 iteration = 75.6329
# Average test loss after 90 iteration = 0.0427
# Total test chrF after 90 iteration = 76.7696
# Time for the iteration 25.4 seconds
#
#
# Average train loss after 91 iteration = 0.0000
# Total train chrF after 91 iteration = 91.6390
# Average val loss after 91 iteration = 0.0439
# Total val chrF after 91 iteration = 75.6178
# Average test loss after 91 iteration = 0.0429
# Total test chrF after 91 iteration = 76.7624
# Time for the iteration 25.3 seconds
#
#
# Average train loss after 92 iteration = 0.0000
# Total train chrF after 92 iteration = 91.6390
# Average val loss after 92 iteration = 0.0444
# Total val chrF after 92 iteration = 75.6986
# Average test loss after 92 iteration = 0.0431
# Total test chrF after 92 iteration = 76.7865
# Time for the iteration 25.4 seconds
#
#
# Average train loss after 93 iteration = 0.0000
# Total train chrF after 93 iteration = 91.6349
# Average val loss after 93 iteration = 0.0439
# Total val chrF after 93 iteration = 75.4469
# Average test loss after 93 iteration = 0.0428
# Total test chrF after 93 iteration = 76.6489
# Time for the iteration 25.4 seconds
#
#
# Average train loss after 94 iteration = 0.0000
# Total train chrF after 94 iteration = 91.6366
# Average val loss after 94 iteration = 0.0437
# Total val chrF after 94 iteration = 75.6773
# Average test loss after 94 iteration = 0.0426
# Total test chrF after 94 iteration = 76.5457
# Time for the iteration 25.6 seconds
#
#
# Average train loss after 95 iteration = 0.0000
# Total train chrF after 95 iteration = 91.6380
# Average val loss after 95 iteration = 0.0445
# Total val chrF after 95 iteration = 75.4727
# Average test loss after 95 iteration = 0.0429
# Total test chrF after 95 iteration = 76.7104
# Time for the iteration 25.5 seconds
#
#
# Average train loss after 96 iteration = 0.0000
# Total train chrF after 96 iteration = 91.6384
# Average val loss after 96 iteration = 0.0433
# Total val chrF after 96 iteration = 75.5540
# Average test loss after 96 iteration = 0.0437
# Total test chrF after 96 iteration = 76.4281
# Time for the iteration 25.5 seconds
#
#
# Average train loss after 97 iteration = 0.0000
# Total train chrF after 97 iteration = 91.6387
# Average val loss after 97 iteration = 0.0435
# Total val chrF after 97 iteration = 75.6411
# Average test loss after 97 iteration = 0.0433
# Total test chrF after 97 iteration = 76.5054
# Time for the iteration 25.3 seconds
#
#
# Average train loss after 98 iteration = 0.0000
# Total train chrF after 98 iteration = 91.6372
# Average val loss after 98 iteration = 0.0440
# Total val chrF after 98 iteration = 75.5270
# Average test loss after 98 iteration = 0.0439
# Total test chrF after 98 iteration = 76.4340
# Time for the iteration 25.5 seconds
#
#
# Average train loss after 99 iteration = 0.0000
# Total train chrF after 99 iteration = 91.6385
# Average val loss after 99 iteration = 0.0443
# Total val chrF after 99 iteration = 75.6044
# Average test loss after 99 iteration = 0.0444
# Total test chrF after 99 iteration = 76.3950
# Time for the iteration 25.4 seconds
#
#
# Average train loss after 100 iteration = 0.0000
# Total train chrF after 100 iteration = 91.6390
# Average val loss after 100 iteration = 0.0446
# Total val chrF after 100 iteration = 75.6120
# Average test loss after 100 iteration = 0.0447
# Total test chrF after 100 iteration = 76.3484
# Time for the iteration 25.6 seconds
#
#
# <Figure size 640x480 with 1 Axes>
# <Figure size 640x480 with 1 Axes>

# %%
language = "ya"
task_name = "phongrafamb_unnorm_teacher_general"
vocab_size = 4999
num_epochs = 100
batch_size = 32
model = "50_1"
optimizer = "Adam"
metric = "chrF"

# %%
from IPython.display import Image

Image("curves/{}_{}_{}_{}_{}_loss.png".format(language, task_name, vocab_size, num_epochs, batch_size))

# %%
Image("curves/{}_{}_{}_{}_{}_{}.png".format(language, task_name, vocab_size, num_epochs, batch_size, metric))

# %%
print("{}.{}.{}.{}.{}.{}.{}".format(language, task_name, vocab_size, num_epochs, batch_size, model, optimizer))
# Out:
# ya.phongrafamb_unnorm_teacher_general.4999.100.32.50_1.Adam
