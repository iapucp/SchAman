# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
# %cd "drive/MyDrive/Tesis/scRNN"
# Out:
# /content/drive/MyDrive/Tesis/scRNN

# %%
import torch

torch.cuda.is_available()
# Out:
# True

# %%
# !pip install sacrebleu
# Out:
# Collecting sacrebleu
#   Downloading sacrebleu-2.0.0-py3-none-any.whl (90 kB)
#      |████████████████████████████████| 90 kB 5.9 MB/s
# Requirement already satisfied: regex in /usr/local/lib/python3.7/dist-packages (from sacrebleu) (2019.12.20)
# Collecting colorama
#   Downloading colorama-0.4.4-py2.py3-none-any.whl (16 kB)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from sacrebleu) (1.19.5)
# Collecting portalocker
#   Downloading portalocker-2.3.2-py2.py3-none-any.whl (15 kB)
# Requirement already satisfied: tabulate>=0.8.9 in /usr/local/lib/python3.7/dist-packages (from sacrebleu) (0.8.9)
# Installing collected packages: portalocker, colorama, sacrebleu
# Successfully installed colorama-0.4.4 portalocker-2.3.2 sacrebleu-2.0.0

# %%
# !python3 train.py --language ya --task-name keyprox_teacher_general --num-epochs 100 --batch-size 32 --vocab-size 4999 --new-vocab --train --train-sentences-errors-file ya.keyprox_teacher_general.train.sentences.errors.txt --train-sentences-file ya.keyprox_teacher_general.train.sentences.txt --val-sentences-errors-file ya.teacher_general.val.sentences.errors.txt --val-sentences-file ya.teacher_general.val.sentences.txt --test-sentences-errors-file ya.teacher_general.test.sentences.errors.txt --test-sentences-file ya.teacher_general.test.sentences.txt --metric chrF --save
# Out:
# Parameters
# {'language': 'ya', 'task_name': 'keyprox_teacher_general', 'vocab_size': 4999, 'num_epochs': 100, 'batch_size': 32, 'model_name': 'shi_random_20531_100_32', 'new_vocab': True, 'need_to_train': True, 'train_sentences_errors_file': 'ya.keyprox_teacher_general.train.sentences.errors.txt', 'train_sentences_file': 'ya.keyprox_teacher_general.train.sentences.txt', 'val_sentences_errors_file': 'ya.teacher_general.val.sentences.errors.txt', 'val_sentences_file': 'ya.teacher_general.val.sentences.txt', 'test_sentences_errors_file': 'ya.teacher_general.test.sentences.errors.txt', 'test_sentences_file': 'ya.teacher_general.test.sentences.txt', 'metric': 'chrF', 'save_model': True}
#
#
# Creating new vocabulary
# Len of w2i:  4999
# Len of i2w:  4999
# Len of char vocab:  32
#
#
# Initializing an only ScRNN model
#
#
# Training the model...
#
# Average train loss after 1 iteration = 0.1749
# Total train chrF after 1 iteration = 59.9758
# Average val loss after 1 iteration = 0.2447
# Total val chrF after 1 iteration = 70.6021
# Average test loss after 1 iteration = 0.2426
# Total test chrF after 1 iteration = 71.1796
# Dumping after  1
# Time for the iteration 10.6 seconds
#
#
# Average train loss after 2 iteration = 0.1429
# Total train chrF after 2 iteration = 61.3531
# Average val loss after 2 iteration = 0.1430
# Total val chrF after 2 iteration = 70.7717
# Average test loss after 2 iteration = 0.1397
# Total test chrF after 2 iteration = 71.5848
# Dumping after  2
# Time for the iteration 10.2 seconds
#
#
# Average train loss after 3 iteration = 0.1114
# Total train chrF after 3 iteration = 65.3925
# Average val loss after 3 iteration = 0.1124
# Total val chrF after 3 iteration = 70.6723
# Average test loss after 3 iteration = 0.1094
# Total test chrF after 3 iteration = 71.6562
# Time for the iteration 10.4 seconds
#
#
# Average train loss after 4 iteration = 0.0883
# Total train chrF after 4 iteration = 68.6262
# Average val loss after 4 iteration = 0.0930
# Total val chrF after 4 iteration = 70.7923
# Average test loss after 4 iteration = 0.0905
# Total test chrF after 4 iteration = 71.7975
# Dumping after  4
# Time for the iteration 10.4 seconds
#
#
# Average train loss after 5 iteration = 0.0707
# Total train chrF after 5 iteration = 71.2022
# Average val loss after 5 iteration = 0.0790
# Total val chrF after 5 iteration = 70.9974
# Average test loss after 5 iteration = 0.0768
# Total test chrF after 5 iteration = 71.8963
# Dumping after  5
# Time for the iteration 10.4 seconds
#
#
# Average train loss after 6 iteration = 0.0572
# Total train chrF after 6 iteration = 73.3483
# Average val loss after 6 iteration = 0.0688
# Total val chrF after 6 iteration = 71.3116
# Average test loss after 6 iteration = 0.0669
# Total test chrF after 6 iteration = 72.1670
# Dumping after  6
# Time for the iteration 10.5 seconds
#
#
# Average train loss after 7 iteration = 0.0467
# Total train chrF after 7 iteration = 75.1299
# Average val loss after 7 iteration = 0.0607
# Total val chrF after 7 iteration = 71.6005
# Average test loss after 7 iteration = 0.0590
# Total test chrF after 7 iteration = 72.3851
# Dumping after  7
# Time for the iteration 10.5 seconds
#
#
# Average train loss after 8 iteration = 0.0384
# Total train chrF after 8 iteration = 76.7520
# Average val loss after 8 iteration = 0.0538
# Total val chrF after 8 iteration = 71.9158
# Average test loss after 8 iteration = 0.0524
# Total test chrF after 8 iteration = 72.5957
# Dumping after  8
# Time for the iteration 10.5 seconds
#
#
# Average train loss after 9 iteration = 0.0320
# Total train chrF after 9 iteration = 78.0826
# Average val loss after 9 iteration = 0.0483
# Total val chrF after 9 iteration = 72.1163
# Average test loss after 9 iteration = 0.0471
# Total test chrF after 9 iteration = 72.8160
# Dumping after  9
# Time for the iteration 10.6 seconds
#
#
# Average train loss after 10 iteration = 0.0269
# Total train chrF after 10 iteration = 79.3217
# Average val loss after 10 iteration = 0.0440
# Total val chrF after 10 iteration = 72.4377
# Average test loss after 10 iteration = 0.0430
# Total test chrF after 10 iteration = 73.0273
# Dumping after  10
# Time for the iteration 10.6 seconds
#
#
# Average train loss after 11 iteration = 0.0229
# Total train chrF after 11 iteration = 80.4542
# Average val loss after 11 iteration = 0.0406
# Total val chrF after 11 iteration = 72.6078
# Average test loss after 11 iteration = 0.0397
# Total test chrF after 11 iteration = 73.2327
# Dumping after  11
# Time for the iteration 10.5 seconds
#
#
# Average train loss after 12 iteration = 0.0197
# Total train chrF after 12 iteration = 81.5054
# Average val loss after 12 iteration = 0.0378
# Total val chrF after 12 iteration = 72.6471
# Average test loss after 12 iteration = 0.0370
# Total test chrF after 12 iteration = 73.4875
# Dumping after  12
# Time for the iteration 10.5 seconds
#
#
# Average train loss after 13 iteration = 0.0172
# Total train chrF after 13 iteration = 82.4421
# Average val loss after 13 iteration = 0.0356
# Total val chrF after 13 iteration = 72.7474
# Average test loss after 13 iteration = 0.0349
# Total test chrF after 13 iteration = 73.6877
# Dumping after  13
# Time for the iteration 10.5 seconds
#
#
# Average train loss after 14 iteration = 0.0152
# Total train chrF after 14 iteration = 83.2294
# Average val loss after 14 iteration = 0.0338
# Total val chrF after 14 iteration = 72.8463
# Average test loss after 14 iteration = 0.0331
# Total test chrF after 14 iteration = 73.8301
# Dumping after  14
# Time for the iteration 10.5 seconds
#
#
# Average train loss after 15 iteration = 0.0135
# Total train chrF after 15 iteration = 83.9073
# Average val loss after 15 iteration = 0.0323
# Total val chrF after 15 iteration = 72.8571
# Average test loss after 15 iteration = 0.0317
# Total test chrF after 15 iteration = 73.9744
# Dumping after  15
# Time for the iteration 10.5 seconds
#
#
# Average train loss after 16 iteration = 0.0121
# Total train chrF after 16 iteration = 84.5063
# Average val loss after 16 iteration = 0.0311
# Total val chrF after 16 iteration = 72.9893
# Average test loss after 16 iteration = 0.0306
# Total test chrF after 16 iteration = 74.1170
# Dumping after  16
# Time for the iteration 10.6 seconds
#
#
# Average train loss after 17 iteration = 0.0110
# Total train chrF after 17 iteration = 85.0248
# Average val loss after 17 iteration = 0.0301
# Total val chrF after 17 iteration = 73.1070
# Average test loss after 17 iteration = 0.0297
# Total test chrF after 17 iteration = 74.3098
# Dumping after  17
# Time for the iteration 10.5 seconds
#
#
# Average train loss after 18 iteration = 0.0100
# Total train chrF after 18 iteration = 85.4594
# Average val loss after 18 iteration = 0.0293
# Total val chrF after 18 iteration = 73.2989
# Average test loss after 18 iteration = 0.0289
# Total test chrF after 18 iteration = 74.5448
# Dumping after  18
# Time for the iteration 10.6 seconds
#
#
# Average train loss after 19 iteration = 0.0091
# Total train chrF after 19 iteration = 85.8000
# Average val loss after 19 iteration = 0.0285
# Total val chrF after 19 iteration = 73.4437
# Average test loss after 19 iteration = 0.0282
# Total test chrF after 19 iteration = 74.6660
# Dumping after  19
# Time for the iteration 10.7 seconds
#
#
# Average train loss after 20 iteration = 0.0084
# Total train chrF after 20 iteration = 86.0780
# Average val loss after 20 iteration = 0.0279
# Total val chrF after 20 iteration = 73.5863
# Average test loss after 20 iteration = 0.0276
# Total test chrF after 20 iteration = 74.7734
# Dumping after  20
# Time for the iteration 10.5 seconds
#
#
# Average train loss after 21 iteration = 0.0077
# Total train chrF after 21 iteration = 86.3423
# Average val loss after 21 iteration = 0.0274
# Total val chrF after 21 iteration = 73.7095
# Average test loss after 21 iteration = 0.0272
# Total test chrF after 21 iteration = 74.9568
# Dumping after  21
# Time for the iteration 10.6 seconds
#
#
# Average train loss after 22 iteration = 0.0071
# Total train chrF after 22 iteration = 86.5415
# Average val loss after 22 iteration = 0.0269
# Total val chrF after 22 iteration = 73.9266
# Average test loss after 22 iteration = 0.0267
# Total test chrF after 22 iteration = 75.0579
# Dumping after  22
# Time for the iteration 10.6 seconds
#
#
# Average train loss after 23 iteration = 0.0066
# Total train chrF after 23 iteration = 86.7267
# Average val loss after 23 iteration = 0.0264
# Total val chrF after 23 iteration = 74.0411
# Average test loss after 23 iteration = 0.0264
# Total test chrF after 23 iteration = 75.1061
# Dumping after  23
# Time for the iteration 10.6 seconds
#
#
# Average train loss after 24 iteration = 0.0061
# Total train chrF after 24 iteration = 86.8951
# Average val loss after 24 iteration = 0.0261
# Total val chrF after 24 iteration = 74.1084
# Average test loss after 24 iteration = 0.0260
# Total test chrF after 24 iteration = 75.1998
# Dumping after  24
# Time for the iteration 10.6 seconds
#
#
# Average train loss after 25 iteration = 0.0056
# Total train chrF after 25 iteration = 87.0391
# Average val loss after 25 iteration = 0.0257
# Total val chrF after 25 iteration = 74.1860
# Average test loss after 25 iteration = 0.0257
# Total test chrF after 25 iteration = 75.1437
# Dumping after  25
# Time for the iteration 10.6 seconds
#
#
# Average train loss after 26 iteration = 0.0052
# Total train chrF after 26 iteration = 87.1700
# Average val loss after 26 iteration = 0.0255
# Total val chrF after 26 iteration = 74.2634
# Average test loss after 26 iteration = 0.0255
# Total test chrF after 26 iteration = 75.2541
# Dumping after  26
# Time for the iteration 10.6 seconds
#
#
# Average train loss after 27 iteration = 0.0049
# Total train chrF after 27 iteration = 87.2690
# Average val loss after 27 iteration = 0.0252
# Total val chrF after 27 iteration = 74.3048
# Average test loss after 27 iteration = 0.0253
# Total test chrF after 27 iteration = 75.3273
# Dumping after  27
# Time for the iteration 10.6 seconds
#
#
# Average train loss after 28 iteration = 0.0045
# Total train chrF after 28 iteration = 87.3589
# Average val loss after 28 iteration = 0.0250
# Total val chrF after 28 iteration = 74.4935
# Average test loss after 28 iteration = 0.0251
# Total test chrF after 28 iteration = 75.3773
# Dumping after  28
# Time for the iteration 10.6 seconds
#
#
# Average train loss after 29 iteration = 0.0042
# Total train chrF after 29 iteration = 87.4349
# Average val loss after 29 iteration = 0.0248
# Total val chrF after 29 iteration = 74.5674
# Average test loss after 29 iteration = 0.0249
# Total test chrF after 29 iteration = 75.4435
# Dumping after  29
# Time for the iteration 10.6 seconds
#
#
# Average train loss after 30 iteration = 0.0039
# Total train chrF after 30 iteration = 87.5176
# Average val loss after 30 iteration = 0.0246
# Total val chrF after 30 iteration = 74.5858
# Average test loss after 30 iteration = 0.0248
# Total test chrF after 30 iteration = 75.5882
# Dumping after  30
# Time for the iteration 10.5 seconds
#
#
# Average train loss after 31 iteration = 0.0037
# Total train chrF after 31 iteration = 87.5951
# Average val loss after 31 iteration = 0.0245
# Total val chrF after 31 iteration = 74.6647
# Average test loss after 31 iteration = 0.0247
# Total test chrF after 31 iteration = 75.7096
# Dumping after  31
# Time for the iteration 10.6 seconds
#
#
# Average train loss after 32 iteration = 0.0034
# Total train chrF after 32 iteration = 87.6688
# Average val loss after 32 iteration = 0.0244
# Total val chrF after 32 iteration = 74.6933
# Average test loss after 32 iteration = 0.0246
# Total test chrF after 32 iteration = 75.7762
# Dumping after  32
# Time for the iteration 10.6 seconds
#
#
# Average train loss after 33 iteration = 0.0032
# Total train chrF after 33 iteration = 87.7291
# Average val loss after 33 iteration = 0.0243
# Total val chrF after 33 iteration = 74.6809
# Average test loss after 33 iteration = 0.0246
# Total test chrF after 33 iteration = 75.8340
# Time for the iteration 10.6 seconds
#
#
# Average train loss after 34 iteration = 0.0030
# Total train chrF after 34 iteration = 87.7718
# Average val loss after 34 iteration = 0.0242
# Total val chrF after 34 iteration = 74.6744
# Average test loss after 34 iteration = 0.0245
# Total test chrF after 34 iteration = 75.9114
# Time for the iteration 10.5 seconds
#
#
# Average train loss after 35 iteration = 0.0028
# Total train chrF after 35 iteration = 87.8192
# Average val loss after 35 iteration = 0.0242
# Total val chrF after 35 iteration = 74.7104
# Average test loss after 35 iteration = 0.0245
# Total test chrF after 35 iteration = 75.9741
# Dumping after  35
# Time for the iteration 10.7 seconds
#
#
# Average train loss after 36 iteration = 0.0026
# Total train chrF after 36 iteration = 87.8598
# Average val loss after 36 iteration = 0.0241
# Total val chrF after 36 iteration = 74.7308
# Average test loss after 36 iteration = 0.0245
# Total test chrF after 36 iteration = 76.0031
# Dumping after  36
# Time for the iteration 10.5 seconds
#
#
# Average train loss after 37 iteration = 0.0024
# Total train chrF after 37 iteration = 87.8964
# Average val loss after 37 iteration = 0.0241
# Total val chrF after 37 iteration = 74.8539
# Average test loss after 37 iteration = 0.0245
# Total test chrF after 37 iteration = 76.1239
# Dumping after  37
# Time for the iteration 10.5 seconds
#
#
# Average train loss after 38 iteration = 0.0023
# Total train chrF after 38 iteration = 87.9402
# Average val loss after 38 iteration = 0.0241
# Total val chrF after 38 iteration = 75.0082
# Average test loss after 38 iteration = 0.0245
# Total test chrF after 38 iteration = 76.1937
# Dumping after  38
# Time for the iteration 10.6 seconds
#
#
# Average train loss after 39 iteration = 0.0021
# Total train chrF after 39 iteration = 87.9727
# Average val loss after 39 iteration = 0.0241
# Total val chrF after 39 iteration = 74.9697
# Average test loss after 39 iteration = 0.0246
# Total test chrF after 39 iteration = 76.2811
# Time for the iteration 10.5 seconds
#
#
# Average train loss after 40 iteration = 0.0020
# Total train chrF after 40 iteration = 88.0006
# Average val loss after 40 iteration = 0.0241
# Total val chrF after 40 iteration = 75.0194
# Average test loss after 40 iteration = 0.0246
# Total test chrF after 40 iteration = 76.2735
# Dumping after  40
# Time for the iteration 10.5 seconds
#
#
# Average train loss after 41 iteration = 0.0019
# Total train chrF after 41 iteration = 88.0231
# Average val loss after 41 iteration = 0.0241
# Total val chrF after 41 iteration = 75.0162
# Average test loss after 41 iteration = 0.0247
# Total test chrF after 41 iteration = 76.2945
# Time for the iteration 10.5 seconds
#
#
# Average train loss after 42 iteration = 0.0017
# Total train chrF after 42 iteration = 88.0435
# Average val loss after 42 iteration = 0.0241
# Total val chrF after 42 iteration = 75.0179
# Average test loss after 42 iteration = 0.0248
# Total test chrF after 42 iteration = 76.3129
# Time for the iteration 10.6 seconds
#
#
# Average train loss after 43 iteration = 0.0016
# Total train chrF after 43 iteration = 88.0599
# Average val loss after 43 iteration = 0.0242
# Total val chrF after 43 iteration = 75.0182
# Average test loss after 43 iteration = 0.0248
# Total test chrF after 43 iteration = 76.3661
# Time for the iteration 10.6 seconds
#
#
# Average train loss after 44 iteration = 0.0015
# Total train chrF after 44 iteration = 88.0786
# Average val loss after 44 iteration = 0.0243
# Total val chrF after 44 iteration = 75.0408
# Average test loss after 44 iteration = 0.0249
# Total test chrF after 44 iteration = 76.4649
# Dumping after  44
# Time for the iteration 10.5 seconds
#
#
# Average train loss after 45 iteration = 0.0014
# Total train chrF after 45 iteration = 88.0956
# Average val loss after 45 iteration = 0.0243
# Total val chrF after 45 iteration = 74.9932
# Average test loss after 45 iteration = 0.0250
# Total test chrF after 45 iteration = 76.4808
# Time for the iteration 10.6 seconds
#
#
# Average train loss after 46 iteration = 0.0013
# Total train chrF after 46 iteration = 88.1079
# Average val loss after 46 iteration = 0.0244
# Total val chrF after 46 iteration = 74.9581
# Average test loss after 46 iteration = 0.0251
# Total test chrF after 46 iteration = 76.4978
# Time for the iteration 10.5 seconds
#
#
# Average train loss after 47 iteration = 0.0013
# Total train chrF after 47 iteration = 88.1234
# Average val loss after 47 iteration = 0.0245
# Total val chrF after 47 iteration = 75.0060
# Average test loss after 47 iteration = 0.0252
# Total test chrF after 47 iteration = 76.6064
# Time for the iteration 10.6 seconds
#
#
# Average train loss after 48 iteration = 0.0012
# Total train chrF after 48 iteration = 88.1363
# Average val loss after 48 iteration = 0.0245
# Total val chrF after 48 iteration = 74.9266
# Average test loss after 48 iteration = 0.0254
# Total test chrF after 48 iteration = 76.6177
# Time for the iteration 10.5 seconds
#
#
# Average train loss after 49 iteration = 0.0011
# Total train chrF after 49 iteration = 88.1440
# Average val loss after 49 iteration = 0.0246
# Total val chrF after 49 iteration = 74.9745
# Average test loss after 49 iteration = 0.0255
# Total test chrF after 49 iteration = 76.6087
# Time for the iteration 10.6 seconds
#
#
# Average train loss after 50 iteration = 0.0010
# Total train chrF after 50 iteration = 88.1541
# Average val loss after 50 iteration = 0.0247
# Total val chrF after 50 iteration = 75.0086
# Average test loss after 50 iteration = 0.0256
# Total test chrF after 50 iteration = 76.6947
# Time for the iteration 10.6 seconds
#
#
# Average train loss after 51 iteration = 0.0010
# Total train chrF after 51 iteration = 88.1647
# Average val loss after 51 iteration = 0.0248
# Total val chrF after 51 iteration = 75.0141
# Average test loss after 51 iteration = 0.0258
# Total test chrF after 51 iteration = 76.6430
# Time for the iteration 10.5 seconds
#
#
# Average train loss after 52 iteration = 0.0009
# Total train chrF after 52 iteration = 88.1707
# Average val loss after 52 iteration = 0.0249
# Total val chrF after 52 iteration = 75.0671
# Average test loss after 52 iteration = 0.0259
# Total test chrF after 52 iteration = 76.7254
# Dumping after  52
# Time for the iteration 10.6 seconds
#
#
# Average train loss after 53 iteration = 0.0008
# Total train chrF after 53 iteration = 88.1758
# Average val loss after 53 iteration = 0.0250
# Total val chrF after 53 iteration = 75.0810
# Average test loss after 53 iteration = 0.0261
# Total test chrF after 53 iteration = 76.7470
# Dumping after  53
# Time for the iteration 10.6 seconds
#
#
# Average train loss after 54 iteration = 0.0008
# Total train chrF after 54 iteration = 88.1839
# Average val loss after 54 iteration = 0.0251
# Total val chrF after 54 iteration = 75.1446
# Average test loss after 54 iteration = 0.0262
# Total test chrF after 54 iteration = 76.7229
# Dumping after  54
# Time for the iteration 10.6 seconds
#
#
# Average train loss after 55 iteration = 0.0007
# Total train chrF after 55 iteration = 88.1895
# Average val loss after 55 iteration = 0.0252
# Total val chrF after 55 iteration = 75.1514
# Average test loss after 55 iteration = 0.0264
# Total test chrF after 55 iteration = 76.6853
# Dumping after  55
# Time for the iteration 10.6 seconds
#
#
# Average train loss after 56 iteration = 0.0007
# Total train chrF after 56 iteration = 88.1935
# Average val loss after 56 iteration = 0.0253
# Total val chrF after 56 iteration = 75.1705
# Average test loss after 56 iteration = 0.0266
# Total test chrF after 56 iteration = 76.6899
# Dumping after  56
# Time for the iteration 10.6 seconds
#
#
# Average train loss after 57 iteration = 0.0006
# Total train chrF after 57 iteration = 88.1983
# Average val loss after 57 iteration = 0.0255
# Total val chrF after 57 iteration = 75.1040
# Average test loss after 57 iteration = 0.0268
# Total test chrF after 57 iteration = 76.6289
# Time for the iteration 10.6 seconds
#
#
# Average train loss after 58 iteration = 0.0006
# Total train chrF after 58 iteration = 88.2010
# Average val loss after 58 iteration = 0.0256
# Total val chrF after 58 iteration = 75.1612
# Average test loss after 58 iteration = 0.0270
# Total test chrF after 58 iteration = 76.5869
# Time for the iteration 10.5 seconds
#
#
# Average train loss after 59 iteration = 0.0006
# Total train chrF after 59 iteration = 88.2031
# Average val loss after 59 iteration = 0.0257
# Total val chrF after 59 iteration = 75.1273
# Average test loss after 59 iteration = 0.0272
# Total test chrF after 59 iteration = 76.5491
# Time for the iteration 10.5 seconds
#
#
# Average train loss after 60 iteration = 0.0005
# Total train chrF after 60 iteration = 88.2077
# Average val loss after 60 iteration = 0.0259
# Total val chrF after 60 iteration = 75.1582
# Average test loss after 60 iteration = 0.0274
# Total test chrF after 60 iteration = 76.5758
# Time for the iteration 10.5 seconds
#
#
# Average train loss after 61 iteration = 0.0005
# Total train chrF after 61 iteration = 88.2110
# Average val loss after 61 iteration = 0.0260
# Total val chrF after 61 iteration = 75.1437
# Average test loss after 61 iteration = 0.0276
# Total test chrF after 61 iteration = 76.5604
# Time for the iteration 10.5 seconds
#
#
# Average train loss after 62 iteration = 0.0004
# Total train chrF after 62 iteration = 88.2147
# Average val loss after 62 iteration = 0.0262
# Total val chrF after 62 iteration = 75.1764
# Average test loss after 62 iteration = 0.0278
# Total test chrF after 62 iteration = 76.5037
# Dumping after  62
# Time for the iteration 10.6 seconds
#
#
# Average train loss after 63 iteration = 0.0004
# Total train chrF after 63 iteration = 88.2163
# Average val loss after 63 iteration = 0.0263
# Total val chrF after 63 iteration = 75.1924
# Average test loss after 63 iteration = 0.0281
# Total test chrF after 63 iteration = 76.4119
# Dumping after  63
# Time for the iteration 10.5 seconds
#
#
# Average train loss after 64 iteration = 0.0004
# Total train chrF after 64 iteration = 88.2186
# Average val loss after 64 iteration = 0.0265
# Total val chrF after 64 iteration = 75.1971
# Average test loss after 64 iteration = 0.0283
# Total test chrF after 64 iteration = 76.4851
# Dumping after  64
# Time for the iteration 10.7 seconds
#
#
# Average train loss after 65 iteration = 0.0004
# Total train chrF after 65 iteration = 88.2200
# Average val loss after 65 iteration = 0.0266
# Total val chrF after 65 iteration = 75.2151
# Average test loss after 65 iteration = 0.0285
# Total test chrF after 65 iteration = 76.5257
# Dumping after  65
# Time for the iteration 10.6 seconds
#
#
# Average train loss after 66 iteration = 0.0003
# Total train chrF after 66 iteration = 88.2217
# Average val loss after 66 iteration = 0.0268
# Total val chrF after 66 iteration = 75.2317
# Average test loss after 66 iteration = 0.0288
# Total test chrF after 66 iteration = 76.5116
# Dumping after  66
# Time for the iteration 10.6 seconds
#
#
# Average train loss after 67 iteration = 0.0003
# Total train chrF after 67 iteration = 88.2227
# Average val loss after 67 iteration = 0.0270
# Total val chrF after 67 iteration = 75.2687
# Average test loss after 67 iteration = 0.0290
# Total test chrF after 67 iteration = 76.5438
# Dumping after  67
# Time for the iteration 10.5 seconds
#
#
# Average train loss after 68 iteration = 0.0003
# Total train chrF after 68 iteration = 88.2243
# Average val loss after 68 iteration = 0.0272
# Total val chrF after 68 iteration = 75.3028
# Average test loss after 68 iteration = 0.0293
# Total test chrF after 68 iteration = 76.5247
# Dumping after  68
# Time for the iteration 10.6 seconds
#
#
# Average train loss after 69 iteration = 0.0003
# Total train chrF after 69 iteration = 88.2263
# Average val loss after 69 iteration = 0.0273
# Total val chrF after 69 iteration = 75.2916
# Average test loss after 69 iteration = 0.0295
# Total test chrF after 69 iteration = 76.5140
# Time for the iteration 10.6 seconds
#
#
# Average train loss after 70 iteration = 0.0002
# Total train chrF after 70 iteration = 88.2271
# Average val loss after 70 iteration = 0.0275
# Total val chrF after 70 iteration = 75.3086
# Average test loss after 70 iteration = 0.0298
# Total test chrF after 70 iteration = 76.5048
# Dumping after  70
# Time for the iteration 10.5 seconds
#
#
# Average train loss after 71 iteration = 0.0002
# Total train chrF after 71 iteration = 88.2290
# Average val loss after 71 iteration = 0.0277
# Total val chrF after 71 iteration = 75.2981
# Average test loss after 71 iteration = 0.0300
# Total test chrF after 71 iteration = 76.5237
# Time for the iteration 10.6 seconds
#
#
# Average train loss after 72 iteration = 0.0002
# Total train chrF after 72 iteration = 88.2291
# Average val loss after 72 iteration = 0.0279
# Total val chrF after 72 iteration = 75.2960
# Average test loss after 72 iteration = 0.0303
# Total test chrF after 72 iteration = 76.5021
# Time for the iteration 10.6 seconds
#
#
# Average train loss after 73 iteration = 0.0002
# Total train chrF after 73 iteration = 88.2295
# Average val loss after 73 iteration = 0.0281
# Total val chrF after 73 iteration = 75.2500
# Average test loss after 73 iteration = 0.0306
# Total test chrF after 73 iteration = 76.4473
# Time for the iteration 10.6 seconds
#
#
# Average train loss after 74 iteration = 0.0002
# Total train chrF after 74 iteration = 88.2294
# Average val loss after 74 iteration = 0.0283
# Total val chrF after 74 iteration = 75.2065
# Average test loss after 74 iteration = 0.0309
# Total test chrF after 74 iteration = 76.5501
# Time for the iteration 10.5 seconds
#
#
# Average train loss after 75 iteration = 0.0002
# Total train chrF after 75 iteration = 88.2296
# Average val loss after 75 iteration = 0.0285
# Total val chrF after 75 iteration = 75.1907
# Average test loss after 75 iteration = 0.0311
# Total test chrF after 75 iteration = 76.5709
# Time for the iteration 10.5 seconds
#
#
# Average train loss after 76 iteration = 0.0002
# Total train chrF after 76 iteration = 88.2297
# Average val loss after 76 iteration = 0.0287
# Total val chrF after 76 iteration = 75.1847
# Average test loss after 76 iteration = 0.0314
# Total test chrF after 76 iteration = 76.5558
# Time for the iteration 10.6 seconds
#
#
# Average train loss after 77 iteration = 0.0001
# Total train chrF after 77 iteration = 88.2298
# Average val loss after 77 iteration = 0.0289
# Total val chrF after 77 iteration = 75.1485
# Average test loss after 77 iteration = 0.0317
# Total test chrF after 77 iteration = 76.5814
# Time for the iteration 10.5 seconds
#
#
# Average train loss after 78 iteration = 0.0001
# Total train chrF after 78 iteration = 88.2300
# Average val loss after 78 iteration = 0.0291
# Total val chrF after 78 iteration = 75.1253
# Average test loss after 78 iteration = 0.0320
# Total test chrF after 78 iteration = 76.5476
# Time for the iteration 10.5 seconds
#
#
# Average train loss after 79 iteration = 0.0001
# Total train chrF after 79 iteration = 88.2301
# Average val loss after 79 iteration = 0.0293
# Total val chrF after 79 iteration = 75.1392
# Average test loss after 79 iteration = 0.0322
# Total test chrF after 79 iteration = 76.5493
# Time for the iteration 10.5 seconds
#
#
# Average train loss after 80 iteration = 0.0001
# Total train chrF after 80 iteration = 88.2302
# Average val loss after 80 iteration = 0.0295
# Total val chrF after 80 iteration = 75.1162
# Average test loss after 80 iteration = 0.0325
# Total test chrF after 80 iteration = 76.5491
# Time for the iteration 10.5 seconds
#
#
# Average train loss after 81 iteration = 0.0001
# Total train chrF after 81 iteration = 88.2304
# Average val loss after 81 iteration = 0.0298
# Total val chrF after 81 iteration = 75.0416
# Average test loss after 81 iteration = 0.0328
# Total test chrF after 81 iteration = 76.4807
# Time for the iteration 10.5 seconds
#
#
# Average train loss after 82 iteration = 0.0001
# Total train chrF after 82 iteration = 88.2305
# Average val loss after 82 iteration = 0.0300
# Total val chrF after 82 iteration = 75.0680
# Average test loss after 82 iteration = 0.0330
# Total test chrF after 82 iteration = 76.4924
# Time for the iteration 10.5 seconds
#
#
# Average train loss after 83 iteration = 0.0001
# Total train chrF after 83 iteration = 88.2306
# Average val loss after 83 iteration = 0.0302
# Total val chrF after 83 iteration = 75.0708
# Average test loss after 83 iteration = 0.0333
# Total test chrF after 83 iteration = 76.4871
# Time for the iteration 10.5 seconds
#
#
# Average train loss after 84 iteration = 0.0001
# Total train chrF after 84 iteration = 88.2306
# Average val loss after 84 iteration = 0.0305
# Total val chrF after 84 iteration = 75.0971
# Average test loss after 84 iteration = 0.0336
# Total test chrF after 84 iteration = 76.5204
# Time for the iteration 10.4 seconds
#
#
# Average train loss after 85 iteration = 0.0001
# Total train chrF after 85 iteration = 88.2306
# Average val loss after 85 iteration = 0.0307
# Total val chrF after 85 iteration = 75.0941
# Average test loss after 85 iteration = 0.0339
# Total test chrF after 85 iteration = 76.4609
# Time for the iteration 10.5 seconds
#
#
# Average train loss after 86 iteration = 0.0001
# Total train chrF after 86 iteration = 88.2307
# Average val loss after 86 iteration = 0.0308
# Total val chrF after 86 iteration = 75.0066
# Average test loss after 86 iteration = 0.0341
# Total test chrF after 86 iteration = 76.4380
# Time for the iteration 10.5 seconds
#
#
# Average train loss after 87 iteration = 0.0001
# Total train chrF after 87 iteration = 88.2308
# Average val loss after 87 iteration = 0.0311
# Total val chrF after 87 iteration = 75.0080
# Average test loss after 87 iteration = 0.0344
# Total test chrF after 87 iteration = 76.4537
# Time for the iteration 10.4 seconds
#
#
# Average train loss after 88 iteration = 0.0001
# Total train chrF after 88 iteration = 88.2308
# Average val loss after 88 iteration = 0.0313
# Total val chrF after 88 iteration = 75.0308
# Average test loss after 88 iteration = 0.0347
# Total test chrF after 88 iteration = 76.4483
# Time for the iteration 10.6 seconds
#
#
# Average train loss after 89 iteration = 0.0001
# Total train chrF after 89 iteration = 88.2308
# Average val loss after 89 iteration = 0.0315
# Total val chrF after 89 iteration = 75.0449
# Average test loss after 89 iteration = 0.0350
# Total test chrF after 89 iteration = 76.4479
# Time for the iteration 10.5 seconds
#
#
# Average train loss after 90 iteration = 0.0001
# Total train chrF after 90 iteration = 88.2308
# Average val loss after 90 iteration = 0.0318
# Total val chrF after 90 iteration = 75.0579
# Average test loss after 90 iteration = 0.0352
# Total test chrF after 90 iteration = 76.4343
# Time for the iteration 10.5 seconds
#
#
# Average train loss after 91 iteration = 0.0001
# Total train chrF after 91 iteration = 88.2308
# Average val loss after 91 iteration = 0.0320
# Total val chrF after 91 iteration = 75.0383
# Average test loss after 91 iteration = 0.0355
# Total test chrF after 91 iteration = 76.4745
# Time for the iteration 10.5 seconds
#
#
# Average train loss after 92 iteration = 0.0000
# Total train chrF after 92 iteration = 88.2308
# Average val loss after 92 iteration = 0.0323
# Total val chrF after 92 iteration = 75.0267
# Average test loss after 92 iteration = 0.0358
# Total test chrF after 92 iteration = 76.4444
# Time for the iteration 10.5 seconds
#
#
# Average train loss after 93 iteration = 0.0000
# Total train chrF after 93 iteration = 88.2308
# Average val loss after 93 iteration = 0.0325
# Total val chrF after 93 iteration = 75.0438
# Average test loss after 93 iteration = 0.0361
# Total test chrF after 93 iteration = 76.4304
# Time for the iteration 10.6 seconds
#
#
# Average train loss after 94 iteration = 0.0000
# Total train chrF after 94 iteration = 88.2308
# Average val loss after 94 iteration = 0.0328
# Total val chrF after 94 iteration = 75.0237
# Average test loss after 94 iteration = 0.0364
# Total test chrF after 94 iteration = 76.4178
# Time for the iteration 10.7 seconds
#
#
# Average train loss after 95 iteration = 0.0000
# Total train chrF after 95 iteration = 88.2308
# Average val loss after 95 iteration = 0.0330
# Total val chrF after 95 iteration = 75.0377
# Average test loss after 95 iteration = 0.0367
# Total test chrF after 95 iteration = 76.4458
# Time for the iteration 10.6 seconds
#
#
# Average train loss after 96 iteration = 0.0000
# Total train chrF after 96 iteration = 88.2308
# Average val loss after 96 iteration = 0.0332
# Total val chrF after 96 iteration = 74.9867
# Average test loss after 96 iteration = 0.0370
# Total test chrF after 96 iteration = 76.4422
# Time for the iteration 10.6 seconds
#
#
# Average train loss after 97 iteration = 0.0000
# Total train chrF after 97 iteration = 88.2308
# Average val loss after 97 iteration = 0.0335
# Total val chrF after 97 iteration = 74.9587
# Average test loss after 97 iteration = 0.0373
# Total test chrF after 97 iteration = 76.4544
# Time for the iteration 10.7 seconds
#
#
#
#
# Aborting since there hasn't been much progress
# <Figure size 640x480 with 1 Axes>
# <Figure size 640x480 with 1 Axes>

# %%
language = "ya"
task_name = "keyprox_teacher_general"
vocab_size = 4999
num_epochs = 100
batch_size = 32
model = "50_1"
optimizer = "Adam"
metric = "chrF"

# %%
from IPython.display import Image

Image("curves/{}_{}_{}_{}_{}_loss.png".format(language, task_name, vocab_size, num_epochs, batch_size))

# %%
Image("curves/{}_{}_{}_{}_{}_{}.png".format(language, task_name, vocab_size, num_epochs, batch_size, metric))

# %%
print("{}.{}.{}.{}.{}.{}.{}".format(language, task_name, vocab_size, num_epochs, batch_size, model, optimizer))
# Out:
# ya.keyprox_teacher_general.4999.100.32.50_1.Adam
