# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
# %cd "drive/MyDrive/Tesis/scRNN"
# Out:
# /content/drive/MyDrive/Tesis/scRNN

# %%
import torch

torch.cuda.is_available()
# Out:
# True

# %%
# !pip install sacrebleu
# Out:
# Collecting sacrebleu
#   Downloading sacrebleu-2.0.0-py3-none-any.whl (90 kB)
#      |████████████████████████████████| 90 kB 6.2 MB/s
# Collecting portalocker
#   Downloading portalocker-2.4.0-py2.py3-none-any.whl (16 kB)
# Requirement already satisfied: regex in /usr/local/lib/python3.7/dist-packages (from sacrebleu) (2019.12.20)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from sacrebleu) (1.21.6)
# Requirement already satisfied: tabulate>=0.8.9 in /usr/local/lib/python3.7/dist-packages (from sacrebleu) (0.8.9)
# Collecting colorama
#   Downloading colorama-0.4.4-py2.py3-none-any.whl (16 kB)
# Installing collected packages: portalocker, colorama, sacrebleu
# Successfully installed colorama-0.4.4 portalocker-2.4.0 sacrebleu-2.0.0

# %%
# !python3 train.py --language yi --task-name random_teacher_general --num-epochs 100 --batch-size 32 --vocab-size 2999 --new-vocab --train --train-sentences-errors-file yi.random_teacher_general.train.sentences.errors.txt --train-sentences-file yi.random_teacher_general.train.sentences.txt --val-sentences-errors-file yi.teacher_general.val.sentences.errors.txt --val-sentences-file yi.teacher_general.val.sentences.txt --test-sentences-errors-file yi.teacher_general.test.sentences.errors.txt --test-sentences-file yi.teacher_general.test.sentences.txt --metric chrF --save
# Out:
# Parameters
# {'language': 'yi', 'task_name': 'random_teacher_general', 'vocab_size': 2999, 'num_epochs': 100, 'batch_size': 32, 'model_name': 'shi_random_20531_100_32', 'new_vocab': True, 'need_to_train': True, 'train_sentences_errors_file': 'yi.random_teacher_general.train.sentences.errors.txt', 'train_sentences_file': 'yi.random_teacher_general.train.sentences.txt', 'val_sentences_errors_file': 'yi.teacher_general.val.sentences.errors.txt', 'val_sentences_file': 'yi.teacher_general.val.sentences.txt', 'test_sentences_errors_file': 'yi.teacher_general.test.sentences.errors.txt', 'test_sentences_file': 'yi.teacher_general.test.sentences.txt', 'metric': 'chrF', 'save_model': True}
#
#
# Creating new vocabulary
# Len of w2i:  2999
# Len of i2w:  2999
# Len of char vocab:  23
#
#
# Initializing an only ScRNN model
#
#
# Training the model...
#
# Average train loss after 1 iteration = 0.1770
# Total train chrF after 1 iteration = 62.7401
# Average val loss after 1 iteration = 0.1681
# Total val chrF after 1 iteration = 78.4030
# Average test loss after 1 iteration = 0.1703
# Total test chrF after 1 iteration = 78.2531
# Dumping after  1
# Time for the iteration 5.8 seconds
#
#
# Average train loss after 2 iteration = 0.1570
# Total train chrF after 2 iteration = 62.0029
# Average val loss after 2 iteration = 0.1285
# Total val chrF after 2 iteration = 76.2782
# Average test loss after 2 iteration = 0.1304
# Total test chrF after 2 iteration = 75.8777
# Time for the iteration 5.7 seconds
#
#
# Average train loss after 3 iteration = 0.1345
# Total train chrF after 3 iteration = 63.8049
# Average val loss after 3 iteration = 0.1094
# Total val chrF after 3 iteration = 76.8797
# Average test loss after 3 iteration = 0.1110
# Total test chrF after 3 iteration = 76.6873
# Time for the iteration 5.6 seconds
#
#
# Average train loss after 4 iteration = 0.1149
# Total train chrF after 4 iteration = 66.5550
# Average val loss after 4 iteration = 0.0931
# Total val chrF after 4 iteration = 77.2366
# Average test loss after 4 iteration = 0.0945
# Total test chrF after 4 iteration = 76.9835
# Time for the iteration 5.7 seconds
#
#
# Average train loss after 5 iteration = 0.0976
# Total train chrF after 5 iteration = 69.1642
# Average val loss after 5 iteration = 0.0781
# Total val chrF after 5 iteration = 78.2283
# Average test loss after 5 iteration = 0.0796
# Total test chrF after 5 iteration = 78.4717
# Time for the iteration 5.8 seconds
#
#
# Average train loss after 6 iteration = 0.0827
# Total train chrF after 6 iteration = 71.2984
# Average val loss after 6 iteration = 0.0654
# Total val chrF after 6 iteration = 78.8236
# Average test loss after 6 iteration = 0.0670
# Total test chrF after 6 iteration = 79.1315
# Dumping after  6
# Time for the iteration 5.7 seconds
#
#
# Average train loss after 7 iteration = 0.0704
# Total train chrF after 7 iteration = 73.0879
# Average val loss after 7 iteration = 0.0553
# Total val chrF after 7 iteration = 79.5145
# Average test loss after 7 iteration = 0.0568
# Total test chrF after 7 iteration = 79.7027
# Dumping after  7
# Time for the iteration 5.6 seconds
#
#
# Average train loss after 8 iteration = 0.0604
# Total train chrF after 8 iteration = 74.5929
# Average val loss after 8 iteration = 0.0474
# Total val chrF after 8 iteration = 80.1410
# Average test loss after 8 iteration = 0.0490
# Total test chrF after 8 iteration = 80.4973
# Dumping after  8
# Time for the iteration 5.6 seconds
#
#
# Average train loss after 9 iteration = 0.0522
# Total train chrF after 9 iteration = 75.9387
# Average val loss after 9 iteration = 0.0413
# Total val chrF after 9 iteration = 80.5512
# Average test loss after 9 iteration = 0.0428
# Total test chrF after 9 iteration = 81.0228
# Dumping after  9
# Time for the iteration 5.7 seconds
#
#
# Average train loss after 10 iteration = 0.0454
# Total train chrF after 10 iteration = 77.2709
# Average val loss after 10 iteration = 0.0364
# Total val chrF after 10 iteration = 81.1534
# Average test loss after 10 iteration = 0.0378
# Total test chrF after 10 iteration = 81.6353
# Dumping after  10
# Time for the iteration 5.7 seconds
#
#
# Average train loss after 11 iteration = 0.0396
# Total train chrF after 11 iteration = 78.4518
# Average val loss after 11 iteration = 0.0324
# Total val chrF after 11 iteration = 81.8348
# Average test loss after 11 iteration = 0.0336
# Total test chrF after 11 iteration = 82.2996
# Dumping after  11
# Time for the iteration 5.6 seconds
#
#
# Average train loss after 12 iteration = 0.0347
# Total train chrF after 12 iteration = 79.5788
# Average val loss after 12 iteration = 0.0291
# Total val chrF after 12 iteration = 82.4123
# Average test loss after 12 iteration = 0.0302
# Total test chrF after 12 iteration = 82.7584
# Dumping after  12
# Time for the iteration 5.7 seconds
#
#
# Average train loss after 13 iteration = 0.0305
# Total train chrF after 13 iteration = 80.6047
# Average val loss after 13 iteration = 0.0264
# Total val chrF after 13 iteration = 82.9364
# Average test loss after 13 iteration = 0.0273
# Total test chrF after 13 iteration = 83.0833
# Dumping after  13
# Time for the iteration 5.7 seconds
#
#
# Average train loss after 14 iteration = 0.0268
# Total train chrF after 14 iteration = 81.5725
# Average val loss after 14 iteration = 0.0240
# Total val chrF after 14 iteration = 83.3017
# Average test loss after 14 iteration = 0.0247
# Total test chrF after 14 iteration = 83.3811
# Dumping after  14
# Time for the iteration 5.7 seconds
#
#
# Average train loss after 15 iteration = 0.0238
# Total train chrF after 15 iteration = 82.4820
# Average val loss after 15 iteration = 0.0221
# Total val chrF after 15 iteration = 83.5894
# Average test loss after 15 iteration = 0.0226
# Total test chrF after 15 iteration = 83.6301
# Dumping after  15
# Time for the iteration 5.7 seconds
#
#
# Average train loss after 16 iteration = 0.0212
# Total train chrF after 16 iteration = 83.3145
# Average val loss after 16 iteration = 0.0206
# Total val chrF after 16 iteration = 83.8830
# Average test loss after 16 iteration = 0.0209
# Total test chrF after 16 iteration = 83.8800
# Dumping after  16
# Time for the iteration 5.7 seconds
#
#
# Average train loss after 17 iteration = 0.0191
# Total train chrF after 17 iteration = 84.0712
# Average val loss after 17 iteration = 0.0193
# Total val chrF after 17 iteration = 84.0189
# Average test loss after 17 iteration = 0.0195
# Total test chrF after 17 iteration = 84.1689
# Dumping after  17
# Time for the iteration 5.6 seconds
#
#
# Average train loss after 18 iteration = 0.0172
# Total train chrF after 18 iteration = 84.7818
# Average val loss after 18 iteration = 0.0182
# Total val chrF after 18 iteration = 84.2605
# Average test loss after 18 iteration = 0.0182
# Total test chrF after 18 iteration = 84.3272
# Dumping after  18
# Time for the iteration 5.7 seconds
#
#
# Average train loss after 19 iteration = 0.0157
# Total train chrF after 19 iteration = 85.4208
# Average val loss after 19 iteration = 0.0172
# Total val chrF after 19 iteration = 84.4006
# Average test loss after 19 iteration = 0.0172
# Total test chrF after 19 iteration = 84.4539
# Dumping after  19
# Time for the iteration 5.7 seconds
#
#
# Average train loss after 20 iteration = 0.0143
# Total train chrF after 20 iteration = 85.9517
# Average val loss after 20 iteration = 0.0164
# Total val chrF after 20 iteration = 84.6290
# Average test loss after 20 iteration = 0.0163
# Total test chrF after 20 iteration = 84.5873
# Dumping after  20
# Time for the iteration 5.6 seconds
#
#
# Average train loss after 21 iteration = 0.0131
# Total train chrF after 21 iteration = 86.4290
# Average val loss after 21 iteration = 0.0157
# Total val chrF after 21 iteration = 84.7310
# Average test loss after 21 iteration = 0.0155
# Total test chrF after 21 iteration = 84.6898
# Dumping after  21
# Time for the iteration 5.7 seconds
#
#
# Average train loss after 22 iteration = 0.0121
# Total train chrF after 22 iteration = 86.8626
# Average val loss after 22 iteration = 0.0151
# Total val chrF after 22 iteration = 84.8200
# Average test loss after 22 iteration = 0.0148
# Total test chrF after 22 iteration = 84.8103
# Dumping after  22
# Time for the iteration 5.6 seconds
#
#
# Average train loss after 23 iteration = 0.0112
# Total train chrF after 23 iteration = 87.2334
# Average val loss after 23 iteration = 0.0145
# Total val chrF after 23 iteration = 84.9779
# Average test loss after 23 iteration = 0.0142
# Total test chrF after 23 iteration = 84.8807
# Dumping after  23
# Time for the iteration 5.7 seconds
#
#
# Average train loss after 24 iteration = 0.0104
# Total train chrF after 24 iteration = 87.5629
# Average val loss after 24 iteration = 0.0141
# Total val chrF after 24 iteration = 85.0644
# Average test loss after 24 iteration = 0.0137
# Total test chrF after 24 iteration = 85.0638
# Dumping after  24
# Time for the iteration 5.6 seconds
#
#
# Average train loss after 25 iteration = 0.0097
# Total train chrF after 25 iteration = 87.8223
# Average val loss after 25 iteration = 0.0137
# Total val chrF after 25 iteration = 85.1239
# Average test loss after 25 iteration = 0.0133
# Total test chrF after 25 iteration = 85.1977
# Dumping after  25
# Time for the iteration 5.6 seconds
#
#
# Average train loss after 26 iteration = 0.0090
# Total train chrF after 26 iteration = 88.0554
# Average val loss after 26 iteration = 0.0133
# Total val chrF after 26 iteration = 85.2459
# Average test loss after 26 iteration = 0.0129
# Total test chrF after 26 iteration = 85.2594
# Dumping after  26
# Time for the iteration 5.6 seconds
#
#
# Average train loss after 27 iteration = 0.0084
# Total train chrF after 27 iteration = 88.2613
# Average val loss after 27 iteration = 0.0130
# Total val chrF after 27 iteration = 85.2628
# Average test loss after 27 iteration = 0.0125
# Total test chrF after 27 iteration = 85.3266
# Dumping after  27
# Time for the iteration 5.7 seconds
#
#
# Average train loss after 28 iteration = 0.0079
# Total train chrF after 28 iteration = 88.4549
# Average val loss after 28 iteration = 0.0128
# Total val chrF after 28 iteration = 85.3443
# Average test loss after 28 iteration = 0.0122
# Total test chrF after 28 iteration = 85.4338
# Dumping after  28
# Time for the iteration 5.6 seconds
#
#
# Average train loss after 29 iteration = 0.0074
# Total train chrF after 29 iteration = 88.6175
# Average val loss after 29 iteration = 0.0125
# Total val chrF after 29 iteration = 85.4076
# Average test loss after 29 iteration = 0.0119
# Total test chrF after 29 iteration = 85.4972
# Dumping after  29
# Time for the iteration 5.6 seconds
#
#
# Average train loss after 30 iteration = 0.0070
# Total train chrF after 30 iteration = 88.7544
# Average val loss after 30 iteration = 0.0123
# Total val chrF after 30 iteration = 85.4929
# Average test loss after 30 iteration = 0.0117
# Total test chrF after 30 iteration = 85.4957
# Dumping after  30
# Time for the iteration 5.7 seconds
#
#
# Average train loss after 31 iteration = 0.0066
# Total train chrF after 31 iteration = 88.8853
# Average val loss after 31 iteration = 0.0121
# Total val chrF after 31 iteration = 85.4712
# Average test loss after 31 iteration = 0.0115
# Total test chrF after 31 iteration = 85.5485
# Time for the iteration 5.7 seconds
#
#
# Average train loss after 32 iteration = 0.0062
# Total train chrF after 32 iteration = 89.0052
# Average val loss after 32 iteration = 0.0119
# Total val chrF after 32 iteration = 85.4902
# Average test loss after 32 iteration = 0.0113
# Total test chrF after 32 iteration = 85.5661
# Time for the iteration 5.7 seconds
#
#
# Average train loss after 33 iteration = 0.0058
# Total train chrF after 33 iteration = 89.1178
# Average val loss after 33 iteration = 0.0118
# Total val chrF after 33 iteration = 85.5284
# Average test loss after 33 iteration = 0.0111
# Total test chrF after 33 iteration = 85.5481
# Dumping after  33
# Time for the iteration 5.7 seconds
#
#
# Average train loss after 34 iteration = 0.0055
# Total train chrF after 34 iteration = 89.2067
# Average val loss after 34 iteration = 0.0116
# Total val chrF after 34 iteration = 85.5627
# Average test loss after 34 iteration = 0.0109
# Total test chrF after 34 iteration = 85.5381
# Dumping after  34
# Time for the iteration 5.7 seconds
#
#
# Average train loss after 35 iteration = 0.0052
# Total train chrF after 35 iteration = 89.2927
# Average val loss after 35 iteration = 0.0115
# Total val chrF after 35 iteration = 85.6112
# Average test loss after 35 iteration = 0.0108
# Total test chrF after 35 iteration = 85.5619
# Dumping after  35
# Time for the iteration 5.6 seconds
#
#
# Average train loss after 36 iteration = 0.0049
# Total train chrF after 36 iteration = 89.3699
# Average val loss after 36 iteration = 0.0114
# Total val chrF after 36 iteration = 85.6334
# Average test loss after 36 iteration = 0.0106
# Total test chrF after 36 iteration = 85.5483
# Dumping after  36
# Time for the iteration 5.6 seconds
#
#
# Average train loss after 37 iteration = 0.0047
# Total train chrF after 37 iteration = 89.4482
# Average val loss after 37 iteration = 0.0113
# Total val chrF after 37 iteration = 85.6813
# Average test loss after 37 iteration = 0.0105
# Total test chrF after 37 iteration = 85.5638
# Dumping after  37
# Time for the iteration 5.7 seconds
#
#
# Average train loss after 38 iteration = 0.0044
# Total train chrF after 38 iteration = 89.5120
# Average val loss after 38 iteration = 0.0113
# Total val chrF after 38 iteration = 85.6800
# Average test loss after 38 iteration = 0.0104
# Total test chrF after 38 iteration = 85.5852
# Time for the iteration 5.7 seconds
#
#
# Average train loss after 39 iteration = 0.0042
# Total train chrF after 39 iteration = 89.5686
# Average val loss after 39 iteration = 0.0112
# Total val chrF after 39 iteration = 85.7107
# Average test loss after 39 iteration = 0.0103
# Total test chrF after 39 iteration = 85.6082
# Dumping after  39
# Time for the iteration 5.6 seconds
#
#
# Average train loss after 40 iteration = 0.0039
# Total train chrF after 40 iteration = 89.6212
# Average val loss after 40 iteration = 0.0111
# Total val chrF after 40 iteration = 85.7321
# Average test loss after 40 iteration = 0.0102
# Total test chrF after 40 iteration = 85.5924
# Dumping after  40
# Time for the iteration 5.7 seconds
#
#
# Average train loss after 41 iteration = 0.0037
# Total train chrF after 41 iteration = 89.6691
# Average val loss after 41 iteration = 0.0111
# Total val chrF after 41 iteration = 85.7321
# Average test loss after 41 iteration = 0.0102
# Total test chrF after 41 iteration = 85.6043
# Time for the iteration 5.7 seconds
#
#
# Average train loss after 42 iteration = 0.0035
# Total train chrF after 42 iteration = 89.7127
# Average val loss after 42 iteration = 0.0110
# Total val chrF after 42 iteration = 85.7688
# Average test loss after 42 iteration = 0.0101
# Total test chrF after 42 iteration = 85.5980
# Dumping after  42
# Time for the iteration 5.6 seconds
#
#
# Average train loss after 43 iteration = 0.0034
# Total train chrF after 43 iteration = 89.7530
# Average val loss after 43 iteration = 0.0110
# Total val chrF after 43 iteration = 85.7512
# Average test loss after 43 iteration = 0.0100
# Total test chrF after 43 iteration = 85.6021
# Time for the iteration 5.6 seconds
#
#
# Average train loss after 44 iteration = 0.0032
# Total train chrF after 44 iteration = 89.7876
# Average val loss after 44 iteration = 0.0110
# Total val chrF after 44 iteration = 85.7739
# Average test loss after 44 iteration = 0.0100
# Total test chrF after 44 iteration = 85.5742
# Dumping after  44
# Time for the iteration 5.7 seconds
#
#
# Average train loss after 45 iteration = 0.0030
# Total train chrF after 45 iteration = 89.8271
# Average val loss after 45 iteration = 0.0109
# Total val chrF after 45 iteration = 85.7949
# Average test loss after 45 iteration = 0.0099
# Total test chrF after 45 iteration = 85.5469
# Dumping after  45
# Time for the iteration 5.6 seconds
#
#
# Average train loss after 46 iteration = 0.0029
# Total train chrF after 46 iteration = 89.8541
# Average val loss after 46 iteration = 0.0109
# Total val chrF after 46 iteration = 85.7940
# Average test loss after 46 iteration = 0.0099
# Total test chrF after 46 iteration = 85.5388
# Time for the iteration 5.6 seconds
#
#
# Average train loss after 47 iteration = 0.0027
# Total train chrF after 47 iteration = 89.8899
# Average val loss after 47 iteration = 0.0109
# Total val chrF after 47 iteration = 85.8145
# Average test loss after 47 iteration = 0.0099
# Total test chrF after 47 iteration = 85.5355
# Dumping after  47
# Time for the iteration 5.6 seconds
#
#
# Average train loss after 48 iteration = 0.0026
# Total train chrF after 48 iteration = 89.9140
# Average val loss after 48 iteration = 0.0109
# Total val chrF after 48 iteration = 85.8563
# Average test loss after 48 iteration = 0.0098
# Total test chrF after 48 iteration = 85.5120
# Dumping after  48
# Time for the iteration 5.6 seconds
#
#
# Average train loss after 49 iteration = 0.0024
# Total train chrF after 49 iteration = 89.9358
# Average val loss after 49 iteration = 0.0109
# Total val chrF after 49 iteration = 85.8709
# Average test loss after 49 iteration = 0.0098
# Total test chrF after 49 iteration = 85.5058
# Dumping after  49
# Time for the iteration 5.6 seconds
#
#
# Average train loss after 50 iteration = 0.0023
# Total train chrF after 50 iteration = 89.9547
# Average val loss after 50 iteration = 0.0109
# Total val chrF after 50 iteration = 85.8746
# Average test loss after 50 iteration = 0.0098
# Total test chrF after 50 iteration = 85.5043
# Dumping after  50
# Time for the iteration 5.6 seconds
#
#
# Average train loss after 51 iteration = 0.0022
# Total train chrF after 51 iteration = 89.9692
# Average val loss after 51 iteration = 0.0109
# Total val chrF after 51 iteration = 85.8713
# Average test loss after 51 iteration = 0.0098
# Total test chrF after 51 iteration = 85.5131
# Time for the iteration 5.6 seconds
#
#
# Average train loss after 52 iteration = 0.0021
# Total train chrF after 52 iteration = 89.9903
# Average val loss after 52 iteration = 0.0109
# Total val chrF after 52 iteration = 85.8602
# Average test loss after 52 iteration = 0.0098
# Total test chrF after 52 iteration = 85.5182
# Time for the iteration 5.6 seconds
#
#
# Average train loss after 53 iteration = 0.0020
# Total train chrF after 53 iteration = 90.0034
# Average val loss after 53 iteration = 0.0109
# Total val chrF after 53 iteration = 85.8412
# Average test loss after 53 iteration = 0.0098
# Total test chrF after 53 iteration = 85.5391
# Time for the iteration 5.6 seconds
#
#
# Average train loss after 54 iteration = 0.0019
# Total train chrF after 54 iteration = 90.0198
# Average val loss after 54 iteration = 0.0109
# Total val chrF after 54 iteration = 85.8693
# Average test loss after 54 iteration = 0.0098
# Total test chrF after 54 iteration = 85.4804
# Time for the iteration 5.6 seconds
#
#
# Average train loss after 55 iteration = 0.0018
# Total train chrF after 55 iteration = 90.0373
# Average val loss after 55 iteration = 0.0110
# Total val chrF after 55 iteration = 85.8687
# Average test loss after 55 iteration = 0.0098
# Total test chrF after 55 iteration = 85.4980
# Time for the iteration 5.6 seconds
#
#
# Average train loss after 56 iteration = 0.0017
# Total train chrF after 56 iteration = 90.0491
# Average val loss after 56 iteration = 0.0110
# Total val chrF after 56 iteration = 85.8869
# Average test loss after 56 iteration = 0.0098
# Total test chrF after 56 iteration = 85.5095
# Dumping after  56
# Time for the iteration 5.6 seconds
#
#
# Average train loss after 57 iteration = 0.0016
# Total train chrF after 57 iteration = 90.0603
# Average val loss after 57 iteration = 0.0110
# Total val chrF after 57 iteration = 85.8764
# Average test loss after 57 iteration = 0.0098
# Total test chrF after 57 iteration = 85.5363
# Time for the iteration 5.6 seconds
#
#
# Average train loss after 58 iteration = 0.0015
# Total train chrF after 58 iteration = 90.0732
# Average val loss after 58 iteration = 0.0110
# Total val chrF after 58 iteration = 85.8905
# Average test loss after 58 iteration = 0.0098
# Total test chrF after 58 iteration = 85.5742
# Dumping after  58
# Time for the iteration 5.6 seconds
#
#
# Average train loss after 59 iteration = 0.0014
# Total train chrF after 59 iteration = 90.0831
# Average val loss after 59 iteration = 0.0110
# Total val chrF after 59 iteration = 85.8482
# Average test loss after 59 iteration = 0.0098
# Total test chrF after 59 iteration = 85.5742
# Time for the iteration 5.6 seconds
#
#
# Average train loss after 60 iteration = 0.0014
# Total train chrF after 60 iteration = 90.0924
# Average val loss after 60 iteration = 0.0111
# Total val chrF after 60 iteration = 85.8368
# Average test loss after 60 iteration = 0.0098
# Total test chrF after 60 iteration = 85.5748
# Time for the iteration 5.6 seconds
#
#
# Average train loss after 61 iteration = 0.0013
# Total train chrF after 61 iteration = 90.0970
# Average val loss after 61 iteration = 0.0111
# Total val chrF after 61 iteration = 85.8516
# Average test loss after 61 iteration = 0.0098
# Total test chrF after 61 iteration = 85.6013
# Time for the iteration 5.6 seconds
#
#
# Average train loss after 62 iteration = 0.0012
# Total train chrF after 62 iteration = 90.1076
# Average val loss after 62 iteration = 0.0111
# Total val chrF after 62 iteration = 85.8540
# Average test loss after 62 iteration = 0.0099
# Total test chrF after 62 iteration = 85.5910
# Time for the iteration 5.6 seconds
#
#
# Average train loss after 63 iteration = 0.0012
# Total train chrF after 63 iteration = 90.1144
# Average val loss after 63 iteration = 0.0112
# Total val chrF after 63 iteration = 85.8933
# Average test loss after 63 iteration = 0.0099
# Total test chrF after 63 iteration = 85.5948
# Dumping after  63
# Time for the iteration 5.6 seconds
#
#
# Average train loss after 64 iteration = 0.0011
# Total train chrF after 64 iteration = 90.1219
# Average val loss after 64 iteration = 0.0112
# Total val chrF after 64 iteration = 85.9242
# Average test loss after 64 iteration = 0.0099
# Total test chrF after 64 iteration = 85.5848
# Dumping after  64
# Time for the iteration 5.6 seconds
#
#
# Average train loss after 65 iteration = 0.0010
# Total train chrF after 65 iteration = 90.1297
# Average val loss after 65 iteration = 0.0113
# Total val chrF after 65 iteration = 85.9360
# Average test loss after 65 iteration = 0.0099
# Total test chrF after 65 iteration = 85.5755
# Dumping after  65
# Time for the iteration 5.6 seconds
#
#
# Average train loss after 66 iteration = 0.0010
# Total train chrF after 66 iteration = 90.1345
# Average val loss after 66 iteration = 0.0113
# Total val chrF after 66 iteration = 85.9451
# Average test loss after 66 iteration = 0.0100
# Total test chrF after 66 iteration = 85.5934
# Dumping after  66
# Time for the iteration 5.6 seconds
#
#
# Average train loss after 67 iteration = 0.0009
# Total train chrF after 67 iteration = 90.1409
# Average val loss after 67 iteration = 0.0113
# Total val chrF after 67 iteration = 85.9451
# Average test loss after 67 iteration = 0.0100
# Total test chrF after 67 iteration = 85.6210
# Time for the iteration 5.6 seconds
#
#
# Average train loss after 68 iteration = 0.0009
# Total train chrF after 68 iteration = 90.1447
# Average val loss after 68 iteration = 0.0114
# Total val chrF after 68 iteration = 85.9166
# Average test loss after 68 iteration = 0.0100
# Total test chrF after 68 iteration = 85.5949
# Time for the iteration 5.5 seconds
#
#
# Average train loss after 69 iteration = 0.0008
# Total train chrF after 69 iteration = 90.1485
# Average val loss after 69 iteration = 0.0114
# Total val chrF after 69 iteration = 85.8800
# Average test loss after 69 iteration = 0.0101
# Total test chrF after 69 iteration = 85.5718
# Time for the iteration 5.6 seconds
#
#
# Average train loss after 70 iteration = 0.0008
# Total train chrF after 70 iteration = 90.1514
# Average val loss after 70 iteration = 0.0115
# Total val chrF after 70 iteration = 85.8756
# Average test loss after 70 iteration = 0.0101
# Total test chrF after 70 iteration = 85.5471
# Time for the iteration 5.6 seconds
#
#
# Average train loss after 71 iteration = 0.0007
# Total train chrF after 71 iteration = 90.1544
# Average val loss after 71 iteration = 0.0115
# Total val chrF after 71 iteration = 85.8797
# Average test loss after 71 iteration = 0.0102
# Total test chrF after 71 iteration = 85.4620
# Time for the iteration 5.6 seconds
#
#
# Average train loss after 72 iteration = 0.0007
# Total train chrF after 72 iteration = 90.1566
# Average val loss after 72 iteration = 0.0116
# Total val chrF after 72 iteration = 85.7814
# Average test loss after 72 iteration = 0.0102
# Total test chrF after 72 iteration = 85.3691
# Time for the iteration 5.5 seconds
#
#
# Average train loss after 73 iteration = 0.0007
# Total train chrF after 73 iteration = 90.1600
# Average val loss after 73 iteration = 0.0116
# Total val chrF after 73 iteration = 85.7688
# Average test loss after 73 iteration = 0.0103
# Total test chrF after 73 iteration = 85.4275
# Time for the iteration 5.6 seconds
#
#
# Average train loss after 74 iteration = 0.0006
# Total train chrF after 74 iteration = 90.1615
# Average val loss after 74 iteration = 0.0117
# Total val chrF after 74 iteration = 85.7223
# Average test loss after 74 iteration = 0.0103
# Total test chrF after 74 iteration = 85.3555
# Time for the iteration 5.6 seconds
#
#
# Average train loss after 75 iteration = 0.0006
# Total train chrF after 75 iteration = 90.1631
# Average val loss after 75 iteration = 0.0118
# Total val chrF after 75 iteration = 85.6959
# Average test loss after 75 iteration = 0.0104
# Total test chrF after 75 iteration = 85.3305
# Time for the iteration 5.6 seconds
#
#
# Average train loss after 76 iteration = 0.0006
# Total train chrF after 76 iteration = 90.1651
# Average val loss after 76 iteration = 0.0118
# Total val chrF after 76 iteration = 85.6733
# Average test loss after 76 iteration = 0.0104
# Total test chrF after 76 iteration = 85.2664
# Time for the iteration 5.6 seconds
#
#
# Average train loss after 77 iteration = 0.0005
# Total train chrF after 77 iteration = 90.1671
# Average val loss after 77 iteration = 0.0119
# Total val chrF after 77 iteration = 85.6674
# Average test loss after 77 iteration = 0.0105
# Total test chrF after 77 iteration = 85.2418
# Time for the iteration 5.6 seconds
#
#
# Average train loss after 78 iteration = 0.0005
# Total train chrF after 78 iteration = 90.1697
# Average val loss after 78 iteration = 0.0119
# Total val chrF after 78 iteration = 85.6801
# Average test loss after 78 iteration = 0.0105
# Total test chrF after 78 iteration = 85.2407
# Time for the iteration 5.6 seconds
#
#
# Average train loss after 79 iteration = 0.0005
# Total train chrF after 79 iteration = 90.1707
# Average val loss after 79 iteration = 0.0120
# Total val chrF after 79 iteration = 85.6517
# Average test loss after 79 iteration = 0.0106
# Total test chrF after 79 iteration = 85.2129
# Time for the iteration 5.6 seconds
#
#
# Average train loss after 80 iteration = 0.0004
# Total train chrF after 80 iteration = 90.1718
# Average val loss after 80 iteration = 0.0121
# Total val chrF after 80 iteration = 85.6086
# Average test loss after 80 iteration = 0.0107
# Total test chrF after 80 iteration = 85.1937
# Time for the iteration 5.6 seconds
#
#
# Average train loss after 81 iteration = 0.0004
# Total train chrF after 81 iteration = 90.1738
# Average val loss after 81 iteration = 0.0121
# Total val chrF after 81 iteration = 85.5900
# Average test loss after 81 iteration = 0.0107
# Total test chrF after 81 iteration = 85.2086
# Time for the iteration 5.6 seconds
#
#
# Average train loss after 82 iteration = 0.0004
# Total train chrF after 82 iteration = 90.1749
# Average val loss after 82 iteration = 0.0122
# Total val chrF after 82 iteration = 85.5765
# Average test loss after 82 iteration = 0.0108
# Total test chrF after 82 iteration = 85.1389
# Time for the iteration 5.6 seconds
#
#
# Average train loss after 83 iteration = 0.0004
# Total train chrF after 83 iteration = 90.1750
# Average val loss after 83 iteration = 0.0123
# Total val chrF after 83 iteration = 85.5765
# Average test loss after 83 iteration = 0.0109
# Total test chrF after 83 iteration = 85.1389
# Time for the iteration 5.6 seconds
#
#
# Average train loss after 84 iteration = 0.0004
# Total train chrF after 84 iteration = 90.1752
# Average val loss after 84 iteration = 0.0124
# Total val chrF after 84 iteration = 85.6064
# Average test loss after 84 iteration = 0.0109
# Total test chrF after 84 iteration = 85.1325
# Time for the iteration 5.5 seconds
#
#
# Average train loss after 85 iteration = 0.0003
# Total train chrF after 85 iteration = 90.1757
# Average val loss after 85 iteration = 0.0124
# Total val chrF after 85 iteration = 85.5890
# Average test loss after 85 iteration = 0.0110
# Total test chrF after 85 iteration = 85.1511
# Time for the iteration 5.6 seconds
#
#
# Average train loss after 86 iteration = 0.0003
# Total train chrF after 86 iteration = 90.1767
# Average val loss after 86 iteration = 0.0125
# Total val chrF after 86 iteration = 85.5680
# Average test loss after 86 iteration = 0.0111
# Total test chrF after 86 iteration = 85.1702
# Time for the iteration 5.6 seconds
#
#
# Average train loss after 87 iteration = 0.0003
# Total train chrF after 87 iteration = 90.1769
# Average val loss after 87 iteration = 0.0126
# Total val chrF after 87 iteration = 85.5761
# Average test loss after 87 iteration = 0.0112
# Total test chrF after 87 iteration = 85.1491
# Time for the iteration 5.7 seconds
#
#
# Average train loss after 88 iteration = 0.0003
# Total train chrF after 88 iteration = 90.1771
# Average val loss after 88 iteration = 0.0127
# Total val chrF after 88 iteration = 85.5727
# Average test loss after 88 iteration = 0.0112
# Total test chrF after 88 iteration = 85.1374
# Time for the iteration 5.6 seconds
#
#
# Average train loss after 89 iteration = 0.0003
# Total train chrF after 89 iteration = 90.1776
# Average val loss after 89 iteration = 0.0128
# Total val chrF after 89 iteration = 85.5888
# Average test loss after 89 iteration = 0.0113
# Total test chrF after 89 iteration = 85.1426
# Time for the iteration 5.6 seconds
#
#
# Average train loss after 90 iteration = 0.0002
# Total train chrF after 90 iteration = 90.1780
# Average val loss after 90 iteration = 0.0129
# Total val chrF after 90 iteration = 85.5756
# Average test loss after 90 iteration = 0.0114
# Total test chrF after 90 iteration = 85.1229
# Time for the iteration 5.6 seconds
#
#
# Average train loss after 91 iteration = 0.0002
# Total train chrF after 91 iteration = 90.1784
# Average val loss after 91 iteration = 0.0129
# Total val chrF after 91 iteration = 85.6024
# Average test loss after 91 iteration = 0.0115
# Total test chrF after 91 iteration = 85.1245
# Time for the iteration 5.6 seconds
#
#
# Average train loss after 92 iteration = 0.0002
# Total train chrF after 92 iteration = 90.1785
# Average val loss after 92 iteration = 0.0130
# Total val chrF after 92 iteration = 85.6033
# Average test loss after 92 iteration = 0.0115
# Total test chrF after 92 iteration = 85.1071
# Time for the iteration 5.6 seconds
#
#
# Average train loss after 93 iteration = 0.0002
# Total train chrF after 93 iteration = 90.1791
# Average val loss after 93 iteration = 0.0131
# Total val chrF after 93 iteration = 85.5988
# Average test loss after 93 iteration = 0.0116
# Total test chrF after 93 iteration = 85.1071
# Time for the iteration 5.6 seconds
#
#
#
#
# Aborting since there hasn't been much progress
# <Figure size 640x480 with 1 Axes>
# <Figure size 640x480 with 1 Axes>

# %%
language = "yi"
task_name = "random_teacher_general"
vocab_size = 2999
num_epochs = 100
batch_size = 32
model = "50_1"
optimizer = "Adam"
metric = "chrF"

# %%
from IPython.display import Image

Image("curves/{}_{}_{}_{}_{}_loss.png".format(language, task_name, vocab_size, num_epochs, batch_size))

# %%
Image("curves/{}_{}_{}_{}_{}_{}.png".format(language, task_name, vocab_size, num_epochs, batch_size, metric))

# %%
print("{}.{}.{}.{}.{}.{}.{}".format(language, task_name, vocab_size, num_epochs, batch_size, model, optimizer))
# Out:
# yi.random_teacher_general.2999.100.32.50_1.Adam
