# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
# %cd "drive/MyDrive/Tesis/scRNN"
# Out:
# /content/drive/MyDrive/Tesis/scRNN

# %%
import torch

torch.cuda.is_available()
# Out:
# True

# %%
# !pip install sacrebleu
# Out:
# Collecting sacrebleu
#   Downloading sacrebleu-2.0.0-py3-none-any.whl (90 kB)
#      |████████████████████████████████| 90 kB 4.2 MB/s
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from sacrebleu) (1.21.6)
# Collecting portalocker
#   Downloading portalocker-2.4.0-py2.py3-none-any.whl (16 kB)
# Collecting colorama
#   Downloading colorama-0.4.4-py2.py3-none-any.whl (16 kB)
# Requirement already satisfied: regex in /usr/local/lib/python3.7/dist-packages (from sacrebleu) (2019.12.20)
# Requirement already satisfied: tabulate>=0.8.9 in /usr/local/lib/python3.7/dist-packages (from sacrebleu) (0.8.9)
# Installing collected packages: portalocker, colorama, sacrebleu
# Successfully installed colorama-0.4.4 portalocker-2.4.0 sacrebleu-2.0.0

# %%
# !python3 train.py --language yi --task-name sylsim_teacher_general --num-epochs 100 --batch-size 32 --vocab-size 2999 --new-vocab --train --train-sentences-errors-file yi.sylsim_teacher_general.train.sentences.errors.txt --train-sentences-file yi.sylsim_teacher_general.train.sentences.txt --val-sentences-errors-file yi.teacher_general.val.sentences.errors.txt --val-sentences-file yi.teacher_general.val.sentences.txt --test-sentences-errors-file yi.teacher_general.test.sentences.errors.txt --test-sentences-file yi.teacher_general.test.sentences.txt --metric chrF --save
# Out:
# Parameters
# {'language': 'yi', 'task_name': 'sylsim_teacher_general', 'vocab_size': 2999, 'num_epochs': 100, 'batch_size': 32, 'model_name': 'shi_random_20531_100_32', 'new_vocab': True, 'need_to_train': True, 'train_sentences_errors_file': 'yi.sylsim_teacher_general.train.sentences.errors.txt', 'train_sentences_file': 'yi.sylsim_teacher_general.train.sentences.txt', 'val_sentences_errors_file': 'yi.teacher_general.val.sentences.errors.txt', 'val_sentences_file': 'yi.teacher_general.val.sentences.txt', 'test_sentences_errors_file': 'yi.teacher_general.test.sentences.errors.txt', 'test_sentences_file': 'yi.teacher_general.test.sentences.txt', 'metric': 'chrF', 'save_model': True}
#
#
# Creating new vocabulary
# Len of w2i:  2999
# Len of i2w:  2999
# Len of char vocab:  23
#
#
# Initializing an only ScRNN model
#
#
# Training the model...
#
# Average train loss after 1 iteration = 0.1762
# Total train chrF after 1 iteration = 65.0710
# Average val loss after 1 iteration = 0.1668
# Total val chrF after 1 iteration = 78.5000
# Average test loss after 1 iteration = 0.1688
# Total test chrF after 1 iteration = 78.3310
# Dumping after  1
# Time for the iteration 7.5 seconds
#
#
# Average train loss after 2 iteration = 0.1562
# Total train chrF after 2 iteration = 63.3906
# Average val loss after 2 iteration = 0.1270
# Total val chrF after 2 iteration = 76.0730
# Average test loss after 2 iteration = 0.1290
# Total test chrF after 2 iteration = 75.8722
# Time for the iteration 7.2 seconds
#
#
# Average train loss after 3 iteration = 0.1358
# Total train chrF after 3 iteration = 64.8897
# Average val loss after 3 iteration = 0.1100
# Total val chrF after 3 iteration = 76.2515
# Average test loss after 3 iteration = 0.1119
# Total test chrF after 3 iteration = 75.6062
# Time for the iteration 7.2 seconds
#
#
# Average train loss after 4 iteration = 0.1179
# Total train chrF after 4 iteration = 66.5871
# Average val loss after 4 iteration = 0.0945
# Total val chrF after 4 iteration = 76.7443
# Average test loss after 4 iteration = 0.0963
# Total test chrF after 4 iteration = 76.2146
# Time for the iteration 7.2 seconds
#
#
# Average train loss after 5 iteration = 0.1010
# Total train chrF after 5 iteration = 68.8269
# Average val loss after 5 iteration = 0.0800
# Total val chrF after 5 iteration = 77.3491
# Average test loss after 5 iteration = 0.0817
# Total test chrF after 5 iteration = 76.7909
# Time for the iteration 7.2 seconds
#
#
# Average train loss after 6 iteration = 0.0867
# Total train chrF after 6 iteration = 70.6407
# Average val loss after 6 iteration = 0.0679
# Total val chrF after 6 iteration = 78.1249
# Average test loss after 6 iteration = 0.0697
# Total test chrF after 6 iteration = 77.7881
# Time for the iteration 7.2 seconds
#
#
# Average train loss after 7 iteration = 0.0752
# Total train chrF after 7 iteration = 72.2037
# Average val loss after 7 iteration = 0.0584
# Total val chrF after 7 iteration = 78.8693
# Average test loss after 7 iteration = 0.0600
# Total test chrF after 7 iteration = 78.8588
# Dumping after  7
# Time for the iteration 7.3 seconds
#
#
# Average train loss after 8 iteration = 0.0658
# Total train chrF after 8 iteration = 73.5048
# Average val loss after 8 iteration = 0.0509
# Total val chrF after 8 iteration = 79.5500
# Average test loss after 8 iteration = 0.0524
# Total test chrF after 8 iteration = 79.6113
# Dumping after  8
# Time for the iteration 7.2 seconds
#
#
# Average train loss after 9 iteration = 0.0580
# Total train chrF after 9 iteration = 74.7232
# Average val loss after 9 iteration = 0.0448
# Total val chrF after 9 iteration = 80.2851
# Average test loss after 9 iteration = 0.0461
# Total test chrF after 9 iteration = 80.2856
# Dumping after  9
# Time for the iteration 7.2 seconds
#
#
# Average train loss after 10 iteration = 0.0512
# Total train chrF after 10 iteration = 75.7820
# Average val loss after 10 iteration = 0.0397
# Total val chrF after 10 iteration = 81.0577
# Average test loss after 10 iteration = 0.0409
# Total test chrF after 10 iteration = 81.1238
# Dumping after  10
# Time for the iteration 7.3 seconds
#
#
# Average train loss after 11 iteration = 0.0455
# Total train chrF after 11 iteration = 76.7647
# Average val loss after 11 iteration = 0.0356
# Total val chrF after 11 iteration = 81.4932
# Average test loss after 11 iteration = 0.0366
# Total test chrF after 11 iteration = 81.7069
# Dumping after  11
# Time for the iteration 7.2 seconds
#
#
# Average train loss after 12 iteration = 0.0405
# Total train chrF after 12 iteration = 77.7800
# Average val loss after 12 iteration = 0.0322
# Total val chrF after 12 iteration = 81.9350
# Average test loss after 12 iteration = 0.0330
# Total test chrF after 12 iteration = 82.2359
# Dumping after  12
# Time for the iteration 7.3 seconds
#
#
# Average train loss after 13 iteration = 0.0362
# Total train chrF after 13 iteration = 78.6940
# Average val loss after 13 iteration = 0.0293
# Total val chrF after 13 iteration = 82.3216
# Average test loss after 13 iteration = 0.0300
# Total test chrF after 13 iteration = 82.6300
# Dumping after  13
# Time for the iteration 7.6 seconds
#
#
# Average train loss after 14 iteration = 0.0325
# Total train chrF after 14 iteration = 79.5631
# Average val loss after 14 iteration = 0.0269
# Total val chrF after 14 iteration = 82.6739
# Average test loss after 14 iteration = 0.0274
# Total test chrF after 14 iteration = 83.0788
# Dumping after  14
# Time for the iteration 7.3 seconds
#
#
# Average train loss after 15 iteration = 0.0293
# Total train chrF after 15 iteration = 80.4374
# Average val loss after 15 iteration = 0.0250
# Total val chrF after 15 iteration = 83.0051
# Average test loss after 15 iteration = 0.0253
# Total test chrF after 15 iteration = 83.2415
# Dumping after  15
# Time for the iteration 7.2 seconds
#
#
# Average train loss after 16 iteration = 0.0265
# Total train chrF after 16 iteration = 81.2172
# Average val loss after 16 iteration = 0.0233
# Total val chrF after 16 iteration = 83.3680
# Average test loss after 16 iteration = 0.0235
# Total test chrF after 16 iteration = 83.4416
# Dumping after  16
# Time for the iteration 7.3 seconds
#
#
# Average train loss after 17 iteration = 0.0241
# Total train chrF after 17 iteration = 82.0347
# Average val loss after 17 iteration = 0.0219
# Total val chrF after 17 iteration = 83.5899
# Average test loss after 17 iteration = 0.0220
# Total test chrF after 17 iteration = 83.7127
# Dumping after  17
# Time for the iteration 7.3 seconds
#
#
# Average train loss after 18 iteration = 0.0221
# Total train chrF after 18 iteration = 82.6877
# Average val loss after 18 iteration = 0.0207
# Total val chrF after 18 iteration = 83.7246
# Average test loss after 18 iteration = 0.0207
# Total test chrF after 18 iteration = 83.9381
# Dumping after  18
# Time for the iteration 7.2 seconds
#
#
# Average train loss after 19 iteration = 0.0202
# Total train chrF after 19 iteration = 83.3416
# Average val loss after 19 iteration = 0.0197
# Total val chrF after 19 iteration = 83.9475
# Average test loss after 19 iteration = 0.0196
# Total test chrF after 19 iteration = 84.0834
# Dumping after  19
# Time for the iteration 7.3 seconds
#
#
# Average train loss after 20 iteration = 0.0186
# Total train chrF after 20 iteration = 83.9016
# Average val loss after 20 iteration = 0.0188
# Total val chrF after 20 iteration = 84.1069
# Average test loss after 20 iteration = 0.0187
# Total test chrF after 20 iteration = 84.1016
# Dumping after  20
# Time for the iteration 7.3 seconds
#
#
# Average train loss after 21 iteration = 0.0172
# Total train chrF after 21 iteration = 84.4788
# Average val loss after 21 iteration = 0.0181
# Total val chrF after 21 iteration = 84.2923
# Average test loss after 21 iteration = 0.0178
# Total test chrF after 21 iteration = 84.2861
# Dumping after  21
# Time for the iteration 7.5 seconds
#
#
# Average train loss after 22 iteration = 0.0160
# Total train chrF after 22 iteration = 85.0260
# Average val loss after 22 iteration = 0.0174
# Total val chrF after 22 iteration = 84.3636
# Average test loss after 22 iteration = 0.0171
# Total test chrF after 22 iteration = 84.3673
# Dumping after  22
# Time for the iteration 7.3 seconds
#
#
# Average train loss after 23 iteration = 0.0149
# Total train chrF after 23 iteration = 85.5203
# Average val loss after 23 iteration = 0.0169
# Total val chrF after 23 iteration = 84.4929
# Average test loss after 23 iteration = 0.0165
# Total test chrF after 23 iteration = 84.4972
# Dumping after  23
# Time for the iteration 7.4 seconds
#
#
# Average train loss after 24 iteration = 0.0139
# Total train chrF after 24 iteration = 85.9235
# Average val loss after 24 iteration = 0.0164
# Total val chrF after 24 iteration = 84.6543
# Average test loss after 24 iteration = 0.0160
# Total test chrF after 24 iteration = 84.5940
# Dumping after  24
# Time for the iteration 7.4 seconds
#
#
# Average train loss after 25 iteration = 0.0131
# Total train chrF after 25 iteration = 86.2961
# Average val loss after 25 iteration = 0.0160
# Total val chrF after 25 iteration = 84.7101
# Average test loss after 25 iteration = 0.0155
# Total test chrF after 25 iteration = 84.6489
# Dumping after  25
# Time for the iteration 7.4 seconds
#
#
# Average train loss after 26 iteration = 0.0123
# Total train chrF after 26 iteration = 86.6361
# Average val loss after 26 iteration = 0.0156
# Total val chrF after 26 iteration = 84.7782
# Average test loss after 26 iteration = 0.0151
# Total test chrF after 26 iteration = 84.6705
# Dumping after  26
# Time for the iteration 7.4 seconds
#
#
# Average train loss after 27 iteration = 0.0116
# Total train chrF after 27 iteration = 86.9413
# Average val loss after 27 iteration = 0.0153
# Total val chrF after 27 iteration = 84.8397
# Average test loss after 27 iteration = 0.0147
# Total test chrF after 27 iteration = 84.8089
# Dumping after  27
# Time for the iteration 7.4 seconds
#
#
# Average train loss after 28 iteration = 0.0109
# Total train chrF after 28 iteration = 87.2287
# Average val loss after 28 iteration = 0.0150
# Total val chrF after 28 iteration = 84.9371
# Average test loss after 28 iteration = 0.0143
# Total test chrF after 28 iteration = 84.8018
# Dumping after  28
# Time for the iteration 7.4 seconds
#
#
# Average train loss after 29 iteration = 0.0103
# Total train chrF after 29 iteration = 87.4763
# Average val loss after 29 iteration = 0.0148
# Total val chrF after 29 iteration = 84.9968
# Average test loss after 29 iteration = 0.0141
# Total test chrF after 29 iteration = 84.8132
# Dumping after  29
# Time for the iteration 7.4 seconds
#
#
# Average train loss after 30 iteration = 0.0097
# Total train chrF after 30 iteration = 87.6928
# Average val loss after 30 iteration = 0.0146
# Total val chrF after 30 iteration = 85.0906
# Average test loss after 30 iteration = 0.0138
# Total test chrF after 30 iteration = 84.8173
# Dumping after  30
# Time for the iteration 7.4 seconds
#
#
# Average train loss after 31 iteration = 0.0092
# Total train chrF after 31 iteration = 87.8877
# Average val loss after 31 iteration = 0.0144
# Total val chrF after 31 iteration = 85.1268
# Average test loss after 31 iteration = 0.0136
# Total test chrF after 31 iteration = 84.8191
# Dumping after  31
# Time for the iteration 7.4 seconds
#
#
# Average train loss after 32 iteration = 0.0088
# Total train chrF after 32 iteration = 88.0467
# Average val loss after 32 iteration = 0.0142
# Total val chrF after 32 iteration = 85.1701
# Average test loss after 32 iteration = 0.0134
# Total test chrF after 32 iteration = 84.8391
# Dumping after  32
# Time for the iteration 7.4 seconds
#
#
# Average train loss after 33 iteration = 0.0083
# Total train chrF after 33 iteration = 88.2248
# Average val loss after 33 iteration = 0.0140
# Total val chrF after 33 iteration = 85.1976
# Average test loss after 33 iteration = 0.0132
# Total test chrF after 33 iteration = 84.8969
# Dumping after  33
# Time for the iteration 7.4 seconds
#
#
# Average train loss after 34 iteration = 0.0079
# Total train chrF after 34 iteration = 88.3899
# Average val loss after 34 iteration = 0.0139
# Total val chrF after 34 iteration = 85.2307
# Average test loss after 34 iteration = 0.0130
# Total test chrF after 34 iteration = 84.9403
# Dumping after  34
# Time for the iteration 7.4 seconds
#
#
# Average train loss after 35 iteration = 0.0075
# Total train chrF after 35 iteration = 88.5648
# Average val loss after 35 iteration = 0.0138
# Total val chrF after 35 iteration = 85.2477
# Average test loss after 35 iteration = 0.0129
# Total test chrF after 35 iteration = 84.9426
# Dumping after  35
# Time for the iteration 7.4 seconds
#
#
# Average train loss after 36 iteration = 0.0072
# Total train chrF after 36 iteration = 88.6936
# Average val loss after 36 iteration = 0.0137
# Total val chrF after 36 iteration = 85.2764
# Average test loss after 36 iteration = 0.0127
# Total test chrF after 36 iteration = 84.9397
# Dumping after  36
# Time for the iteration 7.4 seconds
#
#
# Average train loss after 37 iteration = 0.0068
# Total train chrF after 37 iteration = 88.8158
# Average val loss after 37 iteration = 0.0136
# Total val chrF after 37 iteration = 85.3574
# Average test loss after 37 iteration = 0.0126
# Total test chrF after 37 iteration = 84.9637
# Dumping after  37
# Time for the iteration 7.4 seconds
#
#
# Average train loss after 38 iteration = 0.0065
# Total train chrF after 38 iteration = 88.9306
# Average val loss after 38 iteration = 0.0135
# Total val chrF after 38 iteration = 85.4401
# Average test loss after 38 iteration = 0.0125
# Total test chrF after 38 iteration = 84.9392
# Dumping after  38
# Time for the iteration 7.4 seconds
#
#
# Average train loss after 39 iteration = 0.0062
# Total train chrF after 39 iteration = 89.0422
# Average val loss after 39 iteration = 0.0134
# Total val chrF after 39 iteration = 85.4697
# Average test loss after 39 iteration = 0.0124
# Total test chrF after 39 iteration = 84.9278
# Dumping after  39
# Time for the iteration 7.4 seconds
#
#
# Average train loss after 40 iteration = 0.0059
# Total train chrF after 40 iteration = 89.1161
# Average val loss after 40 iteration = 0.0134
# Total val chrF after 40 iteration = 85.4899
# Average test loss after 40 iteration = 0.0123
# Total test chrF after 40 iteration = 84.9438
# Dumping after  40
# Time for the iteration 7.4 seconds
#
#
# Average train loss after 41 iteration = 0.0056
# Total train chrF after 41 iteration = 89.1957
# Average val loss after 41 iteration = 0.0133
# Total val chrF after 41 iteration = 85.4938
# Average test loss after 41 iteration = 0.0123
# Total test chrF after 41 iteration = 84.9136
# Dumping after  41
# Time for the iteration 7.3 seconds
#
#
# Average train loss after 42 iteration = 0.0054
# Total train chrF after 42 iteration = 89.2816
# Average val loss after 42 iteration = 0.0133
# Total val chrF after 42 iteration = 85.5002
# Average test loss after 42 iteration = 0.0122
# Total test chrF after 42 iteration = 84.8682
# Dumping after  42
# Time for the iteration 7.4 seconds
#
#
# Average train loss after 43 iteration = 0.0051
# Total train chrF after 43 iteration = 89.3470
# Average val loss after 43 iteration = 0.0133
# Total val chrF after 43 iteration = 85.5730
# Average test loss after 43 iteration = 0.0122
# Total test chrF after 43 iteration = 84.8918
# Dumping after  43
# Time for the iteration 7.4 seconds
#
#
# Average train loss after 44 iteration = 0.0049
# Total train chrF after 44 iteration = 89.4236
# Average val loss after 44 iteration = 0.0132
# Total val chrF after 44 iteration = 85.5589
# Average test loss after 44 iteration = 0.0121
# Total test chrF after 44 iteration = 84.8575
# Time for the iteration 7.3 seconds
#
#
# Average train loss after 45 iteration = 0.0047
# Total train chrF after 45 iteration = 89.4794
# Average val loss after 45 iteration = 0.0132
# Total val chrF after 45 iteration = 85.5587
# Average test loss after 45 iteration = 0.0121
# Total test chrF after 45 iteration = 84.8156
# Time for the iteration 7.3 seconds
#
#
# Average train loss after 46 iteration = 0.0045
# Total train chrF after 46 iteration = 89.5410
# Average val loss after 46 iteration = 0.0132
# Total val chrF after 46 iteration = 85.5776
# Average test loss after 46 iteration = 0.0121
# Total test chrF after 46 iteration = 84.7896
# Dumping after  46
# Time for the iteration 7.4 seconds
#
#
# Average train loss after 47 iteration = 0.0043
# Total train chrF after 47 iteration = 89.5975
# Average val loss after 47 iteration = 0.0132
# Total val chrF after 47 iteration = 85.5921
# Average test loss after 47 iteration = 0.0121
# Total test chrF after 47 iteration = 84.8009
# Dumping after  47
# Time for the iteration 7.4 seconds
#
#
# Average train loss after 48 iteration = 0.0041
# Total train chrF after 48 iteration = 89.6488
# Average val loss after 48 iteration = 0.0132
# Total val chrF after 48 iteration = 85.6036
# Average test loss after 48 iteration = 0.0120
# Total test chrF after 48 iteration = 84.8049
# Dumping after  48
# Time for the iteration 7.4 seconds
#
#
# Average train loss after 49 iteration = 0.0039
# Total train chrF after 49 iteration = 89.6877
# Average val loss after 49 iteration = 0.0132
# Total val chrF after 49 iteration = 85.5961
# Average test loss after 49 iteration = 0.0120
# Total test chrF after 49 iteration = 84.7952
# Time for the iteration 7.3 seconds
#
#
# Average train loss after 50 iteration = 0.0038
# Total train chrF after 50 iteration = 89.7240
# Average val loss after 50 iteration = 0.0132
# Total val chrF after 50 iteration = 85.5770
# Average test loss after 50 iteration = 0.0120
# Total test chrF after 50 iteration = 84.8084
# Time for the iteration 7.4 seconds
#
#
# Average train loss after 51 iteration = 0.0036
# Total train chrF after 51 iteration = 89.7618
# Average val loss after 51 iteration = 0.0132
# Total val chrF after 51 iteration = 85.5749
# Average test loss after 51 iteration = 0.0120
# Total test chrF after 51 iteration = 84.8395
# Time for the iteration 7.3 seconds
#
#
# Average train loss after 52 iteration = 0.0034
# Total train chrF after 52 iteration = 89.8169
# Average val loss after 52 iteration = 0.0132
# Total val chrF after 52 iteration = 85.6132
# Average test loss after 52 iteration = 0.0120
# Total test chrF after 52 iteration = 84.8324
# Dumping after  52
# Time for the iteration 7.3 seconds
#
#
# Average train loss after 53 iteration = 0.0033
# Total train chrF after 53 iteration = 89.8494
# Average val loss after 53 iteration = 0.0132
# Total val chrF after 53 iteration = 85.5794
# Average test loss after 53 iteration = 0.0121
# Total test chrF after 53 iteration = 84.7907
# Time for the iteration 7.3 seconds
#
#
# Average train loss after 54 iteration = 0.0031
# Total train chrF after 54 iteration = 89.8815
# Average val loss after 54 iteration = 0.0132
# Total val chrF after 54 iteration = 85.5474
# Average test loss after 54 iteration = 0.0121
# Total test chrF after 54 iteration = 84.7910
# Time for the iteration 7.4 seconds
#
#
# Average train loss after 55 iteration = 0.0030
# Total train chrF after 55 iteration = 89.9196
# Average val loss after 55 iteration = 0.0132
# Total val chrF after 55 iteration = 85.4972
# Average test loss after 55 iteration = 0.0121
# Total test chrF after 55 iteration = 84.7983
# Time for the iteration 7.3 seconds
#
#
# Average train loss after 56 iteration = 0.0029
# Total train chrF after 56 iteration = 89.9433
# Average val loss after 56 iteration = 0.0132
# Total val chrF after 56 iteration = 85.4972
# Average test loss after 56 iteration = 0.0121
# Total test chrF after 56 iteration = 84.7846
# Time for the iteration 7.3 seconds
#
#
# Average train loss after 57 iteration = 0.0028
# Total train chrF after 57 iteration = 89.9747
# Average val loss after 57 iteration = 0.0133
# Total val chrF after 57 iteration = 85.4802
# Average test loss after 57 iteration = 0.0121
# Total test chrF after 57 iteration = 84.7901
# Time for the iteration 7.4 seconds
#
#
# Average train loss after 58 iteration = 0.0026
# Total train chrF after 58 iteration = 89.9947
# Average val loss after 58 iteration = 0.0133
# Total val chrF after 58 iteration = 85.4821
# Average test loss after 58 iteration = 0.0122
# Total test chrF after 58 iteration = 84.7956
# Time for the iteration 7.4 seconds
#
#
# Average train loss after 59 iteration = 0.0025
# Total train chrF after 59 iteration = 90.0176
# Average val loss after 59 iteration = 0.0133
# Total val chrF after 59 iteration = 85.4779
# Average test loss after 59 iteration = 0.0122
# Total test chrF after 59 iteration = 84.8130
# Time for the iteration 7.3 seconds
#
#
# Average train loss after 60 iteration = 0.0024
# Total train chrF after 60 iteration = 90.0394
# Average val loss after 60 iteration = 0.0133
# Total val chrF after 60 iteration = 85.4637
# Average test loss after 60 iteration = 0.0122
# Total test chrF after 60 iteration = 84.8298
# Time for the iteration 7.5 seconds
#
#
# Average train loss after 61 iteration = 0.0023
# Total train chrF after 61 iteration = 90.0625
# Average val loss after 61 iteration = 0.0133
# Total val chrF after 61 iteration = 85.4082
# Average test loss after 61 iteration = 0.0123
# Total test chrF after 61 iteration = 84.8228
# Time for the iteration 7.4 seconds
#
#
# Average train loss after 62 iteration = 0.0022
# Total train chrF after 62 iteration = 90.0797
# Average val loss after 62 iteration = 0.0134
# Total val chrF after 62 iteration = 85.4472
# Average test loss after 62 iteration = 0.0123
# Total test chrF after 62 iteration = 84.8176
# Time for the iteration 7.3 seconds
#
#
# Average train loss after 63 iteration = 0.0021
# Total train chrF after 63 iteration = 90.0980
# Average val loss after 63 iteration = 0.0134
# Total val chrF after 63 iteration = 85.4229
# Average test loss after 63 iteration = 0.0124
# Total test chrF after 63 iteration = 84.7840
# Time for the iteration 7.4 seconds
#
#
# Average train loss after 64 iteration = 0.0020
# Total train chrF after 64 iteration = 90.1129
# Average val loss after 64 iteration = 0.0134
# Total val chrF after 64 iteration = 85.4127
# Average test loss after 64 iteration = 0.0124
# Total test chrF after 64 iteration = 84.7315
# Time for the iteration 7.3 seconds
#
#
# Average train loss after 65 iteration = 0.0019
# Total train chrF after 65 iteration = 90.1294
# Average val loss after 65 iteration = 0.0135
# Total val chrF after 65 iteration = 85.4345
# Average test loss after 65 iteration = 0.0125
# Total test chrF after 65 iteration = 84.7196
# Time for the iteration 7.4 seconds
#
#
# Average train loss after 66 iteration = 0.0018
# Total train chrF after 66 iteration = 90.1481
# Average val loss after 66 iteration = 0.0135
# Total val chrF after 66 iteration = 85.4646
# Average test loss after 66 iteration = 0.0125
# Total test chrF after 66 iteration = 84.6978
# Time for the iteration 7.4 seconds
#
#
# Average train loss after 67 iteration = 0.0018
# Total train chrF after 67 iteration = 90.1615
# Average val loss after 67 iteration = 0.0135
# Total val chrF after 67 iteration = 85.4516
# Average test loss after 67 iteration = 0.0126
# Total test chrF after 67 iteration = 84.7044
# Time for the iteration 7.3 seconds
#
#
# Average train loss after 68 iteration = 0.0017
# Total train chrF after 68 iteration = 90.1739
# Average val loss after 68 iteration = 0.0136
# Total val chrF after 68 iteration = 85.4461
# Average test loss after 68 iteration = 0.0127
# Total test chrF after 68 iteration = 84.7354
# Time for the iteration 7.3 seconds
#
#
# Average train loss after 69 iteration = 0.0016
# Total train chrF after 69 iteration = 90.1866
# Average val loss after 69 iteration = 0.0136
# Total val chrF after 69 iteration = 85.4204
# Average test loss after 69 iteration = 0.0127
# Total test chrF after 69 iteration = 84.7447
# Time for the iteration 7.3 seconds
#
#
# Average train loss after 70 iteration = 0.0015
# Total train chrF after 70 iteration = 90.1976
# Average val loss after 70 iteration = 0.0137
# Total val chrF after 70 iteration = 85.4101
# Average test loss after 70 iteration = 0.0128
# Total test chrF after 70 iteration = 84.7536
# Time for the iteration 7.3 seconds
#
#
# Average train loss after 71 iteration = 0.0015
# Total train chrF after 71 iteration = 90.2107
# Average val loss after 71 iteration = 0.0137
# Total val chrF after 71 iteration = 85.3980
# Average test loss after 71 iteration = 0.0128
# Total test chrF after 71 iteration = 84.7381
# Time for the iteration 7.3 seconds
#
#
# Average train loss after 72 iteration = 0.0014
# Total train chrF after 72 iteration = 90.2200
# Average val loss after 72 iteration = 0.0138
# Total val chrF after 72 iteration = 85.4140
# Average test loss after 72 iteration = 0.0129
# Total test chrF after 72 iteration = 84.7564
# Time for the iteration 7.4 seconds
#
#
# Average train loss after 73 iteration = 0.0013
# Total train chrF after 73 iteration = 90.2265
# Average val loss after 73 iteration = 0.0138
# Total val chrF after 73 iteration = 85.3686
# Average test loss after 73 iteration = 0.0130
# Total test chrF after 73 iteration = 84.7247
# Time for the iteration 7.3 seconds
#
#
# Average train loss after 74 iteration = 0.0013
# Total train chrF after 74 iteration = 90.2353
# Average val loss after 74 iteration = 0.0139
# Total val chrF after 74 iteration = 85.3626
# Average test loss after 74 iteration = 0.0130
# Total test chrF after 74 iteration = 84.6810
# Time for the iteration 7.3 seconds
#
#
# Average train loss after 75 iteration = 0.0012
# Total train chrF after 75 iteration = 90.2427
# Average val loss after 75 iteration = 0.0139
# Total val chrF after 75 iteration = 85.3271
# Average test loss after 75 iteration = 0.0131
# Total test chrF after 75 iteration = 84.6774
# Time for the iteration 7.4 seconds
#
#
# Average train loss after 76 iteration = 0.0012
# Total train chrF after 76 iteration = 90.2508
# Average val loss after 76 iteration = 0.0140
# Total val chrF after 76 iteration = 85.3070
# Average test loss after 76 iteration = 0.0132
# Total test chrF after 76 iteration = 84.6916
# Time for the iteration 7.3 seconds
#
#
# Average train loss after 77 iteration = 0.0011
# Total train chrF after 77 iteration = 90.2520
# Average val loss after 77 iteration = 0.0140
# Total val chrF after 77 iteration = 85.3042
# Average test loss after 77 iteration = 0.0133
# Total test chrF after 77 iteration = 84.7102
# Time for the iteration 7.3 seconds
#
#
# Average train loss after 78 iteration = 0.0011
# Total train chrF after 78 iteration = 90.2615
# Average val loss after 78 iteration = 0.0141
# Total val chrF after 78 iteration = 85.2834
# Average test loss after 78 iteration = 0.0133
# Total test chrF after 78 iteration = 84.6494
# Time for the iteration 7.3 seconds
#
#
# Average train loss after 79 iteration = 0.0010
# Total train chrF after 79 iteration = 90.2670
# Average val loss after 79 iteration = 0.0142
# Total val chrF after 79 iteration = 85.2998
# Average test loss after 79 iteration = 0.0134
# Total test chrF after 79 iteration = 84.7005
# Time for the iteration 7.3 seconds
#
#
#
#
# Aborting since there hasn't been much progress
# <Figure size 640x480 with 1 Axes>
# <Figure size 640x480 with 1 Axes>

# %%
language = "yi"
task_name = "sylsim_teacher_general"
vocab_size = 2999
num_epochs = 100
batch_size = 32
model = "50_1"
optimizer = "Adam"
metric = "chrF"

# %%
from IPython.display import Image

Image("curves/{}_{}_{}_{}_{}_loss.png".format(language, task_name, vocab_size, num_epochs, batch_size))

# %%
Image("curves/{}_{}_{}_{}_{}_{}.png".format(language, task_name, vocab_size, num_epochs, batch_size, metric))

# %%
print("{}.{}.{}.{}.{}.{}.{}".format(language, task_name, vocab_size, num_epochs, batch_size, model, optimizer))
# Out:
# yi.sylsim_teacher_general.2999.100.32.50_1.Adam
