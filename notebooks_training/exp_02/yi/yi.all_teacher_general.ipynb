# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
# %cd "drive/MyDrive/Tesis/scRNN"
# Out:
# /content/drive/MyDrive/Tesis/scRNN

# %%
import torch

torch.cuda.is_available()
# Out:
# True

# %%
# !pip install sacrebleu
# Out:
# Collecting sacrebleu
#   Downloading sacrebleu-2.0.0-py3-none-any.whl (90 kB)
#      |████████████████████████████████| 90 kB 8.3 MB/s
# Requirement already satisfied: regex in /usr/local/lib/python3.7/dist-packages (from sacrebleu) (2019.12.20)
# Requirement already satisfied: tabulate>=0.8.9 in /usr/local/lib/python3.7/dist-packages (from sacrebleu) (0.8.9)
# Collecting colorama
#   Downloading colorama-0.4.4-py2.py3-none-any.whl (16 kB)
# Collecting portalocker
#   Downloading portalocker-2.4.0-py2.py3-none-any.whl (16 kB)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from sacrebleu) (1.21.6)
# Installing collected packages: portalocker, colorama, sacrebleu
# Successfully installed colorama-0.4.4 portalocker-2.4.0 sacrebleu-2.0.0

# %%
# !python3 train.py --language yi --task-name all_teacher_general --num-epochs 100 --batch-size 32 --vocab-size 2999 --new-vocab --train --train-sentences-errors-file yi.all_teacher_general.train.sentences.errors.txt --train-sentences-file yi.all_teacher_general.train.sentences.txt --val-sentences-errors-file yi.teacher_general.val.sentences.errors.txt --val-sentences-file yi.teacher_general.val.sentences.txt --test-sentences-errors-file yi.teacher_general.test.sentences.errors.txt --test-sentences-file yi.teacher_general.test.sentences.txt --metric chrF --save
# Out:
# Parameters
# {'language': 'yi', 'task_name': 'all_teacher_general', 'vocab_size': 2999, 'num_epochs': 100, 'batch_size': 32, 'model_name': 'shi_random_20531_100_32', 'new_vocab': True, 'need_to_train': True, 'train_sentences_errors_file': 'yi.all_teacher_general.train.sentences.errors.txt', 'train_sentences_file': 'yi.all_teacher_general.train.sentences.txt', 'val_sentences_errors_file': 'yi.teacher_general.val.sentences.errors.txt', 'val_sentences_file': 'yi.teacher_general.val.sentences.txt', 'test_sentences_errors_file': 'yi.teacher_general.test.sentences.errors.txt', 'test_sentences_file': 'yi.teacher_general.test.sentences.txt', 'metric': 'chrF', 'save_model': True}
#
#
# Creating new vocabulary
# Len of w2i:  2999
# Len of i2w:  2999
# Len of char vocab:  23
#
#
# Initializing an only ScRNN model
#
#
# Training the model...
#
# Average train loss after 1 iteration = 0.1369
# Total train chrF after 1 iteration = 65.7744
# Average val loss after 1 iteration = 0.1299
# Total val chrF after 1 iteration = 78.3584
# Average test loss after 1 iteration = 0.1306
# Total test chrF after 1 iteration = 78.3121
# Dumping after  1
# Time for the iteration 18.2 seconds
#
#
# Average train loss after 2 iteration = 0.0761
# Total train chrF after 2 iteration = 72.5111
# Average val loss after 2 iteration = 0.0914
# Total val chrF after 2 iteration = 79.0192
# Average test loss after 2 iteration = 0.0924
# Total test chrF after 2 iteration = 78.9065
# Dumping after  2
# Time for the iteration 18.1 seconds
#
#
# Average train loss after 3 iteration = 0.0457
# Total train chrF after 3 iteration = 77.5266
# Average val loss after 3 iteration = 0.0718
# Total val chrF after 3 iteration = 79.3884
# Average test loss after 3 iteration = 0.0732
# Total test chrF after 3 iteration = 79.1731
# Dumping after  3
# Time for the iteration 18.2 seconds
#
#
# Average train loss after 4 iteration = 0.0304
# Total train chrF after 4 iteration = 80.8624
# Average val loss after 4 iteration = 0.0559
# Total val chrF after 4 iteration = 79.6429
# Average test loss after 4 iteration = 0.0571
# Total test chrF after 4 iteration = 79.4047
# Dumping after  4
# Time for the iteration 18.1 seconds
#
#
# Average train loss after 5 iteration = 0.0221
# Total train chrF after 5 iteration = 83.1432
# Average val loss after 5 iteration = 0.0452
# Total val chrF after 5 iteration = 79.9297
# Average test loss after 5 iteration = 0.0460
# Total test chrF after 5 iteration = 79.7774
# Dumping after  5
# Time for the iteration 18.4 seconds
#
#
# Average train loss after 6 iteration = 0.0172
# Total train chrF after 6 iteration = 84.7206
# Average val loss after 6 iteration = 0.0381
# Total val chrF after 6 iteration = 80.1615
# Average test loss after 6 iteration = 0.0386
# Total test chrF after 6 iteration = 80.1084
# Dumping after  6
# Time for the iteration 18.0 seconds
#
#
# Average train loss after 7 iteration = 0.0141
# Total train chrF after 7 iteration = 85.7792
# Average val loss after 7 iteration = 0.0331
# Total val chrF after 7 iteration = 80.6105
# Average test loss after 7 iteration = 0.0334
# Total test chrF after 7 iteration = 80.4526
# Dumping after  7
# Time for the iteration 18.4 seconds
#
#
# Average train loss after 8 iteration = 0.0120
# Total train chrF after 8 iteration = 86.5544
# Average val loss after 8 iteration = 0.0295
# Total val chrF after 8 iteration = 80.9356
# Average test loss after 8 iteration = 0.0295
# Total test chrF after 8 iteration = 80.7259
# Dumping after  8
# Time for the iteration 18.1 seconds
#
#
# Average train loss after 9 iteration = 0.0105
# Total train chrF after 9 iteration = 87.1778
# Average val loss after 9 iteration = 0.0268
# Total val chrF after 9 iteration = 81.3523
# Average test loss after 9 iteration = 0.0267
# Total test chrF after 9 iteration = 81.1209
# Dumping after  9
# Time for the iteration 18.2 seconds
#
#
# Average train loss after 10 iteration = 0.0093
# Total train chrF after 10 iteration = 87.6159
# Average val loss after 10 iteration = 0.0246
# Total val chrF after 10 iteration = 81.7371
# Average test loss after 10 iteration = 0.0243
# Total test chrF after 10 iteration = 81.5135
# Dumping after  10
# Time for the iteration 18.2 seconds
#
#
# Average train loss after 11 iteration = 0.0083
# Total train chrF after 11 iteration = 87.9656
# Average val loss after 11 iteration = 0.0230
# Total val chrF after 11 iteration = 82.1626
# Average test loss after 11 iteration = 0.0226
# Total test chrF after 11 iteration = 81.8919
# Dumping after  11
# Time for the iteration 18.2 seconds
#
#
# Average train loss after 12 iteration = 0.0075
# Total train chrF after 12 iteration = 88.2605
# Average val loss after 12 iteration = 0.0217
# Total val chrF after 12 iteration = 82.4978
# Average test loss after 12 iteration = 0.0212
# Total test chrF after 12 iteration = 82.2847
# Dumping after  12
# Time for the iteration 18.3 seconds
#
#
# Average train loss after 13 iteration = 0.0068
# Total train chrF after 13 iteration = 88.5264
# Average val loss after 13 iteration = 0.0207
# Total val chrF after 13 iteration = 82.8789
# Average test loss after 13 iteration = 0.0201
# Total test chrF after 13 iteration = 82.6069
# Dumping after  13
# Time for the iteration 18.1 seconds
#
#
# Average train loss after 14 iteration = 0.0062
# Total train chrF after 14 iteration = 88.7465
# Average val loss after 14 iteration = 0.0198
# Total val chrF after 14 iteration = 83.0029
# Average test loss after 14 iteration = 0.0192
# Total test chrF after 14 iteration = 82.7977
# Dumping after  14
# Time for the iteration 18.2 seconds
#
#
# Average train loss after 15 iteration = 0.0057
# Total train chrF after 15 iteration = 88.9460
# Average val loss after 15 iteration = 0.0191
# Total val chrF after 15 iteration = 83.1985
# Average test loss after 15 iteration = 0.0184
# Total test chrF after 15 iteration = 83.0078
# Dumping after  15
# Time for the iteration 18.2 seconds
#
#
# Average train loss after 16 iteration = 0.0053
# Total train chrF after 16 iteration = 89.1118
# Average val loss after 16 iteration = 0.0184
# Total val chrF after 16 iteration = 83.3923
# Average test loss after 16 iteration = 0.0177
# Total test chrF after 16 iteration = 83.2277
# Dumping after  16
# Time for the iteration 18.2 seconds
#
#
# Average train loss after 17 iteration = 0.0049
# Total train chrF after 17 iteration = 89.2507
# Average val loss after 17 iteration = 0.0180
# Total val chrF after 17 iteration = 83.6354
# Average test loss after 17 iteration = 0.0171
# Total test chrF after 17 iteration = 83.4830
# Dumping after  17
# Time for the iteration 18.2 seconds
#
#
# Average train loss after 18 iteration = 0.0046
# Total train chrF after 18 iteration = 89.3766
# Average val loss after 18 iteration = 0.0176
# Total val chrF after 18 iteration = 83.6758
# Average test loss after 18 iteration = 0.0167
# Total test chrF after 18 iteration = 83.4811
# Dumping after  18
# Time for the iteration 18.1 seconds
#
#
# Average train loss after 19 iteration = 0.0042
# Total train chrF after 19 iteration = 89.4912
# Average val loss after 19 iteration = 0.0170
# Total val chrF after 19 iteration = 83.8543
# Average test loss after 19 iteration = 0.0161
# Total test chrF after 19 iteration = 83.7215
# Dumping after  19
# Time for the iteration 18.2 seconds
#
#
# Average train loss after 20 iteration = 0.0040
# Total train chrF after 20 iteration = 89.5883
# Average val loss after 20 iteration = 0.0168
# Total val chrF after 20 iteration = 83.9426
# Average test loss after 20 iteration = 0.0158
# Total test chrF after 20 iteration = 83.8376
# Dumping after  20
# Time for the iteration 18.2 seconds
#
#
# Average train loss after 21 iteration = 0.0037
# Total train chrF after 21 iteration = 89.6744
# Average val loss after 21 iteration = 0.0166
# Total val chrF after 21 iteration = 84.0493
# Average test loss after 21 iteration = 0.0156
# Total test chrF after 21 iteration = 83.9474
# Dumping after  21
# Time for the iteration 18.2 seconds
#
#
# Average train loss after 22 iteration = 0.0035
# Total train chrF after 22 iteration = 89.7511
# Average val loss after 22 iteration = 0.0165
# Total val chrF after 22 iteration = 84.1388
# Average test loss after 22 iteration = 0.0154
# Total test chrF after 22 iteration = 84.0336
# Dumping after  22
# Time for the iteration 18.3 seconds
#
#
# Average train loss after 23 iteration = 0.0032
# Total train chrF after 23 iteration = 89.8213
# Average val loss after 23 iteration = 0.0163
# Total val chrF after 23 iteration = 84.1368
# Average test loss after 23 iteration = 0.0152
# Total test chrF after 23 iteration = 84.0835
# Time for the iteration 18.2 seconds
#
#
# Average train loss after 24 iteration = 0.0030
# Total train chrF after 24 iteration = 89.8857
# Average val loss after 24 iteration = 0.0162
# Total val chrF after 24 iteration = 84.1770
# Average test loss after 24 iteration = 0.0151
# Total test chrF after 24 iteration = 84.0900
# Dumping after  24
# Time for the iteration 18.4 seconds
#
#
# Average train loss after 25 iteration = 0.0028
# Total train chrF after 25 iteration = 89.9462
# Average val loss after 25 iteration = 0.0161
# Total val chrF after 25 iteration = 84.2392
# Average test loss after 25 iteration = 0.0149
# Total test chrF after 25 iteration = 84.0902
# Dumping after  25
# Time for the iteration 18.3 seconds
#
#
# Average train loss after 26 iteration = 0.0027
# Total train chrF after 26 iteration = 89.9981
# Average val loss after 26 iteration = 0.0160
# Total val chrF after 26 iteration = 84.3948
# Average test loss after 26 iteration = 0.0148
# Total test chrF after 26 iteration = 84.1293
# Dumping after  26
# Time for the iteration 18.2 seconds
#
#
# Average train loss after 27 iteration = 0.0025
# Total train chrF after 27 iteration = 90.0396
# Average val loss after 27 iteration = 0.0159
# Total val chrF after 27 iteration = 84.4580
# Average test loss after 27 iteration = 0.0147
# Total test chrF after 27 iteration = 84.1568
# Dumping after  27
# Time for the iteration 18.1 seconds
#
#
# Average train loss after 28 iteration = 0.0024
# Total train chrF after 28 iteration = 90.0849
# Average val loss after 28 iteration = 0.0159
# Total val chrF after 28 iteration = 84.4850
# Average test loss after 28 iteration = 0.0146
# Total test chrF after 28 iteration = 84.1923
# Dumping after  28
# Time for the iteration 18.1 seconds
#
#
# Average train loss after 29 iteration = 0.0022
# Total train chrF after 29 iteration = 90.1292
# Average val loss after 29 iteration = 0.0159
# Total val chrF after 29 iteration = 84.4724
# Average test loss after 29 iteration = 0.0146
# Total test chrF after 29 iteration = 84.1849
# Time for the iteration 18.3 seconds
#
#
# Average train loss after 30 iteration = 0.0021
# Total train chrF after 30 iteration = 90.1719
# Average val loss after 30 iteration = 0.0159
# Total val chrF after 30 iteration = 84.3858
# Average test loss after 30 iteration = 0.0146
# Total test chrF after 30 iteration = 84.1678
# Time for the iteration 18.2 seconds
#
#
# Average train loss after 31 iteration = 0.0020
# Total train chrF after 31 iteration = 90.2070
# Average val loss after 31 iteration = 0.0159
# Total val chrF after 31 iteration = 84.3771
# Average test loss after 31 iteration = 0.0145
# Total test chrF after 31 iteration = 84.1545
# Time for the iteration 18.1 seconds
#
#
# Average train loss after 32 iteration = 0.0019
# Total train chrF after 32 iteration = 90.2417
# Average val loss after 32 iteration = 0.0159
# Total val chrF after 32 iteration = 84.3911
# Average test loss after 32 iteration = 0.0145
# Total test chrF after 32 iteration = 84.1431
# Time for the iteration 18.1 seconds
#
#
# Average train loss after 33 iteration = 0.0018
# Total train chrF after 33 iteration = 90.2709
# Average val loss after 33 iteration = 0.0159
# Total val chrF after 33 iteration = 84.3586
# Average test loss after 33 iteration = 0.0145
# Total test chrF after 33 iteration = 84.1920
# Time for the iteration 18.1 seconds
#
#
# Average train loss after 34 iteration = 0.0017
# Total train chrF after 34 iteration = 90.3026
# Average val loss after 34 iteration = 0.0160
# Total val chrF after 34 iteration = 84.3653
# Average test loss after 34 iteration = 0.0145
# Total test chrF after 34 iteration = 84.2432
# Time for the iteration 18.2 seconds
#
#
# Average train loss after 35 iteration = 0.0016
# Total train chrF after 35 iteration = 90.3312
# Average val loss after 35 iteration = 0.0160
# Total val chrF after 35 iteration = 84.2644
# Average test loss after 35 iteration = 0.0146
# Total test chrF after 35 iteration = 84.2279
# Time for the iteration 18.0 seconds
#
#
# Average train loss after 36 iteration = 0.0015
# Total train chrF after 36 iteration = 90.3563
# Average val loss after 36 iteration = 0.0161
# Total val chrF after 36 iteration = 84.2719
# Average test loss after 36 iteration = 0.0146
# Total test chrF after 36 iteration = 84.1553
# Time for the iteration 18.1 seconds
#
#
# Average train loss after 37 iteration = 0.0014
# Total train chrF after 37 iteration = 90.3800
# Average val loss after 37 iteration = 0.0162
# Total val chrF after 37 iteration = 84.2149
# Average test loss after 37 iteration = 0.0146
# Total test chrF after 37 iteration = 84.1110
# Time for the iteration 18.3 seconds
#
#
# Average train loss after 38 iteration = 0.0013
# Total train chrF after 38 iteration = 90.3950
# Average val loss after 38 iteration = 0.0163
# Total val chrF after 38 iteration = 84.2051
# Average test loss after 38 iteration = 0.0146
# Total test chrF after 38 iteration = 84.1340
# Time for the iteration 18.2 seconds
#
#
# Average train loss after 39 iteration = 0.0013
# Total train chrF after 39 iteration = 90.4141
# Average val loss after 39 iteration = 0.0164
# Total val chrF after 39 iteration = 84.2442
# Average test loss after 39 iteration = 0.0147
# Total test chrF after 39 iteration = 84.1307
# Time for the iteration 18.2 seconds
#
#
# Average train loss after 40 iteration = 0.0012
# Total train chrF after 40 iteration = 90.4313
# Average val loss after 40 iteration = 0.0165
# Total val chrF after 40 iteration = 84.3088
# Average test loss after 40 iteration = 0.0147
# Total test chrF after 40 iteration = 84.1348
# Time for the iteration 18.3 seconds
#
#
# Average train loss after 41 iteration = 0.0011
# Total train chrF after 41 iteration = 90.4473
# Average val loss after 41 iteration = 0.0166
# Total val chrF after 41 iteration = 84.2726
# Average test loss after 41 iteration = 0.0148
# Total test chrF after 41 iteration = 84.1423
# Time for the iteration 18.2 seconds
#
#
# Average train loss after 42 iteration = 0.0011
# Total train chrF after 42 iteration = 90.4634
# Average val loss after 42 iteration = 0.0168
# Total val chrF after 42 iteration = 84.1957
# Average test loss after 42 iteration = 0.0149
# Total test chrF after 42 iteration = 84.1716
# Time for the iteration 18.1 seconds
#
#
# Average train loss after 43 iteration = 0.0010
# Total train chrF after 43 iteration = 90.4749
# Average val loss after 43 iteration = 0.0169
# Total val chrF after 43 iteration = 84.2583
# Average test loss after 43 iteration = 0.0149
# Total test chrF after 43 iteration = 84.1189
# Time for the iteration 18.3 seconds
#
#
# Average train loss after 44 iteration = 0.0010
# Total train chrF after 44 iteration = 90.4852
# Average val loss after 44 iteration = 0.0170
# Total val chrF after 44 iteration = 84.2464
# Average test loss after 44 iteration = 0.0150
# Total test chrF after 44 iteration = 84.1069
# Time for the iteration 18.1 seconds
#
#
# Average train loss after 45 iteration = 0.0009
# Total train chrF after 45 iteration = 90.4962
# Average val loss after 45 iteration = 0.0172
# Total val chrF after 45 iteration = 84.2015
# Average test loss after 45 iteration = 0.0151
# Total test chrF after 45 iteration = 84.1091
# Time for the iteration 18.2 seconds
#
#
# Average train loss after 46 iteration = 0.0009
# Total train chrF after 46 iteration = 90.5077
# Average val loss after 46 iteration = 0.0173
# Total val chrF after 46 iteration = 84.2010
# Average test loss after 46 iteration = 0.0151
# Total test chrF after 46 iteration = 84.0507
# Time for the iteration 18.3 seconds
#
#
# Average train loss after 47 iteration = 0.0008
# Total train chrF after 47 iteration = 90.5165
# Average val loss after 47 iteration = 0.0174
# Total val chrF after 47 iteration = 84.2393
# Average test loss after 47 iteration = 0.0152
# Total test chrF after 47 iteration = 83.9505
# Time for the iteration 18.3 seconds
#
#
# Average train loss after 48 iteration = 0.0008
# Total train chrF after 48 iteration = 90.5241
# Average val loss after 48 iteration = 0.0176
# Total val chrF after 48 iteration = 84.1913
# Average test loss after 48 iteration = 0.0153
# Total test chrF after 48 iteration = 83.9239
# Time for the iteration 18.2 seconds
#
#
# Average train loss after 49 iteration = 0.0007
# Total train chrF after 49 iteration = 90.5309
# Average val loss after 49 iteration = 0.0177
# Total val chrF after 49 iteration = 84.2412
# Average test loss after 49 iteration = 0.0154
# Total test chrF after 49 iteration = 83.9052
# Time for the iteration 18.2 seconds
#
#
# Average train loss after 50 iteration = 0.0007
# Total train chrF after 50 iteration = 90.5380
# Average val loss after 50 iteration = 0.0179
# Total val chrF after 50 iteration = 84.1846
# Average test loss after 50 iteration = 0.0155
# Total test chrF after 50 iteration = 83.9249
# Time for the iteration 18.1 seconds
#
#
# Average train loss after 51 iteration = 0.0006
# Total train chrF after 51 iteration = 90.5448
# Average val loss after 51 iteration = 0.0180
# Total val chrF after 51 iteration = 84.2016
# Average test loss after 51 iteration = 0.0156
# Total test chrF after 51 iteration = 83.9108
# Time for the iteration 18.1 seconds
#
#
# Average train loss after 52 iteration = 0.0006
# Total train chrF after 52 iteration = 90.5499
# Average val loss after 52 iteration = 0.0182
# Total val chrF after 52 iteration = 84.1907
# Average test loss after 52 iteration = 0.0157
# Total test chrF after 52 iteration = 83.9388
# Time for the iteration 18.2 seconds
#
#
# Average train loss after 53 iteration = 0.0006
# Total train chrF after 53 iteration = 90.5555
# Average val loss after 53 iteration = 0.0183
# Total val chrF after 53 iteration = 84.2138
# Average test loss after 53 iteration = 0.0158
# Total test chrF after 53 iteration = 83.9651
# Time for the iteration 18.2 seconds
#
#
# Average train loss after 54 iteration = 0.0005
# Total train chrF after 54 iteration = 90.5594
# Average val loss after 54 iteration = 0.0185
# Total val chrF after 54 iteration = 84.1703
# Average test loss after 54 iteration = 0.0159
# Total test chrF after 54 iteration = 83.9555
# Time for the iteration 18.4 seconds
#
#
# Average train loss after 55 iteration = 0.0005
# Total train chrF after 55 iteration = 90.5650
# Average val loss after 55 iteration = 0.0186
# Total val chrF after 55 iteration = 84.0980
# Average test loss after 55 iteration = 0.0160
# Total test chrF after 55 iteration = 83.8974
# Time for the iteration 18.2 seconds
#
#
#
#
# Aborting since there hasn't been much progress
# <Figure size 640x480 with 1 Axes>
# <Figure size 640x480 with 1 Axes>

# %%
language = "yi"
task_name = "all_teacher_general"
vocab_size = 2999
num_epochs = 100
batch_size = 32
model = "50_1"
optimizer = "Adam"
metric = "chrF"

# %%
from IPython.display import Image

Image("curves/{}_{}_{}_{}_{}_loss.png".format(language, task_name, vocab_size, num_epochs, batch_size))

# %%
Image("curves/{}_{}_{}_{}_{}_{}.png".format(language, task_name, vocab_size, num_epochs, batch_size, metric))

# %%
print("{}.{}.{}.{}.{}.{}.{}".format(language, task_name, vocab_size, num_epochs, batch_size, model, optimizer))
# Out:
# yi.all_teacher_general.2999.100.32.50_1.Adam
