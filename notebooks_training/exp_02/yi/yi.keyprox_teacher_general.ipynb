# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
# %cd "drive/MyDrive/Tesis/scRNN"
# Out:
# /content/drive/MyDrive/Tesis/scRNN

# %%
import torch

torch.cuda.is_available()
# Out:
# True

# %%
# !pip install sacrebleu
# Out:
# Collecting sacrebleu
#   Downloading sacrebleu-2.0.0-py3-none-any.whl (90 kB)
#      |████████████████████████████████| 90 kB 10.0 MB/s
# Collecting colorama
#   Downloading colorama-0.4.4-py2.py3-none-any.whl (16 kB)
# Collecting portalocker
#   Downloading portalocker-2.4.0-py2.py3-none-any.whl (16 kB)
# Requirement already satisfied: regex in /usr/local/lib/python3.7/dist-packages (from sacrebleu) (2019.12.20)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from sacrebleu) (1.21.6)
# Requirement already satisfied: tabulate>=0.8.9 in /usr/local/lib/python3.7/dist-packages (from sacrebleu) (0.8.9)
# Installing collected packages: portalocker, colorama, sacrebleu
# Successfully installed colorama-0.4.4 portalocker-2.4.0 sacrebleu-2.0.0

# %%
# !python3 train.py --language yi --task-name keyprox_teacher_general --num-epochs 100 --batch-size 32 --vocab-size 2999 --new-vocab --train --train-sentences-errors-file yi.keyprox_teacher_general.train.sentences.errors.txt --train-sentences-file yi.keyprox_teacher_general.train.sentences.txt --val-sentences-errors-file yi.teacher_general.val.sentences.errors.txt --val-sentences-file yi.teacher_general.val.sentences.txt --test-sentences-errors-file yi.teacher_general.test.sentences.errors.txt --test-sentences-file yi.teacher_general.test.sentences.txt --metric chrF --save
# Out:
# Parameters
# {'language': 'yi', 'task_name': 'keyprox_teacher_general', 'vocab_size': 2999, 'num_epochs': 100, 'batch_size': 32, 'model_name': 'shi_random_20531_100_32', 'new_vocab': True, 'need_to_train': True, 'train_sentences_errors_file': 'yi.keyprox_teacher_general.train.sentences.errors.txt', 'train_sentences_file': 'yi.keyprox_teacher_general.train.sentences.txt', 'val_sentences_errors_file': 'yi.teacher_general.val.sentences.errors.txt', 'val_sentences_file': 'yi.teacher_general.val.sentences.txt', 'test_sentences_errors_file': 'yi.teacher_general.test.sentences.errors.txt', 'test_sentences_file': 'yi.teacher_general.test.sentences.txt', 'metric': 'chrF', 'save_model': True}
#
#
# Creating new vocabulary
# Len of w2i:  2999
# Len of i2w:  2999
# Len of char vocab:  23
#
#
# Initializing an only ScRNN model
#
#
# Training the model...
#
# Average train loss after 1 iteration = 0.1766
# Total train chrF after 1 iteration = 61.4130
# Average val loss after 1 iteration = 0.1779
# Total val chrF after 1 iteration = 79.0981
# Average test loss after 1 iteration = 0.1798
# Total test chrF after 1 iteration = 78.9552
# Dumping after  1
# Time for the iteration 5.6 seconds
#
#
# Average train loss after 2 iteration = 0.1590
# Total train chrF after 2 iteration = 60.6005
# Average val loss after 2 iteration = 0.1317
# Total val chrF after 2 iteration = 77.3473
# Average test loss after 2 iteration = 0.1335
# Total test chrF after 2 iteration = 77.0478
# Time for the iteration 5.5 seconds
#
#
# Average train loss after 3 iteration = 0.1380
# Total train chrF after 3 iteration = 61.9423
# Average val loss after 3 iteration = 0.1127
# Total val chrF after 3 iteration = 76.8176
# Average test loss after 3 iteration = 0.1143
# Total test chrF after 3 iteration = 76.5095
# Time for the iteration 5.3 seconds
#
#
# Average train loss after 4 iteration = 0.1190
# Total train chrF after 4 iteration = 64.4478
# Average val loss after 4 iteration = 0.0960
# Total val chrF after 4 iteration = 77.4691
# Average test loss after 4 iteration = 0.0978
# Total test chrF after 4 iteration = 77.1683
# Time for the iteration 5.4 seconds
#
#
# Average train loss after 5 iteration = 0.1012
# Total train chrF after 5 iteration = 67.3169
# Average val loss after 5 iteration = 0.0812
# Total val chrF after 5 iteration = 77.9071
# Average test loss after 5 iteration = 0.0832
# Total test chrF after 5 iteration = 77.9881
# Time for the iteration 5.4 seconds
#
#
# Average train loss after 6 iteration = 0.0864
# Total train chrF after 6 iteration = 69.5459
# Average val loss after 6 iteration = 0.0691
# Total val chrF after 6 iteration = 78.5775
# Average test loss after 6 iteration = 0.0711
# Total test chrF after 6 iteration = 78.5062
# Time for the iteration 5.4 seconds
#
#
# Average train loss after 7 iteration = 0.0744
# Total train chrF after 7 iteration = 71.1536
# Average val loss after 7 iteration = 0.0590
# Total val chrF after 7 iteration = 79.2698
# Average test loss after 7 iteration = 0.0610
# Total test chrF after 7 iteration = 79.1239
# Dumping after  7
# Time for the iteration 5.4 seconds
#
#
# Average train loss after 8 iteration = 0.0644
# Total train chrF after 8 iteration = 72.6950
# Average val loss after 8 iteration = 0.0510
# Total val chrF after 8 iteration = 79.7471
# Average test loss after 8 iteration = 0.0528
# Total test chrF after 8 iteration = 79.8389
# Dumping after  8
# Time for the iteration 5.5 seconds
#
#
# Average train loss after 9 iteration = 0.0559
# Total train chrF after 9 iteration = 74.1809
# Average val loss after 9 iteration = 0.0444
# Total val chrF after 9 iteration = 80.3473
# Average test loss after 9 iteration = 0.0461
# Total test chrF after 9 iteration = 80.6369
# Dumping after  9
# Time for the iteration 5.4 seconds
#
#
# Average train loss after 10 iteration = 0.0487
# Total train chrF after 10 iteration = 75.4553
# Average val loss after 10 iteration = 0.0390
# Total val chrF after 10 iteration = 81.1428
# Average test loss after 10 iteration = 0.0405
# Total test chrF after 10 iteration = 81.2851
# Dumping after  10
# Time for the iteration 5.5 seconds
#
#
# Average train loss after 11 iteration = 0.0426
# Total train chrF after 11 iteration = 76.6116
# Average val loss after 11 iteration = 0.0347
# Total val chrF after 11 iteration = 81.7215
# Average test loss after 11 iteration = 0.0360
# Total test chrF after 11 iteration = 81.9573
# Dumping after  11
# Time for the iteration 5.5 seconds
#
#
# Average train loss after 12 iteration = 0.0375
# Total train chrF after 12 iteration = 77.7084
# Average val loss after 12 iteration = 0.0312
# Total val chrF after 12 iteration = 82.1386
# Average test loss after 12 iteration = 0.0323
# Total test chrF after 12 iteration = 82.2175
# Dumping after  12
# Time for the iteration 5.6 seconds
#
#
# Average train loss after 13 iteration = 0.0330
# Total train chrF after 13 iteration = 78.7819
# Average val loss after 13 iteration = 0.0283
# Total val chrF after 13 iteration = 82.5899
# Average test loss after 13 iteration = 0.0292
# Total test chrF after 13 iteration = 82.6356
# Dumping after  13
# Time for the iteration 5.7 seconds
#
#
# Average train loss after 14 iteration = 0.0293
# Total train chrF after 14 iteration = 79.7953
# Average val loss after 14 iteration = 0.0258
# Total val chrF after 14 iteration = 82.8633
# Average test loss after 14 iteration = 0.0266
# Total test chrF after 14 iteration = 82.8922
# Dumping after  14
# Time for the iteration 5.5 seconds
#
#
# Average train loss after 15 iteration = 0.0260
# Total train chrF after 15 iteration = 80.7973
# Average val loss after 15 iteration = 0.0238
# Total val chrF after 15 iteration = 83.1011
# Average test loss after 15 iteration = 0.0244
# Total test chrF after 15 iteration = 83.1400
# Dumping after  15
# Time for the iteration 5.5 seconds
#
#
# Average train loss after 16 iteration = 0.0232
# Total train chrF after 16 iteration = 81.7331
# Average val loss after 16 iteration = 0.0221
# Total val chrF after 16 iteration = 83.4192
# Average test loss after 16 iteration = 0.0225
# Total test chrF after 16 iteration = 83.3671
# Dumping after  16
# Time for the iteration 5.6 seconds
#
#
# Average train loss after 17 iteration = 0.0208
# Total train chrF after 17 iteration = 82.4793
# Average val loss after 17 iteration = 0.0206
# Total val chrF after 17 iteration = 83.6504
# Average test loss after 17 iteration = 0.0210
# Total test chrF after 17 iteration = 83.5509
# Dumping after  17
# Time for the iteration 5.5 seconds
#
#
# Average train loss after 18 iteration = 0.0187
# Total train chrF after 18 iteration = 83.2646
# Average val loss after 18 iteration = 0.0194
# Total val chrF after 18 iteration = 83.8414
# Average test loss after 18 iteration = 0.0196
# Total test chrF after 18 iteration = 83.7846
# Dumping after  18
# Time for the iteration 5.5 seconds
#
#
# Average train loss after 19 iteration = 0.0170
# Total train chrF after 19 iteration = 83.9521
# Average val loss after 19 iteration = 0.0184
# Total val chrF after 19 iteration = 84.1174
# Average test loss after 19 iteration = 0.0185
# Total test chrF after 19 iteration = 83.9453
# Dumping after  19
# Time for the iteration 5.5 seconds
#
#
# Average train loss after 20 iteration = 0.0154
# Total train chrF after 20 iteration = 84.5780
# Average val loss after 20 iteration = 0.0175
# Total val chrF after 20 iteration = 84.3033
# Average test loss after 20 iteration = 0.0175
# Total test chrF after 20 iteration = 84.0103
# Dumping after  20
# Time for the iteration 5.5 seconds
#
#
# Average train loss after 21 iteration = 0.0141
# Total train chrF after 21 iteration = 85.1805
# Average val loss after 21 iteration = 0.0167
# Total val chrF after 21 iteration = 84.4348
# Average test loss after 21 iteration = 0.0166
# Total test chrF after 21 iteration = 84.2410
# Dumping after  21
# Time for the iteration 5.5 seconds
#
#
# Average train loss after 22 iteration = 0.0130
# Total train chrF after 22 iteration = 85.7038
# Average val loss after 22 iteration = 0.0160
# Total val chrF after 22 iteration = 84.5997
# Average test loss after 22 iteration = 0.0159
# Total test chrF after 22 iteration = 84.3490
# Dumping after  22
# Time for the iteration 5.5 seconds
#
#
# Average train loss after 23 iteration = 0.0119
# Total train chrF after 23 iteration = 86.1477
# Average val loss after 23 iteration = 0.0154
# Total val chrF after 23 iteration = 84.8463
# Average test loss after 23 iteration = 0.0152
# Total test chrF after 23 iteration = 84.5008
# Dumping after  23
# Time for the iteration 5.5 seconds
#
#
# Average train loss after 24 iteration = 0.0110
# Total train chrF after 24 iteration = 86.5269
# Average val loss after 24 iteration = 0.0149
# Total val chrF after 24 iteration = 84.8946
# Average test loss after 24 iteration = 0.0147
# Total test chrF after 24 iteration = 84.5231
# Dumping after  24
# Time for the iteration 5.6 seconds
#
#
# Average train loss after 25 iteration = 0.0102
# Total train chrF after 25 iteration = 86.8550
# Average val loss after 25 iteration = 0.0144
# Total val chrF after 25 iteration = 85.0335
# Average test loss after 25 iteration = 0.0142
# Total test chrF after 25 iteration = 84.5998
# Dumping after  25
# Time for the iteration 5.5 seconds
#
#
# Average train loss after 26 iteration = 0.0095
# Total train chrF after 26 iteration = 87.1248
# Average val loss after 26 iteration = 0.0140
# Total val chrF after 26 iteration = 85.0673
# Average test loss after 26 iteration = 0.0137
# Total test chrF after 26 iteration = 84.6878
# Dumping after  26
# Time for the iteration 5.5 seconds
#
#
# Average train loss after 27 iteration = 0.0089
# Total train chrF after 27 iteration = 87.3675
# Average val loss after 27 iteration = 0.0137
# Total val chrF after 27 iteration = 85.1054
# Average test loss after 27 iteration = 0.0133
# Total test chrF after 27 iteration = 84.7647
# Dumping after  27
# Time for the iteration 5.5 seconds
#
#
# Average train loss after 28 iteration = 0.0083
# Total train chrF after 28 iteration = 87.5989
# Average val loss after 28 iteration = 0.0134
# Total val chrF after 28 iteration = 85.2087
# Average test loss after 28 iteration = 0.0130
# Total test chrF after 28 iteration = 84.9179
# Dumping after  28
# Time for the iteration 5.6 seconds
#
#
# Average train loss after 29 iteration = 0.0078
# Total train chrF after 29 iteration = 87.8082
# Average val loss after 29 iteration = 0.0131
# Total val chrF after 29 iteration = 85.2128
# Average test loss after 29 iteration = 0.0127
# Total test chrF after 29 iteration = 84.9311
# Dumping after  29
# Time for the iteration 5.5 seconds
#
#
# Average train loss after 30 iteration = 0.0073
# Total train chrF after 30 iteration = 87.9993
# Average val loss after 30 iteration = 0.0128
# Total val chrF after 30 iteration = 85.2389
# Average test loss after 30 iteration = 0.0124
# Total test chrF after 30 iteration = 85.0067
# Dumping after  30
# Time for the iteration 5.5 seconds
#
#
# Average train loss after 31 iteration = 0.0068
# Total train chrF after 31 iteration = 88.1391
# Average val loss after 31 iteration = 0.0126
# Total val chrF after 31 iteration = 85.2435
# Average test loss after 31 iteration = 0.0121
# Total test chrF after 31 iteration = 84.9834
# Dumping after  31
# Time for the iteration 5.5 seconds
#
#
# Average train loss after 32 iteration = 0.0064
# Total train chrF after 32 iteration = 88.2767
# Average val loss after 32 iteration = 0.0124
# Total val chrF after 32 iteration = 85.2558
# Average test loss after 32 iteration = 0.0119
# Total test chrF after 32 iteration = 84.9901
# Dumping after  32
# Time for the iteration 5.5 seconds
#
#
# Average train loss after 33 iteration = 0.0061
# Total train chrF after 33 iteration = 88.4209
# Average val loss after 33 iteration = 0.0123
# Total val chrF after 33 iteration = 85.3140
# Average test loss after 33 iteration = 0.0117
# Total test chrF after 33 iteration = 85.0115
# Dumping after  33
# Time for the iteration 5.5 seconds
#
#
# Average train loss after 34 iteration = 0.0057
# Total train chrF after 34 iteration = 88.5326
# Average val loss after 34 iteration = 0.0121
# Total val chrF after 34 iteration = 85.4057
# Average test loss after 34 iteration = 0.0115
# Total test chrF after 34 iteration = 85.0163
# Dumping after  34
# Time for the iteration 5.5 seconds
#
#
# Average train loss after 35 iteration = 0.0054
# Total train chrF after 35 iteration = 88.6041
# Average val loss after 35 iteration = 0.0120
# Total val chrF after 35 iteration = 85.4626
# Average test loss after 35 iteration = 0.0114
# Total test chrF after 35 iteration = 85.0151
# Dumping after  35
# Time for the iteration 5.5 seconds
#
#
# Average train loss after 36 iteration = 0.0051
# Total train chrF after 36 iteration = 88.6870
# Average val loss after 36 iteration = 0.0119
# Total val chrF after 36 iteration = 85.4779
# Average test loss after 36 iteration = 0.0112
# Total test chrF after 36 iteration = 85.0788
# Dumping after  36
# Time for the iteration 5.5 seconds
#
#
# Average train loss after 37 iteration = 0.0048
# Total train chrF after 37 iteration = 88.7616
# Average val loss after 37 iteration = 0.0118
# Total val chrF after 37 iteration = 85.5468
# Average test loss after 37 iteration = 0.0111
# Total test chrF after 37 iteration = 85.0935
# Dumping after  37
# Time for the iteration 5.5 seconds
#
#
# Average train loss after 38 iteration = 0.0045
# Total train chrF after 38 iteration = 88.8267
# Average val loss after 38 iteration = 0.0117
# Total val chrF after 38 iteration = 85.5956
# Average test loss after 38 iteration = 0.0110
# Total test chrF after 38 iteration = 85.1332
# Dumping after  38
# Time for the iteration 5.5 seconds
#
#
# Average train loss after 39 iteration = 0.0043
# Total train chrF after 39 iteration = 88.8931
# Average val loss after 39 iteration = 0.0116
# Total val chrF after 39 iteration = 85.5867
# Average test loss after 39 iteration = 0.0109
# Total test chrF after 39 iteration = 85.1593
# Time for the iteration 5.5 seconds
#
#
# Average train loss after 40 iteration = 0.0040
# Total train chrF after 40 iteration = 88.9515
# Average val loss after 40 iteration = 0.0115
# Total val chrF after 40 iteration = 85.6058
# Average test loss after 40 iteration = 0.0108
# Total test chrF after 40 iteration = 85.1880
# Dumping after  40
# Time for the iteration 5.5 seconds
#
#
# Average train loss after 41 iteration = 0.0038
# Total train chrF after 41 iteration = 89.0041
# Average val loss after 41 iteration = 0.0115
# Total val chrF after 41 iteration = 85.6261
# Average test loss after 41 iteration = 0.0107
# Total test chrF after 41 iteration = 85.2091
# Dumping after  41
# Time for the iteration 5.5 seconds
#
#
# Average train loss after 42 iteration = 0.0036
# Total train chrF after 42 iteration = 89.0453
# Average val loss after 42 iteration = 0.0114
# Total val chrF after 42 iteration = 85.6702
# Average test loss after 42 iteration = 0.0106
# Total test chrF after 42 iteration = 85.2268
# Dumping after  42
# Time for the iteration 5.6 seconds
#
#
# Average train loss after 43 iteration = 0.0034
# Total train chrF after 43 iteration = 89.0818
# Average val loss after 43 iteration = 0.0114
# Total val chrF after 43 iteration = 85.6336
# Average test loss after 43 iteration = 0.0106
# Total test chrF after 43 iteration = 85.2343
# Time for the iteration 5.5 seconds
#
#
# Average train loss after 44 iteration = 0.0032
# Total train chrF after 44 iteration = 89.1179
# Average val loss after 44 iteration = 0.0114
# Total val chrF after 44 iteration = 85.6207
# Average test loss after 44 iteration = 0.0105
# Total test chrF after 44 iteration = 85.2509
# Time for the iteration 5.5 seconds
#
#
# Average train loss after 45 iteration = 0.0031
# Total train chrF after 45 iteration = 89.1448
# Average val loss after 45 iteration = 0.0113
# Total val chrF after 45 iteration = 85.5864
# Average test loss after 45 iteration = 0.0105
# Total test chrF after 45 iteration = 85.2640
# Time for the iteration 5.5 seconds
#
#
# Average train loss after 46 iteration = 0.0029
# Total train chrF after 46 iteration = 89.1867
# Average val loss after 46 iteration = 0.0113
# Total val chrF after 46 iteration = 85.5964
# Average test loss after 46 iteration = 0.0104
# Total test chrF after 46 iteration = 85.2651
# Time for the iteration 5.5 seconds
#
#
# Average train loss after 47 iteration = 0.0028
# Total train chrF after 47 iteration = 89.2214
# Average val loss after 47 iteration = 0.0113
# Total val chrF after 47 iteration = 85.6040
# Average test loss after 47 iteration = 0.0104
# Total test chrF after 47 iteration = 85.2459
# Time for the iteration 5.5 seconds
#
#
# Average train loss after 48 iteration = 0.0026
# Total train chrF after 48 iteration = 89.2475
# Average val loss after 48 iteration = 0.0113
# Total val chrF after 48 iteration = 85.6497
# Average test loss after 48 iteration = 0.0104
# Total test chrF after 48 iteration = 85.2718
# Time for the iteration 5.5 seconds
#
#
# Average train loss after 49 iteration = 0.0025
# Total train chrF after 49 iteration = 89.2673
# Average val loss after 49 iteration = 0.0113
# Total val chrF after 49 iteration = 85.6421
# Average test loss after 49 iteration = 0.0104
# Total test chrF after 49 iteration = 85.2517
# Time for the iteration 5.5 seconds
#
#
# Average train loss after 50 iteration = 0.0023
# Total train chrF after 50 iteration = 89.2873
# Average val loss after 50 iteration = 0.0113
# Total val chrF after 50 iteration = 85.6672
# Average test loss after 50 iteration = 0.0104
# Total test chrF after 50 iteration = 85.2252
# Time for the iteration 5.5 seconds
#
#
# Average train loss after 51 iteration = 0.0022
# Total train chrF after 51 iteration = 89.3105
# Average val loss after 51 iteration = 0.0113
# Total val chrF after 51 iteration = 85.6500
# Average test loss after 51 iteration = 0.0104
# Total test chrF after 51 iteration = 85.2214
# Time for the iteration 5.5 seconds
#
#
# Average train loss after 52 iteration = 0.0021
# Total train chrF after 52 iteration = 89.3296
# Average val loss after 52 iteration = 0.0113
# Total val chrF after 52 iteration = 85.6618
# Average test loss after 52 iteration = 0.0104
# Total test chrF after 52 iteration = 85.2305
# Time for the iteration 5.5 seconds
#
#
# Average train loss after 53 iteration = 0.0020
# Total train chrF after 53 iteration = 89.3462
# Average val loss after 53 iteration = 0.0113
# Total val chrF after 53 iteration = 85.6127
# Average test loss after 53 iteration = 0.0104
# Total test chrF after 53 iteration = 85.2609
# Time for the iteration 5.5 seconds
#
#
# Average train loss after 54 iteration = 0.0019
# Total train chrF after 54 iteration = 89.3627
# Average val loss after 54 iteration = 0.0114
# Total val chrF after 54 iteration = 85.5840
# Average test loss after 54 iteration = 0.0104
# Total test chrF after 54 iteration = 85.2439
# Time for the iteration 5.5 seconds
#
#
# Average train loss after 55 iteration = 0.0018
# Total train chrF after 55 iteration = 89.3767
# Average val loss after 55 iteration = 0.0114
# Total val chrF after 55 iteration = 85.5160
# Average test loss after 55 iteration = 0.0104
# Total test chrF after 55 iteration = 85.2333
# Time for the iteration 5.5 seconds
#
#
# Average train loss after 56 iteration = 0.0017
# Total train chrF after 56 iteration = 89.3895
# Average val loss after 56 iteration = 0.0114
# Total val chrF after 56 iteration = 85.5260
# Average test loss after 56 iteration = 0.0104
# Total test chrF after 56 iteration = 85.2361
# Time for the iteration 5.5 seconds
#
#
# Average train loss after 57 iteration = 0.0016
# Total train chrF after 57 iteration = 89.4026
# Average val loss after 57 iteration = 0.0114
# Total val chrF after 57 iteration = 85.5348
# Average test loss after 57 iteration = 0.0104
# Total test chrF after 57 iteration = 85.2361
# Time for the iteration 5.6 seconds
#
#
# Average train loss after 58 iteration = 0.0015
# Total train chrF after 58 iteration = 89.4124
# Average val loss after 58 iteration = 0.0115
# Total val chrF after 58 iteration = 85.4856
# Average test loss after 58 iteration = 0.0105
# Total test chrF after 58 iteration = 85.2361
# Time for the iteration 5.5 seconds
#
#
# Average train loss after 59 iteration = 0.0014
# Total train chrF after 59 iteration = 89.4232
# Average val loss after 59 iteration = 0.0115
# Total val chrF after 59 iteration = 85.4881
# Average test loss after 59 iteration = 0.0105
# Total test chrF after 59 iteration = 85.2373
# Time for the iteration 5.5 seconds
#
#
# Average train loss after 60 iteration = 0.0014
# Total train chrF after 60 iteration = 89.4310
# Average val loss after 60 iteration = 0.0115
# Total val chrF after 60 iteration = 85.4978
# Average test loss after 60 iteration = 0.0105
# Total test chrF after 60 iteration = 85.2271
# Time for the iteration 5.5 seconds
#
#
# Average train loss after 61 iteration = 0.0013
# Total train chrF after 61 iteration = 89.4377
# Average val loss after 61 iteration = 0.0116
# Total val chrF after 61 iteration = 85.5439
# Average test loss after 61 iteration = 0.0105
# Total test chrF after 61 iteration = 85.2474
# Time for the iteration 5.5 seconds
#
#
# Average train loss after 62 iteration = 0.0012
# Total train chrF after 62 iteration = 89.4459
# Average val loss after 62 iteration = 0.0116
# Total val chrF after 62 iteration = 85.5025
# Average test loss after 62 iteration = 0.0106
# Total test chrF after 62 iteration = 85.2474
# Time for the iteration 5.5 seconds
#
#
# Average train loss after 63 iteration = 0.0012
# Total train chrF after 63 iteration = 89.4526
# Average val loss after 63 iteration = 0.0117
# Total val chrF after 63 iteration = 85.5221
# Average test loss after 63 iteration = 0.0106
# Total test chrF after 63 iteration = 85.2577
# Time for the iteration 5.5 seconds
#
#
# Average train loss after 64 iteration = 0.0011
# Total train chrF after 64 iteration = 89.4586
# Average val loss after 64 iteration = 0.0117
# Total val chrF after 64 iteration = 85.5151
# Average test loss after 64 iteration = 0.0106
# Total test chrF after 64 iteration = 85.2701
# Time for the iteration 5.5 seconds
#
#
# Average train loss after 65 iteration = 0.0010
# Total train chrF after 65 iteration = 89.4621
# Average val loss after 65 iteration = 0.0118
# Total val chrF after 65 iteration = 85.5360
# Average test loss after 65 iteration = 0.0107
# Total test chrF after 65 iteration = 85.3030
# Time for the iteration 5.5 seconds
#
#
# Average train loss after 66 iteration = 0.0010
# Total train chrF after 66 iteration = 89.4685
# Average val loss after 66 iteration = 0.0118
# Total val chrF after 66 iteration = 85.5320
# Average test loss after 66 iteration = 0.0107
# Total test chrF after 66 iteration = 85.2595
# Time for the iteration 5.5 seconds
#
#
# Average train loss after 67 iteration = 0.0009
# Total train chrF after 67 iteration = 89.4752
# Average val loss after 67 iteration = 0.0119
# Total val chrF after 67 iteration = 85.5674
# Average test loss after 67 iteration = 0.0108
# Total test chrF after 67 iteration = 85.2626
# Time for the iteration 5.5 seconds
#
#
# Average train loss after 68 iteration = 0.0009
# Total train chrF after 68 iteration = 89.4781
# Average val loss after 68 iteration = 0.0119
# Total val chrF after 68 iteration = 85.5471
# Average test loss after 68 iteration = 0.0108
# Total test chrF after 68 iteration = 85.2717
# Time for the iteration 5.5 seconds
#
#
# Average train loss after 69 iteration = 0.0008
# Total train chrF after 69 iteration = 89.4808
# Average val loss after 69 iteration = 0.0120
# Total val chrF after 69 iteration = 85.5868
# Average test loss after 69 iteration = 0.0109
# Total test chrF after 69 iteration = 85.2515
# Time for the iteration 5.5 seconds
#
#
#
#
# Aborting since there hasn't been much progress
# <Figure size 640x480 with 1 Axes>
# <Figure size 640x480 with 1 Axes>

# %%
language = "yi"
task_name = "keyprox_teacher_general"
vocab_size = 2999
num_epochs = 100
batch_size = 32
model = "50_1"
optimizer = "Adam"
metric = "chrF"

# %%
from IPython.display import Image

Image("curves/{}_{}_{}_{}_{}_loss.png".format(language, task_name, vocab_size, num_epochs, batch_size))

# %%
Image("curves/{}_{}_{}_{}_{}_{}.png".format(language, task_name, vocab_size, num_epochs, batch_size, metric))

# %%
print("{}.{}.{}.{}.{}.{}.{}".format(language, task_name, vocab_size, num_epochs, batch_size, model, optimizer))
# Out:
# yi.keyprox_teacher_general.2999.100.32.50_1.Adam
