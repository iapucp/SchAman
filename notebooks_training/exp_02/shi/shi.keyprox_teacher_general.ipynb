# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
# %cd "drive/MyDrive/Tesis/scRNN"
# Out:
# /content/drive/MyDrive/Tesis/scRNN

# %%
import torch

torch.cuda.is_available()
# Out:
# True

# %%
# !pip install sacrebleu
# Out:
# Collecting sacrebleu
#   Downloading sacrebleu-2.0.0-py3-none-any.whl (90 kB)
#      |████████████████████████████████| 90 kB 6.8 MB/s
# Collecting colorama
#   Downloading colorama-0.4.4-py2.py3-none-any.whl (16 kB)
# Requirement already satisfied: tabulate>=0.8.9 in /usr/local/lib/python3.7/dist-packages (from sacrebleu) (0.8.9)
# Collecting portalocker
#   Downloading portalocker-2.3.2-py2.py3-none-any.whl (15 kB)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from sacrebleu) (1.19.5)
# Requirement already satisfied: regex in /usr/local/lib/python3.7/dist-packages (from sacrebleu) (2019.12.20)
# Installing collected packages: portalocker, colorama, sacrebleu
# Successfully installed colorama-0.4.4 portalocker-2.3.2 sacrebleu-2.0.0

# %%
# !python3 train.py --language shi --task-name keyprox_teacher_general --num-epochs 100 --batch-size 32 --vocab-size 4999 --new-vocab --train --train-sentences-errors-file shi.keyprox_teacher_general.train.sentences.errors.txt --train-sentences-file shi.keyprox_teacher_general.train.sentences.txt --val-sentences-errors-file shi.teacher_general.val.sentences.errors.txt --val-sentences-file shi.teacher_general.val.sentences.txt --test-sentences-errors-file shi.teacher_general.test.sentences.errors.txt --test-sentences-file shi.teacher_general.test.sentences.txt --metric chrF --save
# Out:
# Parameters
# {'language': 'shi', 'task_name': 'keyprox_teacher_general', 'vocab_size': 4999, 'num_epochs': 100, 'batch_size': 32, 'model_name': 'shi_random_20531_100_32', 'new_vocab': True, 'need_to_train': True, 'train_sentences_errors_file': 'shi.keyprox_teacher_general.train.sentences.errors.txt', 'train_sentences_file': 'shi.keyprox_teacher_general.train.sentences.txt', 'val_sentences_errors_file': 'shi.teacher_general.val.sentences.errors.txt', 'val_sentences_file': 'shi.teacher_general.val.sentences.txt', 'test_sentences_errors_file': 'shi.teacher_general.test.sentences.errors.txt', 'test_sentences_file': 'shi.teacher_general.test.sentences.txt', 'metric': 'chrF', 'save_model': True}
#
#
# Creating new vocabulary
# Len of w2i:  4999
# Len of i2w:  4999
# Len of char vocab:  33
#
#
# Initializing an only ScRNN model
#
#
# Training the model...
#
# Average train loss after 1 iteration = 0.1775
# Total train chrF after 1 iteration = 51.0382
# Average val loss after 1 iteration = 0.1639
# Total val chrF after 1 iteration = 74.4589
# Average test loss after 1 iteration = 0.1674
# Total test chrF after 1 iteration = 74.9403
# Dumping after  1
# Time for the iteration 16.8 seconds
#
#
# Average train loss after 2 iteration = 0.1139
# Total train chrF after 2 iteration = 60.8251
# Average val loss after 2 iteration = 0.0993
# Total val chrF after 2 iteration = 77.0542
# Average test loss after 2 iteration = 0.1020
# Total test chrF after 2 iteration = 77.7639
# Dumping after  2
# Time for the iteration 16.5 seconds
#
#
# Average train loss after 3 iteration = 0.0743
# Total train chrF after 3 iteration = 68.6651
# Average val loss after 3 iteration = 0.0716
# Total val chrF after 3 iteration = 79.6127
# Average test loss after 3 iteration = 0.0737
# Total test chrF after 3 iteration = 80.1819
# Dumping after  3
# Time for the iteration 16.4 seconds
#
#
# Average train loss after 4 iteration = 0.0522
# Total train chrF after 4 iteration = 73.7350
# Average val loss after 4 iteration = 0.0567
# Total val chrF after 4 iteration = 80.6450
# Average test loss after 4 iteration = 0.0583
# Total test chrF after 4 iteration = 81.1400
# Dumping after  4
# Time for the iteration 16.6 seconds
#
#
# Average train loss after 5 iteration = 0.0391
# Total train chrF after 5 iteration = 76.9755
# Average val loss after 5 iteration = 0.0461
# Total val chrF after 5 iteration = 81.1854
# Average test loss after 5 iteration = 0.0474
# Total test chrF after 5 iteration = 81.5811
# Dumping after  5
# Time for the iteration 17.0 seconds
#
#
# Average train loss after 6 iteration = 0.0308
# Total train chrF after 6 iteration = 79.3410
# Average val loss after 6 iteration = 0.0391
# Total val chrF after 6 iteration = 81.5341
# Average test loss after 6 iteration = 0.0401
# Total test chrF after 6 iteration = 81.8902
# Dumping after  6
# Time for the iteration 16.9 seconds
#
#
# Average train loss after 7 iteration = 0.0252
# Total train chrF after 7 iteration = 81.1958
# Average val loss after 7 iteration = 0.0339
# Total val chrF after 7 iteration = 82.1643
# Average test loss after 7 iteration = 0.0346
# Total test chrF after 7 iteration = 82.3390
# Dumping after  7
# Time for the iteration 16.8 seconds
#
#
# Average train loss after 8 iteration = 0.0213
# Total train chrF after 8 iteration = 82.6980
# Average val loss after 8 iteration = 0.0297
# Total val chrF after 8 iteration = 82.4320
# Average test loss after 8 iteration = 0.0302
# Total test chrF after 8 iteration = 82.7493
# Dumping after  8
# Time for the iteration 16.7 seconds
#
#
# Average train loss after 9 iteration = 0.0184
# Total train chrF after 9 iteration = 83.9248
# Average val loss after 9 iteration = 0.0267
# Total val chrF after 9 iteration = 82.6260
# Average test loss after 9 iteration = 0.0270
# Total test chrF after 9 iteration = 82.9768
# Dumping after  9
# Time for the iteration 16.7 seconds
#
#
# Average train loss after 10 iteration = 0.0162
# Total train chrF after 10 iteration = 84.9505
# Average val loss after 10 iteration = 0.0245
# Total val chrF after 10 iteration = 82.8435
# Average test loss after 10 iteration = 0.0247
# Total test chrF after 10 iteration = 83.2815
# Dumping after  10
# Time for the iteration 16.9 seconds
#
#
# Average train loss after 11 iteration = 0.0145
# Total train chrF after 11 iteration = 85.7093
# Average val loss after 11 iteration = 0.0227
# Total val chrF after 11 iteration = 83.0724
# Average test loss after 11 iteration = 0.0228
# Total test chrF after 11 iteration = 83.5877
# Dumping after  11
# Time for the iteration 16.6 seconds
#
#
# Average train loss after 12 iteration = 0.0131
# Total train chrF after 12 iteration = 86.4126
# Average val loss after 12 iteration = 0.0214
# Total val chrF after 12 iteration = 83.0606
# Average test loss after 12 iteration = 0.0214
# Total test chrF after 12 iteration = 83.7703
# Time for the iteration 16.8 seconds
#
#
# Average train loss after 13 iteration = 0.0120
# Total train chrF after 13 iteration = 86.9838
# Average val loss after 13 iteration = 0.0202
# Total val chrF after 13 iteration = 83.2618
# Average test loss after 13 iteration = 0.0203
# Total test chrF after 13 iteration = 84.0038
# Dumping after  13
# Time for the iteration 16.8 seconds
#
#
# Average train loss after 14 iteration = 0.0111
# Total train chrF after 14 iteration = 87.4807
# Average val loss after 14 iteration = 0.0193
# Total val chrF after 14 iteration = 83.4716
# Average test loss after 14 iteration = 0.0194
# Total test chrF after 14 iteration = 84.1841
# Dumping after  14
# Time for the iteration 16.9 seconds
#
#
# Average train loss after 15 iteration = 0.0103
# Total train chrF after 15 iteration = 87.8990
# Average val loss after 15 iteration = 0.0186
# Total val chrF after 15 iteration = 83.6516
# Average test loss after 15 iteration = 0.0186
# Total test chrF after 15 iteration = 84.3289
# Dumping after  15
# Time for the iteration 16.9 seconds
#
#
# Average train loss after 16 iteration = 0.0096
# Total train chrF after 16 iteration = 88.2719
# Average val loss after 16 iteration = 0.0180
# Total val chrF after 16 iteration = 83.7078
# Average test loss after 16 iteration = 0.0180
# Total test chrF after 16 iteration = 84.4624
# Dumping after  16
# Time for the iteration 16.9 seconds
#
#
# Average train loss after 17 iteration = 0.0089
# Total train chrF after 17 iteration = 88.5601
# Average val loss after 17 iteration = 0.0174
# Total val chrF after 17 iteration = 83.9040
# Average test loss after 17 iteration = 0.0175
# Total test chrF after 17 iteration = 84.5861
# Dumping after  17
# Time for the iteration 17.1 seconds
#
#
# Average train loss after 18 iteration = 0.0084
# Total train chrF after 18 iteration = 88.8369
# Average val loss after 18 iteration = 0.0170
# Total val chrF after 18 iteration = 84.0789
# Average test loss after 18 iteration = 0.0170
# Total test chrF after 18 iteration = 84.7457
# Dumping after  18
# Time for the iteration 16.9 seconds
#
#
# Average train loss after 19 iteration = 0.0079
# Total train chrF after 19 iteration = 89.0817
# Average val loss after 19 iteration = 0.0165
# Total val chrF after 19 iteration = 84.1506
# Average test loss after 19 iteration = 0.0166
# Total test chrF after 19 iteration = 84.9205
# Dumping after  19
# Time for the iteration 17.0 seconds
#
#
# Average train loss after 20 iteration = 0.0074
# Total train chrF after 20 iteration = 89.2996
# Average val loss after 20 iteration = 0.0162
# Total val chrF after 20 iteration = 84.1774
# Average test loss after 20 iteration = 0.0162
# Total test chrF after 20 iteration = 85.0509
# Dumping after  20
# Time for the iteration 17.2 seconds
#
#
# Average train loss after 21 iteration = 0.0070
# Total train chrF after 21 iteration = 89.5107
# Average val loss after 21 iteration = 0.0159
# Total val chrF after 21 iteration = 84.2170
# Average test loss after 21 iteration = 0.0160
# Total test chrF after 21 iteration = 85.1074
# Dumping after  21
# Time for the iteration 16.7 seconds
#
#
# Average train loss after 22 iteration = 0.0066
# Total train chrF after 22 iteration = 89.7062
# Average val loss after 22 iteration = 0.0157
# Total val chrF after 22 iteration = 84.2983
# Average test loss after 22 iteration = 0.0157
# Total test chrF after 22 iteration = 85.2144
# Dumping after  22
# Time for the iteration 16.8 seconds
#
#
# Average train loss after 23 iteration = 0.0063
# Total train chrF after 23 iteration = 89.8810
# Average val loss after 23 iteration = 0.0154
# Total val chrF after 23 iteration = 84.3849
# Average test loss after 23 iteration = 0.0155
# Total test chrF after 23 iteration = 85.2413
# Dumping after  23
# Time for the iteration 16.9 seconds
#
#
# Average train loss after 24 iteration = 0.0060
# Total train chrF after 24 iteration = 90.0263
# Average val loss after 24 iteration = 0.0152
# Total val chrF after 24 iteration = 84.5226
# Average test loss after 24 iteration = 0.0153
# Total test chrF after 24 iteration = 85.3565
# Dumping after  24
# Time for the iteration 16.9 seconds
#
#
# Average train loss after 25 iteration = 0.0057
# Total train chrF after 25 iteration = 90.1606
# Average val loss after 25 iteration = 0.0151
# Total val chrF after 25 iteration = 84.5423
# Average test loss after 25 iteration = 0.0151
# Total test chrF after 25 iteration = 85.4124
# Dumping after  25
# Time for the iteration 16.8 seconds
#
#
# Average train loss after 26 iteration = 0.0054
# Total train chrF after 26 iteration = 90.2817
# Average val loss after 26 iteration = 0.0149
# Total val chrF after 26 iteration = 84.6446
# Average test loss after 26 iteration = 0.0150
# Total test chrF after 26 iteration = 85.5986
# Dumping after  26
# Time for the iteration 16.8 seconds
#
#
# Average train loss after 27 iteration = 0.0051
# Total train chrF after 27 iteration = 90.3916
# Average val loss after 27 iteration = 0.0148
# Total val chrF after 27 iteration = 84.6663
# Average test loss after 27 iteration = 0.0148
# Total test chrF after 27 iteration = 85.5856
# Dumping after  27
# Time for the iteration 17.0 seconds
#
#
# Average train loss after 28 iteration = 0.0049
# Total train chrF after 28 iteration = 90.4954
# Average val loss after 28 iteration = 0.0147
# Total val chrF after 28 iteration = 84.6769
# Average test loss after 28 iteration = 0.0147
# Total test chrF after 28 iteration = 85.5962
# Dumping after  28
# Time for the iteration 16.9 seconds
#
#
# Average train loss after 29 iteration = 0.0047
# Total train chrF after 29 iteration = 90.5844
# Average val loss after 29 iteration = 0.0146
# Total val chrF after 29 iteration = 84.6651
# Average test loss after 29 iteration = 0.0146
# Total test chrF after 29 iteration = 85.6290
# Time for the iteration 17.0 seconds
#
#
# Average train loss after 30 iteration = 0.0044
# Total train chrF after 30 iteration = 90.6846
# Average val loss after 30 iteration = 0.0145
# Total val chrF after 30 iteration = 84.6988
# Average test loss after 30 iteration = 0.0145
# Total test chrF after 30 iteration = 85.7344
# Dumping after  30
# Time for the iteration 17.0 seconds
#
#
# Average train loss after 31 iteration = 0.0042
# Total train chrF after 31 iteration = 90.7694
# Average val loss after 31 iteration = 0.0145
# Total val chrF after 31 iteration = 84.7318
# Average test loss after 31 iteration = 0.0145
# Total test chrF after 31 iteration = 85.7916
# Dumping after  31
# Time for the iteration 16.8 seconds
#
#
# Average train loss after 32 iteration = 0.0041
# Total train chrF after 32 iteration = 90.8455
# Average val loss after 32 iteration = 0.0144
# Total val chrF after 32 iteration = 84.7812
# Average test loss after 32 iteration = 0.0144
# Total test chrF after 32 iteration = 85.8264
# Dumping after  32
# Time for the iteration 16.7 seconds
#
#
# Average train loss after 33 iteration = 0.0039
# Total train chrF after 33 iteration = 90.9134
# Average val loss after 33 iteration = 0.0144
# Total val chrF after 33 iteration = 84.7834
# Average test loss after 33 iteration = 0.0144
# Total test chrF after 33 iteration = 85.7826
# Dumping after  33
# Time for the iteration 16.9 seconds
#
#
# Average train loss after 34 iteration = 0.0037
# Total train chrF after 34 iteration = 90.9814
# Average val loss after 34 iteration = 0.0144
# Total val chrF after 34 iteration = 84.7971
# Average test loss after 34 iteration = 0.0144
# Total test chrF after 34 iteration = 85.7962
# Dumping after  34
# Time for the iteration 16.7 seconds
#
#
# Average train loss after 35 iteration = 0.0036
# Total train chrF after 35 iteration = 91.0509
# Average val loss after 35 iteration = 0.0143
# Total val chrF after 35 iteration = 84.8134
# Average test loss after 35 iteration = 0.0144
# Total test chrF after 35 iteration = 85.8098
# Dumping after  35
# Time for the iteration 16.9 seconds
#
#
# Average train loss after 36 iteration = 0.0034
# Total train chrF after 36 iteration = 91.1094
# Average val loss after 36 iteration = 0.0143
# Total val chrF after 36 iteration = 84.8239
# Average test loss after 36 iteration = 0.0143
# Total test chrF after 36 iteration = 85.7971
# Dumping after  36
# Time for the iteration 17.0 seconds
#
#
# Average train loss after 37 iteration = 0.0033
# Total train chrF after 37 iteration = 91.1663
# Average val loss after 37 iteration = 0.0143
# Total val chrF after 37 iteration = 84.8497
# Average test loss after 37 iteration = 0.0144
# Total test chrF after 37 iteration = 85.8763
# Dumping after  37
# Time for the iteration 16.9 seconds
#
#
# Average train loss after 38 iteration = 0.0031
# Total train chrF after 38 iteration = 91.2196
# Average val loss after 38 iteration = 0.0143
# Total val chrF after 38 iteration = 84.8962
# Average test loss after 38 iteration = 0.0144
# Total test chrF after 38 iteration = 85.9717
# Dumping after  38
# Time for the iteration 17.1 seconds
#
#
# Average train loss after 39 iteration = 0.0030
# Total train chrF after 39 iteration = 91.2712
# Average val loss after 39 iteration = 0.0143
# Total val chrF after 39 iteration = 84.8896
# Average test loss after 39 iteration = 0.0144
# Total test chrF after 39 iteration = 85.9556
# Time for the iteration 16.8 seconds
#
#
# Average train loss after 40 iteration = 0.0029
# Total train chrF after 40 iteration = 91.3177
# Average val loss after 40 iteration = 0.0144
# Total val chrF after 40 iteration = 84.9087
# Average test loss after 40 iteration = 0.0144
# Total test chrF after 40 iteration = 86.0606
# Dumping after  40
# Time for the iteration 16.7 seconds
#
#
# Average train loss after 41 iteration = 0.0027
# Total train chrF after 41 iteration = 91.3648
# Average val loss after 41 iteration = 0.0144
# Total val chrF after 41 iteration = 84.8676
# Average test loss after 41 iteration = 0.0144
# Total test chrF after 41 iteration = 86.0322
# Time for the iteration 16.9 seconds
#
#
# Average train loss after 42 iteration = 0.0026
# Total train chrF after 42 iteration = 91.4034
# Average val loss after 42 iteration = 0.0144
# Total val chrF after 42 iteration = 84.8840
# Average test loss after 42 iteration = 0.0144
# Total test chrF after 42 iteration = 86.0454
# Time for the iteration 16.9 seconds
#
#
# Average train loss after 43 iteration = 0.0025
# Total train chrF after 43 iteration = 91.4437
# Average val loss after 43 iteration = 0.0144
# Total val chrF after 43 iteration = 84.8795
# Average test loss after 43 iteration = 0.0145
# Total test chrF after 43 iteration = 86.0116
# Time for the iteration 17.0 seconds
#
#
# Average train loss after 44 iteration = 0.0024
# Total train chrF after 44 iteration = 91.4810
# Average val loss after 44 iteration = 0.0145
# Total val chrF after 44 iteration = 84.8790
# Average test loss after 44 iteration = 0.0145
# Total test chrF after 44 iteration = 86.0289
# Time for the iteration 16.8 seconds
#
#
# Average train loss after 45 iteration = 0.0023
# Total train chrF after 45 iteration = 91.5151
# Average val loss after 45 iteration = 0.0145
# Total val chrF after 45 iteration = 84.9267
# Average test loss after 45 iteration = 0.0145
# Total test chrF after 45 iteration = 86.0145
# Dumping after  45
# Time for the iteration 16.8 seconds
#
#
# Average train loss after 46 iteration = 0.0022
# Total train chrF after 46 iteration = 91.5483
# Average val loss after 46 iteration = 0.0145
# Total val chrF after 46 iteration = 85.0047
# Average test loss after 46 iteration = 0.0146
# Total test chrF after 46 iteration = 86.0593
# Dumping after  46
# Time for the iteration 16.9 seconds
#
#
# Average train loss after 47 iteration = 0.0021
# Total train chrF after 47 iteration = 91.5852
# Average val loss after 47 iteration = 0.0146
# Total val chrF after 47 iteration = 85.0098
# Average test loss after 47 iteration = 0.0146
# Total test chrF after 47 iteration = 86.0287
# Dumping after  47
# Time for the iteration 17.0 seconds
#
#
# Average train loss after 48 iteration = 0.0021
# Total train chrF after 48 iteration = 91.6134
# Average val loss after 48 iteration = 0.0146
# Total val chrF after 48 iteration = 85.0158
# Average test loss after 48 iteration = 0.0147
# Total test chrF after 48 iteration = 86.0352
# Dumping after  48
# Time for the iteration 16.8 seconds
#
#
# Average train loss after 49 iteration = 0.0020
# Total train chrF after 49 iteration = 91.6321
# Average val loss after 49 iteration = 0.0147
# Total val chrF after 49 iteration = 84.9782
# Average test loss after 49 iteration = 0.0147
# Total test chrF after 49 iteration = 86.0262
# Time for the iteration 16.8 seconds
#
#
# Average train loss after 50 iteration = 0.0019
# Total train chrF after 50 iteration = 91.6643
# Average val loss after 50 iteration = 0.0147
# Total val chrF after 50 iteration = 84.9326
# Average test loss after 50 iteration = 0.0148
# Total test chrF after 50 iteration = 85.9720
# Time for the iteration 17.1 seconds
#
#
# Average train loss after 51 iteration = 0.0018
# Total train chrF after 51 iteration = 91.6904
# Average val loss after 51 iteration = 0.0148
# Total val chrF after 51 iteration = 84.9209
# Average test loss after 51 iteration = 0.0148
# Total test chrF after 51 iteration = 85.9068
# Time for the iteration 16.8 seconds
#
#
# Average train loss after 52 iteration = 0.0017
# Total train chrF after 52 iteration = 91.7097
# Average val loss after 52 iteration = 0.0148
# Total val chrF after 52 iteration = 84.9288
# Average test loss after 52 iteration = 0.0149
# Total test chrF after 52 iteration = 85.8987
# Time for the iteration 17.2 seconds
#
#
# Average train loss after 53 iteration = 0.0017
# Total train chrF after 53 iteration = 91.7376
# Average val loss after 53 iteration = 0.0149
# Total val chrF after 53 iteration = 84.9687
# Average test loss after 53 iteration = 0.0150
# Total test chrF after 53 iteration = 85.9116
# Time for the iteration 16.8 seconds
#
#
# Average train loss after 54 iteration = 0.0016
# Total train chrF after 54 iteration = 91.7585
# Average val loss after 54 iteration = 0.0150
# Total val chrF after 54 iteration = 84.9366
# Average test loss after 54 iteration = 0.0150
# Total test chrF after 54 iteration = 85.8899
# Time for the iteration 16.7 seconds
#
#
# Average train loss after 55 iteration = 0.0015
# Total train chrF after 55 iteration = 91.7772
# Average val loss after 55 iteration = 0.0150
# Total val chrF after 55 iteration = 84.8631
# Average test loss after 55 iteration = 0.0151
# Total test chrF after 55 iteration = 85.9045
# Time for the iteration 17.1 seconds
#
#
# Average train loss after 56 iteration = 0.0015
# Total train chrF after 56 iteration = 91.8029
# Average val loss after 56 iteration = 0.0151
# Total val chrF after 56 iteration = 84.8720
# Average test loss after 56 iteration = 0.0152
# Total test chrF after 56 iteration = 85.8806
# Time for the iteration 16.9 seconds
#
#
# Average train loss after 57 iteration = 0.0014
# Total train chrF after 57 iteration = 91.8261
# Average val loss after 57 iteration = 0.0152
# Total val chrF after 57 iteration = 84.9573
# Average test loss after 57 iteration = 0.0152
# Total test chrF after 57 iteration = 85.8588
# Time for the iteration 17.0 seconds
#
#
# Average train loss after 58 iteration = 0.0014
# Total train chrF after 58 iteration = 91.8433
# Average val loss after 58 iteration = 0.0152
# Total val chrF after 58 iteration = 84.9958
# Average test loss after 58 iteration = 0.0153
# Total test chrF after 58 iteration = 85.8228
# Time for the iteration 17.0 seconds
#
#
# Average train loss after 59 iteration = 0.0013
# Total train chrF after 59 iteration = 91.8590
# Average val loss after 59 iteration = 0.0153
# Total val chrF after 59 iteration = 84.9995
# Average test loss after 59 iteration = 0.0154
# Total test chrF after 59 iteration = 85.8032
# Time for the iteration 16.9 seconds
#
#
# Average train loss after 60 iteration = 0.0013
# Total train chrF after 60 iteration = 91.8772
# Average val loss after 60 iteration = 0.0154
# Total val chrF after 60 iteration = 84.9566
# Average test loss after 60 iteration = 0.0155
# Total test chrF after 60 iteration = 85.7968
# Time for the iteration 17.1 seconds
#
#
# Average train loss after 61 iteration = 0.0012
# Total train chrF after 61 iteration = 91.8909
# Average val loss after 61 iteration = 0.0155
# Total val chrF after 61 iteration = 84.9273
# Average test loss after 61 iteration = 0.0155
# Total test chrF after 61 iteration = 85.8284
# Time for the iteration 17.0 seconds
#
#
# Average train loss after 62 iteration = 0.0012
# Total train chrF after 62 iteration = 91.9071
# Average val loss after 62 iteration = 0.0156
# Total val chrF after 62 iteration = 84.9046
# Average test loss after 62 iteration = 0.0156
# Total test chrF after 62 iteration = 85.8384
# Time for the iteration 16.8 seconds
#
#
# Average train loss after 63 iteration = 0.0011
# Total train chrF after 63 iteration = 91.9199
# Average val loss after 63 iteration = 0.0157
# Total val chrF after 63 iteration = 84.9718
# Average test loss after 63 iteration = 0.0157
# Total test chrF after 63 iteration = 85.8518
# Time for the iteration 16.7 seconds
#
#
# Average train loss after 64 iteration = 0.0011
# Total train chrF after 64 iteration = 91.9319
# Average val loss after 64 iteration = 0.0157
# Total val chrF after 64 iteration = 84.9507
# Average test loss after 64 iteration = 0.0158
# Total test chrF after 64 iteration = 85.8717
# Time for the iteration 16.8 seconds
#
#
# Average train loss after 65 iteration = 0.0010
# Total train chrF after 65 iteration = 91.9474
# Average val loss after 65 iteration = 0.0158
# Total val chrF after 65 iteration = 85.0192
# Average test loss after 65 iteration = 0.0159
# Total test chrF after 65 iteration = 85.8363
# Dumping after  65
# Time for the iteration 16.9 seconds
#
#
# Average train loss after 66 iteration = 0.0010
# Total train chrF after 66 iteration = 91.9629
# Average val loss after 66 iteration = 0.0159
# Total val chrF after 66 iteration = 85.0222
# Average test loss after 66 iteration = 0.0160
# Total test chrF after 66 iteration = 85.8458
# Dumping after  66
# Time for the iteration 16.8 seconds
#
#
# Average train loss after 67 iteration = 0.0009
# Total train chrF after 67 iteration = 91.9759
# Average val loss after 67 iteration = 0.0160
# Total val chrF after 67 iteration = 85.0637
# Average test loss after 67 iteration = 0.0161
# Total test chrF after 67 iteration = 85.8059
# Dumping after  67
# Time for the iteration 16.9 seconds
#
#
# Average train loss after 68 iteration = 0.0009
# Total train chrF after 68 iteration = 91.9901
# Average val loss after 68 iteration = 0.0161
# Total val chrF after 68 iteration = 85.0793
# Average test loss after 68 iteration = 0.0162
# Total test chrF after 68 iteration = 85.7984
# Dumping after  68
# Time for the iteration 16.8 seconds
#
#
# Average train loss after 69 iteration = 0.0009
# Total train chrF after 69 iteration = 91.9986
# Average val loss after 69 iteration = 0.0162
# Total val chrF after 69 iteration = 85.0483
# Average test loss after 69 iteration = 0.0163
# Total test chrF after 69 iteration = 85.7583
# Time for the iteration 16.8 seconds
#
#
# Average train loss after 70 iteration = 0.0008
# Total train chrF after 70 iteration = 92.0096
# Average val loss after 70 iteration = 0.0163
# Total val chrF after 70 iteration = 85.1310
# Average test loss after 70 iteration = 0.0164
# Total test chrF after 70 iteration = 85.7405
# Dumping after  70
# Time for the iteration 16.9 seconds
#
#
# Average train loss after 71 iteration = 0.0008
# Total train chrF after 71 iteration = 92.0176
# Average val loss after 71 iteration = 0.0164
# Total val chrF after 71 iteration = 85.1010
# Average test loss after 71 iteration = 0.0165
# Total test chrF after 71 iteration = 85.7256
# Time for the iteration 17.0 seconds
#
#
# Average train loss after 72 iteration = 0.0008
# Total train chrF after 72 iteration = 92.0263
# Average val loss after 72 iteration = 0.0164
# Total val chrF after 72 iteration = 85.0954
# Average test loss after 72 iteration = 0.0166
# Total test chrF after 72 iteration = 85.7454
# Time for the iteration 16.8 seconds
#
#
# Average train loss after 73 iteration = 0.0007
# Total train chrF after 73 iteration = 92.0373
# Average val loss after 73 iteration = 0.0165
# Total val chrF after 73 iteration = 85.1486
# Average test loss after 73 iteration = 0.0167
# Total test chrF after 73 iteration = 85.7764
# Dumping after  73
# Time for the iteration 16.9 seconds
#
#
# Average train loss after 74 iteration = 0.0007
# Total train chrF after 74 iteration = 92.0487
# Average val loss after 74 iteration = 0.0166
# Total val chrF after 74 iteration = 85.1392
# Average test loss after 74 iteration = 0.0168
# Total test chrF after 74 iteration = 85.7362
# Time for the iteration 17.1 seconds
#
#
# Average train loss after 75 iteration = 0.0007
# Total train chrF after 75 iteration = 92.0562
# Average val loss after 75 iteration = 0.0167
# Total val chrF after 75 iteration = 85.1219
# Average test loss after 75 iteration = 0.0169
# Total test chrF after 75 iteration = 85.7281
# Time for the iteration 16.9 seconds
#
#
# Average train loss after 76 iteration = 0.0006
# Total train chrF after 76 iteration = 92.0645
# Average val loss after 76 iteration = 0.0168
# Total val chrF after 76 iteration = 85.1129
# Average test loss after 76 iteration = 0.0170
# Total test chrF after 76 iteration = 85.7080
# Time for the iteration 16.9 seconds
#
#
# Average train loss after 77 iteration = 0.0006
# Total train chrF after 77 iteration = 92.0706
# Average val loss after 77 iteration = 0.0169
# Total val chrF after 77 iteration = 85.0978
# Average test loss after 77 iteration = 0.0171
# Total test chrF after 77 iteration = 85.7495
# Time for the iteration 16.9 seconds
#
#
# Average train loss after 78 iteration = 0.0006
# Total train chrF after 78 iteration = 92.0770
# Average val loss after 78 iteration = 0.0170
# Total val chrF after 78 iteration = 85.0919
# Average test loss after 78 iteration = 0.0173
# Total test chrF after 78 iteration = 85.7416
# Time for the iteration 16.8 seconds
#
#
# Average train loss after 79 iteration = 0.0006
# Total train chrF after 79 iteration = 92.0844
# Average val loss after 79 iteration = 0.0171
# Total val chrF after 79 iteration = 85.0791
# Average test loss after 79 iteration = 0.0174
# Total test chrF after 79 iteration = 85.7269
# Time for the iteration 17.2 seconds
#
#
# Average train loss after 80 iteration = 0.0005
# Total train chrF after 80 iteration = 92.0898
# Average val loss after 80 iteration = 0.0173
# Total val chrF after 80 iteration = 85.0790
# Average test loss after 80 iteration = 0.0175
# Total test chrF after 80 iteration = 85.7754
# Time for the iteration 16.8 seconds
#
#
# Average train loss after 81 iteration = 0.0005
# Total train chrF after 81 iteration = 92.0932
# Average val loss after 81 iteration = 0.0174
# Total val chrF after 81 iteration = 85.0965
# Average test loss after 81 iteration = 0.0176
# Total test chrF after 81 iteration = 85.7596
# Time for the iteration 16.9 seconds
#
#
# Average train loss after 82 iteration = 0.0005
# Total train chrF after 82 iteration = 92.0990
# Average val loss after 82 iteration = 0.0175
# Total val chrF after 82 iteration = 85.0803
# Average test loss after 82 iteration = 0.0177
# Total test chrF after 82 iteration = 85.6696
# Time for the iteration 16.8 seconds
#
#
# Average train loss after 83 iteration = 0.0005
# Total train chrF after 83 iteration = 92.1024
# Average val loss after 83 iteration = 0.0176
# Total val chrF after 83 iteration = 85.0544
# Average test loss after 83 iteration = 0.0178
# Total test chrF after 83 iteration = 85.6948
# Time for the iteration 16.8 seconds
#
#
# Average train loss after 84 iteration = 0.0004
# Total train chrF after 84 iteration = 92.1065
# Average val loss after 84 iteration = 0.0177
# Total val chrF after 84 iteration = 85.1064
# Average test loss after 84 iteration = 0.0179
# Total test chrF after 84 iteration = 85.6373
# Time for the iteration 17.1 seconds
#
#
# Average train loss after 85 iteration = 0.0004
# Total train chrF after 85 iteration = 92.1108
# Average val loss after 85 iteration = 0.0178
# Total val chrF after 85 iteration = 85.0490
# Average test loss after 85 iteration = 0.0181
# Total test chrF after 85 iteration = 85.6392
# Time for the iteration 16.7 seconds
#
#
# Average train loss after 86 iteration = 0.0004
# Total train chrF after 86 iteration = 92.1134
# Average val loss after 86 iteration = 0.0179
# Total val chrF after 86 iteration = 85.0396
# Average test loss after 86 iteration = 0.0182
# Total test chrF after 86 iteration = 85.6651
# Time for the iteration 16.8 seconds
#
#
# Average train loss after 87 iteration = 0.0004
# Total train chrF after 87 iteration = 92.1174
# Average val loss after 87 iteration = 0.0180
# Total val chrF after 87 iteration = 85.0342
# Average test loss after 87 iteration = 0.0183
# Total test chrF after 87 iteration = 85.6586
# Time for the iteration 16.8 seconds
#
#
# Average train loss after 88 iteration = 0.0004
# Total train chrF after 88 iteration = 92.1199
# Average val loss after 88 iteration = 0.0181
# Total val chrF after 88 iteration = 85.0029
# Average test loss after 88 iteration = 0.0184
# Total test chrF after 88 iteration = 85.6234
# Time for the iteration 17.2 seconds
#
#
# Average train loss after 89 iteration = 0.0003
# Total train chrF after 89 iteration = 92.1227
# Average val loss after 89 iteration = 0.0183
# Total val chrF after 89 iteration = 84.9714
# Average test loss after 89 iteration = 0.0186
# Total test chrF after 89 iteration = 85.5845
# Time for the iteration 16.9 seconds
#
#
# Average train loss after 90 iteration = 0.0003
# Total train chrF after 90 iteration = 92.1243
# Average val loss after 90 iteration = 0.0184
# Total val chrF after 90 iteration = 84.9281
# Average test loss after 90 iteration = 0.0187
# Total test chrF after 90 iteration = 85.6012
# Time for the iteration 16.8 seconds
#
#
# Average train loss after 91 iteration = 0.0003
# Total train chrF after 91 iteration = 92.1260
# Average val loss after 91 iteration = 0.0185
# Total val chrF after 91 iteration = 84.9649
# Average test loss after 91 iteration = 0.0188
# Total test chrF after 91 iteration = 85.6197
# Time for the iteration 16.8 seconds
#
#
# Average train loss after 92 iteration = 0.0003
# Total train chrF after 92 iteration = 92.1259
# Average val loss after 92 iteration = 0.0186
# Total val chrF after 92 iteration = 84.9256
# Average test loss after 92 iteration = 0.0189
# Total test chrF after 92 iteration = 85.5582
# Time for the iteration 17.0 seconds
#
#
# Average train loss after 93 iteration = 0.0003
# Total train chrF after 93 iteration = 92.1296
# Average val loss after 93 iteration = 0.0187
# Total val chrF after 93 iteration = 84.9758
# Average test loss after 93 iteration = 0.0190
# Total test chrF after 93 iteration = 85.5885
# Time for the iteration 17.1 seconds
#
#
# Average train loss after 94 iteration = 0.0003
# Total train chrF after 94 iteration = 92.1311
# Average val loss after 94 iteration = 0.0189
# Total val chrF after 94 iteration = 84.9417
# Average test loss after 94 iteration = 0.0192
# Total test chrF after 94 iteration = 85.6380
# Time for the iteration 16.8 seconds
#
#
# Average train loss after 95 iteration = 0.0003
# Total train chrF after 95 iteration = 92.1325
# Average val loss after 95 iteration = 0.0190
# Total val chrF after 95 iteration = 84.9508
# Average test loss after 95 iteration = 0.0193
# Total test chrF after 95 iteration = 85.6507
# Time for the iteration 16.9 seconds
#
#
# Average train loss after 96 iteration = 0.0002
# Total train chrF after 96 iteration = 92.1347
# Average val loss after 96 iteration = 0.0191
# Total val chrF after 96 iteration = 84.9073
# Average test loss after 96 iteration = 0.0194
# Total test chrF after 96 iteration = 85.7047
# Time for the iteration 16.8 seconds
#
#
# Average train loss after 97 iteration = 0.0002
# Total train chrF after 97 iteration = 92.1357
# Average val loss after 97 iteration = 0.0193
# Total val chrF after 97 iteration = 84.8368
# Average test loss after 97 iteration = 0.0195
# Total test chrF after 97 iteration = 85.6967
# Time for the iteration 17.0 seconds
#
#
# Average train loss after 98 iteration = 0.0002
# Total train chrF after 98 iteration = 92.1374
# Average val loss after 98 iteration = 0.0194
# Total val chrF after 98 iteration = 84.9093
# Average test loss after 98 iteration = 0.0197
# Total test chrF after 98 iteration = 85.6756
# Time for the iteration 17.0 seconds
#
#
# Average train loss after 99 iteration = 0.0002
# Total train chrF after 99 iteration = 92.1377
# Average val loss after 99 iteration = 0.0195
# Total val chrF after 99 iteration = 84.8642
# Average test loss after 99 iteration = 0.0198
# Total test chrF after 99 iteration = 85.6969
# Time for the iteration 16.9 seconds
#
#
# Average train loss after 100 iteration = 0.0002
# Total train chrF after 100 iteration = 92.1399
# Average val loss after 100 iteration = 0.0197
# Total val chrF after 100 iteration = 84.8835
# Average test loss after 100 iteration = 0.0199
# Total test chrF after 100 iteration = 85.6815
# Time for the iteration 16.9 seconds
#
#
#
#
# Aborting since there hasn't been much progress
# <Figure size 640x480 with 1 Axes>
# <Figure size 640x480 with 1 Axes>

# %%
language = "shi"
task_name = "keyprox_teacher_general"
vocab_size = 4999
num_epochs = 100
batch_size = 32
model = "50_1"
optimizer = "Adam"
metric = "chrF"

# %%
from IPython.display import Image

Image("curves/{}_{}_{}_{}_{}_loss.png".format(language, task_name, vocab_size, num_epochs, batch_size))

# %%
Image("curves/{}_{}_{}_{}_{}_{}.png".format(language, task_name, vocab_size, num_epochs, batch_size, metric))

# %%
print("{}.{}.{}.{}.{}.{}.{}".format(language, task_name, vocab_size, num_epochs, batch_size, model, optimizer))
# Out:
# shi.keyprox_teacher_general.4999.100.32.50_1.Adam
