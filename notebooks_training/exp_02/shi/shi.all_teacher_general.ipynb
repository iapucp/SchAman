# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
# %cd "drive/MyDrive/Tesis/scRNN"
# Out:
# /content/drive/MyDrive/Tesis/scRNN

# %%
import torch

torch.cuda.is_available()
# Out:
# True

# %%
# !pip install sacrebleu
# Out:
# Collecting sacrebleu
#   Downloading sacrebleu-2.0.0-py3-none-any.whl (90 kB)
#      |████████████████████████████████| 90 kB 4.5 MB/s
# Requirement already satisfied: tabulate>=0.8.9 in /usr/local/lib/python3.7/dist-packages (from sacrebleu) (0.8.9)
# Collecting portalocker
#   Downloading portalocker-2.3.2-py2.py3-none-any.whl (15 kB)
# Collecting colorama
#   Downloading colorama-0.4.4-py2.py3-none-any.whl (16 kB)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from sacrebleu) (1.19.5)
# Requirement already satisfied: regex in /usr/local/lib/python3.7/dist-packages (from sacrebleu) (2019.12.20)
# Installing collected packages: portalocker, colorama, sacrebleu
# Successfully installed colorama-0.4.4 portalocker-2.3.2 sacrebleu-2.0.0

# %%
# !python3 train.py --language shi --task-name all_teacher_general --num-epochs 100 --batch-size 32 --vocab-size 4999 --new-vocab --train --train-sentences-errors-file shi.all_teacher_general.train.sentences.errors.txt --train-sentences-file shi.all_teacher_general.train.sentences.txt --val-sentences-errors-file shi.teacher_general.val.sentences.errors.txt --val-sentences-file shi.teacher_general.val.sentences.txt --test-sentences-errors-file shi.teacher_general.test.sentences.errors.txt --test-sentences-file shi.teacher_general.test.sentences.txt --metric chrF --save
# Out:
# Parameters
# {'language': 'shi', 'task_name': 'all_teacher_general', 'vocab_size': 4999, 'num_epochs': 100, 'batch_size': 32, 'model_name': 'shi_random_20531_100_32', 'new_vocab': True, 'need_to_train': True, 'train_sentences_errors_file': 'shi.all_teacher_general.train.sentences.errors.txt', 'train_sentences_file': 'shi.all_teacher_general.train.sentences.txt', 'val_sentences_errors_file': 'shi.teacher_general.val.sentences.errors.txt', 'val_sentences_file': 'shi.teacher_general.val.sentences.txt', 'test_sentences_errors_file': 'shi.teacher_general.test.sentences.errors.txt', 'test_sentences_file': 'shi.teacher_general.test.sentences.txt', 'metric': 'chrF', 'save_model': True}
#
#
# Creating new vocabulary
# Len of w2i:  4999
# Len of i2w:  4999
# Len of char vocab:  33
#
#
# Initializing an only ScRNN model
#
#
# Training the model...
#
# Average train loss after 1 iteration = 0.0934
# Total train chrF after 1 iteration = 65.8320
# Average val loss after 1 iteration = 0.0665
# Total val chrF after 1 iteration = 80.1359
# Average test loss after 1 iteration = 0.0679
# Total test chrF after 1 iteration = 80.0932
# Dumping after  1
# Time for the iteration 74.1 seconds
#
#
# Average train loss after 2 iteration = 0.0336
# Total train chrF after 2 iteration = 78.0796
# Average val loss after 2 iteration = 0.0435
# Total val chrF after 2 iteration = 81.0953
# Average test loss after 2 iteration = 0.0438
# Total test chrF after 2 iteration = 81.2072
# Dumping after  2
# Time for the iteration 74.4 seconds
#
#
# Average train loss after 3 iteration = 0.0236
# Total train chrF after 3 iteration = 81.3197
# Average val loss after 3 iteration = 0.0345
# Total val chrF after 3 iteration = 81.7439
# Average test loss after 3 iteration = 0.0345
# Total test chrF after 3 iteration = 82.1389
# Dumping after  3
# Time for the iteration 75.2 seconds
#
#
# Average train loss after 4 iteration = 0.0199
# Total train chrF after 4 iteration = 82.8241
# Average val loss after 4 iteration = 0.0299
# Total val chrF after 4 iteration = 82.4463
# Average test loss after 4 iteration = 0.0298
# Total test chrF after 4 iteration = 82.5646
# Dumping after  4
# Time for the iteration 75.0 seconds
#
#
# Average train loss after 5 iteration = 0.0178
# Total train chrF after 5 iteration = 83.7483
# Average val loss after 5 iteration = 0.0269
# Total val chrF after 5 iteration = 82.8583
# Average test loss after 5 iteration = 0.0268
# Total test chrF after 5 iteration = 82.9679
# Dumping after  5
# Time for the iteration 75.2 seconds
#
#
# Average train loss after 6 iteration = 0.0163
# Total train chrF after 6 iteration = 84.4187
# Average val loss after 6 iteration = 0.0249
# Total val chrF after 6 iteration = 83.0421
# Average test loss after 6 iteration = 0.0248
# Total test chrF after 6 iteration = 83.3506
# Dumping after  6
# Time for the iteration 74.7 seconds
#
#
# Average train loss after 7 iteration = 0.0152
# Total train chrF after 7 iteration = 84.9602
# Average val loss after 7 iteration = 0.0235
# Total val chrF after 7 iteration = 83.2496
# Average test loss after 7 iteration = 0.0233
# Total test chrF after 7 iteration = 83.5674
# Dumping after  7
# Time for the iteration 74.8 seconds
#
#
# Average train loss after 8 iteration = 0.0143
# Total train chrF after 8 iteration = 85.3960
# Average val loss after 8 iteration = 0.0224
# Total val chrF after 8 iteration = 83.4473
# Average test loss after 8 iteration = 0.0222
# Total test chrF after 8 iteration = 83.7818
# Dumping after  8
# Time for the iteration 75.2 seconds
#
#
# Average train loss after 9 iteration = 0.0136
# Total train chrF after 9 iteration = 85.7490
# Average val loss after 9 iteration = 0.0216
# Total val chrF after 9 iteration = 83.6191
# Average test loss after 9 iteration = 0.0213
# Total test chrF after 9 iteration = 83.9005
# Dumping after  9
# Time for the iteration 75.1 seconds
#
#
# Average train loss after 10 iteration = 0.0130
# Total train chrF after 10 iteration = 86.0665
# Average val loss after 10 iteration = 0.0211
# Total val chrF after 10 iteration = 83.6113
# Average test loss after 10 iteration = 0.0208
# Total test chrF after 10 iteration = 83.9445
# Time for the iteration 75.1 seconds
#
#
# Average train loss after 11 iteration = 0.0124
# Total train chrF after 11 iteration = 86.3488
# Average val loss after 11 iteration = 0.0207
# Total val chrF after 11 iteration = 83.6823
# Average test loss after 11 iteration = 0.0204
# Total test chrF after 11 iteration = 84.0427
# Dumping after  11
# Time for the iteration 75.2 seconds
#
#
# Average train loss after 12 iteration = 0.0119
# Total train chrF after 12 iteration = 86.5902
# Average val loss after 12 iteration = 0.0205
# Total val chrF after 12 iteration = 83.8210
# Average test loss after 12 iteration = 0.0201
# Total test chrF after 12 iteration = 84.1074
# Dumping after  12
# Time for the iteration 75.3 seconds
#
#
# Average train loss after 13 iteration = 0.0115
# Total train chrF after 13 iteration = 86.8209
# Average val loss after 13 iteration = 0.0203
# Total val chrF after 13 iteration = 83.9074
# Average test loss after 13 iteration = 0.0199
# Total test chrF after 13 iteration = 84.2226
# Dumping after  13
# Time for the iteration 75.1 seconds
#
#
# Average train loss after 14 iteration = 0.0111
# Total train chrF after 14 iteration = 87.0138
# Average val loss after 14 iteration = 0.0201
# Total val chrF after 14 iteration = 83.9969
# Average test loss after 14 iteration = 0.0197
# Total test chrF after 14 iteration = 84.3909
# Dumping after  14
# Time for the iteration 75.0 seconds
#
#
# Average train loss after 15 iteration = 0.0107
# Total train chrF after 15 iteration = 87.2008
# Average val loss after 15 iteration = 0.0200
# Total val chrF after 15 iteration = 84.0732
# Average test loss after 15 iteration = 0.0196
# Total test chrF after 15 iteration = 84.3892
# Dumping after  15
# Time for the iteration 74.7 seconds
#
#
# Average train loss after 16 iteration = 0.0104
# Total train chrF after 16 iteration = 87.3730
# Average val loss after 16 iteration = 0.0199
# Total val chrF after 16 iteration = 84.0869
# Average test loss after 16 iteration = 0.0194
# Total test chrF after 16 iteration = 84.4097
# Dumping after  16
# Time for the iteration 74.8 seconds
#
#
# Average train loss after 17 iteration = 0.0101
# Total train chrF after 17 iteration = 87.5320
# Average val loss after 17 iteration = 0.0198
# Total val chrF after 17 iteration = 84.1296
# Average test loss after 17 iteration = 0.0193
# Total test chrF after 17 iteration = 84.4262
# Dumping after  17
# Time for the iteration 74.7 seconds
#
#
# Average train loss after 18 iteration = 0.0098
# Total train chrF after 18 iteration = 87.6743
# Average val loss after 18 iteration = 0.0198
# Total val chrF after 18 iteration = 84.2083
# Average test loss after 18 iteration = 0.0193
# Total test chrF after 18 iteration = 84.4447
# Dumping after  18
# Time for the iteration 74.7 seconds
#
#
# Average train loss after 19 iteration = 0.0096
# Total train chrF after 19 iteration = 87.8065
# Average val loss after 19 iteration = 0.0197
# Total val chrF after 19 iteration = 84.3263
# Average test loss after 19 iteration = 0.0192
# Total test chrF after 19 iteration = 84.5014
# Dumping after  19
# Time for the iteration 74.6 seconds
#
#
# Average train loss after 20 iteration = 0.0094
# Total train chrF after 20 iteration = 87.9397
# Average val loss after 20 iteration = 0.0197
# Total val chrF after 20 iteration = 84.3049
# Average test loss after 20 iteration = 0.0192
# Total test chrF after 20 iteration = 84.4405
# Time for the iteration 74.2 seconds
#
#
# Average train loss after 21 iteration = 0.0091
# Total train chrF after 21 iteration = 88.0589
# Average val loss after 21 iteration = 0.0197
# Total val chrF after 21 iteration = 84.3731
# Average test loss after 21 iteration = 0.0192
# Total test chrF after 21 iteration = 84.4401
# Dumping after  21
# Time for the iteration 74.4 seconds
#
#
# Average train loss after 22 iteration = 0.0089
# Total train chrF after 22 iteration = 88.1679
# Average val loss after 22 iteration = 0.0197
# Total val chrF after 22 iteration = 84.2894
# Average test loss after 22 iteration = 0.0192
# Total test chrF after 22 iteration = 84.3984
# Time for the iteration 74.4 seconds
#
#
# Average train loss after 23 iteration = 0.0087
# Total train chrF after 23 iteration = 88.2719
# Average val loss after 23 iteration = 0.0197
# Total val chrF after 23 iteration = 84.3677
# Average test loss after 23 iteration = 0.0192
# Total test chrF after 23 iteration = 84.3610
# Time for the iteration 74.5 seconds
#
#
# Average train loss after 24 iteration = 0.0086
# Total train chrF after 24 iteration = 88.3705
# Average val loss after 24 iteration = 0.0197
# Total val chrF after 24 iteration = 84.4021
# Average test loss after 24 iteration = 0.0192
# Total test chrF after 24 iteration = 84.4492
# Dumping after  24
# Time for the iteration 74.7 seconds
#
#
# Average train loss after 25 iteration = 0.0084
# Total train chrF after 25 iteration = 88.4648
# Average val loss after 25 iteration = 0.0198
# Total val chrF after 25 iteration = 84.3923
# Average test loss after 25 iteration = 0.0192
# Total test chrF after 25 iteration = 84.5189
# Time for the iteration 75.1 seconds
#
#
# Average train loss after 26 iteration = 0.0082
# Total train chrF after 26 iteration = 88.5507
# Average val loss after 26 iteration = 0.0198
# Total val chrF after 26 iteration = 84.4454
# Average test loss after 26 iteration = 0.0193
# Total test chrF after 26 iteration = 84.4972
# Dumping after  26
# Time for the iteration 74.9 seconds
#
#
# Average train loss after 27 iteration = 0.0081
# Total train chrF after 27 iteration = 88.6292
# Average val loss after 27 iteration = 0.0198
# Total val chrF after 27 iteration = 84.4197
# Average test loss after 27 iteration = 0.0193
# Total test chrF after 27 iteration = 84.5418
# Time for the iteration 74.8 seconds
#
#
# Average train loss after 28 iteration = 0.0079
# Total train chrF after 28 iteration = 88.7076
# Average val loss after 28 iteration = 0.0198
# Total val chrF after 28 iteration = 84.4434
# Average test loss after 28 iteration = 0.0194
# Total test chrF after 28 iteration = 84.6291
# Time for the iteration 74.8 seconds
#
#
# Average train loss after 29 iteration = 0.0078
# Total train chrF after 29 iteration = 88.7823
# Average val loss after 29 iteration = 0.0199
# Total val chrF after 29 iteration = 84.4373
# Average test loss after 29 iteration = 0.0194
# Total test chrF after 29 iteration = 84.6493
# Time for the iteration 74.8 seconds
#
#
# Average train loss after 30 iteration = 0.0077
# Total train chrF after 30 iteration = 88.8493
# Average val loss after 30 iteration = 0.0199
# Total val chrF after 30 iteration = 84.4546
# Average test loss after 30 iteration = 0.0194
# Total test chrF after 30 iteration = 84.6556
# Dumping after  30
# Time for the iteration 74.9 seconds
#
#
# Average train loss after 31 iteration = 0.0075
# Total train chrF after 31 iteration = 88.9209
# Average val loss after 31 iteration = 0.0199
# Total val chrF after 31 iteration = 84.4450
# Average test loss after 31 iteration = 0.0195
# Total test chrF after 31 iteration = 84.7791
# Time for the iteration 74.5 seconds
#
#
# Average train loss after 32 iteration = 0.0074
# Total train chrF after 32 iteration = 88.9851
# Average val loss after 32 iteration = 0.0199
# Total val chrF after 32 iteration = 84.4870
# Average test loss after 32 iteration = 0.0195
# Total test chrF after 32 iteration = 84.8053
# Dumping after  32
# Time for the iteration 74.7 seconds
#
#
# Average train loss after 33 iteration = 0.0073
# Total train chrF after 33 iteration = 89.0486
# Average val loss after 33 iteration = 0.0200
# Total val chrF after 33 iteration = 84.5101
# Average test loss after 33 iteration = 0.0196
# Total test chrF after 33 iteration = 84.8208
# Dumping after  33
# Time for the iteration 74.6 seconds
#
#
# Average train loss after 34 iteration = 0.0072
# Total train chrF after 34 iteration = 89.1067
# Average val loss after 34 iteration = 0.0200
# Total val chrF after 34 iteration = 84.5187
# Average test loss after 34 iteration = 0.0196
# Total test chrF after 34 iteration = 84.8251
# Dumping after  34
# Time for the iteration 75.4 seconds
#
#
# Average train loss after 35 iteration = 0.0071
# Total train chrF after 35 iteration = 89.1607
# Average val loss after 35 iteration = 0.0200
# Total val chrF after 35 iteration = 84.4891
# Average test loss after 35 iteration = 0.0197
# Total test chrF after 35 iteration = 84.8647
# Time for the iteration 75.3 seconds
#
#
# Average train loss after 36 iteration = 0.0070
# Total train chrF after 36 iteration = 89.2114
# Average val loss after 36 iteration = 0.0200
# Total val chrF after 36 iteration = 84.3788
# Average test loss after 36 iteration = 0.0198
# Total test chrF after 36 iteration = 84.9024
# Time for the iteration 75.1 seconds
#
#
# Average train loss after 37 iteration = 0.0069
# Total train chrF after 37 iteration = 89.2641
# Average val loss after 37 iteration = 0.0201
# Total val chrF after 37 iteration = 84.3890
# Average test loss after 37 iteration = 0.0198
# Total test chrF after 37 iteration = 84.8690
# Time for the iteration 74.6 seconds
#
#
# Average train loss after 38 iteration = 0.0068
# Total train chrF after 38 iteration = 89.3124
# Average val loss after 38 iteration = 0.0201
# Total val chrF after 38 iteration = 84.4395
# Average test loss after 38 iteration = 0.0199
# Total test chrF after 38 iteration = 84.8454
# Time for the iteration 75.1 seconds
#
#
# Average train loss after 39 iteration = 0.0067
# Total train chrF after 39 iteration = 89.3602
# Average val loss after 39 iteration = 0.0202
# Total val chrF after 39 iteration = 84.4535
# Average test loss after 39 iteration = 0.0200
# Total test chrF after 39 iteration = 84.8140
# Time for the iteration 75.2 seconds
#
#
# Average train loss after 40 iteration = 0.0066
# Total train chrF after 40 iteration = 89.4042
# Average val loss after 40 iteration = 0.0202
# Total val chrF after 40 iteration = 84.4904
# Average test loss after 40 iteration = 0.0200
# Total test chrF after 40 iteration = 84.7897
# Time for the iteration 74.5 seconds
#
#
# Average train loss after 41 iteration = 0.0066
# Total train chrF after 41 iteration = 89.4456
# Average val loss after 41 iteration = 0.0202
# Total val chrF after 41 iteration = 84.4793
# Average test loss after 41 iteration = 0.0201
# Total test chrF after 41 iteration = 84.7770
# Time for the iteration 75.2 seconds
#
#
# Average train loss after 42 iteration = 0.0065
# Total train chrF after 42 iteration = 89.4847
# Average val loss after 42 iteration = 0.0203
# Total val chrF after 42 iteration = 84.4785
# Average test loss after 42 iteration = 0.0202
# Total test chrF after 42 iteration = 84.7990
# Time for the iteration 75.1 seconds
#
#
# Average train loss after 43 iteration = 0.0064
# Total train chrF after 43 iteration = 89.5254
# Average val loss after 43 iteration = 0.0203
# Total val chrF after 43 iteration = 84.4181
# Average test loss after 43 iteration = 0.0202
# Total test chrF after 43 iteration = 84.7809
# Time for the iteration 75.1 seconds
#
#
# Average train loss after 44 iteration = 0.0063
# Total train chrF after 44 iteration = 89.5695
# Average val loss after 44 iteration = 0.0204
# Total val chrF after 44 iteration = 84.4450
# Average test loss after 44 iteration = 0.0203
# Total test chrF after 44 iteration = 84.7676
# Time for the iteration 74.6 seconds
#
#
# Average train loss after 45 iteration = 0.0063
# Total train chrF after 45 iteration = 89.6078
# Average val loss after 45 iteration = 0.0204
# Total val chrF after 45 iteration = 84.4558
# Average test loss after 45 iteration = 0.0204
# Total test chrF after 45 iteration = 84.7792
# Time for the iteration 75.1 seconds
#
#
# Average train loss after 46 iteration = 0.0062
# Total train chrF after 46 iteration = 89.6438
# Average val loss after 46 iteration = 0.0205
# Total val chrF after 46 iteration = 84.4974
# Average test loss after 46 iteration = 0.0204
# Total test chrF after 46 iteration = 84.8017
# Time for the iteration 74.9 seconds
#
#
# Average train loss after 47 iteration = 0.0061
# Total train chrF after 47 iteration = 89.6801
# Average val loss after 47 iteration = 0.0205
# Total val chrF after 47 iteration = 84.5214
# Average test loss after 47 iteration = 0.0205
# Total test chrF after 47 iteration = 84.7499
# Dumping after  47
# Time for the iteration 74.5 seconds
#
#
# Average train loss after 48 iteration = 0.0061
# Total train chrF after 48 iteration = 89.7131
# Average val loss after 48 iteration = 0.0206
# Total val chrF after 48 iteration = 84.4830
# Average test loss after 48 iteration = 0.0206
# Total test chrF after 48 iteration = 84.7558
# Time for the iteration 74.8 seconds
#
#
# Average train loss after 49 iteration = 0.0060
# Total train chrF after 49 iteration = 89.7436
# Average val loss after 49 iteration = 0.0206
# Total val chrF after 49 iteration = 84.4564
# Average test loss after 49 iteration = 0.0206
# Total test chrF after 49 iteration = 84.7461
# Time for the iteration 75.1 seconds
#
#
# Average train loss after 50 iteration = 0.0059
# Total train chrF after 50 iteration = 89.7753
# Average val loss after 50 iteration = 0.0207
# Total val chrF after 50 iteration = 84.4148
# Average test loss after 50 iteration = 0.0207
# Total test chrF after 50 iteration = 84.8059
# Time for the iteration 74.4 seconds
#
#
# Average train loss after 51 iteration = 0.0059
# Total train chrF after 51 iteration = 89.8065
# Average val loss after 51 iteration = 0.0207
# Total val chrF after 51 iteration = 84.4206
# Average test loss after 51 iteration = 0.0208
# Total test chrF after 51 iteration = 84.7932
# Time for the iteration 75.1 seconds
#
#
# Average train loss after 52 iteration = 0.0058
# Total train chrF after 52 iteration = 89.8387
# Average val loss after 52 iteration = 0.0208
# Total val chrF after 52 iteration = 84.4233
# Average test loss after 52 iteration = 0.0208
# Total test chrF after 52 iteration = 84.7698
# Time for the iteration 75.2 seconds
#
#
# Average train loss after 53 iteration = 0.0058
# Total train chrF after 53 iteration = 89.8666
# Average val loss after 53 iteration = 0.0209
# Total val chrF after 53 iteration = 84.3691
# Average test loss after 53 iteration = 0.0209
# Total test chrF after 53 iteration = 84.7412
# Time for the iteration 74.7 seconds
#
#
# Average train loss after 54 iteration = 0.0057
# Total train chrF after 54 iteration = 89.8960
# Average val loss after 54 iteration = 0.0209
# Total val chrF after 54 iteration = 84.3454
# Average test loss after 54 iteration = 0.0210
# Total test chrF after 54 iteration = 84.7732
# Time for the iteration 74.8 seconds
#
#
# Average train loss after 55 iteration = 0.0057
# Total train chrF after 55 iteration = 89.9255
# Average val loss after 55 iteration = 0.0210
# Total val chrF after 55 iteration = 84.3460
# Average test loss after 55 iteration = 0.0210
# Total test chrF after 55 iteration = 84.7498
# Time for the iteration 74.6 seconds
#
#
# Average train loss after 56 iteration = 0.0056
# Total train chrF after 56 iteration = 89.9525
# Average val loss after 56 iteration = 0.0210
# Total val chrF after 56 iteration = 84.3556
# Average test loss after 56 iteration = 0.0211
# Total test chrF after 56 iteration = 84.7787
# Time for the iteration 74.8 seconds
#
#
# Average train loss after 57 iteration = 0.0056
# Total train chrF after 57 iteration = 89.9767
# Average val loss after 57 iteration = 0.0211
# Total val chrF after 57 iteration = 84.3730
# Average test loss after 57 iteration = 0.0212
# Total test chrF after 57 iteration = 84.8377
# Time for the iteration 75.3 seconds
#
#
# Average train loss after 58 iteration = 0.0055
# Total train chrF after 58 iteration = 90.0012
# Average val loss after 58 iteration = 0.0212
# Total val chrF after 58 iteration = 84.3624
# Average test loss after 58 iteration = 0.0212
# Total test chrF after 58 iteration = 84.7531
# Time for the iteration 75.4 seconds
#
#
# Average train loss after 59 iteration = 0.0055
# Total train chrF after 59 iteration = 90.0291
# Average val loss after 59 iteration = 0.0212
# Total val chrF after 59 iteration = 84.3198
# Average test loss after 59 iteration = 0.0213
# Total test chrF after 59 iteration = 84.7369
# Time for the iteration 74.9 seconds
#
#
# Average train loss after 60 iteration = 0.0054
# Total train chrF after 60 iteration = 90.0529
# Average val loss after 60 iteration = 0.0213
# Total val chrF after 60 iteration = 84.3075
# Average test loss after 60 iteration = 0.0214
# Total test chrF after 60 iteration = 84.7529
# Time for the iteration 75.2 seconds
#
#
# Average train loss after 61 iteration = 0.0054
# Total train chrF after 61 iteration = 90.0751
# Average val loss after 61 iteration = 0.0214
# Total val chrF after 61 iteration = 84.3086
# Average test loss after 61 iteration = 0.0215
# Total test chrF after 61 iteration = 84.7384
# Time for the iteration 75.1 seconds
#
#
# Average train loss after 62 iteration = 0.0053
# Total train chrF after 62 iteration = 90.0996
# Average val loss after 62 iteration = 0.0214
# Total val chrF after 62 iteration = 84.2561
# Average test loss after 62 iteration = 0.0215
# Total test chrF after 62 iteration = 84.7586
# Time for the iteration 75.4 seconds
#
#
# Average train loss after 63 iteration = 0.0053
# Total train chrF after 63 iteration = 90.1241
# Average val loss after 63 iteration = 0.0215
# Total val chrF after 63 iteration = 84.2270
# Average test loss after 63 iteration = 0.0216
# Total test chrF after 63 iteration = 84.7074
# Time for the iteration 75.0 seconds
#
#
# Average train loss after 64 iteration = 0.0052
# Total train chrF after 64 iteration = 90.1461
# Average val loss after 64 iteration = 0.0216
# Total val chrF after 64 iteration = 84.2559
# Average test loss after 64 iteration = 0.0217
# Total test chrF after 64 iteration = 84.6768
# Time for the iteration 75.0 seconds
#
#
# Average train loss after 65 iteration = 0.0052
# Total train chrF after 65 iteration = 90.1665
# Average val loss after 65 iteration = 0.0216
# Total val chrF after 65 iteration = 84.2417
# Average test loss after 65 iteration = 0.0218
# Total test chrF after 65 iteration = 84.7014
# Time for the iteration 75.0 seconds
#
#
# Average train loss after 66 iteration = 0.0052
# Total train chrF after 66 iteration = 90.1874
# Average val loss after 66 iteration = 0.0217
# Total val chrF after 66 iteration = 84.2177
# Average test loss after 66 iteration = 0.0218
# Total test chrF after 66 iteration = 84.7022
# Time for the iteration 75.0 seconds
#
#
# Average train loss after 67 iteration = 0.0051
# Total train chrF after 67 iteration = 90.2053
# Average val loss after 67 iteration = 0.0218
# Total val chrF after 67 iteration = 84.2200
# Average test loss after 67 iteration = 0.0219
# Total test chrF after 67 iteration = 84.6583
# Time for the iteration 74.9 seconds
#
#
# Average train loss after 68 iteration = 0.0051
# Total train chrF after 68 iteration = 90.2225
# Average val loss after 68 iteration = 0.0218
# Total val chrF after 68 iteration = 84.1898
# Average test loss after 68 iteration = 0.0220
# Total test chrF after 68 iteration = 84.5958
# Time for the iteration 75.2 seconds
#
#
# Average train loss after 69 iteration = 0.0051
# Total train chrF after 69 iteration = 90.2446
# Average val loss after 69 iteration = 0.0219
# Total val chrF after 69 iteration = 84.1504
# Average test loss after 69 iteration = 0.0221
# Total test chrF after 69 iteration = 84.6143
# Time for the iteration 74.9 seconds
#
#
# Average train loss after 70 iteration = 0.0050
# Total train chrF after 70 iteration = 90.2634
# Average val loss after 70 iteration = 0.0220
# Total val chrF after 70 iteration = 84.1233
# Average test loss after 70 iteration = 0.0221
# Total test chrF after 70 iteration = 84.6102
# Time for the iteration 75.3 seconds
#
#
# Average train loss after 71 iteration = 0.0050
# Total train chrF after 71 iteration = 90.2840
# Average val loss after 71 iteration = 0.0220
# Total val chrF after 71 iteration = 84.1073
# Average test loss after 71 iteration = 0.0222
# Total test chrF after 71 iteration = 84.6149
# Time for the iteration 75.1 seconds
#
#
# Average train loss after 72 iteration = 0.0049
# Total train chrF after 72 iteration = 90.3011
# Average val loss after 72 iteration = 0.0221
# Total val chrF after 72 iteration = 84.1477
# Average test loss after 72 iteration = 0.0223
# Total test chrF after 72 iteration = 84.5955
# Time for the iteration 75.4 seconds
#
#
# Average train loss after 73 iteration = 0.0049
# Total train chrF after 73 iteration = 90.3170
# Average val loss after 73 iteration = 0.0222
# Total val chrF after 73 iteration = 84.1188
# Average test loss after 73 iteration = 0.0224
# Total test chrF after 73 iteration = 84.6115
# Time for the iteration 75.4 seconds
#
#
# Average train loss after 74 iteration = 0.0049
# Total train chrF after 74 iteration = 90.3346
# Average val loss after 74 iteration = 0.0222
# Total val chrF after 74 iteration = 84.1043
# Average test loss after 74 iteration = 0.0224
# Total test chrF after 74 iteration = 84.6157
# Time for the iteration 75.1 seconds
#
#
#
#
# Aborting since there hasn't been much progress
# <Figure size 640x480 with 1 Axes>
# <Figure size 640x480 with 1 Axes>

# %%
language = "shi"
task_name = "all_teacher_general"
vocab_size = 4999
num_epochs = 100
batch_size = 32
model = "50_1"
optimizer = "Adam"
metric = "chrF"

# %%
from IPython.display import Image

Image("curves/{}_{}_{}_{}_{}_loss.png".format(language, task_name, vocab_size, num_epochs, batch_size))

# %%
Image("curves/{}_{}_{}_{}_{}_{}.png".format(language, task_name, vocab_size, num_epochs, batch_size, metric))

# %%
print("{}.{}.{}.{}.{}.{}.{}".format(language, task_name, vocab_size, num_epochs, batch_size, model, optimizer))
# Out:
# shi.all_teacher_general.4999.100.32.50_1.Adam
