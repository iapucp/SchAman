# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
# %cd "drive/MyDrive/Tesis/scRNN"
# Out:
# /content/drive/MyDrive/Tesis/scRNN

# %%
import torch

torch.cuda.is_available()
# Out:
# True

# %%
# !pip install sacrebleu
# Out:
# Collecting sacrebleu
#   Downloading sacrebleu-2.0.0-py3-none-any.whl (90 kB)
#      |████████████████████████████████| 90 kB 5.8 MB/s
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from sacrebleu) (1.19.5)
# Requirement already satisfied: regex in /usr/local/lib/python3.7/dist-packages (from sacrebleu) (2019.12.20)
# Collecting colorama
#   Downloading colorama-0.4.4-py2.py3-none-any.whl (16 kB)
# Requirement already satisfied: tabulate>=0.8.9 in /usr/local/lib/python3.7/dist-packages (from sacrebleu) (0.8.9)
# Collecting portalocker
#   Downloading portalocker-2.3.2-py2.py3-none-any.whl (15 kB)
# Installing collected packages: portalocker, colorama, sacrebleu
# Successfully installed colorama-0.4.4 portalocker-2.3.2 sacrebleu-2.0.0

# %%
# !python3 train.py --language shi --task-name unnorm_teacher_general --num-epochs 100 --batch-size 32 --vocab-size 4999 --new-vocab --train --train-sentences-errors-file shi.unnorm_teacher_general.train.sentences.errors.txt --train-sentences-file shi.unnorm_teacher_general.train.sentences.txt --val-sentences-errors-file shi.teacher_general.val.sentences.errors.txt --val-sentences-file shi.teacher_general.val.sentences.txt --test-sentences-errors-file shi.teacher_general.test.sentences.errors.txt --test-sentences-file shi.teacher_general.test.sentences.txt --metric chrF --save
# Out:
# Parameters
# {'language': 'shi', 'task_name': 'unnorm_teacher_general', 'vocab_size': 4999, 'num_epochs': 100, 'batch_size': 32, 'model_name': 'shi_random_20531_100_32', 'new_vocab': True, 'need_to_train': True, 'train_sentences_errors_file': 'shi.unnorm_teacher_general.train.sentences.errors.txt', 'train_sentences_file': 'shi.unnorm_teacher_general.train.sentences.txt', 'val_sentences_errors_file': 'shi.teacher_general.val.sentences.errors.txt', 'val_sentences_file': 'shi.teacher_general.val.sentences.txt', 'test_sentences_errors_file': 'shi.teacher_general.test.sentences.errors.txt', 'test_sentences_file': 'shi.teacher_general.test.sentences.txt', 'metric': 'chrF', 'save_model': True}
#
#
# Creating new vocabulary
# Len of w2i:  4999
# Len of i2w:  4999
# Len of char vocab:  33
#
#
# Initializing an only ScRNN model
#
#
# Training the model...
#
# Average train loss after 1 iteration = 0.1665
# Total train chrF after 1 iteration = 62.3465
# Average val loss after 1 iteration = 0.1449
# Total val chrF after 1 iteration = 77.3991
# Average test loss after 1 iteration = 0.1472
# Total test chrF after 1 iteration = 77.5463
# Dumping after  1
# Time for the iteration 17.0 seconds
#
#
# Average train loss after 2 iteration = 0.0896
# Total train chrF after 2 iteration = 71.4175
# Average val loss after 2 iteration = 0.0882
# Total val chrF after 2 iteration = 80.3616
# Average test loss after 2 iteration = 0.0898
# Total test chrF after 2 iteration = 80.8601
# Dumping after  2
# Time for the iteration 16.6 seconds
#
#
# Average train loss after 3 iteration = 0.0528
# Total train chrF after 3 iteration = 78.8533
# Average val loss after 3 iteration = 0.0655
# Total val chrF after 3 iteration = 81.6798
# Average test loss after 3 iteration = 0.0668
# Total test chrF after 3 iteration = 81.9599
# Dumping after  3
# Time for the iteration 16.7 seconds
#
#
# Average train loss after 4 iteration = 0.0339
# Total train chrF after 4 iteration = 82.9975
# Average val loss after 4 iteration = 0.0519
# Total val chrF after 4 iteration = 82.3993
# Average test loss after 4 iteration = 0.0530
# Total test chrF after 4 iteration = 82.8488
# Dumping after  4
# Time for the iteration 16.9 seconds
#
#
# Average train loss after 5 iteration = 0.0233
# Total train chrF after 5 iteration = 85.7111
# Average val loss after 5 iteration = 0.0433
# Total val chrF after 5 iteration = 82.7974
# Average test loss after 5 iteration = 0.0443
# Total test chrF after 5 iteration = 83.2198
# Dumping after  5
# Time for the iteration 16.8 seconds
#
#
# Average train loss after 6 iteration = 0.0168
# Total train chrF after 6 iteration = 87.5525
# Average val loss after 6 iteration = 0.0372
# Total val chrF after 6 iteration = 83.1340
# Average test loss after 6 iteration = 0.0381
# Total test chrF after 6 iteration = 83.6340
# Dumping after  6
# Time for the iteration 16.8 seconds
#
#
# Average train loss after 7 iteration = 0.0126
# Total train chrF after 7 iteration = 88.9092
# Average val loss after 7 iteration = 0.0325
# Total val chrF after 7 iteration = 83.4985
# Average test loss after 7 iteration = 0.0333
# Total test chrF after 7 iteration = 83.9622
# Dumping after  7
# Time for the iteration 16.9 seconds
#
#
# Average train loss after 8 iteration = 0.0099
# Total train chrF after 8 iteration = 89.9134
# Average val loss after 8 iteration = 0.0289
# Total val chrF after 8 iteration = 83.7729
# Average test loss after 8 iteration = 0.0297
# Total test chrF after 8 iteration = 84.1932
# Dumping after  8
# Time for the iteration 16.8 seconds
#
#
# Average train loss after 9 iteration = 0.0080
# Total train chrF after 9 iteration = 90.6429
# Average val loss after 9 iteration = 0.0260
# Total val chrF after 9 iteration = 84.1903
# Average test loss after 9 iteration = 0.0268
# Total test chrF after 9 iteration = 84.5085
# Dumping after  9
# Time for the iteration 16.9 seconds
#
#
# Average train loss after 10 iteration = 0.0067
# Total train chrF after 10 iteration = 91.1840
# Average val loss after 10 iteration = 0.0237
# Total val chrF after 10 iteration = 84.4887
# Average test loss after 10 iteration = 0.0244
# Total test chrF after 10 iteration = 84.8605
# Dumping after  10
# Time for the iteration 16.9 seconds
#
#
# Average train loss after 11 iteration = 0.0056
# Total train chrF after 11 iteration = 91.5876
# Average val loss after 11 iteration = 0.0218
# Total val chrF after 11 iteration = 84.7197
# Average test loss after 11 iteration = 0.0225
# Total test chrF after 11 iteration = 85.1504
# Dumping after  11
# Time for the iteration 16.8 seconds
#
#
# Average train loss after 12 iteration = 0.0049
# Total train chrF after 12 iteration = 91.8811
# Average val loss after 12 iteration = 0.0203
# Total val chrF after 12 iteration = 85.0018
# Average test loss after 12 iteration = 0.0210
# Total test chrF after 12 iteration = 85.4983
# Dumping after  12
# Time for the iteration 16.8 seconds
#
#
# Average train loss after 13 iteration = 0.0042
# Total train chrF after 13 iteration = 92.0891
# Average val loss after 13 iteration = 0.0190
# Total val chrF after 13 iteration = 85.3055
# Average test loss after 13 iteration = 0.0197
# Total test chrF after 13 iteration = 85.7519
# Dumping after  13
# Time for the iteration 16.7 seconds
#
#
# Average train loss after 14 iteration = 0.0037
# Total train chrF after 14 iteration = 92.2408
# Average val loss after 14 iteration = 0.0180
# Total val chrF after 14 iteration = 85.5726
# Average test loss after 14 iteration = 0.0186
# Total test chrF after 14 iteration = 85.9716
# Dumping after  14
# Time for the iteration 16.8 seconds
#
#
# Average train loss after 15 iteration = 0.0033
# Total train chrF after 15 iteration = 92.3651
# Average val loss after 15 iteration = 0.0171
# Total val chrF after 15 iteration = 85.7784
# Average test loss after 15 iteration = 0.0177
# Total test chrF after 15 iteration = 86.2616
# Dumping after  15
# Time for the iteration 16.9 seconds
#
#
# Average train loss after 16 iteration = 0.0030
# Total train chrF after 16 iteration = 92.4628
# Average val loss after 16 iteration = 0.0163
# Total val chrF after 16 iteration = 86.0169
# Average test loss after 16 iteration = 0.0169
# Total test chrF after 16 iteration = 86.5219
# Dumping after  16
# Time for the iteration 16.8 seconds
#
#
# Average train loss after 17 iteration = 0.0026
# Total train chrF after 17 iteration = 92.5379
# Average val loss after 17 iteration = 0.0157
# Total val chrF after 17 iteration = 86.1791
# Average test loss after 17 iteration = 0.0162
# Total test chrF after 17 iteration = 86.6755
# Dumping after  17
# Time for the iteration 16.7 seconds
#
#
# Average train loss after 18 iteration = 0.0024
# Total train chrF after 18 iteration = 92.6048
# Average val loss after 18 iteration = 0.0151
# Total val chrF after 18 iteration = 86.3634
# Average test loss after 18 iteration = 0.0157
# Total test chrF after 18 iteration = 86.9245
# Dumping after  18
# Time for the iteration 16.8 seconds
#
#
# Average train loss after 19 iteration = 0.0022
# Total train chrF after 19 iteration = 92.6688
# Average val loss after 19 iteration = 0.0146
# Total val chrF after 19 iteration = 86.5442
# Average test loss after 19 iteration = 0.0152
# Total test chrF after 19 iteration = 87.1491
# Dumping after  19
# Time for the iteration 16.7 seconds
#
#
# Average train loss after 20 iteration = 0.0020
# Total train chrF after 20 iteration = 92.7233
# Average val loss after 20 iteration = 0.0142
# Total val chrF after 20 iteration = 86.6974
# Average test loss after 20 iteration = 0.0148
# Total test chrF after 20 iteration = 87.3184
# Dumping after  20
# Time for the iteration 16.8 seconds
#
#
# Average train loss after 21 iteration = 0.0018
# Total train chrF after 21 iteration = 92.7717
# Average val loss after 21 iteration = 0.0139
# Total val chrF after 21 iteration = 86.7820
# Average test loss after 21 iteration = 0.0144
# Total test chrF after 21 iteration = 87.3643
# Dumping after  21
# Time for the iteration 16.9 seconds
#
#
# Average train loss after 22 iteration = 0.0016
# Total train chrF after 22 iteration = 92.8191
# Average val loss after 22 iteration = 0.0136
# Total val chrF after 22 iteration = 86.8742
# Average test loss after 22 iteration = 0.0141
# Total test chrF after 22 iteration = 87.5012
# Dumping after  22
# Time for the iteration 16.7 seconds
#
#
# Average train loss after 23 iteration = 0.0015
# Total train chrF after 23 iteration = 92.8562
# Average val loss after 23 iteration = 0.0133
# Total val chrF after 23 iteration = 86.9816
# Average test loss after 23 iteration = 0.0139
# Total test chrF after 23 iteration = 87.5432
# Dumping after  23
# Time for the iteration 16.8 seconds
#
#
# Average train loss after 24 iteration = 0.0013
# Total train chrF after 24 iteration = 92.8934
# Average val loss after 24 iteration = 0.0131
# Total val chrF after 24 iteration = 87.0821
# Average test loss after 24 iteration = 0.0137
# Total test chrF after 24 iteration = 87.6099
# Dumping after  24
# Time for the iteration 16.7 seconds
#
#
# Average train loss after 25 iteration = 0.0012
# Total train chrF after 25 iteration = 92.9190
# Average val loss after 25 iteration = 0.0129
# Total val chrF after 25 iteration = 87.1924
# Average test loss after 25 iteration = 0.0135
# Total test chrF after 25 iteration = 87.7237
# Dumping after  25
# Time for the iteration 16.9 seconds
#
#
# Average train loss after 26 iteration = 0.0011
# Total train chrF after 26 iteration = 92.9446
# Average val loss after 26 iteration = 0.0128
# Total val chrF after 26 iteration = 87.2697
# Average test loss after 26 iteration = 0.0134
# Total test chrF after 26 iteration = 87.7600
# Dumping after  26
# Time for the iteration 16.8 seconds
#
#
# Average train loss after 27 iteration = 0.0010
# Total train chrF after 27 iteration = 92.9725
# Average val loss after 27 iteration = 0.0126
# Total val chrF after 27 iteration = 87.3545
# Average test loss after 27 iteration = 0.0132
# Total test chrF after 27 iteration = 87.8141
# Dumping after  27
# Time for the iteration 16.9 seconds
#
#
# Average train loss after 28 iteration = 0.0009
# Total train chrF after 28 iteration = 92.9973
# Average val loss after 28 iteration = 0.0125
# Total val chrF after 28 iteration = 87.3515
# Average test loss after 28 iteration = 0.0131
# Total test chrF after 28 iteration = 87.8415
# Time for the iteration 16.8 seconds
#
#
# Average train loss after 29 iteration = 0.0009
# Total train chrF after 29 iteration = 93.0156
# Average val loss after 29 iteration = 0.0124
# Total val chrF after 29 iteration = 87.4686
# Average test loss after 29 iteration = 0.0130
# Total test chrF after 29 iteration = 87.9234
# Dumping after  29
# Time for the iteration 16.9 seconds
#
#
# Average train loss after 30 iteration = 0.0008
# Total train chrF after 30 iteration = 93.0371
# Average val loss after 30 iteration = 0.0123
# Total val chrF after 30 iteration = 87.5429
# Average test loss after 30 iteration = 0.0129
# Total test chrF after 30 iteration = 87.9906
# Dumping after  30
# Time for the iteration 16.9 seconds
#
#
# Average train loss after 31 iteration = 0.0007
# Total train chrF after 31 iteration = 93.0549
# Average val loss after 31 iteration = 0.0122
# Total val chrF after 31 iteration = 87.5879
# Average test loss after 31 iteration = 0.0128
# Total test chrF after 31 iteration = 88.0537
# Dumping after  31
# Time for the iteration 16.9 seconds
#
#
# Average train loss after 32 iteration = 0.0007
# Total train chrF after 32 iteration = 93.0688
# Average val loss after 32 iteration = 0.0121
# Total val chrF after 32 iteration = 87.6778
# Average test loss after 32 iteration = 0.0127
# Total test chrF after 32 iteration = 88.1140
# Dumping after  32
# Time for the iteration 16.7 seconds
#
#
# Average train loss after 33 iteration = 0.0006
# Total train chrF after 33 iteration = 93.0848
# Average val loss after 33 iteration = 0.0121
# Total val chrF after 33 iteration = 87.7556
# Average test loss after 33 iteration = 0.0126
# Total test chrF after 33 iteration = 88.1685
# Dumping after  33
# Time for the iteration 16.8 seconds
#
#
# Average train loss after 34 iteration = 0.0006
# Total train chrF after 34 iteration = 93.0956
# Average val loss after 34 iteration = 0.0120
# Total val chrF after 34 iteration = 87.7970
# Average test loss after 34 iteration = 0.0126
# Total test chrF after 34 iteration = 88.2226
# Dumping after  34
# Time for the iteration 16.8 seconds
#
#
# Average train loss after 35 iteration = 0.0005
# Total train chrF after 35 iteration = 93.1071
# Average val loss after 35 iteration = 0.0120
# Total val chrF after 35 iteration = 87.8029
# Average test loss after 35 iteration = 0.0125
# Total test chrF after 35 iteration = 88.2266
# Dumping after  35
# Time for the iteration 16.9 seconds
#
#
# Average train loss after 36 iteration = 0.0005
# Total train chrF after 36 iteration = 93.1160
# Average val loss after 36 iteration = 0.0120
# Total val chrF after 36 iteration = 87.8142
# Average test loss after 36 iteration = 0.0125
# Total test chrF after 36 iteration = 88.2667
# Dumping after  36
# Time for the iteration 16.8 seconds
#
#
# Average train loss after 37 iteration = 0.0004
# Total train chrF after 37 iteration = 93.1236
# Average val loss after 37 iteration = 0.0119
# Total val chrF after 37 iteration = 87.8229
# Average test loss after 37 iteration = 0.0125
# Total test chrF after 37 iteration = 88.3167
# Dumping after  37
# Time for the iteration 16.8 seconds
#
#
# Average train loss after 38 iteration = 0.0004
# Total train chrF after 38 iteration = 93.1288
# Average val loss after 38 iteration = 0.0119
# Total val chrF after 38 iteration = 87.8504
# Average test loss after 38 iteration = 0.0125
# Total test chrF after 38 iteration = 88.3295
# Dumping after  38
# Time for the iteration 16.8 seconds
#
#
# Average train loss after 39 iteration = 0.0004
# Total train chrF after 39 iteration = 93.1341
# Average val loss after 39 iteration = 0.0119
# Total val chrF after 39 iteration = 87.8133
# Average test loss after 39 iteration = 0.0125
# Total test chrF after 39 iteration = 88.3872
# Time for the iteration 17.0 seconds
#
#
# Average train loss after 40 iteration = 0.0003
# Total train chrF after 40 iteration = 93.1427
# Average val loss after 40 iteration = 0.0120
# Total val chrF after 40 iteration = 87.8605
# Average test loss after 40 iteration = 0.0126
# Total test chrF after 40 iteration = 88.4299
# Dumping after  40
# Time for the iteration 16.8 seconds
#
#
# Average train loss after 41 iteration = 0.0003
# Total train chrF after 41 iteration = 93.1442
# Average val loss after 41 iteration = 0.0120
# Total val chrF after 41 iteration = 87.8572
# Average test loss after 41 iteration = 0.0126
# Total test chrF after 41 iteration = 88.4418
# Time for the iteration 16.8 seconds
#
#
# Average train loss after 42 iteration = 0.0003
# Total train chrF after 42 iteration = 93.1497
# Average val loss after 42 iteration = 0.0120
# Total val chrF after 42 iteration = 87.8806
# Average test loss after 42 iteration = 0.0127
# Total test chrF after 42 iteration = 88.4299
# Dumping after  42
# Time for the iteration 16.8 seconds
#
#
# Average train loss after 43 iteration = 0.0002
# Total train chrF after 43 iteration = 93.1541
# Average val loss after 43 iteration = 0.0120
# Total val chrF after 43 iteration = 87.8890
# Average test loss after 43 iteration = 0.0127
# Total test chrF after 43 iteration = 88.4686
# Dumping after  43
# Time for the iteration 16.9 seconds
#
#
# Average train loss after 44 iteration = 0.0002
# Total train chrF after 44 iteration = 93.1576
# Average val loss after 44 iteration = 0.0121
# Total val chrF after 44 iteration = 87.9104
# Average test loss after 44 iteration = 0.0128
# Total test chrF after 44 iteration = 88.5007
# Dumping after  44
# Time for the iteration 17.0 seconds
#
#
# Average train loss after 45 iteration = 0.0002
# Total train chrF after 45 iteration = 93.1594
# Average val loss after 45 iteration = 0.0121
# Total val chrF after 45 iteration = 87.9018
# Average test loss after 45 iteration = 0.0129
# Total test chrF after 45 iteration = 88.4986
# Time for the iteration 16.8 seconds
#
#
# Average train loss after 46 iteration = 0.0002
# Total train chrF after 46 iteration = 93.1603
# Average val loss after 46 iteration = 0.0122
# Total val chrF after 46 iteration = 87.9250
# Average test loss after 46 iteration = 0.0130
# Total test chrF after 46 iteration = 88.5212
# Dumping after  46
# Time for the iteration 16.8 seconds
#
#
# Average train loss after 47 iteration = 0.0002
# Total train chrF after 47 iteration = 93.1624
# Average val loss after 47 iteration = 0.0123
# Total val chrF after 47 iteration = 87.9501
# Average test loss after 47 iteration = 0.0131
# Total test chrF after 47 iteration = 88.5355
# Dumping after  47
# Time for the iteration 16.8 seconds
#
#
# Average train loss after 48 iteration = 0.0002
# Total train chrF after 48 iteration = 93.1644
# Average val loss after 48 iteration = 0.0123
# Total val chrF after 48 iteration = 87.9645
# Average test loss after 48 iteration = 0.0132
# Total test chrF after 48 iteration = 88.5929
# Dumping after  48
# Time for the iteration 16.8 seconds
#
#
# Average train loss after 49 iteration = 0.0001
# Total train chrF after 49 iteration = 93.1658
# Average val loss after 49 iteration = 0.0124
# Total val chrF after 49 iteration = 87.9349
# Average test loss after 49 iteration = 0.0133
# Total test chrF after 49 iteration = 88.6014
# Time for the iteration 16.9 seconds
#
#
# Average train loss after 50 iteration = 0.0001
# Total train chrF after 50 iteration = 93.1668
# Average val loss after 50 iteration = 0.0125
# Total val chrF after 50 iteration = 87.9590
# Average test loss after 50 iteration = 0.0133
# Total test chrF after 50 iteration = 88.6044
# Time for the iteration 16.7 seconds
#
#
# Average train loss after 51 iteration = 0.0001
# Total train chrF after 51 iteration = 93.1676
# Average val loss after 51 iteration = 0.0125
# Total val chrF after 51 iteration = 87.9561
# Average test loss after 51 iteration = 0.0134
# Total test chrF after 51 iteration = 88.6019
# Time for the iteration 16.7 seconds
#
#
# Average train loss after 52 iteration = 0.0001
# Total train chrF after 52 iteration = 93.1695
# Average val loss after 52 iteration = 0.0126
# Total val chrF after 52 iteration = 87.9556
# Average test loss after 52 iteration = 0.0136
# Total test chrF after 52 iteration = 88.6086
# Time for the iteration 16.7 seconds
#
#
# Average train loss after 53 iteration = 0.0001
# Total train chrF after 53 iteration = 93.1701
# Average val loss after 53 iteration = 0.0127
# Total val chrF after 53 iteration = 87.9505
# Average test loss after 53 iteration = 0.0137
# Total test chrF after 53 iteration = 88.5808
# Time for the iteration 16.7 seconds
#
#
# Average train loss after 54 iteration = 0.0001
# Total train chrF after 54 iteration = 93.1710
# Average val loss after 54 iteration = 0.0128
# Total val chrF after 54 iteration = 87.9579
# Average test loss after 54 iteration = 0.0138
# Total test chrF after 54 iteration = 88.5474
# Time for the iteration 16.7 seconds
#
#
# Average train loss after 55 iteration = 0.0001
# Total train chrF after 55 iteration = 93.1721
# Average val loss after 55 iteration = 0.0129
# Total val chrF after 55 iteration = 88.0186
# Average test loss after 55 iteration = 0.0139
# Total test chrF after 55 iteration = 88.5253
# Dumping after  55
# Time for the iteration 16.7 seconds
#
#
# Average train loss after 56 iteration = 0.0001
# Total train chrF after 56 iteration = 93.1724
# Average val loss after 56 iteration = 0.0130
# Total val chrF after 56 iteration = 88.0186
# Average test loss after 56 iteration = 0.0140
# Total test chrF after 56 iteration = 88.5560
# Time for the iteration 16.7 seconds
#
#
# Average train loss after 57 iteration = 0.0001
# Total train chrF after 57 iteration = 93.1727
# Average val loss after 57 iteration = 0.0131
# Total val chrF after 57 iteration = 87.9946
# Average test loss after 57 iteration = 0.0141
# Total test chrF after 57 iteration = 88.5467
# Time for the iteration 16.7 seconds
#
#
# Average train loss after 58 iteration = 0.0001
# Total train chrF after 58 iteration = 93.1729
# Average val loss after 58 iteration = 0.0132
# Total val chrF after 58 iteration = 87.9654
# Average test loss after 58 iteration = 0.0142
# Total test chrF after 58 iteration = 88.5311
# Time for the iteration 16.8 seconds
#
#
# Average train loss after 59 iteration = 0.0001
# Total train chrF after 59 iteration = 93.1729
# Average val loss after 59 iteration = 0.0133
# Total val chrF after 59 iteration = 87.9086
# Average test loss after 59 iteration = 0.0143
# Total test chrF after 59 iteration = 88.5357
# Time for the iteration 16.7 seconds
#
#
# Average train loss after 60 iteration = 0.0000
# Total train chrF after 60 iteration = 93.1730
# Average val loss after 60 iteration = 0.0134
# Total val chrF after 60 iteration = 87.9096
# Average test loss after 60 iteration = 0.0145
# Total test chrF after 60 iteration = 88.5167
# Time for the iteration 16.7 seconds
#
#
# Average train loss after 61 iteration = 0.0000
# Total train chrF after 61 iteration = 93.1731
# Average val loss after 61 iteration = 0.0135
# Total val chrF after 61 iteration = 87.9113
# Average test loss after 61 iteration = 0.0146
# Total test chrF after 61 iteration = 88.5274
# Time for the iteration 16.8 seconds
#
#
# Average train loss after 62 iteration = 0.0000
# Total train chrF after 62 iteration = 93.1735
# Average val loss after 62 iteration = 0.0136
# Total val chrF after 62 iteration = 87.8989
# Average test loss after 62 iteration = 0.0147
# Total test chrF after 62 iteration = 88.5315
# Time for the iteration 16.7 seconds
#
#
# Average train loss after 63 iteration = 0.0000
# Total train chrF after 63 iteration = 93.1739
# Average val loss after 63 iteration = 0.0137
# Total val chrF after 63 iteration = 87.8759
# Average test loss after 63 iteration = 0.0148
# Total test chrF after 63 iteration = 88.5296
# Time for the iteration 16.8 seconds
#
#
# Average train loss after 64 iteration = 0.0000
# Total train chrF after 64 iteration = 93.1740
# Average val loss after 64 iteration = 0.0138
# Total val chrF after 64 iteration = 87.8707
# Average test loss after 64 iteration = 0.0150
# Total test chrF after 64 iteration = 88.5502
# Time for the iteration 16.9 seconds
#
#
# Average train loss after 65 iteration = 0.0000
# Total train chrF after 65 iteration = 93.1743
# Average val loss after 65 iteration = 0.0139
# Total val chrF after 65 iteration = 87.8517
# Average test loss after 65 iteration = 0.0151
# Total test chrF after 65 iteration = 88.5553
# Time for the iteration 16.6 seconds
#
#
# Average train loss after 66 iteration = 0.0000
# Total train chrF after 66 iteration = 93.1744
# Average val loss after 66 iteration = 0.0140
# Total val chrF after 66 iteration = 87.8723
# Average test loss after 66 iteration = 0.0152
# Total test chrF after 66 iteration = 88.5451
# Time for the iteration 16.7 seconds
#
#
# Average train loss after 67 iteration = 0.0000
# Total train chrF after 67 iteration = 93.1744
# Average val loss after 67 iteration = 0.0141
# Total val chrF after 67 iteration = 87.8979
# Average test loss after 67 iteration = 0.0153
# Total test chrF after 67 iteration = 88.5644
# Time for the iteration 16.7 seconds
#
#
# Average train loss after 68 iteration = 0.0000
# Total train chrF after 68 iteration = 93.1747
# Average val loss after 68 iteration = 0.0141
# Total val chrF after 68 iteration = 87.9180
# Average test loss after 68 iteration = 0.0153
# Total test chrF after 68 iteration = 88.4830
# Time for the iteration 16.8 seconds
#
#
# Average train loss after 69 iteration = 0.0000
# Total train chrF after 69 iteration = 93.1748
# Average val loss after 69 iteration = 0.0143
# Total val chrF after 69 iteration = 87.8679
# Average test loss after 69 iteration = 0.0154
# Total test chrF after 69 iteration = 88.5256
# Time for the iteration 16.7 seconds
#
#
# Average train loss after 70 iteration = 0.0000
# Total train chrF after 70 iteration = 93.1749
# Average val loss after 70 iteration = 0.0144
# Total val chrF after 70 iteration = 87.8014
# Average test loss after 70 iteration = 0.0156
# Total test chrF after 70 iteration = 88.5221
# Time for the iteration 16.8 seconds
#
#
# Average train loss after 71 iteration = 0.0000
# Total train chrF after 71 iteration = 93.1742
# Average val loss after 71 iteration = 0.0144
# Total val chrF after 71 iteration = 87.8379
# Average test loss after 71 iteration = 0.0156
# Total test chrF after 71 iteration = 88.4880
# Time for the iteration 16.6 seconds
#
#
# Average train loss after 72 iteration = 0.0000
# Total train chrF after 72 iteration = 93.1749
# Average val loss after 72 iteration = 0.0145
# Total val chrF after 72 iteration = 87.8488
# Average test loss after 72 iteration = 0.0157
# Total test chrF after 72 iteration = 88.4746
# Time for the iteration 16.6 seconds
#
#
# Average train loss after 73 iteration = 0.0000
# Total train chrF after 73 iteration = 93.1757
# Average val loss after 73 iteration = 0.0146
# Total val chrF after 73 iteration = 87.8241
# Average test loss after 73 iteration = 0.0158
# Total test chrF after 73 iteration = 88.5023
# Time for the iteration 16.8 seconds
#
#
# Average train loss after 74 iteration = 0.0000
# Total train chrF after 74 iteration = 93.1757
# Average val loss after 74 iteration = 0.0148
# Total val chrF after 74 iteration = 87.8765
# Average test loss after 74 iteration = 0.0160
# Total test chrF after 74 iteration = 88.4835
# Time for the iteration 16.7 seconds
#
#
# Average train loss after 75 iteration = 0.0000
# Total train chrF after 75 iteration = 93.1745
# Average val loss after 75 iteration = 0.0148
# Total val chrF after 75 iteration = 87.8891
# Average test loss after 75 iteration = 0.0161
# Total test chrF after 75 iteration = 88.5068
# Time for the iteration 16.7 seconds
#
#
# Average train loss after 76 iteration = 0.0000
# Total train chrF after 76 iteration = 93.1755
# Average val loss after 76 iteration = 0.0149
# Total val chrF after 76 iteration = 87.9158
# Average test loss after 76 iteration = 0.0162
# Total test chrF after 76 iteration = 88.4765
# Time for the iteration 16.7 seconds
#
#
# Average train loss after 77 iteration = 0.0000
# Total train chrF after 77 iteration = 93.1759
# Average val loss after 77 iteration = 0.0150
# Total val chrF after 77 iteration = 87.9322
# Average test loss after 77 iteration = 0.0163
# Total test chrF after 77 iteration = 88.5103
# Time for the iteration 16.7 seconds
#
#
# Average train loss after 78 iteration = 0.0000
# Total train chrF after 78 iteration = 93.1759
# Average val loss after 78 iteration = 0.0152
# Total val chrF after 78 iteration = 87.8825
# Average test loss after 78 iteration = 0.0165
# Total test chrF after 78 iteration = 88.4974
# Time for the iteration 16.8 seconds
#
#
# Average train loss after 79 iteration = 0.0000
# Total train chrF after 79 iteration = 93.1759
# Average val loss after 79 iteration = 0.0153
# Total val chrF after 79 iteration = 87.8667
# Average test loss after 79 iteration = 0.0167
# Total test chrF after 79 iteration = 88.4703
# Time for the iteration 16.9 seconds
#
#
# Average train loss after 80 iteration = 0.0000
# Total train chrF after 80 iteration = 93.1759
# Average val loss after 80 iteration = 0.0155
# Total val chrF after 80 iteration = 87.8531
# Average test loss after 80 iteration = 0.0169
# Total test chrF after 80 iteration = 88.4384
# Time for the iteration 16.8 seconds
#
#
# Average train loss after 81 iteration = 0.0000
# Total train chrF after 81 iteration = 93.1759
# Average val loss after 81 iteration = 0.0157
# Total val chrF after 81 iteration = 87.8799
# Average test loss after 81 iteration = 0.0171
# Total test chrF after 81 iteration = 88.4131
# Time for the iteration 16.6 seconds
#
#
# Average train loss after 82 iteration = 0.0000
# Total train chrF after 82 iteration = 93.1759
# Average val loss after 82 iteration = 0.0158
# Total val chrF after 82 iteration = 87.8458
# Average test loss after 82 iteration = 0.0173
# Total test chrF after 82 iteration = 88.4264
# Time for the iteration 16.8 seconds
#
#
#
#
# Aborting since there hasn't been much progress
# <Figure size 640x480 with 1 Axes>
# <Figure size 640x480 with 1 Axes>

# %%
language = "shi"
task_name = "unnorm_teacher_general"
vocab_size = 4999
num_epochs = 100
batch_size = 32
model = "50_1"
optimizer = "Adam"
metric = "chrF"

# %%
from IPython.display import Image

Image("curves/{}_{}_{}_{}_{}_loss.png".format(language, task_name, vocab_size, num_epochs, batch_size))

# %%
Image("curves/{}_{}_{}_{}_{}_{}.png".format(language, task_name, vocab_size, num_epochs, batch_size, metric))

# %%
print("{}.{}.{}.{}.{}.{}.{}".format(language, task_name, vocab_size, num_epochs, batch_size, model, optimizer))
# Out:
# shi.unnorm_teacher_general.4999.100.32.50_1.Adam
