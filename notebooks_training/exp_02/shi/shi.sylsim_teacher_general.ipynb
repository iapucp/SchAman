# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
# %cd "drive/MyDrive/Tesis/scRNN"
# Out:
# /content/drive/MyDrive/Tesis/scRNN

# %%
import torch

torch.cuda.is_available()
# Out:
# True

# %%
# !pip install sacrebleu
# Out:
# Collecting sacrebleu
#   Downloading sacrebleu-2.0.0-py3-none-any.whl (90 kB)
#      |████████████████████████████████| 90 kB 3.3 MB/s
# Requirement already satisfied: tabulate>=0.8.9 in /usr/local/lib/python3.7/dist-packages (from sacrebleu) (0.8.9)
# Collecting portalocker
#   Downloading portalocker-2.3.2-py2.py3-none-any.whl (15 kB)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from sacrebleu) (1.19.5)
# Requirement already satisfied: regex in /usr/local/lib/python3.7/dist-packages (from sacrebleu) (2019.12.20)
# Collecting colorama
#   Downloading colorama-0.4.4-py2.py3-none-any.whl (16 kB)
# Installing collected packages: portalocker, colorama, sacrebleu
# Successfully installed colorama-0.4.4 portalocker-2.3.2 sacrebleu-2.0.0

# %%
# !python3 train.py --language shi --task-name sylsim_teacher_general --num-epochs 100 --batch-size 32 --vocab-size 4999 --new-vocab --train --train-sentences-errors-file shi.sylsim_teacher_general.train.sentences.errors.txt --train-sentences-file shi.sylsim_teacher_general.train.sentences.txt --val-sentences-errors-file shi.teacher_general.val.sentences.errors.txt --val-sentences-file shi.teacher_general.val.sentences.txt --test-sentences-errors-file shi.teacher_general.test.sentences.errors.txt --test-sentences-file shi.teacher_general.test.sentences.txt --metric chrF --save
# Out:
# Parameters
# {'language': 'shi', 'task_name': 'sylsim_teacher_general', 'vocab_size': 4999, 'num_epochs': 100, 'batch_size': 32, 'model_name': 'shi_random_20531_100_32', 'new_vocab': True, 'need_to_train': True, 'train_sentences_errors_file': 'shi.sylsim_teacher_general.train.sentences.errors.txt', 'train_sentences_file': 'shi.sylsim_teacher_general.train.sentences.txt', 'val_sentences_errors_file': 'shi.teacher_general.val.sentences.errors.txt', 'val_sentences_file': 'shi.teacher_general.val.sentences.txt', 'test_sentences_errors_file': 'shi.teacher_general.test.sentences.errors.txt', 'test_sentences_file': 'shi.teacher_general.test.sentences.txt', 'metric': 'chrF', 'save_model': True}
#
#
# Creating new vocabulary
# Len of w2i:  4999
# Len of i2w:  4999
# Len of char vocab:  33
#
#
# Initializing an only ScRNN model
#
#
# Training the model...
#
# Average train loss after 1 iteration = 0.1763
# Total train chrF after 1 iteration = 54.1908
# Average val loss after 1 iteration = 0.1688
# Total val chrF after 1 iteration = 75.7048
# Average test loss after 1 iteration = 0.1724
# Total test chrF after 1 iteration = 75.9184
# Dumping after  1
# Time for the iteration 20.3 seconds
#
#
# Average train loss after 2 iteration = 0.1206
# Total train chrF after 2 iteration = 59.3130
# Average val loss after 2 iteration = 0.1093
# Total val chrF after 2 iteration = 76.4631
# Average test loss after 2 iteration = 0.1120
# Total test chrF after 2 iteration = 76.5301
# Dumping after  2
# Time for the iteration 19.9 seconds
#
#
# Average train loss after 3 iteration = 0.0870
# Total train chrF after 3 iteration = 64.3877
# Average val loss after 3 iteration = 0.0819
# Total val chrF after 3 iteration = 78.4010
# Average test loss after 3 iteration = 0.0839
# Total test chrF after 3 iteration = 78.7511
# Dumping after  3
# Time for the iteration 20.0 seconds
#
#
# Average train loss after 4 iteration = 0.0672
# Total train chrF after 4 iteration = 67.9477
# Average val loss after 4 iteration = 0.0632
# Total val chrF after 4 iteration = 79.6805
# Average test loss after 4 iteration = 0.0649
# Total test chrF after 4 iteration = 79.9003
# Dumping after  4
# Time for the iteration 20.0 seconds
#
#
# Average train loss after 5 iteration = 0.0549
# Total train chrF after 5 iteration = 70.3969
# Average val loss after 5 iteration = 0.0521
# Total val chrF after 5 iteration = 80.1992
# Average test loss after 5 iteration = 0.0535
# Total test chrF after 5 iteration = 80.6847
# Dumping after  5
# Time for the iteration 20.0 seconds
#
#
# Average train loss after 6 iteration = 0.0467
# Total train chrF after 6 iteration = 72.2776
# Average val loss after 6 iteration = 0.0444
# Total val chrF after 6 iteration = 80.7263
# Average test loss after 6 iteration = 0.0455
# Total test chrF after 6 iteration = 81.3307
# Dumping after  6
# Time for the iteration 20.1 seconds
#
#
# Average train loss after 7 iteration = 0.0408
# Total train chrF after 7 iteration = 73.7755
# Average val loss after 7 iteration = 0.0386
# Total val chrF after 7 iteration = 81.1839
# Average test loss after 7 iteration = 0.0396
# Total test chrF after 7 iteration = 81.5817
# Dumping after  7
# Time for the iteration 20.0 seconds
#
#
# Average train loss after 8 iteration = 0.0364
# Total train chrF after 8 iteration = 75.1219
# Average val loss after 8 iteration = 0.0343
# Total val chrF after 8 iteration = 81.4468
# Average test loss after 8 iteration = 0.0351
# Total test chrF after 8 iteration = 81.8141
# Dumping after  8
# Time for the iteration 20.0 seconds
#
#
# Average train loss after 9 iteration = 0.0330
# Total train chrF after 9 iteration = 76.2711
# Average val loss after 9 iteration = 0.0310
# Total val chrF after 9 iteration = 81.7604
# Average test loss after 9 iteration = 0.0316
# Total test chrF after 9 iteration = 82.0329
# Dumping after  9
# Time for the iteration 20.1 seconds
#
#
# Average train loss after 10 iteration = 0.0303
# Total train chrF after 10 iteration = 77.2831
# Average val loss after 10 iteration = 0.0284
# Total val chrF after 10 iteration = 82.0249
# Average test loss after 10 iteration = 0.0290
# Total test chrF after 10 iteration = 82.3699
# Dumping after  10
# Time for the iteration 20.1 seconds
#
#
# Average train loss after 11 iteration = 0.0281
# Total train chrF after 11 iteration = 78.2258
# Average val loss after 11 iteration = 0.0265
# Total val chrF after 11 iteration = 82.2468
# Average test loss after 11 iteration = 0.0270
# Total test chrF after 11 iteration = 82.5676
# Dumping after  11
# Time for the iteration 20.1 seconds
#
#
# Average train loss after 12 iteration = 0.0263
# Total train chrF after 12 iteration = 79.0851
# Average val loss after 12 iteration = 0.0249
# Total val chrF after 12 iteration = 82.5282
# Average test loss after 12 iteration = 0.0253
# Total test chrF after 12 iteration = 82.9182
# Dumping after  12
# Time for the iteration 20.2 seconds
#
#
# Average train loss after 13 iteration = 0.0248
# Total train chrF after 13 iteration = 79.7989
# Average val loss after 13 iteration = 0.0236
# Total val chrF after 13 iteration = 82.7635
# Average test loss after 13 iteration = 0.0240
# Total test chrF after 13 iteration = 83.0953
# Dumping after  13
# Time for the iteration 20.1 seconds
#
#
# Average train loss after 14 iteration = 0.0235
# Total train chrF after 14 iteration = 80.4828
# Average val loss after 14 iteration = 0.0226
# Total val chrF after 14 iteration = 82.9625
# Average test loss after 14 iteration = 0.0230
# Total test chrF after 14 iteration = 83.3289
# Dumping after  14
# Time for the iteration 20.2 seconds
#
#
# Average train loss after 15 iteration = 0.0223
# Total train chrF after 15 iteration = 81.1193
# Average val loss after 15 iteration = 0.0218
# Total val chrF after 15 iteration = 83.1011
# Average test loss after 15 iteration = 0.0222
# Total test chrF after 15 iteration = 83.3888
# Dumping after  15
# Time for the iteration 20.1 seconds
#
#
# Average train loss after 16 iteration = 0.0213
# Total train chrF after 16 iteration = 81.6568
# Average val loss after 16 iteration = 0.0211
# Total val chrF after 16 iteration = 83.1486
# Average test loss after 16 iteration = 0.0215
# Total test chrF after 16 iteration = 83.5023
# Dumping after  16
# Time for the iteration 20.2 seconds
#
#
# Average train loss after 17 iteration = 0.0204
# Total train chrF after 17 iteration = 82.1771
# Average val loss after 17 iteration = 0.0205
# Total val chrF after 17 iteration = 83.1760
# Average test loss after 17 iteration = 0.0209
# Total test chrF after 17 iteration = 83.5622
# Dumping after  17
# Time for the iteration 20.2 seconds
#
#
# Average train loss after 18 iteration = 0.0196
# Total train chrF after 18 iteration = 82.6253
# Average val loss after 18 iteration = 0.0201
# Total val chrF after 18 iteration = 83.3617
# Average test loss after 18 iteration = 0.0204
# Total test chrF after 18 iteration = 83.6784
# Dumping after  18
# Time for the iteration 20.3 seconds
#
#
# Average train loss after 19 iteration = 0.0188
# Total train chrF after 19 iteration = 83.0615
# Average val loss after 19 iteration = 0.0196
# Total val chrF after 19 iteration = 83.3995
# Average test loss after 19 iteration = 0.0200
# Total test chrF after 19 iteration = 83.7787
# Dumping after  19
# Time for the iteration 20.2 seconds
#
#
# Average train loss after 20 iteration = 0.0181
# Total train chrF after 20 iteration = 83.4766
# Average val loss after 20 iteration = 0.0193
# Total val chrF after 20 iteration = 83.3297
# Average test loss after 20 iteration = 0.0197
# Total test chrF after 20 iteration = 83.9023
# Time for the iteration 20.4 seconds
#
#
# Average train loss after 21 iteration = 0.0175
# Total train chrF after 21 iteration = 83.8345
# Average val loss after 21 iteration = 0.0190
# Total val chrF after 21 iteration = 83.3317
# Average test loss after 21 iteration = 0.0194
# Total test chrF after 21 iteration = 83.9577
# Time for the iteration 20.2 seconds
#
#
# Average train loss after 22 iteration = 0.0169
# Total train chrF after 22 iteration = 84.1694
# Average val loss after 22 iteration = 0.0187
# Total val chrF after 22 iteration = 83.3674
# Average test loss after 22 iteration = 0.0191
# Total test chrF after 22 iteration = 84.0104
# Time for the iteration 20.1 seconds
#
#
# Average train loss after 23 iteration = 0.0163
# Total train chrF after 23 iteration = 84.4582
# Average val loss after 23 iteration = 0.0185
# Total val chrF after 23 iteration = 83.4996
# Average test loss after 23 iteration = 0.0189
# Total test chrF after 23 iteration = 83.9669
# Dumping after  23
# Time for the iteration 20.2 seconds
#
#
# Average train loss after 24 iteration = 0.0158
# Total train chrF after 24 iteration = 84.7482
# Average val loss after 24 iteration = 0.0183
# Total val chrF after 24 iteration = 83.5113
# Average test loss after 24 iteration = 0.0187
# Total test chrF after 24 iteration = 84.0882
# Dumping after  24
# Time for the iteration 20.2 seconds
#
#
# Average train loss after 25 iteration = 0.0153
# Total train chrF after 25 iteration = 85.0024
# Average val loss after 25 iteration = 0.0182
# Total val chrF after 25 iteration = 83.4743
# Average test loss after 25 iteration = 0.0186
# Total test chrF after 25 iteration = 84.2191
# Time for the iteration 20.2 seconds
#
#
# Average train loss after 26 iteration = 0.0149
# Total train chrF after 26 iteration = 85.2797
# Average val loss after 26 iteration = 0.0180
# Total val chrF after 26 iteration = 83.4266
# Average test loss after 26 iteration = 0.0185
# Total test chrF after 26 iteration = 84.2666
# Time for the iteration 20.0 seconds
#
#
# Average train loss after 27 iteration = 0.0145
# Total train chrF after 27 iteration = 85.5129
# Average val loss after 27 iteration = 0.0179
# Total val chrF after 27 iteration = 83.4160
# Average test loss after 27 iteration = 0.0184
# Total test chrF after 27 iteration = 84.2769
# Time for the iteration 20.0 seconds
#
#
# Average train loss after 28 iteration = 0.0140
# Total train chrF after 28 iteration = 85.7339
# Average val loss after 28 iteration = 0.0179
# Total val chrF after 28 iteration = 83.4209
# Average test loss after 28 iteration = 0.0183
# Total test chrF after 28 iteration = 84.2594
# Time for the iteration 20.0 seconds
#
#
# Average train loss after 29 iteration = 0.0137
# Total train chrF after 29 iteration = 85.9425
# Average val loss after 29 iteration = 0.0178
# Total val chrF after 29 iteration = 83.3681
# Average test loss after 29 iteration = 0.0182
# Total test chrF after 29 iteration = 84.2533
# Time for the iteration 20.1 seconds
#
#
# Average train loss after 30 iteration = 0.0133
# Total train chrF after 30 iteration = 86.1397
# Average val loss after 30 iteration = 0.0177
# Total val chrF after 30 iteration = 83.3694
# Average test loss after 30 iteration = 0.0182
# Total test chrF after 30 iteration = 84.2675
# Time for the iteration 20.1 seconds
#
#
# Average train loss after 31 iteration = 0.0129
# Total train chrF after 31 iteration = 86.3431
# Average val loss after 31 iteration = 0.0177
# Total val chrF after 31 iteration = 83.3474
# Average test loss after 31 iteration = 0.0181
# Total test chrF after 31 iteration = 84.2898
# Time for the iteration 20.2 seconds
#
#
# Average train loss after 32 iteration = 0.0126
# Total train chrF after 32 iteration = 86.5271
# Average val loss after 32 iteration = 0.0177
# Total val chrF after 32 iteration = 83.4327
# Average test loss after 32 iteration = 0.0181
# Total test chrF after 32 iteration = 84.2845
# Time for the iteration 20.0 seconds
#
#
# Average train loss after 33 iteration = 0.0123
# Total train chrF after 33 iteration = 86.6917
# Average val loss after 33 iteration = 0.0177
# Total val chrF after 33 iteration = 83.4428
# Average test loss after 33 iteration = 0.0181
# Total test chrF after 33 iteration = 84.2420
# Time for the iteration 20.1 seconds
#
#
# Average train loss after 34 iteration = 0.0120
# Total train chrF after 34 iteration = 86.8660
# Average val loss after 34 iteration = 0.0177
# Total val chrF after 34 iteration = 83.4261
# Average test loss after 34 iteration = 0.0181
# Total test chrF after 34 iteration = 84.2469
# Time for the iteration 20.0 seconds
#
#
# Average train loss after 35 iteration = 0.0117
# Total train chrF after 35 iteration = 87.0238
# Average val loss after 35 iteration = 0.0177
# Total val chrF after 35 iteration = 83.4481
# Average test loss after 35 iteration = 0.0181
# Total test chrF after 35 iteration = 84.2177
# Time for the iteration 20.1 seconds
#
#
# Average train loss after 36 iteration = 0.0114
# Total train chrF after 36 iteration = 87.1795
# Average val loss after 36 iteration = 0.0177
# Total val chrF after 36 iteration = 83.4060
# Average test loss after 36 iteration = 0.0181
# Total test chrF after 36 iteration = 84.2737
# Time for the iteration 20.1 seconds
#
#
# Average train loss after 37 iteration = 0.0112
# Total train chrF after 37 iteration = 87.3302
# Average val loss after 37 iteration = 0.0177
# Total val chrF after 37 iteration = 83.4329
# Average test loss after 37 iteration = 0.0181
# Total test chrF after 37 iteration = 84.2481
# Time for the iteration 19.9 seconds
#
#
# Average train loss after 38 iteration = 0.0109
# Total train chrF after 38 iteration = 87.4628
# Average val loss after 38 iteration = 0.0177
# Total val chrF after 38 iteration = 83.4425
# Average test loss after 38 iteration = 0.0181
# Total test chrF after 38 iteration = 84.2547
# Time for the iteration 20.2 seconds
#
#
# Average train loss after 39 iteration = 0.0107
# Total train chrF after 39 iteration = 87.5888
# Average val loss after 39 iteration = 0.0178
# Total val chrF after 39 iteration = 83.4262
# Average test loss after 39 iteration = 0.0182
# Total test chrF after 39 iteration = 84.2158
# Time for the iteration 20.1 seconds
#
#
# Average train loss after 40 iteration = 0.0104
# Total train chrF after 40 iteration = 87.7252
# Average val loss after 40 iteration = 0.0178
# Total val chrF after 40 iteration = 83.3792
# Average test loss after 40 iteration = 0.0182
# Total test chrF after 40 iteration = 84.1836
# Time for the iteration 20.1 seconds
#
#
# Average train loss after 41 iteration = 0.0102
# Total train chrF after 41 iteration = 87.8582
# Average val loss after 41 iteration = 0.0178
# Total val chrF after 41 iteration = 83.4119
# Average test loss after 41 iteration = 0.0183
# Total test chrF after 41 iteration = 84.1854
# Time for the iteration 20.1 seconds
#
#
# Average train loss after 42 iteration = 0.0100
# Total train chrF after 42 iteration = 87.9920
# Average val loss after 42 iteration = 0.0179
# Total val chrF after 42 iteration = 83.3926
# Average test loss after 42 iteration = 0.0183
# Total test chrF after 42 iteration = 84.1945
# Time for the iteration 20.0 seconds
#
#
# Average train loss after 43 iteration = 0.0098
# Total train chrF after 43 iteration = 88.1021
# Average val loss after 43 iteration = 0.0179
# Total val chrF after 43 iteration = 83.3818
# Average test loss after 43 iteration = 0.0183
# Total test chrF after 43 iteration = 84.2389
# Time for the iteration 20.0 seconds
#
#
# Average train loss after 44 iteration = 0.0096
# Total train chrF after 44 iteration = 88.2119
# Average val loss after 44 iteration = 0.0180
# Total val chrF after 44 iteration = 83.3777
# Average test loss after 44 iteration = 0.0184
# Total test chrF after 44 iteration = 84.2594
# Time for the iteration 20.2 seconds
#
#
# Average train loss after 45 iteration = 0.0094
# Total train chrF after 45 iteration = 88.3188
# Average val loss after 45 iteration = 0.0181
# Total val chrF after 45 iteration = 83.3339
# Average test loss after 45 iteration = 0.0185
# Total test chrF after 45 iteration = 84.2011
# Time for the iteration 20.0 seconds
#
#
# Average train loss after 46 iteration = 0.0092
# Total train chrF after 46 iteration = 88.4262
# Average val loss after 46 iteration = 0.0181
# Total val chrF after 46 iteration = 83.2913
# Average test loss after 46 iteration = 0.0185
# Total test chrF after 46 iteration = 84.1926
# Time for the iteration 20.0 seconds
#
#
# Average train loss after 47 iteration = 0.0090
# Total train chrF after 47 iteration = 88.5255
# Average val loss after 47 iteration = 0.0182
# Total val chrF after 47 iteration = 83.2359
# Average test loss after 47 iteration = 0.0186
# Total test chrF after 47 iteration = 84.1679
# Time for the iteration 20.1 seconds
#
#
# Average train loss after 48 iteration = 0.0088
# Total train chrF after 48 iteration = 88.6269
# Average val loss after 48 iteration = 0.0183
# Total val chrF after 48 iteration = 83.2175
# Average test loss after 48 iteration = 0.0186
# Total test chrF after 48 iteration = 84.0950
# Time for the iteration 20.1 seconds
#
#
# Average train loss after 49 iteration = 0.0086
# Total train chrF after 49 iteration = 88.7151
# Average val loss after 49 iteration = 0.0183
# Total val chrF after 49 iteration = 83.2218
# Average test loss after 49 iteration = 0.0187
# Total test chrF after 49 iteration = 84.1072
# Time for the iteration 20.0 seconds
#
#
# Average train loss after 50 iteration = 0.0085
# Total train chrF after 50 iteration = 88.8059
# Average val loss after 50 iteration = 0.0184
# Total val chrF after 50 iteration = 83.2618
# Average test loss after 50 iteration = 0.0188
# Total test chrF after 50 iteration = 84.0098
# Time for the iteration 20.1 seconds
#
#
# Average train loss after 51 iteration = 0.0083
# Total train chrF after 51 iteration = 88.8991
# Average val loss after 51 iteration = 0.0185
# Total val chrF after 51 iteration = 83.2255
# Average test loss after 51 iteration = 0.0188
# Total test chrF after 51 iteration = 83.9236
# Time for the iteration 20.1 seconds
#
#
#
#
# Aborting since there hasn't been much progress
# <Figure size 640x480 with 1 Axes>
# <Figure size 640x480 with 1 Axes>

# %%
language = "shi"
task_name = "sylsim_teacher_general"
vocab_size = 4999
num_epochs = 100
batch_size = 32
model = "50_1"
optimizer = "Adam"
metric = "chrF"

# %%
from IPython.display import Image

Image("curves/{}_{}_{}_{}_{}_loss.png".format(language, task_name, vocab_size, num_epochs, batch_size))

# %%
Image("curves/{}_{}_{}_{}_{}_{}.png".format(language, task_name, vocab_size, num_epochs, batch_size, metric))

# %%
print("{}.{}.{}.{}.{}.{}.{}".format(language, task_name, vocab_size, num_epochs, batch_size, model, optimizer))
# Out:
# shi.sylsim_teacher_general.4999.100.32.50_1.Adam
