# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
# %cd "drive/MyDrive/Tesis/scRNN"
# Out:
# /content/drive/MyDrive/Tesis/scRNN

# %%
import torch

torch.cuda.is_available()
# Out:
# True

# %%
# !pip install sacrebleu
# Out:
# Collecting sacrebleu
#   Downloading sacrebleu-2.0.0-py3-none-any.whl (90 kB)
#      |████████████████████████████████| 90 kB 3.4 MB/s
# Collecting portalocker
#   Downloading portalocker-2.3.2-py2.py3-none-any.whl (15 kB)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from sacrebleu) (1.19.5)
# Requirement already satisfied: tabulate>=0.8.9 in /usr/local/lib/python3.7/dist-packages (from sacrebleu) (0.8.9)
# Collecting colorama
#   Downloading colorama-0.4.4-py2.py3-none-any.whl (16 kB)
# Requirement already satisfied: regex in /usr/local/lib/python3.7/dist-packages (from sacrebleu) (2019.12.20)
# Installing collected packages: portalocker, colorama, sacrebleu
# Successfully installed colorama-0.4.4 portalocker-2.3.2 sacrebleu-2.0.0

# %%
# !python3 train.py --language shi --task-name phongrafamb_teacher_general --num-epochs 100 --batch-size 32 --vocab-size 4999 --new-vocab --train --train-sentences-errors-file shi.phongrafamb_teacher_general.train.sentences.errors.txt --train-sentences-file shi.phongrafamb_teacher_general.train.sentences.txt --val-sentences-errors-file shi.teacher_general.val.sentences.errors.txt --val-sentences-file shi.teacher_general.val.sentences.txt --test-sentences-errors-file shi.teacher_general.test.sentences.errors.txt --test-sentences-file shi.teacher_general.test.sentences.txt --metric chrF --save
# Out:
# Parameters
# {'language': 'shi', 'task_name': 'phongrafamb_teacher_general', 'vocab_size': 4999, 'num_epochs': 100, 'batch_size': 32, 'model_name': 'shi_random_20531_100_32', 'new_vocab': True, 'need_to_train': True, 'train_sentences_errors_file': 'shi.phongrafamb_teacher_general.train.sentences.errors.txt', 'train_sentences_file': 'shi.phongrafamb_teacher_general.train.sentences.txt', 'val_sentences_errors_file': 'shi.teacher_general.val.sentences.errors.txt', 'val_sentences_file': 'shi.teacher_general.val.sentences.txt', 'test_sentences_errors_file': 'shi.teacher_general.test.sentences.errors.txt', 'test_sentences_file': 'shi.teacher_general.test.sentences.txt', 'metric': 'chrF', 'save_model': True}
#
#
# Creating new vocabulary
# Len of w2i:  4999
# Len of i2w:  4999
# Len of char vocab:  33
#
#
# Initializing an only ScRNN model
#
#
# Training the model...
#
# Average train loss after 1 iteration = 0.1723
# Total train chrF after 1 iteration = 55.6364
# Average val loss after 1 iteration = 0.1476
# Total val chrF after 1 iteration = 76.1936
# Average test loss after 1 iteration = 0.1503
# Total test chrF after 1 iteration = 76.3293
# Dumping after  1
# Time for the iteration 16.3 seconds
#
#
# Average train loss after 2 iteration = 0.0930
# Total train chrF after 2 iteration = 68.4781
# Average val loss after 2 iteration = 0.0865
# Total val chrF after 2 iteration = 79.6594
# Average test loss after 2 iteration = 0.0883
# Total test chrF after 2 iteration = 79.7231
# Dumping after  2
# Time for the iteration 16.1 seconds
#
#
# Average train loss after 3 iteration = 0.0529
# Total train chrF after 3 iteration = 77.1389
# Average val loss after 3 iteration = 0.0629
# Total val chrF after 3 iteration = 81.4475
# Average test loss after 3 iteration = 0.0642
# Total test chrF after 3 iteration = 81.4846
# Dumping after  3
# Time for the iteration 16.3 seconds
#
#
# Average train loss after 4 iteration = 0.0337
# Total train chrF after 4 iteration = 81.7687
# Average val loss after 4 iteration = 0.0503
# Total val chrF after 4 iteration = 82.1810
# Average test loss after 4 iteration = 0.0513
# Total test chrF after 4 iteration = 82.2727
# Dumping after  4
# Time for the iteration 16.4 seconds
#
#
# Average train loss after 5 iteration = 0.0230
# Total train chrF after 5 iteration = 84.6898
# Average val loss after 5 iteration = 0.0415
# Total val chrF after 5 iteration = 82.7909
# Average test loss after 5 iteration = 0.0424
# Total test chrF after 5 iteration = 82.8044
# Dumping after  5
# Time for the iteration 16.5 seconds
#
#
# Average train loss after 6 iteration = 0.0164
# Total train chrF after 6 iteration = 86.6753
# Average val loss after 6 iteration = 0.0349
# Total val chrF after 6 iteration = 83.2272
# Average test loss after 6 iteration = 0.0358
# Total test chrF after 6 iteration = 83.1536
# Dumping after  6
# Time for the iteration 16.6 seconds
#
#
# Average train loss after 7 iteration = 0.0123
# Total train chrF after 7 iteration = 88.1381
# Average val loss after 7 iteration = 0.0300
# Total val chrF after 7 iteration = 83.6661
# Average test loss after 7 iteration = 0.0309
# Total test chrF after 7 iteration = 83.6014
# Dumping after  7
# Time for the iteration 16.4 seconds
#
#
# Average train loss after 8 iteration = 0.0096
# Total train chrF after 8 iteration = 89.1946
# Average val loss after 8 iteration = 0.0264
# Total val chrF after 8 iteration = 84.0739
# Average test loss after 8 iteration = 0.0274
# Total test chrF after 8 iteration = 84.2209
# Dumping after  8
# Time for the iteration 16.5 seconds
#
#
# Average train loss after 9 iteration = 0.0077
# Total train chrF after 9 iteration = 89.9704
# Average val loss after 9 iteration = 0.0238
# Total val chrF after 9 iteration = 84.4316
# Average test loss after 9 iteration = 0.0248
# Total test chrF after 9 iteration = 84.4119
# Dumping after  9
# Time for the iteration 16.5 seconds
#
#
# Average train loss after 10 iteration = 0.0064
# Total train chrF after 10 iteration = 90.5248
# Average val loss after 10 iteration = 0.0218
# Total val chrF after 10 iteration = 84.6527
# Average test loss after 10 iteration = 0.0228
# Total test chrF after 10 iteration = 84.6800
# Dumping after  10
# Time for the iteration 16.6 seconds
#
#
# Average train loss after 11 iteration = 0.0055
# Total train chrF after 11 iteration = 90.9021
# Average val loss after 11 iteration = 0.0202
# Total val chrF after 11 iteration = 84.8988
# Average test loss after 11 iteration = 0.0212
# Total test chrF after 11 iteration = 85.0461
# Dumping after  11
# Time for the iteration 16.6 seconds
#
#
# Average train loss after 12 iteration = 0.0047
# Total train chrF after 12 iteration = 91.1780
# Average val loss after 12 iteration = 0.0189
# Total val chrF after 12 iteration = 85.1913
# Average test loss after 12 iteration = 0.0200
# Total test chrF after 12 iteration = 85.3709
# Dumping after  12
# Time for the iteration 16.6 seconds
#
#
# Average train loss after 13 iteration = 0.0041
# Total train chrF after 13 iteration = 91.3685
# Average val loss after 13 iteration = 0.0178
# Total val chrF after 13 iteration = 85.3886
# Average test loss after 13 iteration = 0.0189
# Total test chrF after 13 iteration = 85.5661
# Dumping after  13
# Time for the iteration 16.5 seconds
#
#
# Average train loss after 14 iteration = 0.0036
# Total train chrF after 14 iteration = 91.5171
# Average val loss after 14 iteration = 0.0170
# Total val chrF after 14 iteration = 85.5957
# Average test loss after 14 iteration = 0.0180
# Total test chrF after 14 iteration = 85.8381
# Dumping after  14
# Time for the iteration 16.5 seconds
#
#
# Average train loss after 15 iteration = 0.0032
# Total train chrF after 15 iteration = 91.6266
# Average val loss after 15 iteration = 0.0162
# Total val chrF after 15 iteration = 85.8034
# Average test loss after 15 iteration = 0.0172
# Total test chrF after 15 iteration = 86.0123
# Dumping after  15
# Time for the iteration 16.6 seconds
#
#
# Average train loss after 16 iteration = 0.0029
# Total train chrF after 16 iteration = 91.7184
# Average val loss after 16 iteration = 0.0156
# Total val chrF after 16 iteration = 86.0774
# Average test loss after 16 iteration = 0.0166
# Total test chrF after 16 iteration = 86.1978
# Dumping after  16
# Time for the iteration 16.5 seconds
#
#
# Average train loss after 17 iteration = 0.0026
# Total train chrF after 17 iteration = 91.7900
# Average val loss after 17 iteration = 0.0150
# Total val chrF after 17 iteration = 86.2579
# Average test loss after 17 iteration = 0.0160
# Total test chrF after 17 iteration = 86.3752
# Dumping after  17
# Time for the iteration 16.5 seconds
#
#
# Average train loss after 18 iteration = 0.0024
# Total train chrF after 18 iteration = 91.8449
# Average val loss after 18 iteration = 0.0145
# Total val chrF after 18 iteration = 86.3095
# Average test loss after 18 iteration = 0.0155
# Total test chrF after 18 iteration = 86.6526
# Dumping after  18
# Time for the iteration 16.5 seconds
#
#
# Average train loss after 19 iteration = 0.0021
# Total train chrF after 19 iteration = 91.9006
# Average val loss after 19 iteration = 0.0141
# Total val chrF after 19 iteration = 86.4494
# Average test loss after 19 iteration = 0.0151
# Total test chrF after 19 iteration = 86.7963
# Dumping after  19
# Time for the iteration 16.6 seconds
#
#
# Average train loss after 20 iteration = 0.0019
# Total train chrF after 20 iteration = 91.9481
# Average val loss after 20 iteration = 0.0138
# Total val chrF after 20 iteration = 86.5855
# Average test loss after 20 iteration = 0.0148
# Total test chrF after 20 iteration = 86.8622
# Dumping after  20
# Time for the iteration 16.6 seconds
#
#
# Average train loss after 21 iteration = 0.0018
# Total train chrF after 21 iteration = 91.9980
# Average val loss after 21 iteration = 0.0135
# Total val chrF after 21 iteration = 86.7185
# Average test loss after 21 iteration = 0.0145
# Total test chrF after 21 iteration = 87.0297
# Dumping after  21
# Time for the iteration 16.4 seconds
#
#
# Average train loss after 22 iteration = 0.0016
# Total train chrF after 22 iteration = 92.0470
# Average val loss after 22 iteration = 0.0132
# Total val chrF after 22 iteration = 86.8570
# Average test loss after 22 iteration = 0.0142
# Total test chrF after 22 iteration = 87.1659
# Dumping after  22
# Time for the iteration 16.7 seconds
#
#
# Average train loss after 23 iteration = 0.0015
# Total train chrF after 23 iteration = 92.0842
# Average val loss after 23 iteration = 0.0130
# Total val chrF after 23 iteration = 86.9758
# Average test loss after 23 iteration = 0.0140
# Total test chrF after 23 iteration = 87.2912
# Dumping after  23
# Time for the iteration 16.6 seconds
#
#
# Average train loss after 24 iteration = 0.0014
# Total train chrF after 24 iteration = 92.1087
# Average val loss after 24 iteration = 0.0128
# Total val chrF after 24 iteration = 87.0231
# Average test loss after 24 iteration = 0.0138
# Total test chrF after 24 iteration = 87.3689
# Dumping after  24
# Time for the iteration 16.7 seconds
#
#
# Average train loss after 25 iteration = 0.0012
# Total train chrF after 25 iteration = 92.1450
# Average val loss after 25 iteration = 0.0127
# Total val chrF after 25 iteration = 87.0894
# Average test loss after 25 iteration = 0.0136
# Total test chrF after 25 iteration = 87.4429
# Dumping after  25
# Time for the iteration 16.7 seconds
#
#
# Average train loss after 26 iteration = 0.0011
# Total train chrF after 26 iteration = 92.1700
# Average val loss after 26 iteration = 0.0125
# Total val chrF after 26 iteration = 87.1665
# Average test loss after 26 iteration = 0.0134
# Total test chrF after 26 iteration = 87.5793
# Dumping after  26
# Time for the iteration 16.7 seconds
#
#
# Average train loss after 27 iteration = 0.0011
# Total train chrF after 27 iteration = 92.1932
# Average val loss after 27 iteration = 0.0124
# Total val chrF after 27 iteration = 87.2945
# Average test loss after 27 iteration = 0.0133
# Total test chrF after 27 iteration = 87.6499
# Dumping after  27
# Time for the iteration 16.4 seconds
#
#
# Average train loss after 28 iteration = 0.0010
# Total train chrF after 28 iteration = 92.2193
# Average val loss after 28 iteration = 0.0123
# Total val chrF after 28 iteration = 87.3244
# Average test loss after 28 iteration = 0.0132
# Total test chrF after 28 iteration = 87.7279
# Dumping after  28
# Time for the iteration 16.5 seconds
#
#
# Average train loss after 29 iteration = 0.0009
# Total train chrF after 29 iteration = 92.2418
# Average val loss after 29 iteration = 0.0121
# Total val chrF after 29 iteration = 87.4581
# Average test loss after 29 iteration = 0.0131
# Total test chrF after 29 iteration = 87.7613
# Dumping after  29
# Time for the iteration 16.6 seconds
#
#
# Average train loss after 30 iteration = 0.0008
# Total train chrF after 30 iteration = 92.2639
# Average val loss after 30 iteration = 0.0121
# Total val chrF after 30 iteration = 87.4473
# Average test loss after 30 iteration = 0.0130
# Total test chrF after 30 iteration = 87.8298
# Time for the iteration 16.5 seconds
#
#
# Average train loss after 31 iteration = 0.0008
# Total train chrF after 31 iteration = 92.2821
# Average val loss after 31 iteration = 0.0120
# Total val chrF after 31 iteration = 87.4966
# Average test loss after 31 iteration = 0.0129
# Total test chrF after 31 iteration = 87.8706
# Dumping after  31
# Time for the iteration 16.5 seconds
#
#
# Average train loss after 32 iteration = 0.0007
# Total train chrF after 32 iteration = 92.3003
# Average val loss after 32 iteration = 0.0119
# Total val chrF after 32 iteration = 87.5300
# Average test loss after 32 iteration = 0.0129
# Total test chrF after 32 iteration = 87.9222
# Dumping after  32
# Time for the iteration 16.5 seconds
#
#
# Average train loss after 33 iteration = 0.0006
# Total train chrF after 33 iteration = 92.3093
# Average val loss after 33 iteration = 0.0119
# Total val chrF after 33 iteration = 87.6002
# Average test loss after 33 iteration = 0.0128
# Total test chrF after 33 iteration = 87.9148
# Dumping after  33
# Time for the iteration 16.6 seconds
#
#
# Average train loss after 34 iteration = 0.0006
# Total train chrF after 34 iteration = 92.3241
# Average val loss after 34 iteration = 0.0119
# Total val chrF after 34 iteration = 87.6615
# Average test loss after 34 iteration = 0.0128
# Total test chrF after 34 iteration = 87.9247
# Dumping after  34
# Time for the iteration 16.6 seconds
#
#
# Average train loss after 35 iteration = 0.0005
# Total train chrF after 35 iteration = 92.3365
# Average val loss after 35 iteration = 0.0118
# Total val chrF after 35 iteration = 87.7133
# Average test loss after 35 iteration = 0.0128
# Total test chrF after 35 iteration = 87.9046
# Dumping after  35
# Time for the iteration 16.6 seconds
#
#
# Average train loss after 36 iteration = 0.0005
# Total train chrF after 36 iteration = 92.3486
# Average val loss after 36 iteration = 0.0118
# Total val chrF after 36 iteration = 87.7912
# Average test loss after 36 iteration = 0.0128
# Total test chrF after 36 iteration = 87.9282
# Dumping after  36
# Time for the iteration 16.6 seconds
#
#
# Average train loss after 37 iteration = 0.0005
# Total train chrF after 37 iteration = 92.3558
# Average val loss after 37 iteration = 0.0118
# Total val chrF after 37 iteration = 87.7844
# Average test loss after 37 iteration = 0.0128
# Total test chrF after 37 iteration = 87.9366
# Time for the iteration 16.6 seconds
#
#
# Average train loss after 38 iteration = 0.0004
# Total train chrF after 38 iteration = 92.3664
# Average val loss after 38 iteration = 0.0119
# Total val chrF after 38 iteration = 87.8517
# Average test loss after 38 iteration = 0.0128
# Total test chrF after 38 iteration = 87.9376
# Dumping after  38
# Time for the iteration 16.7 seconds
#
#
# Average train loss after 39 iteration = 0.0004
# Total train chrF after 39 iteration = 92.3760
# Average val loss after 39 iteration = 0.0119
# Total val chrF after 39 iteration = 87.9283
# Average test loss after 39 iteration = 0.0128
# Total test chrF after 39 iteration = 87.9508
# Dumping after  39
# Time for the iteration 16.7 seconds
#
#
# Average train loss after 40 iteration = 0.0004
# Total train chrF after 40 iteration = 92.3858
# Average val loss after 40 iteration = 0.0119
# Total val chrF after 40 iteration = 87.9208
# Average test loss after 40 iteration = 0.0128
# Total test chrF after 40 iteration = 87.9537
# Time for the iteration 16.5 seconds
#
#
# Average train loss after 41 iteration = 0.0003
# Total train chrF after 41 iteration = 92.3928
# Average val loss after 41 iteration = 0.0119
# Total val chrF after 41 iteration = 87.9368
# Average test loss after 41 iteration = 0.0129
# Total test chrF after 41 iteration = 87.9980
# Dumping after  41
# Time for the iteration 16.6 seconds
#
#
# Average train loss after 42 iteration = 0.0003
# Total train chrF after 42 iteration = 92.3978
# Average val loss after 42 iteration = 0.0119
# Total val chrF after 42 iteration = 87.9656
# Average test loss after 42 iteration = 0.0129
# Total test chrF after 42 iteration = 87.9800
# Dumping after  42
# Time for the iteration 16.6 seconds
#
#
# Average train loss after 43 iteration = 0.0003
# Total train chrF after 43 iteration = 92.4025
# Average val loss after 43 iteration = 0.0120
# Total val chrF after 43 iteration = 87.9533
# Average test loss after 43 iteration = 0.0129
# Total test chrF after 43 iteration = 88.0047
# Time for the iteration 16.6 seconds
#
#
# Average train loss after 44 iteration = 0.0002
# Total train chrF after 44 iteration = 92.4077
# Average val loss after 44 iteration = 0.0120
# Total val chrF after 44 iteration = 87.9672
# Average test loss after 44 iteration = 0.0130
# Total test chrF after 44 iteration = 88.0171
# Dumping after  44
# Time for the iteration 16.7 seconds
#
#
# Average train loss after 45 iteration = 0.0002
# Total train chrF after 45 iteration = 92.4109
# Average val loss after 45 iteration = 0.0120
# Total val chrF after 45 iteration = 87.9857
# Average test loss after 45 iteration = 0.0130
# Total test chrF after 45 iteration = 88.0220
# Dumping after  45
# Time for the iteration 16.5 seconds
#
#
# Average train loss after 46 iteration = 0.0002
# Total train chrF after 46 iteration = 92.4155
# Average val loss after 46 iteration = 0.0121
# Total val chrF after 46 iteration = 87.9541
# Average test loss after 46 iteration = 0.0131
# Total test chrF after 46 iteration = 88.0600
# Time for the iteration 16.5 seconds
#
#
# Average train loss after 47 iteration = 0.0002
# Total train chrF after 47 iteration = 92.4180
# Average val loss after 47 iteration = 0.0121
# Total val chrF after 47 iteration = 87.9221
# Average test loss after 47 iteration = 0.0131
# Total test chrF after 47 iteration = 88.0639
# Time for the iteration 16.5 seconds
#
#
# Average train loss after 48 iteration = 0.0002
# Total train chrF after 48 iteration = 92.4203
# Average val loss after 48 iteration = 0.0122
# Total val chrF after 48 iteration = 87.8978
# Average test loss after 48 iteration = 0.0132
# Total test chrF after 48 iteration = 88.0699
# Time for the iteration 16.7 seconds
#
#
# Average train loss after 49 iteration = 0.0002
# Total train chrF after 49 iteration = 92.4231
# Average val loss after 49 iteration = 0.0122
# Total val chrF after 49 iteration = 87.9493
# Average test loss after 49 iteration = 0.0133
# Total test chrF after 49 iteration = 88.0499
# Time for the iteration 16.6 seconds
#
#
# Average train loss after 50 iteration = 0.0001
# Total train chrF after 50 iteration = 92.4242
# Average val loss after 50 iteration = 0.0123
# Total val chrF after 50 iteration = 87.9429
# Average test loss after 50 iteration = 0.0134
# Total test chrF after 50 iteration = 88.0486
# Time for the iteration 16.6 seconds
#
#
# Average train loss after 51 iteration = 0.0001
# Total train chrF after 51 iteration = 92.4255
# Average val loss after 51 iteration = 0.0124
# Total val chrF after 51 iteration = 87.9499
# Average test loss after 51 iteration = 0.0135
# Total test chrF after 51 iteration = 88.0935
# Time for the iteration 16.4 seconds
#
#
# Average train loss after 52 iteration = 0.0001
# Total train chrF after 52 iteration = 92.4261
# Average val loss after 52 iteration = 0.0124
# Total val chrF after 52 iteration = 87.9829
# Average test loss after 52 iteration = 0.0135
# Total test chrF after 52 iteration = 88.0732
# Time for the iteration 16.6 seconds
#
#
# Average train loss after 53 iteration = 0.0001
# Total train chrF after 53 iteration = 92.4269
# Average val loss after 53 iteration = 0.0125
# Total val chrF after 53 iteration = 88.0045
# Average test loss after 53 iteration = 0.0136
# Total test chrF after 53 iteration = 88.0988
# Dumping after  53
# Time for the iteration 16.5 seconds
#
#
# Average train loss after 54 iteration = 0.0001
# Total train chrF after 54 iteration = 92.4278
# Average val loss after 54 iteration = 0.0126
# Total val chrF after 54 iteration = 88.0493
# Average test loss after 54 iteration = 0.0137
# Total test chrF after 54 iteration = 88.0596
# Dumping after  54
# Time for the iteration 16.6 seconds
#
#
# Average train loss after 55 iteration = 0.0001
# Total train chrF after 55 iteration = 92.4278
# Average val loss after 55 iteration = 0.0126
# Total val chrF after 55 iteration = 88.0325
# Average test loss after 55 iteration = 0.0138
# Total test chrF after 55 iteration = 88.0931
# Time for the iteration 16.6 seconds
#
#
# Average train loss after 56 iteration = 0.0001
# Total train chrF after 56 iteration = 92.4285
# Average val loss after 56 iteration = 0.0127
# Total val chrF after 56 iteration = 88.0798
# Average test loss after 56 iteration = 0.0139
# Total test chrF after 56 iteration = 88.0405
# Dumping after  56
# Time for the iteration 16.6 seconds
#
#
# Average train loss after 57 iteration = 0.0001
# Total train chrF after 57 iteration = 92.4286
# Average val loss after 57 iteration = 0.0128
# Total val chrF after 57 iteration = 88.1048
# Average test loss after 57 iteration = 0.0140
# Total test chrF after 57 iteration = 88.1152
# Dumping after  57
# Time for the iteration 16.6 seconds
#
#
# Average train loss after 58 iteration = 0.0001
# Total train chrF after 58 iteration = 92.4292
# Average val loss after 58 iteration = 0.0129
# Total val chrF after 58 iteration = 88.0697
# Average test loss after 58 iteration = 0.0140
# Total test chrF after 58 iteration = 88.0698
# Time for the iteration 16.7 seconds
#
#
# Average train loss after 59 iteration = 0.0001
# Total train chrF after 59 iteration = 92.4292
# Average val loss after 59 iteration = 0.0129
# Total val chrF after 59 iteration = 88.0831
# Average test loss after 59 iteration = 0.0141
# Total test chrF after 59 iteration = 88.1185
# Time for the iteration 16.6 seconds
#
#
# Average train loss after 60 iteration = 0.0001
# Total train chrF after 60 iteration = 92.4296
# Average val loss after 60 iteration = 0.0130
# Total val chrF after 60 iteration = 88.0590
# Average test loss after 60 iteration = 0.0142
# Total test chrF after 60 iteration = 88.0901
# Time for the iteration 16.6 seconds
#
#
# Average train loss after 61 iteration = 0.0001
# Total train chrF after 61 iteration = 92.4303
# Average val loss after 61 iteration = 0.0131
# Total val chrF after 61 iteration = 88.0525
# Average test loss after 61 iteration = 0.0143
# Total test chrF after 61 iteration = 88.1259
# Time for the iteration 16.6 seconds
#
#
# Average train loss after 62 iteration = 0.0000
# Total train chrF after 62 iteration = 92.4302
# Average val loss after 62 iteration = 0.0132
# Total val chrF after 62 iteration = 88.0594
# Average test loss after 62 iteration = 0.0144
# Total test chrF after 62 iteration = 88.0467
# Time for the iteration 16.6 seconds
#
#
# Average train loss after 63 iteration = 0.0000
# Total train chrF after 63 iteration = 92.4305
# Average val loss after 63 iteration = 0.0132
# Total val chrF after 63 iteration = 88.0207
# Average test loss after 63 iteration = 0.0144
# Total test chrF after 63 iteration = 88.1091
# Time for the iteration 16.7 seconds
#
#
# Average train loss after 64 iteration = 0.0000
# Total train chrF after 64 iteration = 92.4313
# Average val loss after 64 iteration = 0.0134
# Total val chrF after 64 iteration = 88.0355
# Average test loss after 64 iteration = 0.0146
# Total test chrF after 64 iteration = 88.0627
# Time for the iteration 16.6 seconds
#
#
# Average train loss after 65 iteration = 0.0000
# Total train chrF after 65 iteration = 92.4314
# Average val loss after 65 iteration = 0.0134
# Total val chrF after 65 iteration = 88.0283
# Average test loss after 65 iteration = 0.0146
# Total test chrF after 65 iteration = 88.1374
# Time for the iteration 16.5 seconds
#
#
# Average train loss after 66 iteration = 0.0000
# Total train chrF after 66 iteration = 92.4320
# Average val loss after 66 iteration = 0.0135
# Total val chrF after 66 iteration = 87.9975
# Average test loss after 66 iteration = 0.0147
# Total test chrF after 66 iteration = 88.0304
# Time for the iteration 16.6 seconds
#
#
# Average train loss after 67 iteration = 0.0000
# Total train chrF after 67 iteration = 92.4319
# Average val loss after 67 iteration = 0.0136
# Total val chrF after 67 iteration = 88.0226
# Average test loss after 67 iteration = 0.0148
# Total test chrF after 67 iteration = 88.1197
# Time for the iteration 16.6 seconds
#
#
# Average train loss after 68 iteration = 0.0000
# Total train chrF after 68 iteration = 92.4322
# Average val loss after 68 iteration = 0.0137
# Total val chrF after 68 iteration = 88.0348
# Average test loss after 68 iteration = 0.0149
# Total test chrF after 68 iteration = 88.1307
# Time for the iteration 16.6 seconds
#
#
# Average train loss after 69 iteration = 0.0000
# Total train chrF after 69 iteration = 92.4320
# Average val loss after 69 iteration = 0.0138
# Total val chrF after 69 iteration = 88.0045
# Average test loss after 69 iteration = 0.0150
# Total test chrF after 69 iteration = 88.1106
# Time for the iteration 16.6 seconds
#
#
# Average train loss after 70 iteration = 0.0000
# Total train chrF after 70 iteration = 92.4322
# Average val loss after 70 iteration = 0.0139
# Total val chrF after 70 iteration = 88.0536
# Average test loss after 70 iteration = 0.0151
# Total test chrF after 70 iteration = 88.1935
# Time for the iteration 16.6 seconds
#
#
# Average train loss after 71 iteration = 0.0000
# Total train chrF after 71 iteration = 92.4325
# Average val loss after 71 iteration = 0.0140
# Total val chrF after 71 iteration = 88.0255
# Average test loss after 71 iteration = 0.0152
# Total test chrF after 71 iteration = 88.1167
# Time for the iteration 16.6 seconds
#
#
# Average train loss after 72 iteration = 0.0000
# Total train chrF after 72 iteration = 92.4335
# Average val loss after 72 iteration = 0.0141
# Total val chrF after 72 iteration = 88.0116
# Average test loss after 72 iteration = 0.0154
# Total test chrF after 72 iteration = 88.1416
# Time for the iteration 16.5 seconds
#
#
# Average train loss after 73 iteration = 0.0000
# Total train chrF after 73 iteration = 92.4336
# Average val loss after 73 iteration = 0.0142
# Total val chrF after 73 iteration = 88.0382
# Average test loss after 73 iteration = 0.0155
# Total test chrF after 73 iteration = 88.1509
# Time for the iteration 16.6 seconds
#
#
# Average train loss after 74 iteration = 0.0000
# Total train chrF after 74 iteration = 92.4336
# Average val loss after 74 iteration = 0.0143
# Total val chrF after 74 iteration = 88.0134
# Average test loss after 74 iteration = 0.0156
# Total test chrF after 74 iteration = 88.1416
# Time for the iteration 16.6 seconds
#
#
# Average train loss after 75 iteration = 0.0000
# Total train chrF after 75 iteration = 92.4336
# Average val loss after 75 iteration = 0.0144
# Total val chrF after 75 iteration = 87.9886
# Average test loss after 75 iteration = 0.0157
# Total test chrF after 75 iteration = 88.1215
# Time for the iteration 16.4 seconds
#
#
# Average train loss after 76 iteration = 0.0000
# Total train chrF after 76 iteration = 92.4318
# Average val loss after 76 iteration = 0.0141
# Total val chrF after 76 iteration = 87.9627
# Average test loss after 76 iteration = 0.0153
# Total test chrF after 76 iteration = 88.2416
# Time for the iteration 16.6 seconds
#
#
# Average train loss after 77 iteration = 0.0000
# Total train chrF after 77 iteration = 92.4335
# Average val loss after 77 iteration = 0.0140
# Total val chrF after 77 iteration = 88.0260
# Average test loss after 77 iteration = 0.0153
# Total test chrF after 77 iteration = 88.1883
# Time for the iteration 16.6 seconds
#
#
# Average train loss after 78 iteration = 0.0000
# Total train chrF after 78 iteration = 92.4336
# Average val loss after 78 iteration = 0.0140
# Total val chrF after 78 iteration = 88.1139
# Average test loss after 78 iteration = 0.0153
# Total test chrF after 78 iteration = 88.2607
# Dumping after  78
# Time for the iteration 16.7 seconds
#
#
# Average train loss after 79 iteration = 0.0000
# Total train chrF after 79 iteration = 92.4336
# Average val loss after 79 iteration = 0.0142
# Total val chrF after 79 iteration = 88.0431
# Average test loss after 79 iteration = 0.0155
# Total test chrF after 79 iteration = 88.2342
# Time for the iteration 16.6 seconds
#
#
# Average train loss after 80 iteration = 0.0000
# Total train chrF after 80 iteration = 92.4336
# Average val loss after 80 iteration = 0.0144
# Total val chrF after 80 iteration = 87.9817
# Average test loss after 80 iteration = 0.0157
# Total test chrF after 80 iteration = 88.1993
# Time for the iteration 16.7 seconds
#
#
# Average train loss after 81 iteration = 0.0000
# Total train chrF after 81 iteration = 92.4336
# Average val loss after 81 iteration = 0.0146
# Total val chrF after 81 iteration = 87.9524
# Average test loss after 81 iteration = 0.0159
# Total test chrF after 81 iteration = 88.1784
# Time for the iteration 16.6 seconds
#
#
# Average train loss after 82 iteration = 0.0000
# Total train chrF after 82 iteration = 92.4336
# Average val loss after 82 iteration = 0.0147
# Total val chrF after 82 iteration = 87.9169
# Average test loss after 82 iteration = 0.0161
# Total test chrF after 82 iteration = 88.1935
# Time for the iteration 16.5 seconds
#
#
# Average train loss after 83 iteration = 0.0000
# Total train chrF after 83 iteration = 92.4336
# Average val loss after 83 iteration = 0.0149
# Total val chrF after 83 iteration = 87.9129
# Average test loss after 83 iteration = 0.0163
# Total test chrF after 83 iteration = 88.1703
# Time for the iteration 16.6 seconds
#
#
# Average train loss after 84 iteration = 0.0000
# Total train chrF after 84 iteration = 92.4336
# Average val loss after 84 iteration = 0.0150
# Total val chrF after 84 iteration = 87.8851
# Average test loss after 84 iteration = 0.0165
# Total test chrF after 84 iteration = 88.1834
# Time for the iteration 16.7 seconds
#
#
# Average train loss after 85 iteration = 0.0000
# Total train chrF after 85 iteration = 92.4336
# Average val loss after 85 iteration = 0.0152
# Total val chrF after 85 iteration = 87.9036
# Average test loss after 85 iteration = 0.0167
# Total test chrF after 85 iteration = 88.1433
# Time for the iteration 16.7 seconds
#
#
# Average train loss after 86 iteration = 0.0000
# Total train chrF after 86 iteration = 92.4336
# Average val loss after 86 iteration = 0.0153
# Total val chrF after 86 iteration = 87.9036
# Average test loss after 86 iteration = 0.0168
# Total test chrF after 86 iteration = 88.1575
# Time for the iteration 16.6 seconds
#
#
# Average train loss after 87 iteration = 0.0000
# Total train chrF after 87 iteration = 92.4198
# Average val loss after 87 iteration = 0.0149
# Total val chrF after 87 iteration = 88.2868
# Average test loss after 87 iteration = 0.0164
# Total test chrF after 87 iteration = 88.0313
# Dumping after  87
# Time for the iteration 16.5 seconds
#
#
# Average train loss after 88 iteration = 0.0000
# Total train chrF after 88 iteration = 92.4313
# Average val loss after 88 iteration = 0.0144
# Total val chrF after 88 iteration = 88.1366
# Average test loss after 88 iteration = 0.0156
# Total test chrF after 88 iteration = 88.1730
# Time for the iteration 16.7 seconds
#
#
# Average train loss after 89 iteration = 0.0000
# Total train chrF after 89 iteration = 92.4336
# Average val loss after 89 iteration = 0.0142
# Total val chrF after 89 iteration = 88.2887
# Average test loss after 89 iteration = 0.0154
# Total test chrF after 89 iteration = 88.3672
# Dumping after  89
# Time for the iteration 16.5 seconds
#
#
# Average train loss after 90 iteration = 0.0000
# Total train chrF after 90 iteration = 92.4336
# Average val loss after 90 iteration = 0.0142
# Total val chrF after 90 iteration = 88.2671
# Average test loss after 90 iteration = 0.0155
# Total test chrF after 90 iteration = 88.4028
# Time for the iteration 16.6 seconds
#
#
# Average train loss after 91 iteration = 0.0000
# Total train chrF after 91 iteration = 92.4336
# Average val loss after 91 iteration = 0.0143
# Total val chrF after 91 iteration = 88.3005
# Average test loss after 91 iteration = 0.0155
# Total test chrF after 91 iteration = 88.3873
# Dumping after  91
# Time for the iteration 16.6 seconds
#
#
# Average train loss after 92 iteration = 0.0000
# Total train chrF after 92 iteration = 92.4336
# Average val loss after 92 iteration = 0.0144
# Total val chrF after 92 iteration = 88.2215
# Average test loss after 92 iteration = 0.0157
# Total test chrF after 92 iteration = 88.4134
# Time for the iteration 16.7 seconds
#
#
# Average train loss after 93 iteration = 0.0000
# Total train chrF after 93 iteration = 92.4336
# Average val loss after 93 iteration = 0.0145
# Total val chrF after 93 iteration = 88.2035
# Average test loss after 93 iteration = 0.0158
# Total test chrF after 93 iteration = 88.3768
# Time for the iteration 16.5 seconds
#
#
# Average train loss after 94 iteration = 0.0000
# Total train chrF after 94 iteration = 92.4336
# Average val loss after 94 iteration = 0.0147
# Total val chrF after 94 iteration = 88.1990
# Average test loss after 94 iteration = 0.0160
# Total test chrF after 94 iteration = 88.3637
# Time for the iteration 16.4 seconds
#
#
# Average train loss after 95 iteration = 0.0000
# Total train chrF after 95 iteration = 92.4336
# Average val loss after 95 iteration = 0.0149
# Total val chrF after 95 iteration = 88.1764
# Average test loss after 95 iteration = 0.0162
# Total test chrF after 95 iteration = 88.3981
# Time for the iteration 16.5 seconds
#
#
# Average train loss after 96 iteration = 0.0000
# Total train chrF after 96 iteration = 92.4336
# Average val loss after 96 iteration = 0.0150
# Total val chrF after 96 iteration = 88.2001
# Average test loss after 96 iteration = 0.0164
# Total test chrF after 96 iteration = 88.3591
# Time for the iteration 16.5 seconds
#
#
# Average train loss after 97 iteration = 0.0000
# Total train chrF after 97 iteration = 92.4336
# Average val loss after 97 iteration = 0.0152
# Total val chrF after 97 iteration = 88.1812
# Average test loss after 97 iteration = 0.0167
# Total test chrF after 97 iteration = 88.4013
# Time for the iteration 16.7 seconds
#
#
# Average train loss after 98 iteration = 0.0000
# Total train chrF after 98 iteration = 92.4336
# Average val loss after 98 iteration = 0.0154
# Total val chrF after 98 iteration = 88.1337
# Average test loss after 98 iteration = 0.0169
# Total test chrF after 98 iteration = 88.3523
# Time for the iteration 16.7 seconds
#
#
# Average train loss after 99 iteration = 0.0000
# Total train chrF after 99 iteration = 92.4336
# Average val loss after 99 iteration = 0.0156
# Total val chrF after 99 iteration = 88.1330
# Average test loss after 99 iteration = 0.0170
# Total test chrF after 99 iteration = 88.3585
# Time for the iteration 16.8 seconds
#
#
# Average train loss after 100 iteration = 0.0000
# Total train chrF after 100 iteration = 92.4336
# Average val loss after 100 iteration = 0.0157
# Total val chrF after 100 iteration = 88.0804
# Average test loss after 100 iteration = 0.0173
# Total test chrF after 100 iteration = 88.2445
# Time for the iteration 16.5 seconds
#
#
# <Figure size 640x480 with 1 Axes>
# <Figure size 640x480 with 1 Axes>

# %%
language = "shi"
task_name = "phongrafamb_teacher_general"
vocab_size = 4999
num_epochs = 100
batch_size = 32
model = "50_1"
optimizer = "Adam"
metric = "chrF"

# %%
from IPython.display import Image

Image("curves/{}_{}_{}_{}_{}_loss.png".format(language, task_name, vocab_size, num_epochs, batch_size))

# %%
Image("curves/{}_{}_{}_{}_{}_{}.png".format(language, task_name, vocab_size, num_epochs, batch_size, metric))

# %%
print("{}.{}.{}.{}.{}.{}.{}".format(language, task_name, vocab_size, num_epochs, batch_size, model, optimizer))
# Out:
# shi.phongrafamb_teacher_general.4999.100.32.50_1.Adam
