# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
# %cd "drive/MyDrive/Tesis/scRNN"
# Out:
# /content/drive/MyDrive/Tesis/scRNN

# %%
import torch

torch.cuda.is_available()
# Out:
# True

# %%
# !pip install sacrebleu
# Out:
# Collecting sacrebleu
#   Downloading sacrebleu-2.0.0-py3-none-any.whl (90 kB)
#      |████████████████████████████████| 90 kB 4.3 MB/s
# Collecting portalocker
#   Downloading portalocker-2.3.2-py2.py3-none-any.whl (15 kB)
# Requirement already satisfied: tabulate>=0.8.9 in /usr/local/lib/python3.7/dist-packages (from sacrebleu) (0.8.9)
# Requirement already satisfied: regex in /usr/local/lib/python3.7/dist-packages (from sacrebleu) (2019.12.20)
# Collecting colorama
#   Downloading colorama-0.4.4-py2.py3-none-any.whl (16 kB)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from sacrebleu) (1.19.5)
# Installing collected packages: portalocker, colorama, sacrebleu
# Successfully installed colorama-0.4.4 portalocker-2.3.2 sacrebleu-2.0.0

# %%
# !python3 train.py --language shi --task-name random_teacher_general --num-epochs 100 --batch-size 32 --vocab-size 4999 --new-vocab --train --train-sentences-errors-file shi.random_teacher_general.train.sentences.errors.txt --train-sentences-file shi.random_teacher_general.train.sentences.txt --val-sentences-errors-file shi.teacher_general.val.sentences.errors.txt --val-sentences-file shi.teacher_general.val.sentences.txt --test-sentences-errors-file shi.teacher_general.test.sentences.errors.txt --test-sentences-file shi.teacher_general.test.sentences.txt --metric chrF --save
# Out:
# Parameters
# {'language': 'shi', 'task_name': 'random_teacher_general', 'vocab_size': 4999, 'num_epochs': 100, 'batch_size': 32, 'model_name': 'shi_random_20531_100_32', 'new_vocab': True, 'need_to_train': True, 'train_sentences_errors_file': 'shi.random_teacher_general.train.sentences.errors.txt', 'train_sentences_file': 'shi.random_teacher_general.train.sentences.txt', 'val_sentences_errors_file': 'shi.teacher_general.val.sentences.errors.txt', 'val_sentences_file': 'shi.teacher_general.val.sentences.txt', 'test_sentences_errors_file': 'shi.teacher_general.test.sentences.errors.txt', 'test_sentences_file': 'shi.teacher_general.test.sentences.txt', 'metric': 'chrF', 'save_model': True}
#
#
# Creating new vocabulary
# Len of w2i:  4999
# Len of i2w:  4999
# Len of char vocab:  33
#
#
# Initializing an only ScRNN model
#
#
# Training the model...
#
# Average train loss after 1 iteration = 0.1756
# Total train chrF after 1 iteration = 54.3199
# Average val loss after 1 iteration = 0.1603
# Total val chrF after 1 iteration = 74.0408
# Average test loss after 1 iteration = 0.1632
# Total test chrF after 1 iteration = 74.5440
# Dumping after  1
# Time for the iteration 16.8 seconds
#
#
# Average train loss after 2 iteration = 0.1134
# Total train chrF after 2 iteration = 61.9745
# Average val loss after 2 iteration = 0.1001
# Total val chrF after 2 iteration = 77.1094
# Average test loss after 2 iteration = 0.1023
# Total test chrF after 2 iteration = 77.3213
# Dumping after  2
# Time for the iteration 16.5 seconds
#
#
# Average train loss after 3 iteration = 0.0774
# Total train chrF after 3 iteration = 68.3841
# Average val loss after 3 iteration = 0.0740
# Total val chrF after 3 iteration = 79.5515
# Average test loss after 3 iteration = 0.0760
# Total test chrF after 3 iteration = 79.9126
# Dumping after  3
# Time for the iteration 16.7 seconds
#
#
# Average train loss after 4 iteration = 0.0576
# Total train chrF after 4 iteration = 72.3137
# Average val loss after 4 iteration = 0.0600
# Total val chrF after 4 iteration = 80.2609
# Average test loss after 4 iteration = 0.0618
# Total test chrF after 4 iteration = 80.8146
# Dumping after  4
# Time for the iteration 16.7 seconds
#
#
# Average train loss after 5 iteration = 0.0455
# Total train chrF after 5 iteration = 74.8814
# Average val loss after 5 iteration = 0.0505
# Total val chrF after 5 iteration = 80.8585
# Average test loss after 5 iteration = 0.0521
# Total test chrF after 5 iteration = 81.5296
# Dumping after  5
# Time for the iteration 16.8 seconds
#
#
# Average train loss after 6 iteration = 0.0376
# Total train chrF after 6 iteration = 76.8409
# Average val loss after 6 iteration = 0.0434
# Total val chrF after 6 iteration = 81.3053
# Average test loss after 6 iteration = 0.0447
# Total test chrF after 6 iteration = 81.8746
# Dumping after  6
# Time for the iteration 16.6 seconds
#
#
# Average train loss after 7 iteration = 0.0322
# Total train chrF after 7 iteration = 78.4056
# Average val loss after 7 iteration = 0.0378
# Total val chrF after 7 iteration = 81.5949
# Average test loss after 7 iteration = 0.0390
# Total test chrF after 7 iteration = 82.2214
# Dumping after  7
# Time for the iteration 16.8 seconds
#
#
# Average train loss after 8 iteration = 0.0282
# Total train chrF after 8 iteration = 79.7765
# Average val loss after 8 iteration = 0.0337
# Total val chrF after 8 iteration = 81.8447
# Average test loss after 8 iteration = 0.0347
# Total test chrF after 8 iteration = 82.4725
# Dumping after  8
# Time for the iteration 16.8 seconds
#
#
# Average train loss after 9 iteration = 0.0253
# Total train chrF after 9 iteration = 80.9179
# Average val loss after 9 iteration = 0.0307
# Total val chrF after 9 iteration = 82.1112
# Average test loss after 9 iteration = 0.0316
# Total test chrF after 9 iteration = 82.5648
# Dumping after  9
# Time for the iteration 17.0 seconds
#
#
# Average train loss after 10 iteration = 0.0231
# Total train chrF after 10 iteration = 81.8591
# Average val loss after 10 iteration = 0.0285
# Total val chrF after 10 iteration = 82.3486
# Average test loss after 10 iteration = 0.0293
# Total test chrF after 10 iteration = 82.6926
# Dumping after  10
# Time for the iteration 16.8 seconds
#
#
# Average train loss after 11 iteration = 0.0213
# Total train chrF after 11 iteration = 82.6435
# Average val loss after 11 iteration = 0.0267
# Total val chrF after 11 iteration = 82.6494
# Average test loss after 11 iteration = 0.0275
# Total test chrF after 11 iteration = 82.9688
# Dumping after  11
# Time for the iteration 16.9 seconds
#
#
# Average train loss after 12 iteration = 0.0199
# Total train chrF after 12 iteration = 83.2977
# Average val loss after 12 iteration = 0.0253
# Total val chrF after 12 iteration = 82.7563
# Average test loss after 12 iteration = 0.0260
# Total test chrF after 12 iteration = 83.1351
# Dumping after  12
# Time for the iteration 16.9 seconds
#
#
# Average train loss after 13 iteration = 0.0187
# Total train chrF after 13 iteration = 83.8852
# Average val loss after 13 iteration = 0.0241
# Total val chrF after 13 iteration = 82.9054
# Average test loss after 13 iteration = 0.0248
# Total test chrF after 13 iteration = 83.3275
# Dumping after  13
# Time for the iteration 17.0 seconds
#
#
# Average train loss after 14 iteration = 0.0177
# Total train chrF after 14 iteration = 84.3790
# Average val loss after 14 iteration = 0.0231
# Total val chrF after 14 iteration = 83.0045
# Average test loss after 14 iteration = 0.0238
# Total test chrF after 14 iteration = 83.4868
# Dumping after  14
# Time for the iteration 16.9 seconds
#
#
# Average train loss after 15 iteration = 0.0168
# Total train chrF after 15 iteration = 84.8293
# Average val loss after 15 iteration = 0.0223
# Total val chrF after 15 iteration = 83.1318
# Average test loss after 15 iteration = 0.0229
# Total test chrF after 15 iteration = 83.6678
# Dumping after  15
# Time for the iteration 17.0 seconds
#
#
# Average train loss after 16 iteration = 0.0160
# Total train chrF after 16 iteration = 85.2189
# Average val loss after 16 iteration = 0.0215
# Total val chrF after 16 iteration = 83.3096
# Average test loss after 16 iteration = 0.0221
# Total test chrF after 16 iteration = 83.9159
# Dumping after  16
# Time for the iteration 16.9 seconds
#
#
# Average train loss after 17 iteration = 0.0152
# Total train chrF after 17 iteration = 85.6046
# Average val loss after 17 iteration = 0.0209
# Total val chrF after 17 iteration = 83.4535
# Average test loss after 17 iteration = 0.0215
# Total test chrF after 17 iteration = 84.0537
# Dumping after  17
# Time for the iteration 17.1 seconds
#
#
# Average train loss after 18 iteration = 0.0146
# Total train chrF after 18 iteration = 85.9452
# Average val loss after 18 iteration = 0.0203
# Total val chrF after 18 iteration = 83.5338
# Average test loss after 18 iteration = 0.0210
# Total test chrF after 18 iteration = 84.1336
# Dumping after  18
# Time for the iteration 17.1 seconds
#
#
# Average train loss after 19 iteration = 0.0140
# Total train chrF after 19 iteration = 86.2636
# Average val loss after 19 iteration = 0.0199
# Total val chrF after 19 iteration = 83.6534
# Average test loss after 19 iteration = 0.0205
# Total test chrF after 19 iteration = 84.2657
# Dumping after  19
# Time for the iteration 17.1 seconds
#
#
# Average train loss after 20 iteration = 0.0135
# Total train chrF after 20 iteration = 86.5648
# Average val loss after 20 iteration = 0.0194
# Total val chrF after 20 iteration = 83.7588
# Average test loss after 20 iteration = 0.0200
# Total test chrF after 20 iteration = 84.3160
# Dumping after  20
# Time for the iteration 16.9 seconds
#
#
# Average train loss after 21 iteration = 0.0129
# Total train chrF after 21 iteration = 86.8213
# Average val loss after 21 iteration = 0.0190
# Total val chrF after 21 iteration = 83.7758
# Average test loss after 21 iteration = 0.0197
# Total test chrF after 21 iteration = 84.4276
# Dumping after  21
# Time for the iteration 17.0 seconds
#
#
# Average train loss after 22 iteration = 0.0125
# Total train chrF after 22 iteration = 87.0650
# Average val loss after 22 iteration = 0.0187
# Total val chrF after 22 iteration = 83.9199
# Average test loss after 22 iteration = 0.0194
# Total test chrF after 22 iteration = 84.5914
# Dumping after  22
# Time for the iteration 17.0 seconds
#
#
# Average train loss after 23 iteration = 0.0120
# Total train chrF after 23 iteration = 87.3150
# Average val loss after 23 iteration = 0.0184
# Total val chrF after 23 iteration = 84.0231
# Average test loss after 23 iteration = 0.0191
# Total test chrF after 23 iteration = 84.6120
# Dumping after  23
# Time for the iteration 17.1 seconds
#
#
# Average train loss after 24 iteration = 0.0116
# Total train chrF after 24 iteration = 87.5307
# Average val loss after 24 iteration = 0.0181
# Total val chrF after 24 iteration = 84.2194
# Average test loss after 24 iteration = 0.0188
# Total test chrF after 24 iteration = 84.7110
# Dumping after  24
# Time for the iteration 17.0 seconds
#
#
# Average train loss after 25 iteration = 0.0112
# Total train chrF after 25 iteration = 87.7266
# Average val loss after 25 iteration = 0.0179
# Total val chrF after 25 iteration = 84.3209
# Average test loss after 25 iteration = 0.0186
# Total test chrF after 25 iteration = 84.8079
# Dumping after  25
# Time for the iteration 17.1 seconds
#
#
# Average train loss after 26 iteration = 0.0109
# Total train chrF after 26 iteration = 87.9037
# Average val loss after 26 iteration = 0.0177
# Total val chrF after 26 iteration = 84.3991
# Average test loss after 26 iteration = 0.0184
# Total test chrF after 26 iteration = 84.8310
# Dumping after  26
# Time for the iteration 17.1 seconds
#
#
# Average train loss after 27 iteration = 0.0105
# Total train chrF after 27 iteration = 88.0786
# Average val loss after 27 iteration = 0.0176
# Total val chrF after 27 iteration = 84.4594
# Average test loss after 27 iteration = 0.0183
# Total test chrF after 27 iteration = 84.8805
# Dumping after  27
# Time for the iteration 17.1 seconds
#
#
# Average train loss after 28 iteration = 0.0102
# Total train chrF after 28 iteration = 88.2582
# Average val loss after 28 iteration = 0.0174
# Total val chrF after 28 iteration = 84.5135
# Average test loss after 28 iteration = 0.0181
# Total test chrF after 28 iteration = 84.9002
# Dumping after  28
# Time for the iteration 17.2 seconds
#
#
# Average train loss after 29 iteration = 0.0099
# Total train chrF after 29 iteration = 88.4151
# Average val loss after 29 iteration = 0.0173
# Total val chrF after 29 iteration = 84.5790
# Average test loss after 29 iteration = 0.0180
# Total test chrF after 29 iteration = 84.9409
# Dumping after  29
# Time for the iteration 17.0 seconds
#
#
# Average train loss after 30 iteration = 0.0096
# Total train chrF after 30 iteration = 88.5625
# Average val loss after 30 iteration = 0.0172
# Total val chrF after 30 iteration = 84.6557
# Average test loss after 30 iteration = 0.0179
# Total test chrF after 30 iteration = 84.8933
# Dumping after  30
# Time for the iteration 17.1 seconds
#
#
# Average train loss after 31 iteration = 0.0093
# Total train chrF after 31 iteration = 88.7046
# Average val loss after 31 iteration = 0.0171
# Total val chrF after 31 iteration = 84.7023
# Average test loss after 31 iteration = 0.0179
# Total test chrF after 31 iteration = 84.9235
# Dumping after  31
# Time for the iteration 17.1 seconds
#
#
# Average train loss after 32 iteration = 0.0090
# Total train chrF after 32 iteration = 88.8474
# Average val loss after 32 iteration = 0.0171
# Total val chrF after 32 iteration = 84.7744
# Average test loss after 32 iteration = 0.0178
# Total test chrF after 32 iteration = 84.9227
# Dumping after  32
# Time for the iteration 17.1 seconds
#
#
# Average train loss after 33 iteration = 0.0088
# Total train chrF after 33 iteration = 88.9926
# Average val loss after 33 iteration = 0.0170
# Total val chrF after 33 iteration = 84.8132
# Average test loss after 33 iteration = 0.0178
# Total test chrF after 33 iteration = 84.9428
# Dumping after  33
# Time for the iteration 17.2 seconds
#
#
# Average train loss after 34 iteration = 0.0085
# Total train chrF after 34 iteration = 89.1207
# Average val loss after 34 iteration = 0.0170
# Total val chrF after 34 iteration = 84.8447
# Average test loss after 34 iteration = 0.0177
# Total test chrF after 34 iteration = 84.9629
# Dumping after  34
# Time for the iteration 17.0 seconds
#
#
# Average train loss after 35 iteration = 0.0083
# Total train chrF after 35 iteration = 89.2470
# Average val loss after 35 iteration = 0.0169
# Total val chrF after 35 iteration = 84.9159
# Average test loss after 35 iteration = 0.0177
# Total test chrF after 35 iteration = 84.9266
# Dumping after  35
# Time for the iteration 16.9 seconds
#
#
# Average train loss after 36 iteration = 0.0081
# Total train chrF after 36 iteration = 89.3588
# Average val loss after 36 iteration = 0.0169
# Total val chrF after 36 iteration = 84.9250
# Average test loss after 36 iteration = 0.0177
# Total test chrF after 36 iteration = 84.9568
# Dumping after  36
# Time for the iteration 17.2 seconds
#
#
# Average train loss after 37 iteration = 0.0079
# Total train chrF after 37 iteration = 89.4754
# Average val loss after 37 iteration = 0.0169
# Total val chrF after 37 iteration = 84.8940
# Average test loss after 37 iteration = 0.0177
# Total test chrF after 37 iteration = 84.9784
# Time for the iteration 17.1 seconds
#
#
# Average train loss after 38 iteration = 0.0077
# Total train chrF after 38 iteration = 89.5848
# Average val loss after 38 iteration = 0.0169
# Total val chrF after 38 iteration = 84.9083
# Average test loss after 38 iteration = 0.0177
# Total test chrF after 38 iteration = 84.9625
# Time for the iteration 17.1 seconds
#
#
# Average train loss after 39 iteration = 0.0075
# Total train chrF after 39 iteration = 89.6792
# Average val loss after 39 iteration = 0.0169
# Total val chrF after 39 iteration = 84.9322
# Average test loss after 39 iteration = 0.0177
# Total test chrF after 39 iteration = 84.9698
# Dumping after  39
# Time for the iteration 17.1 seconds
#
#
# Average train loss after 40 iteration = 0.0073
# Total train chrF after 40 iteration = 89.7707
# Average val loss after 40 iteration = 0.0169
# Total val chrF after 40 iteration = 84.9038
# Average test loss after 40 iteration = 0.0177
# Total test chrF after 40 iteration = 84.9983
# Time for the iteration 17.0 seconds
#
#
# Average train loss after 41 iteration = 0.0071
# Total train chrF after 41 iteration = 89.8663
# Average val loss after 41 iteration = 0.0169
# Total val chrF after 41 iteration = 84.9374
# Average test loss after 41 iteration = 0.0177
# Total test chrF after 41 iteration = 85.0040
# Dumping after  41
# Time for the iteration 17.3 seconds
#
#
# Average train loss after 42 iteration = 0.0069
# Total train chrF after 42 iteration = 89.9533
# Average val loss after 42 iteration = 0.0169
# Total val chrF after 42 iteration = 84.9336
# Average test loss after 42 iteration = 0.0177
# Total test chrF after 42 iteration = 85.0823
# Time for the iteration 17.1 seconds
#
#
# Average train loss after 43 iteration = 0.0067
# Total train chrF after 43 iteration = 90.0414
# Average val loss after 43 iteration = 0.0169
# Total val chrF after 43 iteration = 85.0044
# Average test loss after 43 iteration = 0.0178
# Total test chrF after 43 iteration = 85.1024
# Dumping after  43
# Time for the iteration 17.1 seconds
#
#
# Average train loss after 44 iteration = 0.0066
# Total train chrF after 44 iteration = 90.1217
# Average val loss after 44 iteration = 0.0169
# Total val chrF after 44 iteration = 85.0095
# Average test loss after 44 iteration = 0.0178
# Total test chrF after 44 iteration = 85.1487
# Dumping after  44
# Time for the iteration 17.2 seconds
#
#
# Average train loss after 45 iteration = 0.0064
# Total train chrF after 45 iteration = 90.2051
# Average val loss after 45 iteration = 0.0170
# Total val chrF after 45 iteration = 85.0424
# Average test loss after 45 iteration = 0.0179
# Total test chrF after 45 iteration = 85.1917
# Dumping after  45
# Time for the iteration 17.2 seconds
#
#
# Average train loss after 46 iteration = 0.0062
# Total train chrF after 46 iteration = 90.2812
# Average val loss after 46 iteration = 0.0170
# Total val chrF after 46 iteration = 84.9908
# Average test loss after 46 iteration = 0.0179
# Total test chrF after 46 iteration = 85.2425
# Time for the iteration 17.1 seconds
#
#
# Average train loss after 47 iteration = 0.0061
# Total train chrF after 47 iteration = 90.3602
# Average val loss after 47 iteration = 0.0170
# Total val chrF after 47 iteration = 85.0124
# Average test loss after 47 iteration = 0.0179
# Total test chrF after 47 iteration = 85.2682
# Time for the iteration 17.1 seconds
#
#
# Average train loss after 48 iteration = 0.0060
# Total train chrF after 48 iteration = 90.4282
# Average val loss after 48 iteration = 0.0171
# Total val chrF after 48 iteration = 85.0122
# Average test loss after 48 iteration = 0.0180
# Total test chrF after 48 iteration = 85.2547
# Time for the iteration 17.0 seconds
#
#
# Average train loss after 49 iteration = 0.0058
# Total train chrF after 49 iteration = 90.4967
# Average val loss after 49 iteration = 0.0171
# Total val chrF after 49 iteration = 84.9994
# Average test loss after 49 iteration = 0.0180
# Total test chrF after 49 iteration = 85.2779
# Time for the iteration 16.9 seconds
#
#
# Average train loss after 50 iteration = 0.0057
# Total train chrF after 50 iteration = 90.5604
# Average val loss after 50 iteration = 0.0171
# Total val chrF after 50 iteration = 84.9880
# Average test loss after 50 iteration = 0.0181
# Total test chrF after 50 iteration = 85.2997
# Time for the iteration 17.2 seconds
#
#
# Average train loss after 51 iteration = 0.0055
# Total train chrF after 51 iteration = 90.6184
# Average val loss after 51 iteration = 0.0172
# Total val chrF after 51 iteration = 84.9917
# Average test loss after 51 iteration = 0.0182
# Total test chrF after 51 iteration = 85.2970
# Time for the iteration 17.3 seconds
#
#
# Average train loss after 52 iteration = 0.0054
# Total train chrF after 52 iteration = 90.6795
# Average val loss after 52 iteration = 0.0172
# Total val chrF after 52 iteration = 85.0350
# Average test loss after 52 iteration = 0.0182
# Total test chrF after 52 iteration = 85.3146
# Time for the iteration 17.2 seconds
#
#
# Average train loss after 53 iteration = 0.0053
# Total train chrF after 53 iteration = 90.7396
# Average val loss after 53 iteration = 0.0173
# Total val chrF after 53 iteration = 85.0531
# Average test loss after 53 iteration = 0.0183
# Total test chrF after 53 iteration = 85.3249
# Dumping after  53
# Time for the iteration 17.1 seconds
#
#
# Average train loss after 54 iteration = 0.0052
# Total train chrF after 54 iteration = 90.7926
# Average val loss after 54 iteration = 0.0173
# Total val chrF after 54 iteration = 85.0177
# Average test loss after 54 iteration = 0.0184
# Total test chrF after 54 iteration = 85.3300
# Time for the iteration 17.1 seconds
#
#
# Average train loss after 55 iteration = 0.0051
# Total train chrF after 55 iteration = 90.8484
# Average val loss after 55 iteration = 0.0173
# Total val chrF after 55 iteration = 84.9970
# Average test loss after 55 iteration = 0.0184
# Total test chrF after 55 iteration = 85.3294
# Time for the iteration 17.1 seconds
#
#
# Average train loss after 56 iteration = 0.0050
# Total train chrF after 56 iteration = 90.8935
# Average val loss after 56 iteration = 0.0174
# Total val chrF after 56 iteration = 85.0620
# Average test loss after 56 iteration = 0.0185
# Total test chrF after 56 iteration = 85.3454
# Dumping after  56
# Time for the iteration 17.1 seconds
#
#
# Average train loss after 57 iteration = 0.0048
# Total train chrF after 57 iteration = 90.9464
# Average val loss after 57 iteration = 0.0174
# Total val chrF after 57 iteration = 85.0180
# Average test loss after 57 iteration = 0.0186
# Total test chrF after 57 iteration = 85.3569
# Time for the iteration 17.1 seconds
#
#
# Average train loss after 58 iteration = 0.0047
# Total train chrF after 58 iteration = 90.9962
# Average val loss after 58 iteration = 0.0175
# Total val chrF after 58 iteration = 85.0186
# Average test loss after 58 iteration = 0.0187
# Total test chrF after 58 iteration = 85.3268
# Time for the iteration 17.0 seconds
#
#
# Average train loss after 59 iteration = 0.0046
# Total train chrF after 59 iteration = 91.0446
# Average val loss after 59 iteration = 0.0176
# Total val chrF after 59 iteration = 84.9694
# Average test loss after 59 iteration = 0.0187
# Total test chrF after 59 iteration = 85.2866
# Time for the iteration 17.1 seconds
#
#
# Average train loss after 60 iteration = 0.0045
# Total train chrF after 60 iteration = 91.0932
# Average val loss after 60 iteration = 0.0176
# Total val chrF after 60 iteration = 84.9058
# Average test loss after 60 iteration = 0.0188
# Total test chrF after 60 iteration = 85.2236
# Time for the iteration 17.0 seconds
#
#
# Average train loss after 61 iteration = 0.0044
# Total train chrF after 61 iteration = 91.1383
# Average val loss after 61 iteration = 0.0177
# Total val chrF after 61 iteration = 84.8659
# Average test loss after 61 iteration = 0.0189
# Total test chrF after 61 iteration = 85.2095
# Time for the iteration 17.1 seconds
#
#
# Average train loss after 62 iteration = 0.0043
# Total train chrF after 62 iteration = 91.1825
# Average val loss after 62 iteration = 0.0177
# Total val chrF after 62 iteration = 84.8539
# Average test loss after 62 iteration = 0.0190
# Total test chrF after 62 iteration = 85.1430
# Time for the iteration 16.9 seconds
#
#
# Average train loss after 63 iteration = 0.0043
# Total train chrF after 63 iteration = 91.2265
# Average val loss after 63 iteration = 0.0178
# Total val chrF after 63 iteration = 84.8649
# Average test loss after 63 iteration = 0.0191
# Total test chrF after 63 iteration = 85.1252
# Time for the iteration 16.9 seconds
#
#
# Average train loss after 64 iteration = 0.0042
# Total train chrF after 64 iteration = 91.2655
# Average val loss after 64 iteration = 0.0178
# Total val chrF after 64 iteration = 84.9195
# Average test loss after 64 iteration = 0.0192
# Total test chrF after 64 iteration = 85.1091
# Time for the iteration 17.1 seconds
#
#
# Average train loss after 65 iteration = 0.0041
# Total train chrF after 65 iteration = 91.3018
# Average val loss after 65 iteration = 0.0179
# Total val chrF after 65 iteration = 84.9194
# Average test loss after 65 iteration = 0.0193
# Total test chrF after 65 iteration = 85.1329
# Time for the iteration 17.2 seconds
#
#
# Average train loss after 66 iteration = 0.0040
# Total train chrF after 66 iteration = 91.3424
# Average val loss after 66 iteration = 0.0180
# Total val chrF after 66 iteration = 84.9096
# Average test loss after 66 iteration = 0.0194
# Total test chrF after 66 iteration = 85.1229
# Time for the iteration 17.0 seconds
#
#
# Average train loss after 67 iteration = 0.0039
# Total train chrF after 67 iteration = 91.3760
# Average val loss after 67 iteration = 0.0180
# Total val chrF after 67 iteration = 84.8916
# Average test loss after 67 iteration = 0.0195
# Total test chrF after 67 iteration = 85.1464
# Time for the iteration 17.3 seconds
#
#
# Average train loss after 68 iteration = 0.0038
# Total train chrF after 68 iteration = 91.4081
# Average val loss after 68 iteration = 0.0181
# Total val chrF after 68 iteration = 84.8791
# Average test loss after 68 iteration = 0.0196
# Total test chrF after 68 iteration = 85.1505
# Time for the iteration 17.2 seconds
#
#
# Average train loss after 69 iteration = 0.0037
# Total train chrF after 69 iteration = 91.4413
# Average val loss after 69 iteration = 0.0181
# Total val chrF after 69 iteration = 84.8543
# Average test loss after 69 iteration = 0.0197
# Total test chrF after 69 iteration = 85.1879
# Time for the iteration 17.3 seconds
#
#
# Average train loss after 70 iteration = 0.0037
# Total train chrF after 70 iteration = 91.4748
# Average val loss after 70 iteration = 0.0182
# Total val chrF after 70 iteration = 84.8490
# Average test loss after 70 iteration = 0.0198
# Total test chrF after 70 iteration = 85.1891
# Time for the iteration 17.1 seconds
#
#
# Average train loss after 71 iteration = 0.0036
# Total train chrF after 71 iteration = 91.5119
# Average val loss after 71 iteration = 0.0183
# Total val chrF after 71 iteration = 84.8812
# Average test loss after 71 iteration = 0.0199
# Total test chrF after 71 iteration = 85.1586
# Time for the iteration 17.1 seconds
#
#
# Average train loss after 72 iteration = 0.0035
# Total train chrF after 72 iteration = 91.5428
# Average val loss after 72 iteration = 0.0183
# Total val chrF after 72 iteration = 84.8428
# Average test loss after 72 iteration = 0.0200
# Total test chrF after 72 iteration = 85.1126
# Time for the iteration 17.0 seconds
#
#
# Average train loss after 73 iteration = 0.0034
# Total train chrF after 73 iteration = 91.5776
# Average val loss after 73 iteration = 0.0184
# Total val chrF after 73 iteration = 84.8480
# Average test loss after 73 iteration = 0.0201
# Total test chrF after 73 iteration = 85.0848
# Time for the iteration 17.1 seconds
#
#
# Average train loss after 74 iteration = 0.0034
# Total train chrF after 74 iteration = 91.6047
# Average val loss after 74 iteration = 0.0185
# Total val chrF after 74 iteration = 84.8524
# Average test loss after 74 iteration = 0.0202
# Total test chrF after 74 iteration = 85.0467
# Time for the iteration 17.2 seconds
#
#
# Average train loss after 75 iteration = 0.0033
# Total train chrF after 75 iteration = 91.6336
# Average val loss after 75 iteration = 0.0186
# Total val chrF after 75 iteration = 84.8576
# Average test loss after 75 iteration = 0.0203
# Total test chrF after 75 iteration = 85.0306
# Time for the iteration 17.1 seconds
#
#
# Average train loss after 76 iteration = 0.0032
# Total train chrF after 76 iteration = 91.6570
# Average val loss after 76 iteration = 0.0186
# Total val chrF after 76 iteration = 84.8274
# Average test loss after 76 iteration = 0.0204
# Total test chrF after 76 iteration = 85.0396
# Time for the iteration 17.0 seconds
#
#
# Average train loss after 77 iteration = 0.0032
# Total train chrF after 77 iteration = 91.6914
# Average val loss after 77 iteration = 0.0187
# Total val chrF after 77 iteration = 84.8346
# Average test loss after 77 iteration = 0.0205
# Total test chrF after 77 iteration = 85.0125
# Time for the iteration 17.1 seconds
#
#
# Average train loss after 78 iteration = 0.0031
# Total train chrF after 78 iteration = 91.7206
# Average val loss after 78 iteration = 0.0188
# Total val chrF after 78 iteration = 84.8394
# Average test loss after 78 iteration = 0.0206
# Total test chrF after 78 iteration = 84.9701
# Time for the iteration 16.9 seconds
#
#
# Average train loss after 79 iteration = 0.0030
# Total train chrF after 79 iteration = 91.7492
# Average val loss after 79 iteration = 0.0189
# Total val chrF after 79 iteration = 84.8092
# Average test loss after 79 iteration = 0.0207
# Total test chrF after 79 iteration = 84.9333
# Time for the iteration 17.2 seconds
#
#
# Average train loss after 80 iteration = 0.0030
# Total train chrF after 80 iteration = 91.7743
# Average val loss after 80 iteration = 0.0190
# Total val chrF after 80 iteration = 84.7783
# Average test loss after 80 iteration = 0.0208
# Total test chrF after 80 iteration = 84.8885
# Time for the iteration 17.0 seconds
#
#
# Average train loss after 81 iteration = 0.0029
# Total train chrF after 81 iteration = 91.7988
# Average val loss after 81 iteration = 0.0190
# Total val chrF after 81 iteration = 84.7595
# Average test loss after 81 iteration = 0.0210
# Total test chrF after 81 iteration = 84.8736
# Time for the iteration 17.1 seconds
#
#
# Average train loss after 82 iteration = 0.0029
# Total train chrF after 82 iteration = 91.8210
# Average val loss after 82 iteration = 0.0191
# Total val chrF after 82 iteration = 84.7730
# Average test loss after 82 iteration = 0.0211
# Total test chrF after 82 iteration = 84.8891
# Time for the iteration 17.2 seconds
#
#
# Average train loss after 83 iteration = 0.0028
# Total train chrF after 83 iteration = 91.8449
# Average val loss after 83 iteration = 0.0192
# Total val chrF after 83 iteration = 84.7268
# Average test loss after 83 iteration = 0.0212
# Total test chrF after 83 iteration = 84.9265
# Time for the iteration 17.2 seconds
#
#
#
#
# Aborting since there hasn't been much progress
# <Figure size 640x480 with 1 Axes>
# <Figure size 640x480 with 1 Axes>

# %%
language = "shi"
task_name = "random_teacher_general"
vocab_size = 4999
num_epochs = 100
batch_size = 32
model = "50_1"
optimizer = "Adam"
metric = "chrF"

# %%
from IPython.display import Image

Image("curves/{}_{}_{}_{}_{}_loss.png".format(language, task_name, vocab_size, num_epochs, batch_size))

# %%
Image("curves/{}_{}_{}_{}_{}_{}.png".format(language, task_name, vocab_size, num_epochs, batch_size, metric))

# %%
print("{}.{}.{}.{}.{}.{}.{}".format(language, task_name, vocab_size, num_epochs, batch_size, model, optimizer))
# Out:
# shi.random_teacher_general.4999.100.32.50_1.Adam
