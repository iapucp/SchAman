# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
# %cd "drive/MyDrive/Tesis/scRNN"
# Out:
# /content/drive/MyDrive/Tesis/scRNN

# %%
import torch

torch.cuda.is_available()
# Out:
# True

# %%
# !pip install sacrebleu
# Out:
# Collecting sacrebleu
#   Downloading sacrebleu-2.0.0-py3-none-any.whl (90 kB)
#      |████████████████████████████████| 90 kB 5.8 MB/s
# Requirement already satisfied: regex in /usr/local/lib/python3.7/dist-packages (from sacrebleu) (2019.12.20)
# Collecting colorama
#   Downloading colorama-0.4.4-py2.py3-none-any.whl (16 kB)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from sacrebleu) (1.19.5)
# Requirement already satisfied: tabulate>=0.8.9 in /usr/local/lib/python3.7/dist-packages (from sacrebleu) (0.8.9)
# Collecting portalocker
#   Downloading portalocker-2.3.2-py2.py3-none-any.whl (15 kB)
# Installing collected packages: portalocker, colorama, sacrebleu
# Successfully installed colorama-0.4.4 portalocker-2.3.2 sacrebleu-2.0.0

# %%
# !python3 train.py --language ash --task-name sylsim_teacher_general --num-epochs 100 --batch-size 32 --vocab-size 4999 --new-vocab --train --train-sentences-errors-file ash.sylsim_teacher_general.train.sentences.errors.txt --train-sentences-file ash.sylsim_teacher_general.train.sentences.txt --val-sentences-errors-file ash.teacher_general.val.sentences.errors.txt --val-sentences-file ash.teacher_general.val.sentences.txt --test-sentences-errors-file ash.teacher_general.test.sentences.errors.txt --test-sentences-file ash.teacher_general.test.sentences.txt --metric chrF --save
# Out:
# Parameters
# {'language': 'ash', 'task_name': 'sylsim_teacher_general', 'vocab_size': 4999, 'num_epochs': 100, 'batch_size': 32, 'model_name': 'shi_random_20531_100_32', 'new_vocab': True, 'need_to_train': True, 'train_sentences_errors_file': 'ash.sylsim_teacher_general.train.sentences.errors.txt', 'train_sentences_file': 'ash.sylsim_teacher_general.train.sentences.txt', 'val_sentences_errors_file': 'ash.teacher_general.val.sentences.errors.txt', 'val_sentences_file': 'ash.teacher_general.val.sentences.txt', 'test_sentences_errors_file': 'ash.teacher_general.test.sentences.errors.txt', 'test_sentences_file': 'ash.teacher_general.test.sentences.txt', 'metric': 'chrF', 'save_model': True}
#
#
# Creating new vocabulary
# Len of w2i:  4999
# Len of i2w:  4999
# Len of char vocab:  23
#
#
# Initializing an only ScRNN model
#
#
# Training the model...
#
# Average train loss after 1 iteration = 0.1846
# Total train chrF after 1 iteration = 71.2310
# Average val loss after 1 iteration = 0.2079
# Total val chrF after 1 iteration = 83.1435
# Average test loss after 1 iteration = 0.2039
# Total test chrF after 1 iteration = 82.0502
# Dumping after  1
# Time for the iteration 11.0 seconds
#
#
# Average train loss after 2 iteration = 0.1558
# Total train chrF after 2 iteration = 70.7703
# Average val loss after 2 iteration = 0.1425
# Total val chrF after 2 iteration = 81.7655
# Average test loss after 2 iteration = 0.1396
# Total test chrF after 2 iteration = 81.2061
# Time for the iteration 10.8 seconds
#
#
# Average train loss after 3 iteration = 0.1240
# Total train chrF after 3 iteration = 72.7789
# Average val loss after 3 iteration = 0.1086
# Total val chrF after 3 iteration = 84.4269
# Average test loss after 3 iteration = 0.1063
# Total test chrF after 3 iteration = 83.4602
# Dumping after  3
# Time for the iteration 10.8 seconds
#
#
# Average train loss after 4 iteration = 0.1007
# Total train chrF after 4 iteration = 74.6920
# Average val loss after 4 iteration = 0.0875
# Total val chrF after 4 iteration = 85.9257
# Average test loss after 4 iteration = 0.0854
# Total test chrF after 4 iteration = 84.7545
# Dumping after  4
# Time for the iteration 10.7 seconds
#
#
# Average train loss after 5 iteration = 0.0835
# Total train chrF after 5 iteration = 76.2597
# Average val loss after 5 iteration = 0.0731
# Total val chrF after 5 iteration = 86.5991
# Average test loss after 5 iteration = 0.0712
# Total test chrF after 5 iteration = 85.5645
# Dumping after  5
# Time for the iteration 10.8 seconds
#
#
# Average train loss after 6 iteration = 0.0701
# Total train chrF after 6 iteration = 77.6063
# Average val loss after 6 iteration = 0.0628
# Total val chrF after 6 iteration = 86.9642
# Average test loss after 6 iteration = 0.0611
# Total test chrF after 6 iteration = 86.1722
# Dumping after  6
# Time for the iteration 10.8 seconds
#
#
# Average train loss after 7 iteration = 0.0598
# Total train chrF after 7 iteration = 78.7306
# Average val loss after 7 iteration = 0.0549
# Total val chrF after 7 iteration = 87.2071
# Average test loss after 7 iteration = 0.0534
# Total test chrF after 7 iteration = 86.3712
# Dumping after  7
# Time for the iteration 11.0 seconds
#
#
# Average train loss after 8 iteration = 0.0518
# Total train chrF after 8 iteration = 79.7637
# Average val loss after 8 iteration = 0.0488
# Total val chrF after 8 iteration = 87.3832
# Average test loss after 8 iteration = 0.0475
# Total test chrF after 8 iteration = 86.6595
# Dumping after  8
# Time for the iteration 10.9 seconds
#
#
# Average train loss after 9 iteration = 0.0454
# Total train chrF after 9 iteration = 80.6607
# Average val loss after 9 iteration = 0.0439
# Total val chrF after 9 iteration = 87.5217
# Average test loss after 9 iteration = 0.0427
# Total test chrF after 9 iteration = 86.8757
# Dumping after  9
# Time for the iteration 10.8 seconds
#
#
# Average train loss after 10 iteration = 0.0402
# Total train chrF after 10 iteration = 81.4855
# Average val loss after 10 iteration = 0.0400
# Total val chrF after 10 iteration = 87.7412
# Average test loss after 10 iteration = 0.0389
# Total test chrF after 10 iteration = 87.0701
# Dumping after  10
# Time for the iteration 10.9 seconds
#
#
# Average train loss after 11 iteration = 0.0359
# Total train chrF after 11 iteration = 82.2939
# Average val loss after 11 iteration = 0.0370
# Total val chrF after 11 iteration = 87.8043
# Average test loss after 11 iteration = 0.0359
# Total test chrF after 11 iteration = 87.1886
# Dumping after  11
# Time for the iteration 10.9 seconds
#
#
# Average train loss after 12 iteration = 0.0324
# Total train chrF after 12 iteration = 83.0039
# Average val loss after 12 iteration = 0.0346
# Total val chrF after 12 iteration = 87.7799
# Average test loss after 12 iteration = 0.0335
# Total test chrF after 12 iteration = 87.3082
# Time for the iteration 10.9 seconds
#
#
# Average train loss after 13 iteration = 0.0294
# Total train chrF after 13 iteration = 83.6683
# Average val loss after 13 iteration = 0.0326
# Total val chrF after 13 iteration = 87.9002
# Average test loss after 13 iteration = 0.0316
# Total test chrF after 13 iteration = 87.3502
# Dumping after  13
# Time for the iteration 10.9 seconds
#
#
# Average train loss after 14 iteration = 0.0270
# Total train chrF after 14 iteration = 84.2817
# Average val loss after 14 iteration = 0.0311
# Total val chrF after 14 iteration = 87.9960
# Average test loss after 14 iteration = 0.0300
# Total test chrF after 14 iteration = 87.3375
# Dumping after  14
# Time for the iteration 10.9 seconds
#
#
# Average train loss after 15 iteration = 0.0249
# Total train chrF after 15 iteration = 84.8627
# Average val loss after 15 iteration = 0.0298
# Total val chrF after 15 iteration = 88.1343
# Average test loss after 15 iteration = 0.0288
# Total test chrF after 15 iteration = 87.4210
# Dumping after  15
# Time for the iteration 10.9 seconds
#
#
# Average train loss after 16 iteration = 0.0231
# Total train chrF after 16 iteration = 85.4183
# Average val loss after 16 iteration = 0.0288
# Total val chrF after 16 iteration = 88.2510
# Average test loss after 16 iteration = 0.0277
# Total test chrF after 16 iteration = 87.4350
# Dumping after  16
# Time for the iteration 11.0 seconds
#
#
# Average train loss after 17 iteration = 0.0216
# Total train chrF after 17 iteration = 85.9064
# Average val loss after 17 iteration = 0.0280
# Total val chrF after 17 iteration = 88.3243
# Average test loss after 17 iteration = 0.0269
# Total test chrF after 17 iteration = 87.5311
# Dumping after  17
# Time for the iteration 10.9 seconds
#
#
# Average train loss after 18 iteration = 0.0203
# Total train chrF after 18 iteration = 86.3665
# Average val loss after 18 iteration = 0.0273
# Total val chrF after 18 iteration = 88.4413
# Average test loss after 18 iteration = 0.0262
# Total test chrF after 18 iteration = 87.5712
# Dumping after  18
# Time for the iteration 10.9 seconds
#
#
# Average train loss after 19 iteration = 0.0191
# Total train chrF after 19 iteration = 86.7819
# Average val loss after 19 iteration = 0.0267
# Total val chrF after 19 iteration = 88.3764
# Average test loss after 19 iteration = 0.0257
# Total test chrF after 19 iteration = 87.6043
# Time for the iteration 11.0 seconds
#
#
# Average train loss after 20 iteration = 0.0180
# Total train chrF after 20 iteration = 87.1478
# Average val loss after 20 iteration = 0.0263
# Total val chrF after 20 iteration = 88.3436
# Average test loss after 20 iteration = 0.0252
# Total test chrF after 20 iteration = 87.6215
# Time for the iteration 10.8 seconds
#
#
# Average train loss after 21 iteration = 0.0171
# Total train chrF after 21 iteration = 87.4583
# Average val loss after 21 iteration = 0.0259
# Total val chrF after 21 iteration = 88.4068
# Average test loss after 21 iteration = 0.0248
# Total test chrF after 21 iteration = 87.7056
# Time for the iteration 10.8 seconds
#
#
# Average train loss after 22 iteration = 0.0163
# Total train chrF after 22 iteration = 87.7351
# Average val loss after 22 iteration = 0.0256
# Total val chrF after 22 iteration = 88.4065
# Average test loss after 22 iteration = 0.0245
# Total test chrF after 22 iteration = 87.7334
# Time for the iteration 10.9 seconds
#
#
# Average train loss after 23 iteration = 0.0155
# Total train chrF after 23 iteration = 88.0123
# Average val loss after 23 iteration = 0.0254
# Total val chrF after 23 iteration = 88.5569
# Average test loss after 23 iteration = 0.0242
# Total test chrF after 23 iteration = 87.7608
# Dumping after  23
# Time for the iteration 11.0 seconds
#
#
# Average train loss after 24 iteration = 0.0148
# Total train chrF after 24 iteration = 88.2669
# Average val loss after 24 iteration = 0.0252
# Total val chrF after 24 iteration = 88.5692
# Average test loss after 24 iteration = 0.0240
# Total test chrF after 24 iteration = 87.7989
# Dumping after  24
# Time for the iteration 10.9 seconds
#
#
# Average train loss after 25 iteration = 0.0141
# Total train chrF after 25 iteration = 88.5020
# Average val loss after 25 iteration = 0.0250
# Total val chrF after 25 iteration = 88.5224
# Average test loss after 25 iteration = 0.0238
# Total test chrF after 25 iteration = 87.7833
# Time for the iteration 10.9 seconds
#
#
# Average train loss after 26 iteration = 0.0135
# Total train chrF after 26 iteration = 88.7150
# Average val loss after 26 iteration = 0.0249
# Total val chrF after 26 iteration = 88.5897
# Average test loss after 26 iteration = 0.0236
# Total test chrF after 26 iteration = 87.7154
# Dumping after  26
# Time for the iteration 10.9 seconds
#
#
# Average train loss after 27 iteration = 0.0130
# Total train chrF after 27 iteration = 88.9061
# Average val loss after 27 iteration = 0.0248
# Total val chrF after 27 iteration = 88.5883
# Average test loss after 27 iteration = 0.0234
# Total test chrF after 27 iteration = 87.7406
# Time for the iteration 10.9 seconds
#
#
# Average train loss after 28 iteration = 0.0124
# Total train chrF after 28 iteration = 89.0975
# Average val loss after 28 iteration = 0.0247
# Total val chrF after 28 iteration = 88.5904
# Average test loss after 28 iteration = 0.0233
# Total test chrF after 28 iteration = 87.7658
# Dumping after  28
# Time for the iteration 10.9 seconds
#
#
# Average train loss after 29 iteration = 0.0119
# Total train chrF after 29 iteration = 89.2725
# Average val loss after 29 iteration = 0.0246
# Total val chrF after 29 iteration = 88.5668
# Average test loss after 29 iteration = 0.0232
# Total test chrF after 29 iteration = 87.7495
# Time for the iteration 10.9 seconds
#
#
# Average train loss after 30 iteration = 0.0115
# Total train chrF after 30 iteration = 89.4338
# Average val loss after 30 iteration = 0.0246
# Total val chrF after 30 iteration = 88.6295
# Average test loss after 30 iteration = 0.0231
# Total test chrF after 30 iteration = 87.8525
# Dumping after  30
# Time for the iteration 11.0 seconds
#
#
# Average train loss after 31 iteration = 0.0110
# Total train chrF after 31 iteration = 89.5987
# Average val loss after 31 iteration = 0.0245
# Total val chrF after 31 iteration = 88.5969
# Average test loss after 31 iteration = 0.0230
# Total test chrF after 31 iteration = 87.8223
# Time for the iteration 10.9 seconds
#
#
# Average train loss after 32 iteration = 0.0106
# Total train chrF after 32 iteration = 89.7404
# Average val loss after 32 iteration = 0.0245
# Total val chrF after 32 iteration = 88.6099
# Average test loss after 32 iteration = 0.0230
# Total test chrF after 32 iteration = 87.8175
# Time for the iteration 10.9 seconds
#
#
# Average train loss after 33 iteration = 0.0102
# Total train chrF after 33 iteration = 89.8767
# Average val loss after 33 iteration = 0.0245
# Total val chrF after 33 iteration = 88.6098
# Average test loss after 33 iteration = 0.0229
# Total test chrF after 33 iteration = 87.8249
# Time for the iteration 11.0 seconds
#
#
# Average train loss after 34 iteration = 0.0098
# Total train chrF after 34 iteration = 90.0187
# Average val loss after 34 iteration = 0.0245
# Total val chrF after 34 iteration = 88.6458
# Average test loss after 34 iteration = 0.0229
# Total test chrF after 34 iteration = 87.8336
# Dumping after  34
# Time for the iteration 10.9 seconds
#
#
# Average train loss after 35 iteration = 0.0095
# Total train chrF after 35 iteration = 90.1450
# Average val loss after 35 iteration = 0.0245
# Total val chrF after 35 iteration = 88.6235
# Average test loss after 35 iteration = 0.0229
# Total test chrF after 35 iteration = 87.7385
# Time for the iteration 10.9 seconds
#
#
# Average train loss after 36 iteration = 0.0092
# Total train chrF after 36 iteration = 90.2590
# Average val loss after 36 iteration = 0.0245
# Total val chrF after 36 iteration = 88.6076
# Average test loss after 36 iteration = 0.0229
# Total test chrF after 36 iteration = 87.7252
# Time for the iteration 10.9 seconds
#
#
# Average train loss after 37 iteration = 0.0088
# Total train chrF after 37 iteration = 90.3707
# Average val loss after 37 iteration = 0.0245
# Total val chrF after 37 iteration = 88.5385
# Average test loss after 37 iteration = 0.0229
# Total test chrF after 37 iteration = 87.7088
# Time for the iteration 10.9 seconds
#
#
# Average train loss after 38 iteration = 0.0085
# Total train chrF after 38 iteration = 90.4663
# Average val loss after 38 iteration = 0.0246
# Total val chrF after 38 iteration = 88.5652
# Average test loss after 38 iteration = 0.0229
# Total test chrF after 38 iteration = 87.7176
# Time for the iteration 10.9 seconds
#
#
# Average train loss after 39 iteration = 0.0082
# Total train chrF after 39 iteration = 90.5616
# Average val loss after 39 iteration = 0.0246
# Total val chrF after 39 iteration = 88.6028
# Average test loss after 39 iteration = 0.0229
# Total test chrF after 39 iteration = 87.6567
# Time for the iteration 10.9 seconds
#
#
# Average train loss after 40 iteration = 0.0080
# Total train chrF after 40 iteration = 90.6534
# Average val loss after 40 iteration = 0.0247
# Total val chrF after 40 iteration = 88.5747
# Average test loss after 40 iteration = 0.0230
# Total test chrF after 40 iteration = 87.6511
# Time for the iteration 11.0 seconds
#
#
# Average train loss after 41 iteration = 0.0077
# Total train chrF after 41 iteration = 90.7419
# Average val loss after 41 iteration = 0.0247
# Total val chrF after 41 iteration = 88.5883
# Average test loss after 41 iteration = 0.0230
# Total test chrF after 41 iteration = 87.6342
# Time for the iteration 10.9 seconds
#
#
# Average train loss after 42 iteration = 0.0074
# Total train chrF after 42 iteration = 90.8323
# Average val loss after 42 iteration = 0.0248
# Total val chrF after 42 iteration = 88.5537
# Average test loss after 42 iteration = 0.0230
# Total test chrF after 42 iteration = 87.6358
# Time for the iteration 10.9 seconds
#
#
# Average train loss after 43 iteration = 0.0072
# Total train chrF after 43 iteration = 90.9022
# Average val loss after 43 iteration = 0.0248
# Total val chrF after 43 iteration = 88.5192
# Average test loss after 43 iteration = 0.0231
# Total test chrF after 43 iteration = 87.6166
# Time for the iteration 10.8 seconds
#
#
# Average train loss after 44 iteration = 0.0070
# Total train chrF after 44 iteration = 90.9787
# Average val loss after 44 iteration = 0.0249
# Total val chrF after 44 iteration = 88.4746
# Average test loss after 44 iteration = 0.0231
# Total test chrF after 44 iteration = 87.5848
# Time for the iteration 10.9 seconds
#
#
# Average train loss after 45 iteration = 0.0067
# Total train chrF after 45 iteration = 91.0518
# Average val loss after 45 iteration = 0.0249
# Total val chrF after 45 iteration = 88.4239
# Average test loss after 45 iteration = 0.0231
# Total test chrF after 45 iteration = 87.6266
# Time for the iteration 11.1 seconds
#
#
# Average train loss after 46 iteration = 0.0065
# Total train chrF after 46 iteration = 91.1244
# Average val loss after 46 iteration = 0.0250
# Total val chrF after 46 iteration = 88.4335
# Average test loss after 46 iteration = 0.0232
# Total test chrF after 46 iteration = 87.6055
# Time for the iteration 10.9 seconds
#
#
# Average train loss after 47 iteration = 0.0063
# Total train chrF after 47 iteration = 91.1864
# Average val loss after 47 iteration = 0.0251
# Total val chrF after 47 iteration = 88.4734
# Average test loss after 47 iteration = 0.0232
# Total test chrF after 47 iteration = 87.6219
# Time for the iteration 10.9 seconds
#
#
# Average train loss after 48 iteration = 0.0061
# Total train chrF after 48 iteration = 91.2458
# Average val loss after 48 iteration = 0.0252
# Total val chrF after 48 iteration = 88.4716
# Average test loss after 48 iteration = 0.0233
# Total test chrF after 48 iteration = 87.6178
# Time for the iteration 10.8 seconds
#
#
# Average train loss after 49 iteration = 0.0059
# Total train chrF after 49 iteration = 91.3059
# Average val loss after 49 iteration = 0.0252
# Total val chrF after 49 iteration = 88.4437
# Average test loss after 49 iteration = 0.0233
# Total test chrF after 49 iteration = 87.6041
# Time for the iteration 10.9 seconds
#
#
# Average train loss after 50 iteration = 0.0058
# Total train chrF after 50 iteration = 91.3658
# Average val loss after 50 iteration = 0.0253
# Total val chrF after 50 iteration = 88.4240
# Average test loss after 50 iteration = 0.0234
# Total test chrF after 50 iteration = 87.6230
# Time for the iteration 11.0 seconds
#
#
# Average train loss after 51 iteration = 0.0056
# Total train chrF after 51 iteration = 91.4160
# Average val loss after 51 iteration = 0.0254
# Total val chrF after 51 iteration = 88.3801
# Average test loss after 51 iteration = 0.0234
# Total test chrF after 51 iteration = 87.6376
# Time for the iteration 10.9 seconds
#
#
# Average train loss after 52 iteration = 0.0054
# Total train chrF after 52 iteration = 91.4615
# Average val loss after 52 iteration = 0.0255
# Total val chrF after 52 iteration = 88.3276
# Average test loss after 52 iteration = 0.0235
# Total test chrF after 52 iteration = 87.6056
# Time for the iteration 10.9 seconds
#
#
# Average train loss after 53 iteration = 0.0052
# Total train chrF after 53 iteration = 91.5153
# Average val loss after 53 iteration = 0.0256
# Total val chrF after 53 iteration = 88.3541
# Average test loss after 53 iteration = 0.0236
# Total test chrF after 53 iteration = 87.5510
# Time for the iteration 10.9 seconds
#
#
# Average train loss after 54 iteration = 0.0051
# Total train chrF after 54 iteration = 91.5552
# Average val loss after 54 iteration = 0.0257
# Total val chrF after 54 iteration = 88.2860
# Average test loss after 54 iteration = 0.0236
# Total test chrF after 54 iteration = 87.5292
# Time for the iteration 10.8 seconds
#
#
# Average train loss after 55 iteration = 0.0049
# Total train chrF after 55 iteration = 91.5933
# Average val loss after 55 iteration = 0.0259
# Total val chrF after 55 iteration = 88.2496
# Average test loss after 55 iteration = 0.0237
# Total test chrF after 55 iteration = 87.5231
# Time for the iteration 11.0 seconds
#
#
# Average train loss after 56 iteration = 0.0048
# Total train chrF after 56 iteration = 91.6280
# Average val loss after 56 iteration = 0.0260
# Total val chrF after 56 iteration = 88.1604
# Average test loss after 56 iteration = 0.0237
# Total test chrF after 56 iteration = 87.5639
# Time for the iteration 10.9 seconds
#
#
# Average train loss after 57 iteration = 0.0046
# Total train chrF after 57 iteration = 91.6700
# Average val loss after 57 iteration = 0.0261
# Total val chrF after 57 iteration = 88.1695
# Average test loss after 57 iteration = 0.0238
# Total test chrF after 57 iteration = 87.5717
# Time for the iteration 10.9 seconds
#
#
# Average train loss after 58 iteration = 0.0045
# Total train chrF after 58 iteration = 91.7093
# Average val loss after 58 iteration = 0.0262
# Total val chrF after 58 iteration = 88.1631
# Average test loss after 58 iteration = 0.0239
# Total test chrF after 58 iteration = 87.5126
# Time for the iteration 10.9 seconds
#
#
# Average train loss after 59 iteration = 0.0044
# Total train chrF after 59 iteration = 91.7437
# Average val loss after 59 iteration = 0.0263
# Total val chrF after 59 iteration = 88.0992
# Average test loss after 59 iteration = 0.0240
# Total test chrF after 59 iteration = 87.4603
# Time for the iteration 10.9 seconds
#
#
# Average train loss after 60 iteration = 0.0042
# Total train chrF after 60 iteration = 91.7778
# Average val loss after 60 iteration = 0.0265
# Total val chrF after 60 iteration = 88.0737
# Average test loss after 60 iteration = 0.0240
# Total test chrF after 60 iteration = 87.4234
# Time for the iteration 11.0 seconds
#
#
# Average train loss after 61 iteration = 0.0041
# Total train chrF after 61 iteration = 91.8094
# Average val loss after 61 iteration = 0.0266
# Total val chrF after 61 iteration = 88.0726
# Average test loss after 61 iteration = 0.0241
# Total test chrF after 61 iteration = 87.4675
# Time for the iteration 10.9 seconds
#
#
#
#
# Aborting since there hasn't been much progress
# <Figure size 640x480 with 1 Axes>
# <Figure size 640x480 with 1 Axes>

# %%
language = "ash"
task_name = "sylsim_teacher_general"
vocab_size = 4999
num_epochs = 100
batch_size = 32
model = "50_1"
optimizer = "Adam"
metric = "chrF"

# %%
from IPython.display import Image

Image("curves/{}_{}_{}_{}_{}_loss.png".format(language, task_name, vocab_size, num_epochs, batch_size))

# %%
Image("curves/{}_{}_{}_{}_{}_{}.png".format(language, task_name, vocab_size, num_epochs, batch_size, metric))

# %%
print("{}.{}.{}.{}.{}.{}.{}".format(language, task_name, vocab_size, num_epochs, batch_size, model, optimizer))
# Out:
# ash.sylsim_teacher_general.4999.100.32.50_1.Adam
