# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
# %cd "drive/MyDrive/Tesis/scRNN"
# Out:
# /content/drive/MyDrive/Tesis/scRNN

# %%
import torch

torch.cuda.is_available()
# Out:
# True

# %%
# !pip install sacrebleu
# Out:
# Collecting sacrebleu
#   Downloading sacrebleu-2.0.0-py3-none-any.whl (90 kB)
#      |████████████████████████████████| 90 kB 6.0 MB/s
# Collecting portalocker
#   Downloading portalocker-2.3.2-py2.py3-none-any.whl (15 kB)
# Requirement already satisfied: tabulate>=0.8.9 in /usr/local/lib/python3.7/dist-packages (from sacrebleu) (0.8.9)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from sacrebleu) (1.19.5)
# Collecting colorama
#   Downloading colorama-0.4.4-py2.py3-none-any.whl (16 kB)
# Requirement already satisfied: regex in /usr/local/lib/python3.7/dist-packages (from sacrebleu) (2019.12.20)
# Installing collected packages: portalocker, colorama, sacrebleu
# Successfully installed colorama-0.4.4 portalocker-2.3.2 sacrebleu-2.0.0

# %%
# !python3 train.py --language ash --task-name phongrafamb_teacher_general --num-epochs 100 --batch-size 32 --vocab-size 4999 --new-vocab --train --train-sentences-errors-file ash.phongrafamb_teacher_general.train.sentences.errors.txt --train-sentences-file ash.phongrafamb_teacher_general.train.sentences.txt --val-sentences-errors-file ash.teacher_general.val.sentences.errors.txt --val-sentences-file ash.teacher_general.val.sentences.txt --test-sentences-errors-file ash.teacher_general.test.sentences.errors.txt --test-sentences-file ash.teacher_general.test.sentences.txt --metric chrF --save
# Out:
# Parameters
# {'language': 'ash', 'task_name': 'phongrafamb_teacher_general', 'vocab_size': 4999, 'num_epochs': 100, 'batch_size': 32, 'model_name': 'shi_random_20531_100_32', 'new_vocab': True, 'need_to_train': True, 'train_sentences_errors_file': 'ash.phongrafamb_teacher_general.train.sentences.errors.txt', 'train_sentences_file': 'ash.phongrafamb_teacher_general.train.sentences.txt', 'val_sentences_errors_file': 'ash.teacher_general.val.sentences.errors.txt', 'val_sentences_file': 'ash.teacher_general.val.sentences.txt', 'test_sentences_errors_file': 'ash.teacher_general.test.sentences.errors.txt', 'test_sentences_file': 'ash.teacher_general.test.sentences.txt', 'metric': 'chrF', 'save_model': True}
#
#
# Creating new vocabulary
# Len of w2i:  4999
# Len of i2w:  4999
# Len of char vocab:  23
#
#
# Initializing an only ScRNN model
#
#
# Training the model...
#
# Average train loss after 1 iteration = 0.1810
# Total train chrF after 1 iteration = 78.1403
# Average val loss after 1 iteration = 0.1852
# Total val chrF after 1 iteration = 87.3881
# Average test loss after 1 iteration = 0.1815
# Total test chrF after 1 iteration = 86.7321
# Dumping after  1
# Time for the iteration 13.2 seconds
#
#
# Average train loss after 2 iteration = 0.1368
# Total train chrF after 2 iteration = 78.4801
# Average val loss after 2 iteration = 0.1221
# Total val chrF after 2 iteration = 86.0664
# Average test loss after 2 iteration = 0.1196
# Total test chrF after 2 iteration = 85.0417
# Time for the iteration 13.2 seconds
#
#
# Average train loss after 3 iteration = 0.1036
# Total train chrF after 3 iteration = 80.5657
# Average val loss after 3 iteration = 0.0935
# Total val chrF after 3 iteration = 86.8044
# Average test loss after 3 iteration = 0.0914
# Total test chrF after 3 iteration = 85.4647
# Time for the iteration 13.1 seconds
#
#
# Average train loss after 4 iteration = 0.0809
# Total train chrF after 4 iteration = 82.5573
# Average val loss after 4 iteration = 0.0756
# Total val chrF after 4 iteration = 87.2227
# Average test loss after 4 iteration = 0.0738
# Total test chrF after 4 iteration = 86.1909
# Time for the iteration 13.2 seconds
#
#
# Average train loss after 5 iteration = 0.0642
# Total train chrF after 5 iteration = 84.2298
# Average val loss after 5 iteration = 0.0632
# Total val chrF after 5 iteration = 87.8891
# Average test loss after 5 iteration = 0.0616
# Total test chrF after 5 iteration = 86.8958
# Dumping after  5
# Time for the iteration 13.3 seconds
#
#
# Average train loss after 6 iteration = 0.0517
# Total train chrF after 6 iteration = 85.5746
# Average val loss after 6 iteration = 0.0541
# Total val chrF after 6 iteration = 88.0892
# Average test loss after 6 iteration = 0.0526
# Total test chrF after 6 iteration = 87.1751
# Dumping after  6
# Time for the iteration 13.2 seconds
#
#
# Average train loss after 7 iteration = 0.0421
# Total train chrF after 7 iteration = 86.7997
# Average val loss after 7 iteration = 0.0470
# Total val chrF after 7 iteration = 88.1911
# Average test loss after 7 iteration = 0.0456
# Total test chrF after 7 iteration = 87.3640
# Dumping after  7
# Time for the iteration 13.2 seconds
#
#
# Average train loss after 8 iteration = 0.0344
# Total train chrF after 8 iteration = 87.8340
# Average val loss after 8 iteration = 0.0415
# Total val chrF after 8 iteration = 88.2770
# Average test loss after 8 iteration = 0.0401
# Total test chrF after 8 iteration = 87.4918
# Dumping after  8
# Time for the iteration 13.2 seconds
#
#
# Average train loss after 9 iteration = 0.0285
# Total train chrF after 9 iteration = 88.7062
# Average val loss after 9 iteration = 0.0372
# Total val chrF after 9 iteration = 88.4373
# Average test loss after 9 iteration = 0.0359
# Total test chrF after 9 iteration = 87.6314
# Dumping after  9
# Time for the iteration 13.3 seconds
#
#
# Average train loss after 10 iteration = 0.0240
# Total train chrF after 10 iteration = 89.4402
# Average val loss after 10 iteration = 0.0339
# Total val chrF after 10 iteration = 88.5581
# Average test loss after 10 iteration = 0.0326
# Total test chrF after 10 iteration = 87.6916
# Dumping after  10
# Time for the iteration 13.2 seconds
#
#
# Average train loss after 11 iteration = 0.0205
# Total train chrF after 11 iteration = 90.0911
# Average val loss after 11 iteration = 0.0314
# Total val chrF after 11 iteration = 88.7241
# Average test loss after 11 iteration = 0.0301
# Total test chrF after 11 iteration = 87.8673
# Dumping after  11
# Time for the iteration 13.2 seconds
#
#
# Average train loss after 12 iteration = 0.0177
# Total train chrF after 12 iteration = 90.6648
# Average val loss after 12 iteration = 0.0294
# Total val chrF after 12 iteration = 88.7641
# Average test loss after 12 iteration = 0.0281
# Total test chrF after 12 iteration = 87.9789
# Dumping after  12
# Time for the iteration 13.3 seconds
#
#
# Average train loss after 13 iteration = 0.0155
# Total train chrF after 13 iteration = 91.1451
# Average val loss after 13 iteration = 0.0278
# Total val chrF after 13 iteration = 88.9439
# Average test loss after 13 iteration = 0.0265
# Total test chrF after 13 iteration = 88.1891
# Dumping after  13
# Time for the iteration 13.3 seconds
#
#
# Average train loss after 14 iteration = 0.0137
# Total train chrF after 14 iteration = 91.5567
# Average val loss after 14 iteration = 0.0265
# Total val chrF after 14 iteration = 89.0451
# Average test loss after 14 iteration = 0.0252
# Total test chrF after 14 iteration = 88.2908
# Dumping after  14
# Time for the iteration 13.4 seconds
#
#
# Average train loss after 15 iteration = 0.0122
# Total train chrF after 15 iteration = 91.9091
# Average val loss after 15 iteration = 0.0255
# Total val chrF after 15 iteration = 89.1279
# Average test loss after 15 iteration = 0.0242
# Total test chrF after 15 iteration = 88.3756
# Dumping after  15
# Time for the iteration 13.3 seconds
#
#
# Average train loss after 16 iteration = 0.0110
# Total train chrF after 16 iteration = 92.1983
# Average val loss after 16 iteration = 0.0247
# Total val chrF after 16 iteration = 89.1951
# Average test loss after 16 iteration = 0.0233
# Total test chrF after 16 iteration = 88.4891
# Dumping after  16
# Time for the iteration 13.3 seconds
#
#
# Average train loss after 17 iteration = 0.0100
# Total train chrF after 17 iteration = 92.4333
# Average val loss after 17 iteration = 0.0240
# Total val chrF after 17 iteration = 89.2986
# Average test loss after 17 iteration = 0.0226
# Total test chrF after 17 iteration = 88.5869
# Dumping after  17
# Time for the iteration 13.3 seconds
#
#
# Average train loss after 18 iteration = 0.0091
# Total train chrF after 18 iteration = 92.6354
# Average val loss after 18 iteration = 0.0234
# Total val chrF after 18 iteration = 89.3127
# Average test loss after 18 iteration = 0.0220
# Total test chrF after 18 iteration = 88.6634
# Dumping after  18
# Time for the iteration 13.3 seconds
#
#
# Average train loss after 19 iteration = 0.0084
# Total train chrF after 19 iteration = 92.8228
# Average val loss after 19 iteration = 0.0229
# Total val chrF after 19 iteration = 89.3467
# Average test loss after 19 iteration = 0.0215
# Total test chrF after 19 iteration = 88.7226
# Dumping after  19
# Time for the iteration 13.3 seconds
#
#
# Average train loss after 20 iteration = 0.0077
# Total train chrF after 20 iteration = 92.9604
# Average val loss after 20 iteration = 0.0225
# Total val chrF after 20 iteration = 89.4642
# Average test loss after 20 iteration = 0.0211
# Total test chrF after 20 iteration = 88.7814
# Dumping after  20
# Time for the iteration 13.3 seconds
#
#
# Average train loss after 21 iteration = 0.0072
# Total train chrF after 21 iteration = 93.1079
# Average val loss after 21 iteration = 0.0221
# Total val chrF after 21 iteration = 89.5239
# Average test loss after 21 iteration = 0.0207
# Total test chrF after 21 iteration = 88.8693
# Dumping after  21
# Time for the iteration 13.2 seconds
#
#
# Average train loss after 22 iteration = 0.0066
# Total train chrF after 22 iteration = 93.2238
# Average val loss after 22 iteration = 0.0218
# Total val chrF after 22 iteration = 89.5895
# Average test loss after 22 iteration = 0.0204
# Total test chrF after 22 iteration = 88.9071
# Dumping after  22
# Time for the iteration 13.4 seconds
#
#
# Average train loss after 23 iteration = 0.0062
# Total train chrF after 23 iteration = 93.3268
# Average val loss after 23 iteration = 0.0216
# Total val chrF after 23 iteration = 89.6654
# Average test loss after 23 iteration = 0.0202
# Total test chrF after 23 iteration = 88.9732
# Dumping after  23
# Time for the iteration 13.2 seconds
#
#
# Average train loss after 24 iteration = 0.0058
# Total train chrF after 24 iteration = 93.4221
# Average val loss after 24 iteration = 0.0214
# Total val chrF after 24 iteration = 89.6851
# Average test loss after 24 iteration = 0.0200
# Total test chrF after 24 iteration = 88.9859
# Dumping after  24
# Time for the iteration 13.3 seconds
#
#
# Average train loss after 25 iteration = 0.0054
# Total train chrF after 25 iteration = 93.5090
# Average val loss after 25 iteration = 0.0212
# Total val chrF after 25 iteration = 89.7947
# Average test loss after 25 iteration = 0.0198
# Total test chrF after 25 iteration = 89.0663
# Dumping after  25
# Time for the iteration 13.4 seconds
#
#
# Average train loss after 26 iteration = 0.0050
# Total train chrF after 26 iteration = 93.5870
# Average val loss after 26 iteration = 0.0211
# Total val chrF after 26 iteration = 89.8012
# Average test loss after 26 iteration = 0.0196
# Total test chrF after 26 iteration = 89.0973
# Dumping after  26
# Time for the iteration 13.4 seconds
#
#
# Average train loss after 27 iteration = 0.0047
# Total train chrF after 27 iteration = 93.6494
# Average val loss after 27 iteration = 0.0210
# Total val chrF after 27 iteration = 89.7533
# Average test loss after 27 iteration = 0.0195
# Total test chrF after 27 iteration = 89.1563
# Time for the iteration 13.4 seconds
#
#
# Average train loss after 28 iteration = 0.0044
# Total train chrF after 28 iteration = 93.7127
# Average val loss after 28 iteration = 0.0209
# Total val chrF after 28 iteration = 89.7976
# Average test loss after 28 iteration = 0.0194
# Total test chrF after 28 iteration = 89.0735
# Time for the iteration 13.3 seconds
#
#
# Average train loss after 29 iteration = 0.0042
# Total train chrF after 29 iteration = 93.7661
# Average val loss after 29 iteration = 0.0208
# Total val chrF after 29 iteration = 89.8507
# Average test loss after 29 iteration = 0.0193
# Total test chrF after 29 iteration = 89.1296
# Dumping after  29
# Time for the iteration 13.4 seconds
#
#
# Average train loss after 30 iteration = 0.0039
# Total train chrF after 30 iteration = 93.8142
# Average val loss after 30 iteration = 0.0208
# Total val chrF after 30 iteration = 89.8778
# Average test loss after 30 iteration = 0.0193
# Total test chrF after 30 iteration = 89.1670
# Dumping after  30
# Time for the iteration 13.3 seconds
#
#
# Average train loss after 31 iteration = 0.0037
# Total train chrF after 31 iteration = 93.8602
# Average val loss after 31 iteration = 0.0208
# Total val chrF after 31 iteration = 89.9381
# Average test loss after 31 iteration = 0.0192
# Total test chrF after 31 iteration = 89.1740
# Dumping after  31
# Time for the iteration 13.4 seconds
#
#
# Average train loss after 32 iteration = 0.0035
# Total train chrF after 32 iteration = 93.8936
# Average val loss after 32 iteration = 0.0208
# Total val chrF after 32 iteration = 89.9904
# Average test loss after 32 iteration = 0.0192
# Total test chrF after 32 iteration = 89.1780
# Dumping after  32
# Time for the iteration 13.4 seconds
#
#
# Average train loss after 33 iteration = 0.0033
# Total train chrF after 33 iteration = 93.9365
# Average val loss after 33 iteration = 0.0208
# Total val chrF after 33 iteration = 90.0211
# Average test loss after 33 iteration = 0.0192
# Total test chrF after 33 iteration = 89.1444
# Dumping after  33
# Time for the iteration 13.4 seconds
#
#
# Average train loss after 34 iteration = 0.0031
# Total train chrF after 34 iteration = 93.9657
# Average val loss after 34 iteration = 0.0208
# Total val chrF after 34 iteration = 90.0185
# Average test loss after 34 iteration = 0.0192
# Total test chrF after 34 iteration = 89.1516
# Time for the iteration 13.4 seconds
#
#
# Average train loss after 35 iteration = 0.0029
# Total train chrF after 35 iteration = 93.9980
# Average val loss after 35 iteration = 0.0208
# Total val chrF after 35 iteration = 89.9639
# Average test loss after 35 iteration = 0.0192
# Total test chrF after 35 iteration = 89.1723
# Time for the iteration 13.4 seconds
#
#
# Average train loss after 36 iteration = 0.0027
# Total train chrF after 36 iteration = 94.0298
# Average val loss after 36 iteration = 0.0209
# Total val chrF after 36 iteration = 89.9460
# Average test loss after 36 iteration = 0.0192
# Total test chrF after 36 iteration = 89.1801
# Time for the iteration 13.4 seconds
#
#
# Average train loss after 37 iteration = 0.0026
# Total train chrF after 37 iteration = 94.0547
# Average val loss after 37 iteration = 0.0210
# Total val chrF after 37 iteration = 89.9315
# Average test loss after 37 iteration = 0.0192
# Total test chrF after 37 iteration = 89.0869
# Time for the iteration 13.4 seconds
#
#
# Average train loss after 38 iteration = 0.0024
# Total train chrF after 38 iteration = 94.0811
# Average val loss after 38 iteration = 0.0210
# Total val chrF after 38 iteration = 89.8885
# Average test loss after 38 iteration = 0.0193
# Total test chrF after 38 iteration = 89.0477
# Time for the iteration 13.5 seconds
#
#
# Average train loss after 39 iteration = 0.0023
# Total train chrF after 39 iteration = 94.1029
# Average val loss after 39 iteration = 0.0211
# Total val chrF after 39 iteration = 89.8737
# Average test loss after 39 iteration = 0.0193
# Total test chrF after 39 iteration = 89.0816
# Time for the iteration 13.5 seconds
#
#
# Average train loss after 40 iteration = 0.0022
# Total train chrF after 40 iteration = 94.1278
# Average val loss after 40 iteration = 0.0212
# Total val chrF after 40 iteration = 89.8591
# Average test loss after 40 iteration = 0.0194
# Total test chrF after 40 iteration = 89.0800
# Time for the iteration 13.4 seconds
#
#
# Average train loss after 41 iteration = 0.0021
# Total train chrF after 41 iteration = 94.1504
# Average val loss after 41 iteration = 0.0213
# Total val chrF after 41 iteration = 89.8759
# Average test loss after 41 iteration = 0.0194
# Total test chrF after 41 iteration = 89.0521
# Time for the iteration 13.5 seconds
#
#
# Average train loss after 42 iteration = 0.0019
# Total train chrF after 42 iteration = 94.1687
# Average val loss after 42 iteration = 0.0214
# Total val chrF after 42 iteration = 89.8648
# Average test loss after 42 iteration = 0.0195
# Total test chrF after 42 iteration = 89.0636
# Time for the iteration 13.4 seconds
#
#
# Average train loss after 43 iteration = 0.0018
# Total train chrF after 43 iteration = 94.1868
# Average val loss after 43 iteration = 0.0215
# Total val chrF after 43 iteration = 89.8353
# Average test loss after 43 iteration = 0.0196
# Total test chrF after 43 iteration = 89.0612
# Time for the iteration 13.3 seconds
#
#
# Average train loss after 44 iteration = 0.0017
# Total train chrF after 44 iteration = 94.2059
# Average val loss after 44 iteration = 0.0216
# Total val chrF after 44 iteration = 89.8295
# Average test loss after 44 iteration = 0.0197
# Total test chrF after 44 iteration = 89.0515
# Time for the iteration 13.3 seconds
#
#
# Average train loss after 45 iteration = 0.0016
# Total train chrF after 45 iteration = 94.2234
# Average val loss after 45 iteration = 0.0217
# Total val chrF after 45 iteration = 89.8248
# Average test loss after 45 iteration = 0.0198
# Total test chrF after 45 iteration = 89.0475
# Time for the iteration 13.4 seconds
#
#
# Average train loss after 46 iteration = 0.0016
# Total train chrF after 46 iteration = 94.2388
# Average val loss after 46 iteration = 0.0218
# Total val chrF after 46 iteration = 89.8111
# Average test loss after 46 iteration = 0.0199
# Total test chrF after 46 iteration = 89.0383
# Time for the iteration 13.4 seconds
#
#
# Average train loss after 47 iteration = 0.0015
# Total train chrF after 47 iteration = 94.2545
# Average val loss after 47 iteration = 0.0219
# Total val chrF after 47 iteration = 89.8095
# Average test loss after 47 iteration = 0.0200
# Total test chrF after 47 iteration = 89.0495
# Time for the iteration 13.4 seconds
#
#
# Average train loss after 48 iteration = 0.0014
# Total train chrF after 48 iteration = 94.2629
# Average val loss after 48 iteration = 0.0220
# Total val chrF after 48 iteration = 89.8635
# Average test loss after 48 iteration = 0.0201
# Total test chrF after 48 iteration = 89.0632
# Time for the iteration 13.3 seconds
#
#
# Average train loss after 49 iteration = 0.0013
# Total train chrF after 49 iteration = 94.2760
# Average val loss after 49 iteration = 0.0221
# Total val chrF after 49 iteration = 89.8799
# Average test loss after 49 iteration = 0.0202
# Total test chrF after 49 iteration = 89.0406
# Time for the iteration 13.4 seconds
#
#
# Average train loss after 50 iteration = 0.0012
# Total train chrF after 50 iteration = 94.2901
# Average val loss after 50 iteration = 0.0223
# Total val chrF after 50 iteration = 89.8665
# Average test loss after 50 iteration = 0.0203
# Total test chrF after 50 iteration = 89.0722
# Time for the iteration 13.4 seconds
#
#
# Average train loss after 51 iteration = 0.0012
# Total train chrF after 51 iteration = 94.2981
# Average val loss after 51 iteration = 0.0224
# Total val chrF after 51 iteration = 89.8594
# Average test loss after 51 iteration = 0.0205
# Total test chrF after 51 iteration = 89.0668
# Time for the iteration 13.4 seconds
#
#
# Average train loss after 52 iteration = 0.0011
# Total train chrF after 52 iteration = 94.3076
# Average val loss after 52 iteration = 0.0225
# Total val chrF after 52 iteration = 89.8750
# Average test loss after 52 iteration = 0.0206
# Total test chrF after 52 iteration = 89.0619
# Time for the iteration 13.2 seconds
#
#
# Average train loss after 53 iteration = 0.0011
# Total train chrF after 53 iteration = 94.3175
# Average val loss after 53 iteration = 0.0227
# Total val chrF after 53 iteration = 89.8374
# Average test loss after 53 iteration = 0.0207
# Total test chrF after 53 iteration = 89.0789
# Time for the iteration 13.3 seconds
#
#
# Average train loss after 54 iteration = 0.0010
# Total train chrF after 54 iteration = 94.3265
# Average val loss after 54 iteration = 0.0228
# Total val chrF after 54 iteration = 89.8080
# Average test loss after 54 iteration = 0.0209
# Total test chrF after 54 iteration = 89.0277
# Time for the iteration 13.3 seconds
#
#
# Average train loss after 55 iteration = 0.0009
# Total train chrF after 55 iteration = 94.3320
# Average val loss after 55 iteration = 0.0230
# Total val chrF after 55 iteration = 89.7955
# Average test loss after 55 iteration = 0.0210
# Total test chrF after 55 iteration = 88.9764
# Time for the iteration 13.4 seconds
#
#
# Average train loss after 56 iteration = 0.0009
# Total train chrF after 56 iteration = 94.3405
# Average val loss after 56 iteration = 0.0231
# Total val chrF after 56 iteration = 89.7513
# Average test loss after 56 iteration = 0.0211
# Total test chrF after 56 iteration = 88.9595
# Time for the iteration 13.4 seconds
#
#
# Average train loss after 57 iteration = 0.0008
# Total train chrF after 57 iteration = 94.3473
# Average val loss after 57 iteration = 0.0233
# Total val chrF after 57 iteration = 89.7763
# Average test loss after 57 iteration = 0.0213
# Total test chrF after 57 iteration = 88.9490
# Time for the iteration 13.3 seconds
#
#
# Average train loss after 58 iteration = 0.0008
# Total train chrF after 58 iteration = 94.3530
# Average val loss after 58 iteration = 0.0234
# Total val chrF after 58 iteration = 89.7655
# Average test loss after 58 iteration = 0.0215
# Total test chrF after 58 iteration = 88.9074
# Time for the iteration 13.4 seconds
#
#
# Average train loss after 59 iteration = 0.0007
# Total train chrF after 59 iteration = 94.3564
# Average val loss after 59 iteration = 0.0236
# Total val chrF after 59 iteration = 89.7534
# Average test loss after 59 iteration = 0.0216
# Total test chrF after 59 iteration = 88.8880
# Time for the iteration 13.4 seconds
#
#
# Average train loss after 60 iteration = 0.0007
# Total train chrF after 60 iteration = 94.3622
# Average val loss after 60 iteration = 0.0237
# Total val chrF after 60 iteration = 89.7741
# Average test loss after 60 iteration = 0.0218
# Total test chrF after 60 iteration = 88.9094
# Time for the iteration 13.3 seconds
#
#
#
#
# Aborting since there hasn't been much progress
# <Figure size 640x480 with 1 Axes>
# <Figure size 640x480 with 1 Axes>

# %%
language = "ash"
task_name = "phongrafamb_teacher_general"
vocab_size = 4999
num_epochs = 100
batch_size = 32
model = "50_1"
optimizer = "Adam"
metric = "chrF"

# %%
from IPython.display import Image

Image("curves/{}_{}_{}_{}_{}_loss.png".format(language, task_name, vocab_size, num_epochs, batch_size))

# %%
Image("curves/{}_{}_{}_{}_{}_{}.png".format(language, task_name, vocab_size, num_epochs, batch_size, metric))

# %%
print("{}.{}.{}.{}.{}.{}.{}".format(language, task_name, vocab_size, num_epochs, batch_size, model, optimizer))
# Out:
# ash.phongrafamb_teacher_general.4999.100.32.50_1.Adam
