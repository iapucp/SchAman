# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
# %cd "drive/MyDrive/Tesis/scRNN"
# Out:
# /content/drive/MyDrive/Tesis/scRNN

# %%
import torch

torch.cuda.is_available()
# Out:
# True

# %%
# !pip install sacrebleu
# Out:
# Collecting sacrebleu
#   Downloading sacrebleu-2.0.0-py3-none-any.whl (90 kB)
#      |████████████████████████████████| 90 kB 5.7 MB/s
# Collecting colorama
#   Downloading colorama-0.4.4-py2.py3-none-any.whl (16 kB)
# Collecting portalocker
#   Downloading portalocker-2.3.2-py2.py3-none-any.whl (15 kB)
# Requirement already satisfied: tabulate>=0.8.9 in /usr/local/lib/python3.7/dist-packages (from sacrebleu) (0.8.9)
# Requirement already satisfied: regex in /usr/local/lib/python3.7/dist-packages (from sacrebleu) (2019.12.20)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from sacrebleu) (1.19.5)
# Installing collected packages: portalocker, colorama, sacrebleu
# Successfully installed colorama-0.4.4 portalocker-2.3.2 sacrebleu-2.0.0

# %%
# !python3 train.py --language ash --task-name keyprox_teacher_general --num-epochs 100 --batch-size 32 --vocab-size 4999 --new-vocab --train --train-sentences-errors-file ash.keyprox_teacher_general.train.sentences.errors.txt --train-sentences-file ash.keyprox_teacher_general.train.sentences.txt --val-sentences-errors-file ash.teacher_general.val.sentences.errors.txt --val-sentences-file ash.teacher_general.val.sentences.txt --test-sentences-errors-file ash.teacher_general.test.sentences.errors.txt --test-sentences-file ash.teacher_general.test.sentences.txt --metric chrF --save
# Out:
# Parameters
# {'language': 'ash', 'task_name': 'keyprox_teacher_general', 'vocab_size': 4999, 'num_epochs': 100, 'batch_size': 32, 'model_name': 'shi_random_20531_100_32', 'new_vocab': True, 'need_to_train': True, 'train_sentences_errors_file': 'ash.keyprox_teacher_general.train.sentences.errors.txt', 'train_sentences_file': 'ash.keyprox_teacher_general.train.sentences.txt', 'val_sentences_errors_file': 'ash.teacher_general.val.sentences.errors.txt', 'val_sentences_file': 'ash.teacher_general.val.sentences.txt', 'test_sentences_errors_file': 'ash.teacher_general.test.sentences.errors.txt', 'test_sentences_file': 'ash.teacher_general.test.sentences.txt', 'metric': 'chrF', 'save_model': True}
#
#
# Creating new vocabulary
# Len of w2i:  4999
# Len of i2w:  4999
# Len of char vocab:  23
#
#
# Initializing an only ScRNN model
#
#
# Training the model...
#
# Average train loss after 1 iteration = 0.1828
# Total train chrF after 1 iteration = 67.8045
# Average val loss after 1 iteration = 0.1983
# Total val chrF after 1 iteration = 86.7596
# Average test loss after 1 iteration = 0.1943
# Total test chrF after 1 iteration = 85.9283
# Dumping after  1
# Time for the iteration 13.3 seconds
#
#
# Average train loss after 2 iteration = 0.1467
# Total train chrF after 2 iteration = 69.3268
# Average val loss after 2 iteration = 0.1347
# Total val chrF after 2 iteration = 83.5369
# Average test loss after 2 iteration = 0.1321
# Total test chrF after 2 iteration = 82.9418
# Time for the iteration 13.1 seconds
#
#
# Average train loss after 3 iteration = 0.1182
# Total train chrF after 3 iteration = 71.5111
# Average val loss after 3 iteration = 0.1059
# Total val chrF after 3 iteration = 86.0182
# Average test loss after 3 iteration = 0.1037
# Total test chrF after 3 iteration = 85.5253
# Time for the iteration 13.0 seconds
#
#
# Average train loss after 4 iteration = 0.0952
# Total train chrF after 4 iteration = 73.8317
# Average val loss after 4 iteration = 0.0848
# Total val chrF after 4 iteration = 86.8814
# Average test loss after 4 iteration = 0.0828
# Total test chrF after 4 iteration = 86.1906
# Dumping after  4
# Time for the iteration 13.0 seconds
#
#
# Average train loss after 5 iteration = 0.0772
# Total train chrF after 5 iteration = 75.8900
# Average val loss after 5 iteration = 0.0706
# Total val chrF after 5 iteration = 87.3374
# Average test loss after 5 iteration = 0.0689
# Total test chrF after 5 iteration = 86.8177
# Dumping after  5
# Time for the iteration 13.2 seconds
#
#
# Average train loss after 6 iteration = 0.0637
# Total train chrF after 6 iteration = 77.6119
# Average val loss after 6 iteration = 0.0600
# Total val chrF after 6 iteration = 87.6963
# Average test loss after 6 iteration = 0.0586
# Total test chrF after 6 iteration = 87.0198
# Dumping after  6
# Time for the iteration 13.2 seconds
#
#
# Average train loss after 7 iteration = 0.0533
# Total train chrF after 7 iteration = 79.0252
# Average val loss after 7 iteration = 0.0520
# Total val chrF after 7 iteration = 87.9054
# Average test loss after 7 iteration = 0.0508
# Total test chrF after 7 iteration = 87.2825
# Dumping after  7
# Time for the iteration 13.5 seconds
#
#
# Average train loss after 8 iteration = 0.0451
# Total train chrF after 8 iteration = 80.2131
# Average val loss after 8 iteration = 0.0461
# Total val chrF after 8 iteration = 87.9628
# Average test loss after 8 iteration = 0.0451
# Total test chrF after 8 iteration = 87.3792
# Dumping after  8
# Time for the iteration 13.3 seconds
#
#
# Average train loss after 9 iteration = 0.0387
# Total train chrF after 9 iteration = 81.2806
# Average val loss after 9 iteration = 0.0416
# Total val chrF after 9 iteration = 88.1274
# Average test loss after 9 iteration = 0.0406
# Total test chrF after 9 iteration = 87.4285
# Dumping after  9
# Time for the iteration 13.3 seconds
#
#
# Average train loss after 10 iteration = 0.0336
# Total train chrF after 10 iteration = 82.2761
# Average val loss after 10 iteration = 0.0381
# Total val chrF after 10 iteration = 88.2235
# Average test loss after 10 iteration = 0.0371
# Total test chrF after 10 iteration = 87.5642
# Dumping after  10
# Time for the iteration 13.3 seconds
#
#
# Average train loss after 11 iteration = 0.0295
# Total train chrF after 11 iteration = 83.1249
# Average val loss after 11 iteration = 0.0353
# Total val chrF after 11 iteration = 88.2844
# Average test loss after 11 iteration = 0.0343
# Total test chrF after 11 iteration = 87.7318
# Dumping after  11
# Time for the iteration 13.5 seconds
#
#
# Average train loss after 12 iteration = 0.0262
# Total train chrF after 12 iteration = 83.9588
# Average val loss after 12 iteration = 0.0331
# Total val chrF after 12 iteration = 88.4311
# Average test loss after 12 iteration = 0.0320
# Total test chrF after 12 iteration = 87.7840
# Dumping after  12
# Time for the iteration 13.4 seconds
#
#
# Average train loss after 13 iteration = 0.0234
# Total train chrF after 13 iteration = 84.7340
# Average val loss after 13 iteration = 0.0313
# Total val chrF after 13 iteration = 88.5280
# Average test loss after 13 iteration = 0.0301
# Total test chrF after 13 iteration = 87.9540
# Dumping after  13
# Time for the iteration 13.5 seconds
#
#
# Average train loss after 14 iteration = 0.0212
# Total train chrF after 14 iteration = 85.4170
# Average val loss after 14 iteration = 0.0298
# Total val chrF after 14 iteration = 88.6442
# Average test loss after 14 iteration = 0.0285
# Total test chrF after 14 iteration = 88.0437
# Dumping after  14
# Time for the iteration 13.4 seconds
#
#
# Average train loss after 15 iteration = 0.0193
# Total train chrF after 15 iteration = 86.0339
# Average val loss after 15 iteration = 0.0286
# Total val chrF after 15 iteration = 88.7907
# Average test loss after 15 iteration = 0.0272
# Total test chrF after 15 iteration = 88.1714
# Dumping after  15
# Time for the iteration 13.3 seconds
#
#
# Average train loss after 16 iteration = 0.0177
# Total train chrF after 16 iteration = 86.5740
# Average val loss after 16 iteration = 0.0276
# Total val chrF after 16 iteration = 88.9029
# Average test loss after 16 iteration = 0.0262
# Total test chrF after 16 iteration = 88.2016
# Dumping after  16
# Time for the iteration 13.7 seconds
#
#
# Average train loss after 17 iteration = 0.0163
# Total train chrF after 17 iteration = 87.0537
# Average val loss after 17 iteration = 0.0267
# Total val chrF after 17 iteration = 88.9970
# Average test loss after 17 iteration = 0.0253
# Total test chrF after 17 iteration = 88.2731
# Dumping after  17
# Time for the iteration 13.4 seconds
#
#
# Average train loss after 18 iteration = 0.0152
# Total train chrF after 18 iteration = 87.4869
# Average val loss after 18 iteration = 0.0260
# Total val chrF after 18 iteration = 89.0994
# Average test loss after 18 iteration = 0.0245
# Total test chrF after 18 iteration = 88.4071
# Dumping after  18
# Time for the iteration 13.7 seconds
#
#
# Average train loss after 19 iteration = 0.0141
# Total train chrF after 19 iteration = 87.8649
# Average val loss after 19 iteration = 0.0254
# Total val chrF after 19 iteration = 89.1881
# Average test loss after 19 iteration = 0.0239
# Total test chrF after 19 iteration = 88.4817
# Dumping after  19
# Time for the iteration 13.6 seconds
#
#
# Average train loss after 20 iteration = 0.0132
# Total train chrF after 20 iteration = 88.1835
# Average val loss after 20 iteration = 0.0249
# Total val chrF after 20 iteration = 89.2273
# Average test loss after 20 iteration = 0.0233
# Total test chrF after 20 iteration = 88.5810
# Dumping after  20
# Time for the iteration 13.3 seconds
#
#
# Average train loss after 21 iteration = 0.0124
# Total train chrF after 21 iteration = 88.4582
# Average val loss after 21 iteration = 0.0244
# Total val chrF after 21 iteration = 89.2428
# Average test loss after 21 iteration = 0.0229
# Total test chrF after 21 iteration = 88.6642
# Dumping after  21
# Time for the iteration 13.6 seconds
#
#
# Average train loss after 22 iteration = 0.0117
# Total train chrF after 22 iteration = 88.7196
# Average val loss after 22 iteration = 0.0241
# Total val chrF after 22 iteration = 89.2248
# Average test loss after 22 iteration = 0.0225
# Total test chrF after 22 iteration = 88.7343
# Time for the iteration 13.4 seconds
#
#
# Average train loss after 23 iteration = 0.0110
# Total train chrF after 23 iteration = 88.9602
# Average val loss after 23 iteration = 0.0237
# Total val chrF after 23 iteration = 89.2287
# Average test loss after 23 iteration = 0.0221
# Total test chrF after 23 iteration = 88.8076
# Time for the iteration 13.5 seconds
#
#
# Average train loss after 24 iteration = 0.0104
# Total train chrF after 24 iteration = 89.1804
# Average val loss after 24 iteration = 0.0235
# Total val chrF after 24 iteration = 89.2929
# Average test loss after 24 iteration = 0.0218
# Total test chrF after 24 iteration = 88.9137
# Dumping after  24
# Time for the iteration 13.6 seconds
#
#
# Average train loss after 25 iteration = 0.0098
# Total train chrF after 25 iteration = 89.3724
# Average val loss after 25 iteration = 0.0232
# Total val chrF after 25 iteration = 89.3078
# Average test loss after 25 iteration = 0.0216
# Total test chrF after 25 iteration = 88.9763
# Dumping after  25
# Time for the iteration 13.7 seconds
#
#
# Average train loss after 26 iteration = 0.0093
# Total train chrF after 26 iteration = 89.5521
# Average val loss after 26 iteration = 0.0231
# Total val chrF after 26 iteration = 89.3516
# Average test loss after 26 iteration = 0.0214
# Total test chrF after 26 iteration = 88.9986
# Dumping after  26
# Time for the iteration 13.4 seconds
#
#
# Average train loss after 27 iteration = 0.0088
# Total train chrF after 27 iteration = 89.7132
# Average val loss after 27 iteration = 0.0229
# Total val chrF after 27 iteration = 89.3788
# Average test loss after 27 iteration = 0.0212
# Total test chrF after 27 iteration = 89.0596
# Dumping after  27
# Time for the iteration 13.9 seconds
#
#
# Average train loss after 28 iteration = 0.0084
# Total train chrF after 28 iteration = 89.8447
# Average val loss after 28 iteration = 0.0228
# Total val chrF after 28 iteration = 89.4390
# Average test loss after 28 iteration = 0.0210
# Total test chrF after 28 iteration = 89.0315
# Dumping after  28
# Time for the iteration 13.5 seconds
#
#
# Average train loss after 29 iteration = 0.0080
# Total train chrF after 29 iteration = 89.9616
# Average val loss after 29 iteration = 0.0226
# Total val chrF after 29 iteration = 89.4746
# Average test loss after 29 iteration = 0.0209
# Total test chrF after 29 iteration = 89.0289
# Dumping after  29
# Time for the iteration 13.4 seconds
#
#
# Average train loss after 30 iteration = 0.0076
# Total train chrF after 30 iteration = 90.0849
# Average val loss after 30 iteration = 0.0225
# Total val chrF after 30 iteration = 89.4859
# Average test loss after 30 iteration = 0.0207
# Total test chrF after 30 iteration = 89.0396
# Dumping after  30
# Time for the iteration 13.4 seconds
#
#
# Average train loss after 31 iteration = 0.0073
# Total train chrF after 31 iteration = 90.2134
# Average val loss after 31 iteration = 0.0225
# Total val chrF after 31 iteration = 89.5124
# Average test loss after 31 iteration = 0.0206
# Total test chrF after 31 iteration = 89.0838
# Dumping after  31
# Time for the iteration 13.6 seconds
#
#
# Average train loss after 32 iteration = 0.0069
# Total train chrF after 32 iteration = 90.3163
# Average val loss after 32 iteration = 0.0224
# Total val chrF after 32 iteration = 89.5258
# Average test loss after 32 iteration = 0.0205
# Total test chrF after 32 iteration = 89.1250
# Dumping after  32
# Time for the iteration 13.3 seconds
#
#
# Average train loss after 33 iteration = 0.0066
# Total train chrF after 33 iteration = 90.4067
# Average val loss after 33 iteration = 0.0224
# Total val chrF after 33 iteration = 89.5412
# Average test loss after 33 iteration = 0.0205
# Total test chrF after 33 iteration = 89.0852
# Dumping after  33
# Time for the iteration 13.3 seconds
#
#
# Average train loss after 34 iteration = 0.0063
# Total train chrF after 34 iteration = 90.4948
# Average val loss after 34 iteration = 0.0223
# Total val chrF after 34 iteration = 89.5429
# Average test loss after 34 iteration = 0.0204
# Total test chrF after 34 iteration = 89.0900
# Dumping after  34
# Time for the iteration 13.5 seconds
#
#
# Average train loss after 35 iteration = 0.0060
# Total train chrF after 35 iteration = 90.5690
# Average val loss after 35 iteration = 0.0223
# Total val chrF after 35 iteration = 89.5295
# Average test loss after 35 iteration = 0.0204
# Total test chrF after 35 iteration = 89.1602
# Time for the iteration 13.5 seconds
#
#
# Average train loss after 36 iteration = 0.0058
# Total train chrF after 36 iteration = 90.6355
# Average val loss after 36 iteration = 0.0223
# Total val chrF after 36 iteration = 89.4998
# Average test loss after 36 iteration = 0.0203
# Total test chrF after 36 iteration = 89.1688
# Time for the iteration 13.4 seconds
#
#
# Average train loss after 37 iteration = 0.0055
# Total train chrF after 37 iteration = 90.7066
# Average val loss after 37 iteration = 0.0223
# Total val chrF after 37 iteration = 89.5338
# Average test loss after 37 iteration = 0.0203
# Total test chrF after 37 iteration = 89.1716
# Time for the iteration 13.4 seconds
#
#
# Average train loss after 38 iteration = 0.0053
# Total train chrF after 38 iteration = 90.7654
# Average val loss after 38 iteration = 0.0223
# Total val chrF after 38 iteration = 89.5513
# Average test loss after 38 iteration = 0.0203
# Total test chrF after 38 iteration = 89.2050
# Dumping after  38
# Time for the iteration 13.6 seconds
#
#
# Average train loss after 39 iteration = 0.0051
# Total train chrF after 39 iteration = 90.8230
# Average val loss after 39 iteration = 0.0223
# Total val chrF after 39 iteration = 89.5551
# Average test loss after 39 iteration = 0.0203
# Total test chrF after 39 iteration = 89.1879
# Dumping after  39
# Time for the iteration 13.6 seconds
#
#
# Average train loss after 40 iteration = 0.0048
# Total train chrF after 40 iteration = 90.8811
# Average val loss after 40 iteration = 0.0224
# Total val chrF after 40 iteration = 89.5814
# Average test loss after 40 iteration = 0.0203
# Total test chrF after 40 iteration = 89.2219
# Dumping after  40
# Time for the iteration 13.5 seconds
#
#
# Average train loss after 41 iteration = 0.0046
# Total train chrF after 41 iteration = 90.9386
# Average val loss after 41 iteration = 0.0224
# Total val chrF after 41 iteration = 89.6074
# Average test loss after 41 iteration = 0.0203
# Total test chrF after 41 iteration = 89.1866
# Dumping after  41
# Time for the iteration 13.6 seconds
#
#
# Average train loss after 42 iteration = 0.0044
# Total train chrF after 42 iteration = 90.9821
# Average val loss after 42 iteration = 0.0225
# Total val chrF after 42 iteration = 89.6100
# Average test loss after 42 iteration = 0.0204
# Total test chrF after 42 iteration = 89.2061
# Dumping after  42
# Time for the iteration 13.4 seconds
#
#
# Average train loss after 43 iteration = 0.0043
# Total train chrF after 43 iteration = 91.0315
# Average val loss after 43 iteration = 0.0225
# Total val chrF after 43 iteration = 89.5465
# Average test loss after 43 iteration = 0.0204
# Total test chrF after 43 iteration = 89.1791
# Time for the iteration 13.4 seconds
#
#
# Average train loss after 44 iteration = 0.0041
# Total train chrF after 44 iteration = 91.0780
# Average val loss after 44 iteration = 0.0225
# Total val chrF after 44 iteration = 89.4599
# Average test loss after 44 iteration = 0.0204
# Total test chrF after 44 iteration = 89.2023
# Time for the iteration 13.5 seconds
#
#
# Average train loss after 45 iteration = 0.0039
# Total train chrF after 45 iteration = 91.1157
# Average val loss after 45 iteration = 0.0226
# Total val chrF after 45 iteration = 89.4816
# Average test loss after 45 iteration = 0.0205
# Total test chrF after 45 iteration = 89.1865
# Time for the iteration 13.4 seconds
#
#
# Average train loss after 46 iteration = 0.0038
# Total train chrF after 46 iteration = 91.1557
# Average val loss after 46 iteration = 0.0226
# Total val chrF after 46 iteration = 89.4662
# Average test loss after 46 iteration = 0.0205
# Total test chrF after 46 iteration = 89.1298
# Time for the iteration 13.3 seconds
#
#
# Average train loss after 47 iteration = 0.0036
# Total train chrF after 47 iteration = 91.1914
# Average val loss after 47 iteration = 0.0227
# Total val chrF after 47 iteration = 89.5000
# Average test loss after 47 iteration = 0.0206
# Total test chrF after 47 iteration = 89.0783
# Time for the iteration 13.6 seconds
#
#
# Average train loss after 48 iteration = 0.0035
# Total train chrF after 48 iteration = 91.2302
# Average val loss after 48 iteration = 0.0228
# Total val chrF after 48 iteration = 89.5016
# Average test loss after 48 iteration = 0.0206
# Total test chrF after 48 iteration = 89.0436
# Time for the iteration 13.4 seconds
#
#
# Average train loss after 49 iteration = 0.0033
# Total train chrF after 49 iteration = 91.2638
# Average val loss after 49 iteration = 0.0228
# Total val chrF after 49 iteration = 89.5311
# Average test loss after 49 iteration = 0.0207
# Total test chrF after 49 iteration = 89.0982
# Time for the iteration 13.7 seconds
#
#
# Average train loss after 50 iteration = 0.0032
# Total train chrF after 50 iteration = 91.2980
# Average val loss after 50 iteration = 0.0229
# Total val chrF after 50 iteration = 89.5608
# Average test loss after 50 iteration = 0.0208
# Total test chrF after 50 iteration = 89.1048
# Time for the iteration 13.6 seconds
#
#
# Average train loss after 51 iteration = 0.0031
# Total train chrF after 51 iteration = 91.3349
# Average val loss after 51 iteration = 0.0230
# Total val chrF after 51 iteration = 89.5776
# Average test loss after 51 iteration = 0.0208
# Total test chrF after 51 iteration = 89.1054
# Time for the iteration 13.4 seconds
#
#
# Average train loss after 52 iteration = 0.0029
# Total train chrF after 52 iteration = 91.3614
# Average val loss after 52 iteration = 0.0230
# Total val chrF after 52 iteration = 89.5812
# Average test loss after 52 iteration = 0.0209
# Total test chrF after 52 iteration = 89.0484
# Time for the iteration 13.3 seconds
#
#
# Average train loss after 53 iteration = 0.0028
# Total train chrF after 53 iteration = 91.3878
# Average val loss after 53 iteration = 0.0231
# Total val chrF after 53 iteration = 89.5810
# Average test loss after 53 iteration = 0.0210
# Total test chrF after 53 iteration = 89.0053
# Time for the iteration 13.6 seconds
#
#
# Average train loss after 54 iteration = 0.0027
# Total train chrF after 54 iteration = 91.4124
# Average val loss after 54 iteration = 0.0232
# Total val chrF after 54 iteration = 89.5741
# Average test loss after 54 iteration = 0.0211
# Total test chrF after 54 iteration = 88.9572
# Time for the iteration 13.5 seconds
#
#
# Average train loss after 55 iteration = 0.0026
# Total train chrF after 55 iteration = 91.4319
# Average val loss after 55 iteration = 0.0233
# Total val chrF after 55 iteration = 89.5746
# Average test loss after 55 iteration = 0.0212
# Total test chrF after 55 iteration = 88.8883
# Time for the iteration 13.7 seconds
#
#
# Average train loss after 56 iteration = 0.0025
# Total train chrF after 56 iteration = 91.4520
# Average val loss after 56 iteration = 0.0234
# Total val chrF after 56 iteration = 89.5783
# Average test loss after 56 iteration = 0.0212
# Total test chrF after 56 iteration = 88.9022
# Time for the iteration 13.4 seconds
#
#
# Average train loss after 57 iteration = 0.0024
# Total train chrF after 57 iteration = 91.4736
# Average val loss after 57 iteration = 0.0235
# Total val chrF after 57 iteration = 89.5402
# Average test loss after 57 iteration = 0.0213
# Total test chrF after 57 iteration = 88.8916
# Time for the iteration 13.3 seconds
#
#
# Average train loss after 58 iteration = 0.0023
# Total train chrF after 58 iteration = 91.4896
# Average val loss after 58 iteration = 0.0236
# Total val chrF after 58 iteration = 89.5601
# Average test loss after 58 iteration = 0.0214
# Total test chrF after 58 iteration = 88.8499
# Time for the iteration 13.7 seconds
#
#
# Average train loss after 59 iteration = 0.0022
# Total train chrF after 59 iteration = 91.5048
# Average val loss after 59 iteration = 0.0237
# Total val chrF after 59 iteration = 89.5806
# Average test loss after 59 iteration = 0.0215
# Total test chrF after 59 iteration = 88.8687
# Time for the iteration 13.6 seconds
#
#
# Average train loss after 60 iteration = 0.0021
# Total train chrF after 60 iteration = 91.5229
# Average val loss after 60 iteration = 0.0238
# Total val chrF after 60 iteration = 89.5684
# Average test loss after 60 iteration = 0.0216
# Total test chrF after 60 iteration = 88.8387
# Time for the iteration 13.6 seconds
#
#
# Average train loss after 61 iteration = 0.0020
# Total train chrF after 61 iteration = 91.5403
# Average val loss after 61 iteration = 0.0239
# Total val chrF after 61 iteration = 89.5522
# Average test loss after 61 iteration = 0.0217
# Total test chrF after 61 iteration = 88.8375
# Time for the iteration 13.8 seconds
#
#
# Average train loss after 62 iteration = 0.0020
# Total train chrF after 62 iteration = 91.5537
# Average val loss after 62 iteration = 0.0240
# Total val chrF after 62 iteration = 89.5441
# Average test loss after 62 iteration = 0.0218
# Total test chrF after 62 iteration = 88.8162
# Time for the iteration 13.5 seconds
#
#
# Average train loss after 63 iteration = 0.0019
# Total train chrF after 63 iteration = 91.5681
# Average val loss after 63 iteration = 0.0241
# Total val chrF after 63 iteration = 89.5730
# Average test loss after 63 iteration = 0.0219
# Total test chrF after 63 iteration = 88.7884
# Time for the iteration 13.4 seconds
#
#
# Average train loss after 64 iteration = 0.0018
# Total train chrF after 64 iteration = 91.5811
# Average val loss after 64 iteration = 0.0242
# Total val chrF after 64 iteration = 89.5798
# Average test loss after 64 iteration = 0.0221
# Total test chrF after 64 iteration = 88.7799
# Time for the iteration 13.8 seconds
#
#
# Average train loss after 65 iteration = 0.0017
# Total train chrF after 65 iteration = 91.5951
# Average val loss after 65 iteration = 0.0243
# Total val chrF after 65 iteration = 89.5132
# Average test loss after 65 iteration = 0.0222
# Total test chrF after 65 iteration = 88.7456
# Time for the iteration 13.5 seconds
#
#
# Average train loss after 66 iteration = 0.0017
# Total train chrF after 66 iteration = 91.6075
# Average val loss after 66 iteration = 0.0244
# Total val chrF after 66 iteration = 89.5473
# Average test loss after 66 iteration = 0.0223
# Total test chrF after 66 iteration = 88.7499
# Time for the iteration 13.3 seconds
#
#
# Average train loss after 67 iteration = 0.0016
# Total train chrF after 67 iteration = 91.6194
# Average val loss after 67 iteration = 0.0245
# Total val chrF after 67 iteration = 89.5399
# Average test loss after 67 iteration = 0.0224
# Total test chrF after 67 iteration = 88.7411
# Time for the iteration 13.6 seconds
#
#
# Average train loss after 68 iteration = 0.0015
# Total train chrF after 68 iteration = 91.6318
# Average val loss after 68 iteration = 0.0246
# Total val chrF after 68 iteration = 89.5070
# Average test loss after 68 iteration = 0.0225
# Total test chrF after 68 iteration = 88.6880
# Time for the iteration 13.7 seconds
#
#
# Average train loss after 69 iteration = 0.0015
# Total train chrF after 69 iteration = 91.6425
# Average val loss after 69 iteration = 0.0248
# Total val chrF after 69 iteration = 89.5006
# Average test loss after 69 iteration = 0.0227
# Total test chrF after 69 iteration = 88.6995
# Time for the iteration 13.5 seconds
#
#
#
#
# Aborting since there hasn't been much progress
# <Figure size 640x480 with 1 Axes>
# <Figure size 640x480 with 1 Axes>

# %%
language = "ash"
task_name = "keyprox_teacher_general"
vocab_size = 4999
num_epochs = 100
batch_size = 32
model = "50_1"
optimizer = "Adam"
metric = "chrF"

# %%
from IPython.display import Image

Image("curves/{}_{}_{}_{}_{}_loss.png".format(language, task_name, vocab_size, num_epochs, batch_size))

# %%
Image("curves/{}_{}_{}_{}_{}_{}.png".format(language, task_name, vocab_size, num_epochs, batch_size, metric))

# %%
print("{}.{}.{}.{}.{}.{}.{}".format(language, task_name, vocab_size, num_epochs, batch_size, model, optimizer))
# Out:
# ash.keyprox_teacher_general.4999.100.32.50_1.Adam
