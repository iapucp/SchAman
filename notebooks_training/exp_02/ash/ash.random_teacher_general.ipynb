# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
# %cd "drive/MyDrive/Tesis/scRNN"
# Out:
# /content/drive/MyDrive/Tesis/scRNN

# %%
import torch

torch.cuda.is_available()
# Out:
# True

# %%
# !pip install sacrebleu
# Out:
# Collecting sacrebleu
#   Downloading sacrebleu-2.0.0-py3-none-any.whl (90 kB)
#      |████████████████████████████████| 90 kB 3.8 MB/s
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from sacrebleu) (1.19.5)
# Requirement already satisfied: tabulate>=0.8.9 in /usr/local/lib/python3.7/dist-packages (from sacrebleu) (0.8.9)
# Collecting colorama
#   Downloading colorama-0.4.4-py2.py3-none-any.whl (16 kB)
# Requirement already satisfied: regex in /usr/local/lib/python3.7/dist-packages (from sacrebleu) (2019.12.20)
# Collecting portalocker
#   Downloading portalocker-2.3.2-py2.py3-none-any.whl (15 kB)
# Installing collected packages: portalocker, colorama, sacrebleu
# Successfully installed colorama-0.4.4 portalocker-2.3.2 sacrebleu-2.0.0

# %%
# !python3 train.py --language ash --task-name random_teacher_general --num-epochs 100 --batch-size 32 --vocab-size 4999 --new-vocab --train --train-sentences-errors-file ash.random_teacher_general.train.sentences.errors.txt --train-sentences-file ash.random_teacher_general.train.sentences.txt --val-sentences-errors-file ash.teacher_general.val.sentences.errors.txt --val-sentences-file ash.teacher_general.val.sentences.txt --test-sentences-errors-file ash.teacher_general.test.sentences.errors.txt --test-sentences-file ash.teacher_general.test.sentences.txt --metric chrF --save
# Out:
# Parameters
# {'language': 'ash', 'task_name': 'random_teacher_general', 'vocab_size': 4999, 'num_epochs': 100, 'batch_size': 32, 'model_name': 'shi_random_20531_100_32', 'new_vocab': True, 'need_to_train': True, 'train_sentences_errors_file': 'ash.random_teacher_general.train.sentences.errors.txt', 'train_sentences_file': 'ash.random_teacher_general.train.sentences.txt', 'val_sentences_errors_file': 'ash.teacher_general.val.sentences.errors.txt', 'val_sentences_file': 'ash.teacher_general.val.sentences.txt', 'test_sentences_errors_file': 'ash.teacher_general.test.sentences.errors.txt', 'test_sentences_file': 'ash.teacher_general.test.sentences.txt', 'metric': 'chrF', 'save_model': True}
#
#
# Creating new vocabulary
# Len of w2i:  4999
# Len of i2w:  4999
# Len of char vocab:  23
#
#
# Initializing an only ScRNN model
#
#
# Training the model...
#
# Average train loss after 1 iteration = 0.1828
# Total train chrF after 1 iteration = 69.9586
# Average val loss after 1 iteration = 0.1979
# Total val chrF after 1 iteration = 84.6198
# Average test loss after 1 iteration = 0.1929
# Total test chrF after 1 iteration = 83.6101
# Dumping after  1
# Time for the iteration 11.2 seconds
#
#
# Average train loss after 2 iteration = 0.1472
# Total train chrF after 2 iteration = 70.0202
# Average val loss after 2 iteration = 0.1336
# Total val chrF after 2 iteration = 83.9595
# Average test loss after 2 iteration = 0.1299
# Total test chrF after 2 iteration = 83.1882
# Time for the iteration 11.0 seconds
#
#
# Average train loss after 3 iteration = 0.1156
# Total train chrF after 3 iteration = 72.7531
# Average val loss after 3 iteration = 0.1019
# Total val chrF after 3 iteration = 86.0692
# Average test loss after 3 iteration = 0.0989
# Total test chrF after 3 iteration = 85.0957
# Dumping after  3
# Time for the iteration 10.8 seconds
#
#
# Average train loss after 4 iteration = 0.0917
# Total train chrF after 4 iteration = 75.2966
# Average val loss after 4 iteration = 0.0815
# Total val chrF after 4 iteration = 86.9062
# Average test loss after 4 iteration = 0.0788
# Total test chrF after 4 iteration = 85.9195
# Dumping after  4
# Time for the iteration 10.9 seconds
#
#
# Average train loss after 5 iteration = 0.0744
# Total train chrF after 5 iteration = 77.2806
# Average val loss after 5 iteration = 0.0677
# Total val chrF after 5 iteration = 87.3908
# Average test loss after 5 iteration = 0.0652
# Total test chrF after 5 iteration = 86.3293
# Dumping after  5
# Time for the iteration 11.0 seconds
#
#
# Average train loss after 6 iteration = 0.0615
# Total train chrF after 6 iteration = 78.8884
# Average val loss after 6 iteration = 0.0577
# Total val chrF after 6 iteration = 87.6487
# Average test loss after 6 iteration = 0.0555
# Total test chrF after 6 iteration = 86.7897
# Dumping after  6
# Time for the iteration 11.0 seconds
#
#
# Average train loss after 7 iteration = 0.0515
# Total train chrF after 7 iteration = 80.2869
# Average val loss after 7 iteration = 0.0501
# Total val chrF after 7 iteration = 87.7037
# Average test loss after 7 iteration = 0.0481
# Total test chrF after 7 iteration = 87.0019
# Dumping after  7
# Time for the iteration 11.4 seconds
#
#
# Average train loss after 8 iteration = 0.0436
# Total train chrF after 8 iteration = 81.4625
# Average val loss after 8 iteration = 0.0443
# Total val chrF after 8 iteration = 87.8795
# Average test loss after 8 iteration = 0.0424
# Total test chrF after 8 iteration = 87.0448
# Dumping after  8
# Time for the iteration 11.3 seconds
#
#
# Average train loss after 9 iteration = 0.0374
# Total train chrF after 9 iteration = 82.5064
# Average val loss after 9 iteration = 0.0399
# Total val chrF after 9 iteration = 88.0322
# Average test loss after 9 iteration = 0.0382
# Total test chrF after 9 iteration = 87.0911
# Dumping after  9
# Time for the iteration 11.0 seconds
#
#
# Average train loss after 10 iteration = 0.0325
# Total train chrF after 10 iteration = 83.4396
# Average val loss after 10 iteration = 0.0366
# Total val chrF after 10 iteration = 88.1581
# Average test loss after 10 iteration = 0.0349
# Total test chrF after 10 iteration = 87.4079
# Dumping after  10
# Time for the iteration 11.0 seconds
#
#
# Average train loss after 11 iteration = 0.0285
# Total train chrF after 11 iteration = 84.2971
# Average val loss after 11 iteration = 0.0341
# Total val chrF after 11 iteration = 88.3104
# Average test loss after 11 iteration = 0.0324
# Total test chrF after 11 iteration = 87.5065
# Dumping after  11
# Time for the iteration 11.0 seconds
#
#
# Average train loss after 12 iteration = 0.0254
# Total train chrF after 12 iteration = 85.0572
# Average val loss after 12 iteration = 0.0321
# Total val chrF after 12 iteration = 88.3870
# Average test loss after 12 iteration = 0.0304
# Total test chrF after 12 iteration = 87.5993
# Dumping after  12
# Time for the iteration 10.9 seconds
#
#
# Average train loss after 13 iteration = 0.0228
# Total train chrF after 13 iteration = 85.7267
# Average val loss after 13 iteration = 0.0305
# Total val chrF after 13 iteration = 88.4001
# Average test loss after 13 iteration = 0.0288
# Total test chrF after 13 iteration = 87.7646
# Dumping after  13
# Time for the iteration 11.2 seconds
#
#
# Average train loss after 14 iteration = 0.0207
# Total train chrF after 14 iteration = 86.3214
# Average val loss after 14 iteration = 0.0292
# Total val chrF after 14 iteration = 88.4962
# Average test loss after 14 iteration = 0.0275
# Total test chrF after 14 iteration = 87.8646
# Dumping after  14
# Time for the iteration 10.9 seconds
#
#
# Average train loss after 15 iteration = 0.0189
# Total train chrF after 15 iteration = 86.8625
# Average val loss after 15 iteration = 0.0282
# Total val chrF after 15 iteration = 88.4892
# Average test loss after 15 iteration = 0.0265
# Total test chrF after 15 iteration = 87.8480
# Time for the iteration 10.9 seconds
#
#
# Average train loss after 16 iteration = 0.0174
# Total train chrF after 16 iteration = 87.3703
# Average val loss after 16 iteration = 0.0274
# Total val chrF after 16 iteration = 88.5692
# Average test loss after 16 iteration = 0.0256
# Total test chrF after 16 iteration = 87.9339
# Dumping after  16
# Time for the iteration 11.0 seconds
#
#
# Average train loss after 17 iteration = 0.0161
# Total train chrF after 17 iteration = 87.7896
# Average val loss after 17 iteration = 0.0267
# Total val chrF after 17 iteration = 88.6442
# Average test loss after 17 iteration = 0.0249
# Total test chrF after 17 iteration = 87.9793
# Dumping after  17
# Time for the iteration 10.9 seconds
#
#
# Average train loss after 18 iteration = 0.0150
# Total train chrF after 18 iteration = 88.1356
# Average val loss after 18 iteration = 0.0261
# Total val chrF after 18 iteration = 88.7219
# Average test loss after 18 iteration = 0.0243
# Total test chrF after 18 iteration = 88.0493
# Dumping after  18
# Time for the iteration 10.9 seconds
#
#
# Average train loss after 19 iteration = 0.0141
# Total train chrF after 19 iteration = 88.4529
# Average val loss after 19 iteration = 0.0256
# Total val chrF after 19 iteration = 88.7578
# Average test loss after 19 iteration = 0.0237
# Total test chrF after 19 iteration = 88.2233
# Dumping after  19
# Time for the iteration 11.0 seconds
#
#
# Average train loss after 20 iteration = 0.0132
# Total train chrF after 20 iteration = 88.7486
# Average val loss after 20 iteration = 0.0251
# Total val chrF after 20 iteration = 88.8335
# Average test loss after 20 iteration = 0.0232
# Total test chrF after 20 iteration = 88.2812
# Dumping after  20
# Time for the iteration 10.9 seconds
#
#
# Average train loss after 21 iteration = 0.0125
# Total train chrF after 21 iteration = 89.0000
# Average val loss after 21 iteration = 0.0247
# Total val chrF after 21 iteration = 88.8743
# Average test loss after 21 iteration = 0.0228
# Total test chrF after 21 iteration = 88.3165
# Dumping after  21
# Time for the iteration 10.9 seconds
#
#
# Average train loss after 22 iteration = 0.0118
# Total train chrF after 22 iteration = 89.2215
# Average val loss after 22 iteration = 0.0244
# Total val chrF after 22 iteration = 89.0193
# Average test loss after 22 iteration = 0.0224
# Total test chrF after 22 iteration = 88.3375
# Dumping after  22
# Time for the iteration 11.1 seconds
#
#
# Average train loss after 23 iteration = 0.0112
# Total train chrF after 23 iteration = 89.4254
# Average val loss after 23 iteration = 0.0240
# Total val chrF after 23 iteration = 89.0784
# Average test loss after 23 iteration = 0.0221
# Total test chrF after 23 iteration = 88.3343
# Dumping after  23
# Time for the iteration 10.9 seconds
#
#
# Average train loss after 24 iteration = 0.0106
# Total train chrF after 24 iteration = 89.6101
# Average val loss after 24 iteration = 0.0238
# Total val chrF after 24 iteration = 89.0898
# Average test loss after 24 iteration = 0.0218
# Total test chrF after 24 iteration = 88.3526
# Dumping after  24
# Time for the iteration 10.9 seconds
#
#
# Average train loss after 25 iteration = 0.0101
# Total train chrF after 25 iteration = 89.7873
# Average val loss after 25 iteration = 0.0236
# Total val chrF after 25 iteration = 89.1216
# Average test loss after 25 iteration = 0.0216
# Total test chrF after 25 iteration = 88.4384
# Dumping after  25
# Time for the iteration 11.0 seconds
#
#
# Average train loss after 26 iteration = 0.0096
# Total train chrF after 26 iteration = 89.9534
# Average val loss after 26 iteration = 0.0235
# Total val chrF after 26 iteration = 89.1967
# Average test loss after 26 iteration = 0.0214
# Total test chrF after 26 iteration = 88.4971
# Dumping after  26
# Time for the iteration 10.9 seconds
#
#
# Average train loss after 27 iteration = 0.0092
# Total train chrF after 27 iteration = 90.0916
# Average val loss after 27 iteration = 0.0233
# Total val chrF after 27 iteration = 89.2545
# Average test loss after 27 iteration = 0.0212
# Total test chrF after 27 iteration = 88.5142
# Dumping after  27
# Time for the iteration 11.0 seconds
#
#
# Average train loss after 28 iteration = 0.0088
# Total train chrF after 28 iteration = 90.2214
# Average val loss after 28 iteration = 0.0232
# Total val chrF after 28 iteration = 89.2533
# Average test loss after 28 iteration = 0.0211
# Total test chrF after 28 iteration = 88.5418
# Time for the iteration 10.9 seconds
#
#
# Average train loss after 29 iteration = 0.0084
# Total train chrF after 29 iteration = 90.3485
# Average val loss after 29 iteration = 0.0231
# Total val chrF after 29 iteration = 89.2664
# Average test loss after 29 iteration = 0.0210
# Total test chrF after 29 iteration = 88.5774
# Dumping after  29
# Time for the iteration 11.0 seconds
#
#
# Average train loss after 30 iteration = 0.0080
# Total train chrF after 30 iteration = 90.4698
# Average val loss after 30 iteration = 0.0231
# Total val chrF after 30 iteration = 89.2532
# Average test loss after 30 iteration = 0.0209
# Total test chrF after 30 iteration = 88.5855
# Time for the iteration 11.1 seconds
#
#
# Average train loss after 31 iteration = 0.0077
# Total train chrF after 31 iteration = 90.5680
# Average val loss after 31 iteration = 0.0230
# Total val chrF after 31 iteration = 89.2999
# Average test loss after 31 iteration = 0.0208
# Total test chrF after 31 iteration = 88.5788
# Dumping after  31
# Time for the iteration 11.0 seconds
#
#
# Average train loss after 32 iteration = 0.0073
# Total train chrF after 32 iteration = 90.6718
# Average val loss after 32 iteration = 0.0230
# Total val chrF after 32 iteration = 89.3154
# Average test loss after 32 iteration = 0.0207
# Total test chrF after 32 iteration = 88.5416
# Dumping after  32
# Time for the iteration 10.9 seconds
#
#
# Average train loss after 33 iteration = 0.0070
# Total train chrF after 33 iteration = 90.7736
# Average val loss after 33 iteration = 0.0230
# Total val chrF after 33 iteration = 89.2825
# Average test loss after 33 iteration = 0.0207
# Total test chrF after 33 iteration = 88.5881
# Time for the iteration 11.0 seconds
#
#
# Average train loss after 34 iteration = 0.0067
# Total train chrF after 34 iteration = 90.8641
# Average val loss after 34 iteration = 0.0230
# Total val chrF after 34 iteration = 89.2630
# Average test loss after 34 iteration = 0.0206
# Total test chrF after 34 iteration = 88.6261
# Time for the iteration 11.0 seconds
#
#
# Average train loss after 35 iteration = 0.0065
# Total train chrF after 35 iteration = 90.9384
# Average val loss after 35 iteration = 0.0230
# Total val chrF after 35 iteration = 89.2741
# Average test loss after 35 iteration = 0.0206
# Total test chrF after 35 iteration = 88.6705
# Time for the iteration 11.0 seconds
#
#
# Average train loss after 36 iteration = 0.0062
# Total train chrF after 36 iteration = 91.0042
# Average val loss after 36 iteration = 0.0230
# Total val chrF after 36 iteration = 89.2000
# Average test loss after 36 iteration = 0.0206
# Total test chrF after 36 iteration = 88.7053
# Time for the iteration 11.0 seconds
#
#
# Average train loss after 37 iteration = 0.0060
# Total train chrF after 37 iteration = 91.0703
# Average val loss after 37 iteration = 0.0230
# Total val chrF after 37 iteration = 89.1911
# Average test loss after 37 iteration = 0.0206
# Total test chrF after 37 iteration = 88.6831
# Time for the iteration 11.1 seconds
#
#
# Average train loss after 38 iteration = 0.0057
# Total train chrF after 38 iteration = 91.1366
# Average val loss after 38 iteration = 0.0230
# Total val chrF after 38 iteration = 89.1952
# Average test loss after 38 iteration = 0.0206
# Total test chrF after 38 iteration = 88.6861
# Time for the iteration 11.0 seconds
#
#
# Average train loss after 39 iteration = 0.0055
# Total train chrF after 39 iteration = 91.1947
# Average val loss after 39 iteration = 0.0231
# Total val chrF after 39 iteration = 89.1483
# Average test loss after 39 iteration = 0.0206
# Total test chrF after 39 iteration = 88.6364
# Time for the iteration 10.9 seconds
#
#
# Average train loss after 40 iteration = 0.0053
# Total train chrF after 40 iteration = 91.2557
# Average val loss after 40 iteration = 0.0232
# Total val chrF after 40 iteration = 89.1891
# Average test loss after 40 iteration = 0.0206
# Total test chrF after 40 iteration = 88.6808
# Time for the iteration 11.0 seconds
#
#
# Average train loss after 41 iteration = 0.0051
# Total train chrF after 41 iteration = 91.3041
# Average val loss after 41 iteration = 0.0232
# Total val chrF after 41 iteration = 89.1854
# Average test loss after 41 iteration = 0.0207
# Total test chrF after 41 iteration = 88.6113
# Time for the iteration 11.0 seconds
#
#
# Average train loss after 42 iteration = 0.0049
# Total train chrF after 42 iteration = 91.3640
# Average val loss after 42 iteration = 0.0233
# Total val chrF after 42 iteration = 89.1757
# Average test loss after 42 iteration = 0.0207
# Total test chrF after 42 iteration = 88.5852
# Time for the iteration 10.8 seconds
#
#
# Average train loss after 43 iteration = 0.0047
# Total train chrF after 43 iteration = 91.4047
# Average val loss after 43 iteration = 0.0234
# Total val chrF after 43 iteration = 89.2093
# Average test loss after 43 iteration = 0.0207
# Total test chrF after 43 iteration = 88.5609
# Time for the iteration 10.9 seconds
#
#
# Average train loss after 44 iteration = 0.0045
# Total train chrF after 44 iteration = 91.4518
# Average val loss after 44 iteration = 0.0235
# Total val chrF after 44 iteration = 89.1999
# Average test loss after 44 iteration = 0.0208
# Total test chrF after 44 iteration = 88.4853
# Time for the iteration 11.0 seconds
#
#
# Average train loss after 45 iteration = 0.0044
# Total train chrF after 45 iteration = 91.5004
# Average val loss after 45 iteration = 0.0236
# Total val chrF after 45 iteration = 89.2055
# Average test loss after 45 iteration = 0.0209
# Total test chrF after 45 iteration = 88.4313
# Time for the iteration 10.9 seconds
#
#
# Average train loss after 46 iteration = 0.0042
# Total train chrF after 46 iteration = 91.5419
# Average val loss after 46 iteration = 0.0237
# Total val chrF after 46 iteration = 89.2260
# Average test loss after 46 iteration = 0.0210
# Total test chrF after 46 iteration = 88.4055
# Time for the iteration 11.1 seconds
#
#
# Average train loss after 47 iteration = 0.0041
# Total train chrF after 47 iteration = 91.5797
# Average val loss after 47 iteration = 0.0238
# Total val chrF after 47 iteration = 89.1457
# Average test loss after 47 iteration = 0.0210
# Total test chrF after 47 iteration = 88.4612
# Time for the iteration 10.9 seconds
#
#
# Average train loss after 48 iteration = 0.0039
# Total train chrF after 48 iteration = 91.6209
# Average val loss after 48 iteration = 0.0239
# Total val chrF after 48 iteration = 89.1395
# Average test loss after 48 iteration = 0.0211
# Total test chrF after 48 iteration = 88.4108
# Time for the iteration 10.8 seconds
#
#
# Average train loss after 49 iteration = 0.0038
# Total train chrF after 49 iteration = 91.6575
# Average val loss after 49 iteration = 0.0241
# Total val chrF after 49 iteration = 89.1058
# Average test loss after 49 iteration = 0.0212
# Total test chrF after 49 iteration = 88.3956
# Time for the iteration 10.9 seconds
#
#
# Average train loss after 50 iteration = 0.0036
# Total train chrF after 50 iteration = 91.6946
# Average val loss after 50 iteration = 0.0242
# Total val chrF after 50 iteration = 89.0465
# Average test loss after 50 iteration = 0.0213
# Total test chrF after 50 iteration = 88.3822
# Time for the iteration 10.9 seconds
#
#
# Average train loss after 51 iteration = 0.0035
# Total train chrF after 51 iteration = 91.7289
# Average val loss after 51 iteration = 0.0243
# Total val chrF after 51 iteration = 89.0491
# Average test loss after 51 iteration = 0.0214
# Total test chrF after 51 iteration = 88.3652
# Time for the iteration 10.9 seconds
#
#
# Average train loss after 52 iteration = 0.0034
# Total train chrF after 52 iteration = 91.7546
# Average val loss after 52 iteration = 0.0245
# Total val chrF after 52 iteration = 89.0636
# Average test loss after 52 iteration = 0.0215
# Total test chrF after 52 iteration = 88.3037
# Time for the iteration 11.0 seconds
#
#
# Average train loss after 53 iteration = 0.0033
# Total train chrF after 53 iteration = 91.7809
# Average val loss after 53 iteration = 0.0246
# Total val chrF after 53 iteration = 89.0415
# Average test loss after 53 iteration = 0.0216
# Total test chrF after 53 iteration = 88.2624
# Time for the iteration 10.9 seconds
#
#
# Average train loss after 54 iteration = 0.0031
# Total train chrF after 54 iteration = 91.8100
# Average val loss after 54 iteration = 0.0248
# Total val chrF after 54 iteration = 89.0271
# Average test loss after 54 iteration = 0.0218
# Total test chrF after 54 iteration = 88.1950
# Time for the iteration 10.9 seconds
#
#
# Average train loss after 55 iteration = 0.0030
# Total train chrF after 55 iteration = 91.8308
# Average val loss after 55 iteration = 0.0249
# Total val chrF after 55 iteration = 89.0296
# Average test loss after 55 iteration = 0.0219
# Total test chrF after 55 iteration = 88.1602
# Time for the iteration 10.9 seconds
#
#
# Average train loss after 56 iteration = 0.0029
# Total train chrF after 56 iteration = 91.8575
# Average val loss after 56 iteration = 0.0251
# Total val chrF after 56 iteration = 89.0251
# Average test loss after 56 iteration = 0.0220
# Total test chrF after 56 iteration = 88.1693
# Time for the iteration 10.8 seconds
#
#
# Average train loss after 57 iteration = 0.0028
# Total train chrF after 57 iteration = 91.8831
# Average val loss after 57 iteration = 0.0253
# Total val chrF after 57 iteration = 88.9943
# Average test loss after 57 iteration = 0.0222
# Total test chrF after 57 iteration = 88.1711
# Time for the iteration 10.9 seconds
#
#
# Average train loss after 58 iteration = 0.0027
# Total train chrF after 58 iteration = 91.9043
# Average val loss after 58 iteration = 0.0254
# Total val chrF after 58 iteration = 88.8683
# Average test loss after 58 iteration = 0.0223
# Total test chrF after 58 iteration = 88.2168
# Time for the iteration 11.1 seconds
#
#
# Average train loss after 59 iteration = 0.0026
# Total train chrF after 59 iteration = 91.9259
# Average val loss after 59 iteration = 0.0256
# Total val chrF after 59 iteration = 88.8445
# Average test loss after 59 iteration = 0.0224
# Total test chrF after 59 iteration = 88.1611
# Time for the iteration 10.9 seconds
#
#
#
#
# Aborting since there hasn't been much progress
# <Figure size 640x480 with 1 Axes>
# <Figure size 640x480 with 1 Axes>

# %%
language = "ash"
task_name = "random_teacher_general"
vocab_size = 4999
num_epochs = 100
batch_size = 32
model = "50_1"
optimizer = "Adam"
metric = "chrF"

# %%
from IPython.display import Image

Image("curves/{}_{}_{}_{}_{}_loss.png".format(language, task_name, vocab_size, num_epochs, batch_size))

# %%
Image("curves/{}_{}_{}_{}_{}_{}.png".format(language, task_name, vocab_size, num_epochs, batch_size, metric))

# %%
print("{}.{}.{}.{}.{}.{}.{}".format(language, task_name, vocab_size, num_epochs, batch_size, model, optimizer))
# Out:
# ash.random_teacher_general.4999.100.32.50_1.Adam
