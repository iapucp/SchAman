# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
# %cd "drive/MyDrive/Tesis/scRNN"
# Out:
# /content/drive/MyDrive/Tesis/scRNN

# %%
import torch

torch.cuda.is_available()
# Out:
# True

# %%
# !pip install sacrebleu
# Out:
# Collecting sacrebleu
#   Downloading sacrebleu-2.0.0-py3-none-any.whl (90 kB)
#      |████████████████████████████████| 90 kB 6.0 MB/s
# Collecting colorama
#   Downloading colorama-0.4.4-py2.py3-none-any.whl (16 kB)
# Collecting portalocker
#   Downloading portalocker-2.3.2-py2.py3-none-any.whl (15 kB)
# Requirement already satisfied: tabulate>=0.8.9 in /usr/local/lib/python3.7/dist-packages (from sacrebleu) (0.8.9)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from sacrebleu) (1.19.5)
# Requirement already satisfied: regex in /usr/local/lib/python3.7/dist-packages (from sacrebleu) (2019.12.20)
# Installing collected packages: portalocker, colorama, sacrebleu
# Successfully installed colorama-0.4.4 portalocker-2.3.2 sacrebleu-2.0.0

# %%
# !python3 train.py --language ash --task-name unnorm_teacher_general --num-epochs 100 --batch-size 32 --vocab-size 4999 --new-vocab --train --train-sentences-errors-file ash.unnorm_teacher_general.train.sentences.errors.txt --train-sentences-file ash.unnorm_teacher_general.train.sentences.txt --val-sentences-errors-file ash.teacher_general.val.sentences.errors.txt --val-sentences-file ash.teacher_general.val.sentences.txt --test-sentences-errors-file ash.teacher_general.test.sentences.errors.txt --test-sentences-file ash.teacher_general.test.sentences.txt --metric chrF --save
# Out:
# Parameters
# {'language': 'ash', 'task_name': 'unnorm_teacher_general', 'vocab_size': 4999, 'num_epochs': 100, 'batch_size': 32, 'model_name': 'shi_random_20531_100_32', 'new_vocab': True, 'need_to_train': True, 'train_sentences_errors_file': 'ash.unnorm_teacher_general.train.sentences.errors.txt', 'train_sentences_file': 'ash.unnorm_teacher_general.train.sentences.txt', 'val_sentences_errors_file': 'ash.teacher_general.val.sentences.errors.txt', 'val_sentences_file': 'ash.teacher_general.val.sentences.txt', 'test_sentences_errors_file': 'ash.teacher_general.test.sentences.errors.txt', 'test_sentences_file': 'ash.teacher_general.test.sentences.txt', 'metric': 'chrF', 'save_model': True}
#
#
# Creating new vocabulary
# Len of w2i:  4999
# Len of i2w:  4999
# Len of char vocab:  23
#
#
# Initializing an only ScRNN model
#
#
# Training the model...
#
# Average train loss after 1 iteration = 0.1814
# Total train chrF after 1 iteration = 75.8248
# Average val loss after 1 iteration = 0.1863
# Total val chrF after 1 iteration = 87.1266
# Average test loss after 1 iteration = 0.1814
# Total test chrF after 1 iteration = 86.3709
# Dumping after  1
# Time for the iteration 10.9 seconds
#
#
# Average train loss after 2 iteration = 0.1387
# Total train chrF after 2 iteration = 75.6378
# Average val loss after 2 iteration = 0.1227
# Total val chrF after 2 iteration = 85.7196
# Average test loss after 2 iteration = 0.1192
# Total test chrF after 2 iteration = 85.0085
# Time for the iteration 10.9 seconds
#
#
# Average train loss after 3 iteration = 0.1031
# Total train chrF after 3 iteration = 78.3798
# Average val loss after 3 iteration = 0.0921
# Total val chrF after 3 iteration = 87.6266
# Average test loss after 3 iteration = 0.0890
# Total test chrF after 3 iteration = 86.7910
# Dumping after  3
# Time for the iteration 10.7 seconds
#
#
# Average train loss after 4 iteration = 0.0773
# Total train chrF after 4 iteration = 81.0577
# Average val loss after 4 iteration = 0.0725
# Total val chrF after 4 iteration = 88.2727
# Average test loss after 4 iteration = 0.0697
# Total test chrF after 4 iteration = 87.5519
# Dumping after  4
# Time for the iteration 10.9 seconds
#
#
# Average train loss after 5 iteration = 0.0590
# Total train chrF after 5 iteration = 83.0764
# Average val loss after 5 iteration = 0.0590
# Total val chrF after 5 iteration = 88.8325
# Average test loss after 5 iteration = 0.0565
# Total test chrF after 5 iteration = 87.9602
# Dumping after  5
# Time for the iteration 11.0 seconds
#
#
# Average train loss after 6 iteration = 0.0458
# Total train chrF after 6 iteration = 84.7310
# Average val loss after 6 iteration = 0.0498
# Total val chrF after 6 iteration = 89.1623
# Average test loss after 6 iteration = 0.0474
# Total test chrF after 6 iteration = 88.3563
# Dumping after  6
# Time for the iteration 10.9 seconds
#
#
# Average train loss after 7 iteration = 0.0361
# Total train chrF after 7 iteration = 86.0821
# Average val loss after 7 iteration = 0.0428
# Total val chrF after 7 iteration = 89.2623
# Average test loss after 7 iteration = 0.0405
# Total test chrF after 7 iteration = 88.6165
# Dumping after  7
# Time for the iteration 10.8 seconds
#
#
# Average train loss after 8 iteration = 0.0288
# Total train chrF after 8 iteration = 87.2206
# Average val loss after 8 iteration = 0.0376
# Total val chrF after 8 iteration = 89.4288
# Average test loss after 8 iteration = 0.0354
# Total test chrF after 8 iteration = 88.8387
# Dumping after  8
# Time for the iteration 10.9 seconds
#
#
# Average train loss after 9 iteration = 0.0234
# Total train chrF after 9 iteration = 88.1692
# Average val loss after 9 iteration = 0.0336
# Total val chrF after 9 iteration = 89.4766
# Average test loss after 9 iteration = 0.0314
# Total test chrF after 9 iteration = 88.9638
# Dumping after  9
# Time for the iteration 10.9 seconds
#
#
# Average train loss after 10 iteration = 0.0193
# Total train chrF after 10 iteration = 88.9922
# Average val loss after 10 iteration = 0.0306
# Total val chrF after 10 iteration = 89.7044
# Average test loss after 10 iteration = 0.0284
# Total test chrF after 10 iteration = 89.0812
# Dumping after  10
# Time for the iteration 11.2 seconds
#
#
# Average train loss after 11 iteration = 0.0162
# Total train chrF after 11 iteration = 89.6904
# Average val loss after 11 iteration = 0.0283
# Total val chrF after 11 iteration = 89.7800
# Average test loss after 11 iteration = 0.0261
# Total test chrF after 11 iteration = 89.2220
# Dumping after  11
# Time for the iteration 11.1 seconds
#
#
# Average train loss after 12 iteration = 0.0138
# Total train chrF after 12 iteration = 90.2540
# Average val loss after 12 iteration = 0.0264
# Total val chrF after 12 iteration = 89.8435
# Average test loss after 12 iteration = 0.0242
# Total test chrF after 12 iteration = 89.3080
# Dumping after  12
# Time for the iteration 11.0 seconds
#
#
# Average train loss after 13 iteration = 0.0118
# Total train chrF after 13 iteration = 90.7006
# Average val loss after 13 iteration = 0.0250
# Total val chrF after 13 iteration = 89.9470
# Average test loss after 13 iteration = 0.0227
# Total test chrF after 13 iteration = 89.4025
# Dumping after  13
# Time for the iteration 11.0 seconds
#
#
# Average train loss after 14 iteration = 0.0103
# Total train chrF after 14 iteration = 91.1062
# Average val loss after 14 iteration = 0.0239
# Total val chrF after 14 iteration = 89.9740
# Average test loss after 14 iteration = 0.0216
# Total test chrF after 14 iteration = 89.5112
# Dumping after  14
# Time for the iteration 11.0 seconds
#
#
# Average train loss after 15 iteration = 0.0091
# Total train chrF after 15 iteration = 91.4240
# Average val loss after 15 iteration = 0.0230
# Total val chrF after 15 iteration = 90.0427
# Average test loss after 15 iteration = 0.0206
# Total test chrF after 15 iteration = 89.5820
# Dumping after  15
# Time for the iteration 11.0 seconds
#
#
# Average train loss after 16 iteration = 0.0081
# Total train chrF after 16 iteration = 91.7152
# Average val loss after 16 iteration = 0.0223
# Total val chrF after 16 iteration = 90.0752
# Average test loss after 16 iteration = 0.0199
# Total test chrF after 16 iteration = 89.5789
# Dumping after  16
# Time for the iteration 11.1 seconds
#
#
# Average train loss after 17 iteration = 0.0073
# Total train chrF after 17 iteration = 91.9138
# Average val loss after 17 iteration = 0.0217
# Total val chrF after 17 iteration = 90.1407
# Average test loss after 17 iteration = 0.0193
# Total test chrF after 17 iteration = 89.6806
# Dumping after  17
# Time for the iteration 11.0 seconds
#
#
# Average train loss after 18 iteration = 0.0065
# Total train chrF after 18 iteration = 92.0855
# Average val loss after 18 iteration = 0.0212
# Total val chrF after 18 iteration = 90.2040
# Average test loss after 18 iteration = 0.0188
# Total test chrF after 18 iteration = 89.7650
# Dumping after  18
# Time for the iteration 11.0 seconds
#
#
# Average train loss after 19 iteration = 0.0059
# Total train chrF after 19 iteration = 92.2315
# Average val loss after 19 iteration = 0.0208
# Total val chrF after 19 iteration = 90.1561
# Average test loss after 19 iteration = 0.0183
# Total test chrF after 19 iteration = 89.8047
# Time for the iteration 11.1 seconds
#
#
# Average train loss after 20 iteration = 0.0054
# Total train chrF after 20 iteration = 92.3510
# Average val loss after 20 iteration = 0.0205
# Total val chrF after 20 iteration = 90.1618
# Average test loss after 20 iteration = 0.0180
# Total test chrF after 20 iteration = 89.8354
# Time for the iteration 10.9 seconds
#
#
# Average train loss after 21 iteration = 0.0049
# Total train chrF after 21 iteration = 92.4648
# Average val loss after 21 iteration = 0.0203
# Total val chrF after 21 iteration = 90.1616
# Average test loss after 21 iteration = 0.0177
# Total test chrF after 21 iteration = 89.8306
# Time for the iteration 11.0 seconds
#
#
# Average train loss after 22 iteration = 0.0045
# Total train chrF after 22 iteration = 92.5590
# Average val loss after 22 iteration = 0.0201
# Total val chrF after 22 iteration = 90.2176
# Average test loss after 22 iteration = 0.0175
# Total test chrF after 22 iteration = 89.8311
# Dumping after  22
# Time for the iteration 11.2 seconds
#
#
# Average train loss after 23 iteration = 0.0041
# Total train chrF after 23 iteration = 92.6320
# Average val loss after 23 iteration = 0.0200
# Total val chrF after 23 iteration = 90.2364
# Average test loss after 23 iteration = 0.0173
# Total test chrF after 23 iteration = 89.8930
# Dumping after  23
# Time for the iteration 11.0 seconds
#
#
# Average train loss after 24 iteration = 0.0038
# Total train chrF after 24 iteration = 92.7031
# Average val loss after 24 iteration = 0.0199
# Total val chrF after 24 iteration = 90.2576
# Average test loss after 24 iteration = 0.0172
# Total test chrF after 24 iteration = 89.9536
# Dumping after  24
# Time for the iteration 11.1 seconds
#
#
# Average train loss after 25 iteration = 0.0035
# Total train chrF after 25 iteration = 92.7667
# Average val loss after 25 iteration = 0.0198
# Total val chrF after 25 iteration = 90.2884
# Average test loss after 25 iteration = 0.0171
# Total test chrF after 25 iteration = 89.9789
# Dumping after  25
# Time for the iteration 11.0 seconds
#
#
# Average train loss after 26 iteration = 0.0033
# Total train chrF after 26 iteration = 92.8180
# Average val loss after 26 iteration = 0.0198
# Total val chrF after 26 iteration = 90.2869
# Average test loss after 26 iteration = 0.0170
# Total test chrF after 26 iteration = 89.9859
# Time for the iteration 11.0 seconds
#
#
# Average train loss after 27 iteration = 0.0030
# Total train chrF after 27 iteration = 92.8603
# Average val loss after 27 iteration = 0.0198
# Total val chrF after 27 iteration = 90.3421
# Average test loss after 27 iteration = 0.0169
# Total test chrF after 27 iteration = 90.0140
# Dumping after  27
# Time for the iteration 10.9 seconds
#
#
# Average train loss after 28 iteration = 0.0028
# Total train chrF after 28 iteration = 92.9015
# Average val loss after 28 iteration = 0.0198
# Total val chrF after 28 iteration = 90.3233
# Average test loss after 28 iteration = 0.0169
# Total test chrF after 28 iteration = 90.0122
# Time for the iteration 11.0 seconds
#
#
# Average train loss after 29 iteration = 0.0026
# Total train chrF after 29 iteration = 92.9390
# Average val loss after 29 iteration = 0.0199
# Total val chrF after 29 iteration = 90.3339
# Average test loss after 29 iteration = 0.0168
# Total test chrF after 29 iteration = 90.0685
# Time for the iteration 10.9 seconds
#
#
# Average train loss after 30 iteration = 0.0024
# Total train chrF after 30 iteration = 92.9725
# Average val loss after 30 iteration = 0.0199
# Total val chrF after 30 iteration = 90.3612
# Average test loss after 30 iteration = 0.0168
# Total test chrF after 30 iteration = 90.1261
# Dumping after  30
# Time for the iteration 11.0 seconds
#
#
# Average train loss after 31 iteration = 0.0022
# Total train chrF after 31 iteration = 92.9950
# Average val loss after 31 iteration = 0.0200
# Total val chrF after 31 iteration = 90.2828
# Average test loss after 31 iteration = 0.0168
# Total test chrF after 31 iteration = 90.1585
# Time for the iteration 10.9 seconds
#
#
# Average train loss after 32 iteration = 0.0021
# Total train chrF after 32 iteration = 93.0219
# Average val loss after 32 iteration = 0.0200
# Total val chrF after 32 iteration = 90.3427
# Average test loss after 32 iteration = 0.0168
# Total test chrF after 32 iteration = 90.1489
# Time for the iteration 11.1 seconds
#
#
# Average train loss after 33 iteration = 0.0019
# Total train chrF after 33 iteration = 93.0482
# Average val loss after 33 iteration = 0.0201
# Total val chrF after 33 iteration = 90.3246
# Average test loss after 33 iteration = 0.0169
# Total test chrF after 33 iteration = 90.1357
# Time for the iteration 11.1 seconds
#
#
# Average train loss after 34 iteration = 0.0018
# Total train chrF after 34 iteration = 93.0771
# Average val loss after 34 iteration = 0.0202
# Total val chrF after 34 iteration = 90.2773
# Average test loss after 34 iteration = 0.0169
# Total test chrF after 34 iteration = 90.1461
# Time for the iteration 10.9 seconds
#
#
# Average train loss after 35 iteration = 0.0017
# Total train chrF after 35 iteration = 93.0951
# Average val loss after 35 iteration = 0.0203
# Total val chrF after 35 iteration = 90.2483
# Average test loss after 35 iteration = 0.0169
# Total test chrF after 35 iteration = 90.1810
# Time for the iteration 10.9 seconds
#
#
# Average train loss after 36 iteration = 0.0016
# Total train chrF after 36 iteration = 93.1142
# Average val loss after 36 iteration = 0.0204
# Total val chrF after 36 iteration = 90.2836
# Average test loss after 36 iteration = 0.0170
# Total test chrF after 36 iteration = 90.1533
# Time for the iteration 11.1 seconds
#
#
# Average train loss after 37 iteration = 0.0015
# Total train chrF after 37 iteration = 93.1339
# Average val loss after 37 iteration = 0.0205
# Total val chrF after 37 iteration = 90.3596
# Average test loss after 37 iteration = 0.0170
# Total test chrF after 37 iteration = 90.1126
# Time for the iteration 11.1 seconds
#
#
# Average train loss after 38 iteration = 0.0014
# Total train chrF after 38 iteration = 93.1504
# Average val loss after 38 iteration = 0.0206
# Total val chrF after 38 iteration = 90.3405
# Average test loss after 38 iteration = 0.0171
# Total test chrF after 38 iteration = 90.1199
# Time for the iteration 11.1 seconds
#
#
# Average train loss after 39 iteration = 0.0013
# Total train chrF after 39 iteration = 93.1629
# Average val loss after 39 iteration = 0.0207
# Total val chrF after 39 iteration = 90.3551
# Average test loss after 39 iteration = 0.0172
# Total test chrF after 39 iteration = 90.0745
# Time for the iteration 11.0 seconds
#
#
# Average train loss after 40 iteration = 0.0012
# Total train chrF after 40 iteration = 93.1734
# Average val loss after 40 iteration = 0.0208
# Total val chrF after 40 iteration = 90.3700
# Average test loss after 40 iteration = 0.0172
# Total test chrF after 40 iteration = 90.0190
# Dumping after  40
# Time for the iteration 10.9 seconds
#
#
# Average train loss after 41 iteration = 0.0011
# Total train chrF after 41 iteration = 93.1818
# Average val loss after 41 iteration = 0.0209
# Total val chrF after 41 iteration = 90.3326
# Average test loss after 41 iteration = 0.0173
# Total test chrF after 41 iteration = 89.9993
# Time for the iteration 11.0 seconds
#
#
# Average train loss after 42 iteration = 0.0010
# Total train chrF after 42 iteration = 93.1924
# Average val loss after 42 iteration = 0.0211
# Total val chrF after 42 iteration = 90.3349
# Average test loss after 42 iteration = 0.0174
# Total test chrF after 42 iteration = 89.9475
# Time for the iteration 11.0 seconds
#
#
# Average train loss after 43 iteration = 0.0010
# Total train chrF after 43 iteration = 93.2013
# Average val loss after 43 iteration = 0.0212
# Total val chrF after 43 iteration = 90.3090
# Average test loss after 43 iteration = 0.0175
# Total test chrF after 43 iteration = 89.8681
# Time for the iteration 11.0 seconds
#
#
# Average train loss after 44 iteration = 0.0009
# Total train chrF after 44 iteration = 93.2128
# Average val loss after 44 iteration = 0.0214
# Total val chrF after 44 iteration = 90.3205
# Average test loss after 44 iteration = 0.0176
# Total test chrF after 44 iteration = 89.8822
# Time for the iteration 10.9 seconds
#
#
# Average train loss after 45 iteration = 0.0008
# Total train chrF after 45 iteration = 93.2236
# Average val loss after 45 iteration = 0.0215
# Total val chrF after 45 iteration = 90.2947
# Average test loss after 45 iteration = 0.0177
# Total test chrF after 45 iteration = 89.8983
# Time for the iteration 11.0 seconds
#
#
# Average train loss after 46 iteration = 0.0008
# Total train chrF after 46 iteration = 93.2335
# Average val loss after 46 iteration = 0.0217
# Total val chrF after 46 iteration = 90.2774
# Average test loss after 46 iteration = 0.0178
# Total test chrF after 46 iteration = 89.8177
# Time for the iteration 10.9 seconds
#
#
# Average train loss after 47 iteration = 0.0007
# Total train chrF after 47 iteration = 93.2395
# Average val loss after 47 iteration = 0.0218
# Total val chrF after 47 iteration = 90.2793
# Average test loss after 47 iteration = 0.0179
# Total test chrF after 47 iteration = 89.7966
# Time for the iteration 10.9 seconds
#
#
# Average train loss after 48 iteration = 0.0007
# Total train chrF after 48 iteration = 93.2451
# Average val loss after 48 iteration = 0.0220
# Total val chrF after 48 iteration = 90.3495
# Average test loss after 48 iteration = 0.0180
# Total test chrF after 48 iteration = 89.7720
# Time for the iteration 11.1 seconds
#
#
# Average train loss after 49 iteration = 0.0006
# Total train chrF after 49 iteration = 93.2486
# Average val loss after 49 iteration = 0.0221
# Total val chrF after 49 iteration = 90.3796
# Average test loss after 49 iteration = 0.0182
# Total test chrF after 49 iteration = 89.6768
# Dumping after  49
# Time for the iteration 10.9 seconds
#
#
# Average train loss after 50 iteration = 0.0006
# Total train chrF after 50 iteration = 93.2527
# Average val loss after 50 iteration = 0.0223
# Total val chrF after 50 iteration = 90.3619
# Average test loss after 50 iteration = 0.0183
# Total test chrF after 50 iteration = 89.6995
# Time for the iteration 11.0 seconds
#
#
# Average train loss after 51 iteration = 0.0006
# Total train chrF after 51 iteration = 93.2573
# Average val loss after 51 iteration = 0.0225
# Total val chrF after 51 iteration = 90.3588
# Average test loss after 51 iteration = 0.0185
# Total test chrF after 51 iteration = 89.6968
# Time for the iteration 11.0 seconds
#
#
# Average train loss after 52 iteration = 0.0005
# Total train chrF after 52 iteration = 93.2617
# Average val loss after 52 iteration = 0.0227
# Total val chrF after 52 iteration = 90.3625
# Average test loss after 52 iteration = 0.0186
# Total test chrF after 52 iteration = 89.7308
# Time for the iteration 10.9 seconds
#
#
# Average train loss after 53 iteration = 0.0005
# Total train chrF after 53 iteration = 93.2658
# Average val loss after 53 iteration = 0.0228
# Total val chrF after 53 iteration = 90.3734
# Average test loss after 53 iteration = 0.0187
# Total test chrF after 53 iteration = 89.6724
# Time for the iteration 11.1 seconds
#
#
# Average train loss after 54 iteration = 0.0004
# Total train chrF after 54 iteration = 93.2685
# Average val loss after 54 iteration = 0.0230
# Total val chrF after 54 iteration = 90.3955
# Average test loss after 54 iteration = 0.0189
# Total test chrF after 54 iteration = 89.6338
# Dumping after  54
# Time for the iteration 11.0 seconds
#
#
# Average train loss after 55 iteration = 0.0004
# Total train chrF after 55 iteration = 93.2711
# Average val loss after 55 iteration = 0.0232
# Total val chrF after 55 iteration = 90.3774
# Average test loss after 55 iteration = 0.0190
# Total test chrF after 55 iteration = 89.6350
# Time for the iteration 11.0 seconds
#
#
# Average train loss after 56 iteration = 0.0004
# Total train chrF after 56 iteration = 93.2728
# Average val loss after 56 iteration = 0.0234
# Total val chrF after 56 iteration = 90.3745
# Average test loss after 56 iteration = 0.0192
# Total test chrF after 56 iteration = 89.6310
# Time for the iteration 11.1 seconds
#
#
# Average train loss after 57 iteration = 0.0004
# Total train chrF after 57 iteration = 93.2758
# Average val loss after 57 iteration = 0.0236
# Total val chrF after 57 iteration = 90.3502
# Average test loss after 57 iteration = 0.0194
# Total test chrF after 57 iteration = 89.5677
# Time for the iteration 11.1 seconds
#
#
# Average train loss after 58 iteration = 0.0003
# Total train chrF after 58 iteration = 93.2780
# Average val loss after 58 iteration = 0.0237
# Total val chrF after 58 iteration = 90.3422
# Average test loss after 58 iteration = 0.0195
# Total test chrF after 58 iteration = 89.5540
# Time for the iteration 10.9 seconds
#
#
# Average train loss after 59 iteration = 0.0003
# Total train chrF after 59 iteration = 93.2793
# Average val loss after 59 iteration = 0.0239
# Total val chrF after 59 iteration = 90.3416
# Average test loss after 59 iteration = 0.0197
# Total test chrF after 59 iteration = 89.5403
# Time for the iteration 11.0 seconds
#
#
# Average train loss after 60 iteration = 0.0003
# Total train chrF after 60 iteration = 93.2810
# Average val loss after 60 iteration = 0.0241
# Total val chrF after 60 iteration = 90.3027
# Average test loss after 60 iteration = 0.0199
# Total test chrF after 60 iteration = 89.5447
# Time for the iteration 11.0 seconds
#
#
# Average train loss after 61 iteration = 0.0003
# Total train chrF after 61 iteration = 93.2822
# Average val loss after 61 iteration = 0.0243
# Total val chrF after 61 iteration = 90.2734
# Average test loss after 61 iteration = 0.0200
# Total test chrF after 61 iteration = 89.5015
# Time for the iteration 11.0 seconds
#
#
# Average train loss after 62 iteration = 0.0003
# Total train chrF after 62 iteration = 93.2827
# Average val loss after 62 iteration = 0.0245
# Total val chrF after 62 iteration = 90.2328
# Average test loss after 62 iteration = 0.0202
# Total test chrF after 62 iteration = 89.4898
# Time for the iteration 11.0 seconds
#
#
# Average train loss after 63 iteration = 0.0002
# Total train chrF after 63 iteration = 93.2839
# Average val loss after 63 iteration = 0.0247
# Total val chrF after 63 iteration = 90.2082
# Average test loss after 63 iteration = 0.0204
# Total test chrF after 63 iteration = 89.4615
# Time for the iteration 11.1 seconds
#
#
# Average train loss after 64 iteration = 0.0002
# Total train chrF after 64 iteration = 93.2849
# Average val loss after 64 iteration = 0.0249
# Total val chrF after 64 iteration = 90.1958
# Average test loss after 64 iteration = 0.0206
# Total test chrF after 64 iteration = 89.4123
# Time for the iteration 10.8 seconds
#
#
# Average train loss after 65 iteration = 0.0002
# Total train chrF after 65 iteration = 93.2848
# Average val loss after 65 iteration = 0.0251
# Total val chrF after 65 iteration = 90.1868
# Average test loss after 65 iteration = 0.0207
# Total test chrF after 65 iteration = 89.3694
# Time for the iteration 11.1 seconds
#
#
# Average train loss after 66 iteration = 0.0002
# Total train chrF after 66 iteration = 93.2860
# Average val loss after 66 iteration = 0.0253
# Total val chrF after 66 iteration = 90.1960
# Average test loss after 66 iteration = 0.0209
# Total test chrF after 66 iteration = 89.3563
# Time for the iteration 10.9 seconds
#
#
# Average train loss after 67 iteration = 0.0002
# Total train chrF after 67 iteration = 93.2868
# Average val loss after 67 iteration = 0.0255
# Total val chrF after 67 iteration = 90.1987
# Average test loss after 67 iteration = 0.0211
# Total test chrF after 67 iteration = 89.3522
# Time for the iteration 11.1 seconds
#
#
# Average train loss after 68 iteration = 0.0002
# Total train chrF after 68 iteration = 93.2871
# Average val loss after 68 iteration = 0.0257
# Total val chrF after 68 iteration = 90.2045
# Average test loss after 68 iteration = 0.0213
# Total test chrF after 68 iteration = 89.3207
# Time for the iteration 10.9 seconds
#
#
# Average train loss after 69 iteration = 0.0001
# Total train chrF after 69 iteration = 93.2877
# Average val loss after 69 iteration = 0.0259
# Total val chrF after 69 iteration = 90.1582
# Average test loss after 69 iteration = 0.0215
# Total test chrF after 69 iteration = 89.3294
# Time for the iteration 10.8 seconds
#
#
# Average train loss after 70 iteration = 0.0001
# Total train chrF after 70 iteration = 93.2879
# Average val loss after 70 iteration = 0.0261
# Total val chrF after 70 iteration = 90.1999
# Average test loss after 70 iteration = 0.0217
# Total test chrF after 70 iteration = 89.2957
# Time for the iteration 11.0 seconds
#
#
# Average train loss after 71 iteration = 0.0001
# Total train chrF after 71 iteration = 93.2880
# Average val loss after 71 iteration = 0.0264
# Total val chrF after 71 iteration = 90.1428
# Average test loss after 71 iteration = 0.0219
# Total test chrF after 71 iteration = 89.2621
# Time for the iteration 11.1 seconds
#
#
# Average train loss after 72 iteration = 0.0001
# Total train chrF after 72 iteration = 93.2887
# Average val loss after 72 iteration = 0.0266
# Total val chrF after 72 iteration = 90.1412
# Average test loss after 72 iteration = 0.0221
# Total test chrF after 72 iteration = 89.2634
# Time for the iteration 11.0 seconds
#
#
# Average train loss after 73 iteration = 0.0001
# Total train chrF after 73 iteration = 93.2882
# Average val loss after 73 iteration = 0.0268
# Total val chrF after 73 iteration = 90.1654
# Average test loss after 73 iteration = 0.0223
# Total test chrF after 73 iteration = 89.2630
# Time for the iteration 10.9 seconds
#
#
# Average train loss after 74 iteration = 0.0001
# Total train chrF after 74 iteration = 93.2882
# Average val loss after 74 iteration = 0.0270
# Total val chrF after 74 iteration = 90.1460
# Average test loss after 74 iteration = 0.0225
# Total test chrF after 74 iteration = 89.2339
# Time for the iteration 11.0 seconds
#
#
# Average train loss after 75 iteration = 0.0001
# Total train chrF after 75 iteration = 93.2882
# Average val loss after 75 iteration = 0.0273
# Total val chrF after 75 iteration = 90.1400
# Average test loss after 75 iteration = 0.0227
# Total test chrF after 75 iteration = 89.2194
# Time for the iteration 11.0 seconds
#
#
# Average train loss after 76 iteration = 0.0001
# Total train chrF after 76 iteration = 93.2882
# Average val loss after 76 iteration = 0.0275
# Total val chrF after 76 iteration = 90.1487
# Average test loss after 76 iteration = 0.0229
# Total test chrF after 76 iteration = 89.2257
# Time for the iteration 11.0 seconds
#
#
# Average train loss after 77 iteration = 0.0001
# Total train chrF after 77 iteration = 93.2883
# Average val loss after 77 iteration = 0.0278
# Total val chrF after 77 iteration = 90.1462
# Average test loss after 77 iteration = 0.0231
# Total test chrF after 77 iteration = 89.2360
# Time for the iteration 11.0 seconds
#
#
# Average train loss after 78 iteration = 0.0001
# Total train chrF after 78 iteration = 93.2883
# Average val loss after 78 iteration = 0.0280
# Total val chrF after 78 iteration = 90.1380
# Average test loss after 78 iteration = 0.0233
# Total test chrF after 78 iteration = 89.2360
# Time for the iteration 11.1 seconds
#
#
# Average train loss after 79 iteration = 0.0001
# Total train chrF after 79 iteration = 93.2883
# Average val loss after 79 iteration = 0.0282
# Total val chrF after 79 iteration = 90.1694
# Average test loss after 79 iteration = 0.0235
# Total test chrF after 79 iteration = 89.2156
# Time for the iteration 10.9 seconds
#
#
# Average train loss after 80 iteration = 0.0001
# Total train chrF after 80 iteration = 93.2886
# Average val loss after 80 iteration = 0.0285
# Total val chrF after 80 iteration = 90.1745
# Average test loss after 80 iteration = 0.0237
# Total test chrF after 80 iteration = 89.2120
# Time for the iteration 11.0 seconds
#
#
# Average train loss after 81 iteration = 0.0001
# Total train chrF after 81 iteration = 93.2886
# Average val loss after 81 iteration = 0.0287
# Total val chrF after 81 iteration = 90.1910
# Average test loss after 81 iteration = 0.0239
# Total test chrF after 81 iteration = 89.2114
# Time for the iteration 10.8 seconds
#
#
#
#
# Aborting since there hasn't been much progress
# <Figure size 640x480 with 1 Axes>
# <Figure size 640x480 with 1 Axes>

# %%
language = "ash"
task_name = "unnorm_teacher_general"
vocab_size = 4999
num_epochs = 100
batch_size = 32
model = "50_1"
optimizer = "Adam"
metric = "chrF"

# %%
from IPython.display import Image

Image("curves/{}_{}_{}_{}_{}_loss.png".format(language, task_name, vocab_size, num_epochs, batch_size))

# %%
Image("curves/{}_{}_{}_{}_{}_{}.png".format(language, task_name, vocab_size, num_epochs, batch_size, metric))

# %%
print("{}.{}.{}.{}.{}.{}.{}".format(language, task_name, vocab_size, num_epochs, batch_size, model, optimizer))
# Out:
# ash.unnorm_teacher_general.4999.100.32.50_1.Adam
