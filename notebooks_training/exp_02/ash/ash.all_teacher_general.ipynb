# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
# %cd "drive/MyDrive/Tesis/scRNN"
# Out:
# /content/drive/MyDrive/Tesis/scRNN

# %%
import torch

torch.cuda.is_available()
# Out:
# True

# %%
# !pip install sacrebleu
# Out:
# Collecting sacrebleu
#   Downloading sacrebleu-2.0.0-py3-none-any.whl (90 kB)
#      |████████████████████████████████| 90 kB 4.3 MB/s
# Requirement already satisfied: regex in /usr/local/lib/python3.7/dist-packages (from sacrebleu) (2019.12.20)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from sacrebleu) (1.19.5)
# Requirement already satisfied: tabulate>=0.8.9 in /usr/local/lib/python3.7/dist-packages (from sacrebleu) (0.8.9)
# Collecting portalocker
#   Downloading portalocker-2.3.2-py2.py3-none-any.whl (15 kB)
# Collecting colorama
#   Downloading colorama-0.4.4-py2.py3-none-any.whl (16 kB)
# Installing collected packages: portalocker, colorama, sacrebleu
# Successfully installed colorama-0.4.4 portalocker-2.3.2 sacrebleu-2.0.0

# %%
# !python3 train.py --language ash --task-name all_teacher_general --num-epochs 100 --batch-size 32 --vocab-size 4999 --new-vocab --train --train-sentences-errors-file ash.all_teacher_general.train.sentences.errors.txt --train-sentences-file ash.all_teacher_general.train.sentences.txt --val-sentences-errors-file ash.teacher_general.val.sentences.errors.txt --val-sentences-file ash.teacher_general.val.sentences.txt --test-sentences-errors-file ash.teacher_general.test.sentences.errors.txt --test-sentences-file ash.teacher_general.test.sentences.txt --metric chrF --save
# Out:
# Parameters
# {'language': 'ash', 'task_name': 'all_teacher_general', 'vocab_size': 4999, 'num_epochs': 100, 'batch_size': 32, 'model_name': 'shi_random_20531_100_32', 'new_vocab': True, 'need_to_train': True, 'train_sentences_errors_file': 'ash.all_teacher_general.train.sentences.errors.txt', 'train_sentences_file': 'ash.all_teacher_general.train.sentences.txt', 'val_sentences_errors_file': 'ash.teacher_general.val.sentences.errors.txt', 'val_sentences_file': 'ash.teacher_general.val.sentences.txt', 'test_sentences_errors_file': 'ash.teacher_general.test.sentences.errors.txt', 'test_sentences_file': 'ash.teacher_general.test.sentences.txt', 'metric': 'chrF', 'save_model': True}
#
#
# Creating new vocabulary
# Len of w2i:  4999
# Len of i2w:  4999
# Len of char vocab:  23
#
#
# Initializing an only ScRNN model
#
#
# Training the model...
#
# Average train loss after 1 iteration = 0.1223
# Total train chrF after 1 iteration = 73.9867
# Average val loss after 1 iteration = 0.0961
# Total val chrF after 1 iteration = 85.5875
# Average test loss after 1 iteration = 0.0943
# Total test chrF after 1 iteration = 84.7505
# Dumping after  1
# Time for the iteration 46.2 seconds
#
#
# Average train loss after 2 iteration = 0.0507
# Total train chrF after 2 iteration = 81.1971
# Average val loss after 2 iteration = 0.0619
# Total val chrF after 2 iteration = 87.0829
# Average test loss after 2 iteration = 0.0607
# Total test chrF after 2 iteration = 86.2025
# Dumping after  2
# Time for the iteration 46.2 seconds
#
#
# Average train loss after 3 iteration = 0.0293
# Total train chrF after 3 iteration = 84.6898
# Average val loss after 3 iteration = 0.0488
# Total val chrF after 3 iteration = 87.7519
# Average test loss after 3 iteration = 0.0478
# Total test chrF after 3 iteration = 86.8195
# Dumping after  3
# Time for the iteration 46.2 seconds
#
#
# Average train loss after 4 iteration = 0.0211
# Total train chrF after 4 iteration = 86.5129
# Average val loss after 4 iteration = 0.0421
# Total val chrF after 4 iteration = 87.7041
# Average test loss after 4 iteration = 0.0411
# Total test chrF after 4 iteration = 87.0237
# Time for the iteration 46.2 seconds
#
#
# Average train loss after 5 iteration = 0.0171
# Total train chrF after 5 iteration = 87.6002
# Average val loss after 5 iteration = 0.0383
# Total val chrF after 5 iteration = 87.6513
# Average test loss after 5 iteration = 0.0373
# Total test chrF after 5 iteration = 86.9734
# Time for the iteration 46.3 seconds
#
#
# Average train loss after 6 iteration = 0.0146
# Total train chrF after 6 iteration = 88.3306
# Average val loss after 6 iteration = 0.0358
# Total val chrF after 6 iteration = 87.6945
# Average test loss after 6 iteration = 0.0349
# Total test chrF after 6 iteration = 86.8875
# Time for the iteration 46.4 seconds
#
#
# Average train loss after 7 iteration = 0.0129
# Total train chrF after 7 iteration = 88.8614
# Average val loss after 7 iteration = 0.0341
# Total val chrF after 7 iteration = 87.7056
# Average test loss after 7 iteration = 0.0333
# Total test chrF after 7 iteration = 86.8998
# Time for the iteration 46.3 seconds
#
#
# Average train loss after 8 iteration = 0.0116
# Total train chrF after 8 iteration = 89.2581
# Average val loss after 8 iteration = 0.0329
# Total val chrF after 8 iteration = 87.7795
# Average test loss after 8 iteration = 0.0322
# Total test chrF after 8 iteration = 86.7694
# Dumping after  8
# Time for the iteration 46.8 seconds
#
#
# Average train loss after 9 iteration = 0.0106
# Total train chrF after 9 iteration = 89.6004
# Average val loss after 9 iteration = 0.0320
# Total val chrF after 9 iteration = 87.7964
# Average test loss after 9 iteration = 0.0314
# Total test chrF after 9 iteration = 86.7286
# Dumping after  9
# Time for the iteration 46.2 seconds
#
#
# Average train loss after 10 iteration = 0.0098
# Total train chrF after 10 iteration = 89.8692
# Average val loss after 10 iteration = 0.0314
# Total val chrF after 10 iteration = 87.7210
# Average test loss after 10 iteration = 0.0308
# Total test chrF after 10 iteration = 86.6533
# Time for the iteration 46.0 seconds
#
#
# Average train loss after 11 iteration = 0.0091
# Total train chrF after 11 iteration = 90.1005
# Average val loss after 11 iteration = 0.0310
# Total val chrF after 11 iteration = 87.8125
# Average test loss after 11 iteration = 0.0304
# Total test chrF after 11 iteration = 86.6823
# Dumping after  11
# Time for the iteration 46.0 seconds
#
#
# Average train loss after 12 iteration = 0.0085
# Total train chrF after 12 iteration = 90.3035
# Average val loss after 12 iteration = 0.0306
# Total val chrF after 12 iteration = 87.8035
# Average test loss after 12 iteration = 0.0301
# Total test chrF after 12 iteration = 86.6286
# Time for the iteration 46.5 seconds
#
#
# Average train loss after 13 iteration = 0.0080
# Total train chrF after 13 iteration = 90.4765
# Average val loss after 13 iteration = 0.0304
# Total val chrF after 13 iteration = 87.7797
# Average test loss after 13 iteration = 0.0298
# Total test chrF after 13 iteration = 86.6366
# Time for the iteration 46.1 seconds
#
#
# Average train loss after 14 iteration = 0.0076
# Total train chrF after 14 iteration = 90.6253
# Average val loss after 14 iteration = 0.0302
# Total val chrF after 14 iteration = 87.8957
# Average test loss after 14 iteration = 0.0296
# Total test chrF after 14 iteration = 86.6456
# Dumping after  14
# Time for the iteration 46.3 seconds
#
#
# Average train loss after 15 iteration = 0.0072
# Total train chrF after 15 iteration = 90.7622
# Average val loss after 15 iteration = 0.0301
# Total val chrF after 15 iteration = 87.8040
# Average test loss after 15 iteration = 0.0295
# Total test chrF after 15 iteration = 86.6779
# Time for the iteration 46.0 seconds
#
#
# Average train loss after 16 iteration = 0.0068
# Total train chrF after 16 iteration = 90.8827
# Average val loss after 16 iteration = 0.0300
# Total val chrF after 16 iteration = 87.8122
# Average test loss after 16 iteration = 0.0294
# Total test chrF after 16 iteration = 86.6889
# Time for the iteration 46.5 seconds
#
#
# Average train loss after 17 iteration = 0.0065
# Total train chrF after 17 iteration = 91.0080
# Average val loss after 17 iteration = 0.0300
# Total val chrF after 17 iteration = 87.8197
# Average test loss after 17 iteration = 0.0293
# Total test chrF after 17 iteration = 86.7193
# Time for the iteration 46.1 seconds
#
#
# Average train loss after 18 iteration = 0.0062
# Total train chrF after 18 iteration = 91.1019
# Average val loss after 18 iteration = 0.0300
# Total val chrF after 18 iteration = 87.8145
# Average test loss after 18 iteration = 0.0293
# Total test chrF after 18 iteration = 86.6829
# Time for the iteration 46.6 seconds
#
#
# Average train loss after 19 iteration = 0.0059
# Total train chrF after 19 iteration = 91.1909
# Average val loss after 19 iteration = 0.0300
# Total val chrF after 19 iteration = 87.7928
# Average test loss after 19 iteration = 0.0293
# Total test chrF after 19 iteration = 86.6684
# Time for the iteration 46.5 seconds
#
#
# Average train loss after 20 iteration = 0.0057
# Total train chrF after 20 iteration = 91.2751
# Average val loss after 20 iteration = 0.0300
# Total val chrF after 20 iteration = 87.8212
# Average test loss after 20 iteration = 0.0293
# Total test chrF after 20 iteration = 86.6064
# Time for the iteration 46.5 seconds
#
#
# Average train loss after 21 iteration = 0.0054
# Total train chrF after 21 iteration = 91.3561
# Average val loss after 21 iteration = 0.0301
# Total val chrF after 21 iteration = 87.8154
# Average test loss after 21 iteration = 0.0293
# Total test chrF after 21 iteration = 86.5998
# Time for the iteration 46.4 seconds
#
#
# Average train loss after 22 iteration = 0.0052
# Total train chrF after 22 iteration = 91.4273
# Average val loss after 22 iteration = 0.0301
# Total val chrF after 22 iteration = 87.8049
# Average test loss after 22 iteration = 0.0293
# Total test chrF after 22 iteration = 86.6106
# Time for the iteration 46.0 seconds
#
#
# Average train loss after 23 iteration = 0.0050
# Total train chrF after 23 iteration = 91.4917
# Average val loss after 23 iteration = 0.0302
# Total val chrF after 23 iteration = 87.7886
# Average test loss after 23 iteration = 0.0294
# Total test chrF after 23 iteration = 86.6516
# Time for the iteration 46.2 seconds
#
#
# Average train loss after 24 iteration = 0.0049
# Total train chrF after 24 iteration = 91.5538
# Average val loss after 24 iteration = 0.0302
# Total val chrF after 24 iteration = 87.8127
# Average test loss after 24 iteration = 0.0294
# Total test chrF after 24 iteration = 86.6612
# Time for the iteration 46.0 seconds
#
#
# Average train loss after 25 iteration = 0.0047
# Total train chrF after 25 iteration = 91.6090
# Average val loss after 25 iteration = 0.0303
# Total val chrF after 25 iteration = 87.7993
# Average test loss after 25 iteration = 0.0295
# Total test chrF after 25 iteration = 86.6630
# Time for the iteration 45.9 seconds
#
#
# Average train loss after 26 iteration = 0.0045
# Total train chrF after 26 iteration = 91.6579
# Average val loss after 26 iteration = 0.0303
# Total val chrF after 26 iteration = 87.8454
# Average test loss after 26 iteration = 0.0295
# Total test chrF after 26 iteration = 86.6915
# Time for the iteration 46.3 seconds
#
#
# Average train loss after 27 iteration = 0.0044
# Total train chrF after 27 iteration = 91.7093
# Average val loss after 27 iteration = 0.0304
# Total val chrF after 27 iteration = 87.8140
# Average test loss after 27 iteration = 0.0296
# Total test chrF after 27 iteration = 86.7443
# Time for the iteration 46.1 seconds
#
#
# Average train loss after 28 iteration = 0.0042
# Total train chrF after 28 iteration = 91.7603
# Average val loss after 28 iteration = 0.0304
# Total val chrF after 28 iteration = 87.8464
# Average test loss after 28 iteration = 0.0297
# Total test chrF after 28 iteration = 86.6820
# Time for the iteration 46.4 seconds
#
#
# Average train loss after 29 iteration = 0.0041
# Total train chrF after 29 iteration = 91.8004
# Average val loss after 29 iteration = 0.0305
# Total val chrF after 29 iteration = 87.8501
# Average test loss after 29 iteration = 0.0297
# Total test chrF after 29 iteration = 86.6898
# Time for the iteration 46.2 seconds
#
#
# Average train loss after 30 iteration = 0.0040
# Total train chrF after 30 iteration = 91.8434
# Average val loss after 30 iteration = 0.0306
# Total val chrF after 30 iteration = 87.8191
# Average test loss after 30 iteration = 0.0298
# Total test chrF after 30 iteration = 86.6715
# Time for the iteration 46.4 seconds
#
#
# Average train loss after 31 iteration = 0.0038
# Total train chrF after 31 iteration = 91.8835
# Average val loss after 31 iteration = 0.0306
# Total val chrF after 31 iteration = 87.8134
# Average test loss after 31 iteration = 0.0299
# Total test chrF after 31 iteration = 86.6496
# Time for the iteration 46.4 seconds
#
#
# Average train loss after 32 iteration = 0.0037
# Total train chrF after 32 iteration = 91.9228
# Average val loss after 32 iteration = 0.0308
# Total val chrF after 32 iteration = 87.7643
# Average test loss after 32 iteration = 0.0300
# Total test chrF after 32 iteration = 86.6298
# Time for the iteration 46.4 seconds
#
#
# Average train loss after 33 iteration = 0.0036
# Total train chrF after 33 iteration = 91.9560
# Average val loss after 33 iteration = 0.0309
# Total val chrF after 33 iteration = 87.7537
# Average test loss after 33 iteration = 0.0301
# Total test chrF after 33 iteration = 86.6465
# Time for the iteration 46.1 seconds
#
#
# Average train loss after 34 iteration = 0.0035
# Total train chrF after 34 iteration = 91.9903
# Average val loss after 34 iteration = 0.0310
# Total val chrF after 34 iteration = 87.6644
# Average test loss after 34 iteration = 0.0302
# Total test chrF after 34 iteration = 86.6179
# Time for the iteration 46.0 seconds
#
#
# Average train loss after 35 iteration = 0.0034
# Total train chrF after 35 iteration = 92.0184
# Average val loss after 35 iteration = 0.0311
# Total val chrF after 35 iteration = 87.7078
# Average test loss after 35 iteration = 0.0303
# Total test chrF after 35 iteration = 86.5317
# Time for the iteration 46.3 seconds
#
#
# Average train loss after 36 iteration = 0.0033
# Total train chrF after 36 iteration = 92.0497
# Average val loss after 36 iteration = 0.0312
# Total val chrF after 36 iteration = 87.6756
# Average test loss after 36 iteration = 0.0304
# Total test chrF after 36 iteration = 86.5480
# Time for the iteration 46.5 seconds
#
#
# Average train loss after 37 iteration = 0.0032
# Total train chrF after 37 iteration = 92.0780
# Average val loss after 37 iteration = 0.0314
# Total val chrF after 37 iteration = 87.6593
# Average test loss after 37 iteration = 0.0305
# Total test chrF after 37 iteration = 86.5204
# Time for the iteration 46.0 seconds
#
#
# Average train loss after 38 iteration = 0.0032
# Total train chrF after 38 iteration = 92.1026
# Average val loss after 38 iteration = 0.0315
# Total val chrF after 38 iteration = 87.5756
# Average test loss after 38 iteration = 0.0306
# Total test chrF after 38 iteration = 86.4914
# Time for the iteration 46.1 seconds
#
#
# Average train loss after 39 iteration = 0.0031
# Total train chrF after 39 iteration = 92.1291
# Average val loss after 39 iteration = 0.0316
# Total val chrF after 39 iteration = 87.5839
# Average test loss after 39 iteration = 0.0307
# Total test chrF after 39 iteration = 86.4252
# Time for the iteration 46.1 seconds
#
#
# Average train loss after 40 iteration = 0.0030
# Total train chrF after 40 iteration = 92.1512
# Average val loss after 40 iteration = 0.0318
# Total val chrF after 40 iteration = 87.4967
# Average test loss after 40 iteration = 0.0309
# Total test chrF after 40 iteration = 86.3632
# Time for the iteration 46.0 seconds
#
#
# Average train loss after 41 iteration = 0.0029
# Total train chrF after 41 iteration = 92.1780
# Average val loss after 41 iteration = 0.0319
# Total val chrF after 41 iteration = 87.4434
# Average test loss after 41 iteration = 0.0310
# Total test chrF after 41 iteration = 86.3167
# Time for the iteration 45.9 seconds
#
#
#
#
# Aborting since there hasn't been much progress
# <Figure size 640x480 with 1 Axes>
# <Figure size 640x480 with 1 Axes>

# %%
language = "ash"
task_name = "all_teacher_general"
vocab_size = 4999
num_epochs = 100
batch_size = 32
model = "50_1"
optimizer = "Adam"
metric = "chrF"

# %%
from IPython.display import Image

Image("curves/{}_{}_{}_{}_{}_loss.png".format(language, task_name, vocab_size, num_epochs, batch_size))

# %%
Image("curves/{}_{}_{}_{}_{}_{}.png".format(language, task_name, vocab_size, num_epochs, batch_size, metric))

# %%
print("{}.{}.{}.{}.{}.{}.{}".format(language, task_name, vocab_size, num_epochs, batch_size, model, optimizer))
# Out:
# ash.all_teacher_general.4999.100.32.50_1.Adam
